# %% [markdown]
# # US Wages and Union Membership

# %% [markdown]
# *Relationship between wages, union membership and other factors over time*
#
# Part 1: Exploratory Data of Strikes, Wages, and Union Membership

# %%
import requests as rq
import pandas as pd

# %%
strikes = pd.read_csv('./datasets/strikes_monthly_listing.csv')

# %%
strikes.head(1)
# Out:
#                               Organizations involved States     Areas  \
# 0  Marine Towing and Transportation Employers' As...     NY  New York
#
#           Ownership Industry code[1]  \
# 0  Private industry           488330
#
#                                       Union Union acronym Union Local  \
# 0  International Longshoremen's Association           ILA         NaN
#
#   Bargaining unit Work stoppage beginning date Work stoppage ending date  \
# 0             NaN                    2/16/1988                12/20/1993
#
#   Number of workers[2] Days idle, cumulative for this work stoppage[3]  \
# 0                2,500                                       2,879,500
#
#                                                 Note  Unnamed: 14
# 0  The number of workers decreased to 2,000 in De...          NaN

# %%
strikes.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 638 entries, 0 to 637
# Data columns (total 15 columns):
#  #   Column                                           Non-Null Count  Dtype
# ---  ------                                           --------------  -----
#  0   Organizations involved                           635 non-null    object
#  1   States                                           628 non-null    object
#  2   Areas                                            587 non-null    object
#  3   Ownership                                        629 non-null    object
#  4   Industry code[1]                                 629 non-null    object
#  5   Union                                            628 non-null    object
#  6   Union acronym                                    574 non-null    object
#  7   Union Local                                      205 non-null    object
#  8   Bargaining unit                                  20 non-null     object
# ...

# %%
strikes.describe(include='all')
# Out:
#        Organizations involved States      Areas         Ownership  \
# count                     635    628        587               629
# unique                    492    117        251                 4
# top      General Motors Corp.     CA  Statewide  Private industry
# freq                       13    138         55               463
# mean                      NaN    NaN        NaN               NaN
# std                       NaN    NaN        NaN               NaN
# min                       NaN    NaN        NaN               NaN
# 25%                       NaN    NaN        NaN               NaN
# 50%                       NaN    NaN        NaN               NaN
# 75%                       NaN    NaN        NaN               NaN
# max                       NaN    NaN        NaN               NaN
#
#        Industry code[1]                      Union Union acronym  Union Local  \
# count               629                        628           574          205
# ...

# %%
wages_may2022 = pd.read_csv('./datasets/national_M2022_wagebyoccupation.csv')

# %%
wages_may2022.head(1)
# Out:
#    AREA AREA_TITLE  AREA_TYPE PRIM_STATE  NAICS     NAICS_TITLE  \
# 0    99       U.S.          1         US      0  Cross-industry
#
#           I_GROUP  OWN_CODE OCC_CODE        OCC_TITLE  ... H_MEDIAN H_PCT75  \
# 0  cross-industry      1235  00-0000  All Occupations  ...    22.26   35.32
#
#    H_PCT90  A_PCT10  A_PCT25  A_MEDIAN  A_PCT75  A_PCT90 ANNUAL  HOURLY
# 0    53.03   27,340   33,330    46,310   73,460  110,290    NaN     NaN
#
# [1 rows x 32 columns]

# %%
wages_may2022.describe(include='all')
# Out:
#           AREA AREA_TITLE  AREA_TYPE PRIM_STATE   NAICS     NAICS_TITLE  \
# count   1402.0       1402     1402.0       1402  1402.0            1402
# unique     NaN          1        NaN          1     NaN               1
# top        NaN       U.S.        NaN         US     NaN  Cross-industry
# freq       NaN       1402        NaN       1402     NaN            1402
# mean      99.0        NaN        1.0        NaN     0.0             NaN
# std        0.0        NaN        0.0        NaN     0.0             NaN
# min       99.0        NaN        1.0        NaN     0.0             NaN
# 25%       99.0        NaN        1.0        NaN     0.0             NaN
# 50%       99.0        NaN        1.0        NaN     0.0             NaN
# 75%       99.0        NaN        1.0        NaN     0.0             NaN
# max       99.0        NaN        1.0        NaN     0.0             NaN
#
#                I_GROUP  OWN_CODE OCC_CODE               OCC_TITLE  ...  \
# ...

# %%
wages_may2022.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1402 entries, 0 to 1401
# Data columns (total 32 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   AREA          1402 non-null   int64
#  1   AREA_TITLE    1402 non-null   object
#  2   AREA_TYPE     1402 non-null   int64
#  3   PRIM_STATE    1402 non-null   object
#  4   NAICS         1402 non-null   int64
#  5   NAICS_TITLE   1402 non-null   object
#  6   I_GROUP       1402 non-null   object
#  7   OWN_CODE      1402 non-null   int64
#  8   OCC_CODE      1402 non-null   object
#  9   OCC_TITLE     1402 non-null   object
#  10  O_GROUP       1402 non-null   object
#  11  TOT_EMP       1402 non-null   object
#  12  EMP_PRSE      1402 non-null   float64
#  13  JOBS_1000     0 non-null      float64
#  14  LOC_QUOTIENT  0 non-null      float64
#  15  PCT_TOTAL     0 non-null      float64
#  16  PCT_RPT       0 non-null      float64
#  17  H_MEAN        1402 non-null   object
# ...

# %% [markdown]
# #### BLS API

# %%
api_key_bls = '3eabc8340a2341109c8d4c16700043ed'
url_bls = f'https://api.bls.gov/publicAPI/v2/timeseries/data/WMU00000001020000001100000013?registrationkey={api_key_bls}&catalog=true&startyear=2022&endyear=2022'

bls_rq = rq.get(url_bls).json()

# %%
bls_rq
# Out:
# {'status': 'REQUEST_SUCCEEDED',
#  'responseTime': 154,
#  'message': [],
#  'Results': {'series': [{'seriesID': 'WMU00000001020000001100000013',
#     'catalog': {'series_title': 'Average hourly wage for level 13 management occupations in the U.S.',
#      'series_id': 'WMU00000001020000001100000013',
#      'seasonality': 'Not Seasonally Adjusted',
#      'survey_name': 'Modeled Wage Estimates',
#      'survey_abbreviation': 'WM',
#      'measure_data_type': 'Average Hourly Wage',
#      'commerce_industry': 'All industries',
#      'occupation': 'Management Occupations',
#      'occupation_work_class': 'Civilian workers',
#      'area': 'National'},
#     'data': [{'year': '2022',
#       'period': 'A01',
#       'periodName': 'Annual',
#       'latest': 'true',
#       'value': '91.28',
#       'footnotes': [{}]}]}]}}

# %%
bls_results = bls_rq['Results']

# %%
bls_catalog = bls_results['series']

# %%
bls_catalog
# Out:
# [{'seriesID': 'WMU00000001020000001100000013',
#   'catalog': {'series_title': 'Average hourly wage for level 13 management occupations in the U.S.',
#    'series_id': 'WMU00000001020000001100000013',
#    'seasonality': 'Not Seasonally Adjusted',
#    'survey_name': 'Modeled Wage Estimates',
#    'survey_abbreviation': 'WM',
#    'measure_data_type': 'Average Hourly Wage',
#    'commerce_industry': 'All industries',
#    'occupation': 'Management Occupations',
#    'occupation_work_class': 'Civilian workers',
#    'area': 'National'},
#   'data': [{'year': '2022',
#     'period': 'A01',
#     'periodName': 'Annual',
#     'latest': 'true',
#     'value': '91.28',
#     'footnotes': [{}]}]}]
