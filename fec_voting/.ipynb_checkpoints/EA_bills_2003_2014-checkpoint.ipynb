# %% [markdown]
# # US Representative Voting Patterns and Funding Sources

# %% [markdown]
# *Exploratory analysis of how funding influences voting habits in Congress*
#
# Part 2 of Exploratory Analysis: Congressional Member Voting Data

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import ydata_profiling

# %%
h117m = pd.read_json('./datasets/H117_members.json')
h117m.head(1)
# Out:
#    congress    chamber  icpsr  state_icpsr  district_code state_abbrev  \
# 0       117  President  99912           99              0          USA
#
#    party_code occupancy last_means             bioname  ... died  \
# 0         200         0          0  TRUMP, Donald John  ...  NaN
#
#    nominate_dim1  nominate_dim2  nominate_log_likelihood  \
# 0          0.403          0.162                      NaN
#
#    nominate_geo_mean_probability  nominate_number_of_votes  \
# 0                            NaN
#
#    nominate_number_of_errors conditional nokken_poole_dim1  nokken_poole_dim2
# 0                                    NaN               NaN                NaN
#
# [1 rows x 22 columns]

# %%
h117r = pd.read_json('./datasets/H117_rollcalls.json')
h117r.head(4)
# Out:
#    congress chamber  rollnumber       date  session  clerk_rollnumber  \
# 0       117   House           1 2021-01-03        1                 2
# 1       117   House           2 2021-01-03        1                 3
# 2       117   House           3 2021-01-04        1                 4
# 3       117   House           4 2021-01-04        1                 5
#
#    yea_count  nay_count  nominate_mid_1  nominate_mid_2  ...  \
# 0        216        211          -0.057           0.038  ...
# 1        371          2           0.000           0.000  ...
# 2        214        204           0.019          -0.125  ...
# 3        214        196           0.020          -0.133  ...
#
#                                            vote_desc  \
# 0                                               None
# 1  Authorizing and directing the Speaker to admin...
# 2  Adopting the Rules of the House of Representat...
# 3  Adopting the Rules of the House of Representat...
#
# ...

# %%
h117v = pd.read_json('./datasets/H117_votes.json')
h117v.head(1)
# Out:
#    congress  icpsr  cast_code chamber  rollnumber   prob
# 0       117  14066          6   House           1  100.0

# %%
h117r.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 996 entries, 0 to 995
# Data columns (total 25 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   congress                 996 non-null    int64
#  1   chamber                  996 non-null    object
#  2   rollnumber               996 non-null    int64
#  3   date                     996 non-null    datetime64[ns]
#  4   session                  996 non-null    int64
#  5   clerk_rollnumber         996 non-null    int64
#  6   yea_count                996 non-null    int64
#  7   nay_count                996 non-null    int64
#  8   nominate_mid_1           996 non-null    float64
#  9   nominate_mid_2           996 non-null    float64
#  10  nominate_spread_1        996 non-null    float64
#  11  nominate_spread_2        996 non-null    float64
#  12  nominate_log_likelihood  996 non-null    float64
#  13  bill_number              958 non-null    object
# ...
