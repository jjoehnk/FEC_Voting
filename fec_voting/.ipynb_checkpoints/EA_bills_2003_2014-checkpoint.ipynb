# %% [markdown]
# # US Representative Voting Patterns and Funding Sources

# %% [markdown]
# *Exploratory analysis of how funding influences voting habits in Congress*
#
# Part 3 of Exploratory Analysis: DIME PLUS Repository of Congressional Bills

# %%
import sqlite3
import pandas as pd

# %%
bills_df = pd.read_csv('bills_db.csv')

# %%
bills_df.shape
# Out:
# (3182, 33)

# %%
bills_df.head(1)
# Out:
#     bill.id  year        date  \
# 0  113_hr83  2014  2014-12-13
#
#                                             bill.str  \
# 0  H.R. 83|On the Motion to Proceed H.R. 83|To re...
#
#                                            bill.desc  congno sponsors  \
# 0  To require the Secretary of the Interior to as...     113      NaN
#
#   cosponsors  tw.latent1  tw.abortion.and.social.conservatism  ...  \
# 0        NaN    0.471785                                  0.0  ...
#
#    tw.healthcare  tw.higher.education  tw.immigration  tw.indian.affairs  \
# 0            0.0                  0.0             0.0                0.0
#
#    tw.intelligence.and.surveillance  tw.labor  tw.law.courts.and.judges  \
# 0                               0.0       0.0                       0.0
#
#    tw.transportation  tw.veterans.affairs  tw.womens.issues
# 0                0.0                  0.0               0.0
#
# [1 rows x 33 columns]

# %%
bills_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3182 entries, 0 to 3181
# Data columns (total 33 columns):
#  #   Column                                  Non-Null Count  Dtype
# ---  ------                                  --------------  -----
#  0   bill.id                                 3182 non-null   object
#  1   year                                    3182 non-null   int64
#  2   date                                    3182 non-null   object
#  3   bill.str                                3182 non-null   object
#  4   bill.desc                               2785 non-null   object
#  5   congno                                  3182 non-null   int64
#  6   sponsors                                2766 non-null   object
#  7   cosponsors                              1647 non-null   object
#  8   tw.latent1                              3182 non-null   float64
#  9   tw.abortion.and.social.conservatism     3182 non-null   float64
# ...

# %%
bills_df.describe(include='all')
# Out:
#          bill.id         year        date                           bill.str  \
# count       3182  3182.000000        3182                               3182
# unique      3182          NaN        1291                               3156
# top     113_hr83          NaN  2014-12-13  JOURNAL|On Approving the Journal|
# freq           1          NaN          14                                  6
# mean         NaN  2008.890635         NaN                                NaN
# std          NaN     3.322162         NaN                                NaN
# min          NaN  2003.000000         NaN                                NaN
# 25%          NaN  2007.000000         NaN                                NaN
# 50%          NaN  2009.000000         NaN                                NaN
# 75%          NaN  2012.000000         NaN                                NaN
# max          NaN  2014.000000         NaN                                NaN
#
# ...
