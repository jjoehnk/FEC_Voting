# %% [markdown]
# # US Representative Voting Patterns and Funding Sources

# %% [markdown]
# Part 1: Pulling FEC funding data through API

# %%
import requests as rq # to pull data from FEC API
import pandas as pd # for data exploration
from keys import api_key_fec # holds secure API KEY
import sqlite3 as sq # to pull data from sqlite database
from fuzzywuzzy import fuzz # to fuzzy match names from candidate api to voteview member list
import time # for improved request pulls
from IPython.display import clear_output #for improved request pulls
import sqlite3 as sq # link dataframes to sqlite database
conn = sq.connect('congress.db') # open connection to file

# %% [markdown]
# ***

# %% [markdown]
# ## General Functions in All Data Pulls/Cleans
#
# 1. pull_list_of_dicts
#    - reads through api request pulls that come in as [[{}]] into a dataframe
# 2. pull_sub_dict
#    - modification of first function to pull out sub-dictionary, in the form of [[{{}}]] into a dataframe
# 3. page_count
#    - reads the first page of an api json and relays the number of pages in the request
# 4. one_string_in_list
#    - returns a string type of candidate id

# %%
def pull_list_of_dicts(dataset):
    dictionary = {}
    for list in dataset:
        for sub_list in list:
            for key, value in sub_list.items():
                # if key is already in dictionary, append value
                if key in dictionary:
                    dictionary[key].append(value)
                # if key is not in dictionary, create new key with the first value 
                else:
                    dictionary[key] = [value] 
    return pd.DataFrame(dictionary)

# %%
def pull_sub_dict(dataframe, filter_key='results', include_key='principal_committees'):
# set up with params to pull the committee ids attached to each candidate, other keys may be specified if there is a need to iterate through other non-flat files
    dictionary = {}    
    # first loop cycles through each candidate's api request pull 
    for cand_dicts in dataframe:
        # second loop cycles specifically to one dictionary for each candidate's page, auto-setting is to the 'results' section
        for cand_results in cand_dicts[filter_key]:
            # third loop cycles through the keys and values of a dictionary
            for result_key, result_value in cand_results.items():        
                # specifies which key and values need to be gathered for dataframe, auto-setting is to the 'principal_committees key'
                if result_key == include_key:
                    # fourth loop cycles through the principal_committee lists for each candidate
                    for committee_list in result_value:
                        # cycle through keys, values in each list into a new dictionary and appends it into one
                        for key, value in committee_list.items():
                            # if key is already in dictionary, append value
                            if key in dictionary:
                                dictionary[key].append(value)
                            # if key is not in dictionary, create new key with the first value 
                            else:
                                dictionary[key] = [value] 
    return pd.DataFrame(dictionary)

# %%
def page_count(json, column='pagination', key='pages'):
    page_len = 0
    for keys, values in json[column].items():
        if keys == key:
            page_len += values
    return page_len

# %%
def one_string_in_list(df, column):
    for index, row in enumerate(df[column]):
        if len(row) > 0:
            df[column][index] = row[0]
    return df

# %% [markdown]
# #### Reference Tables/Lists Needed
# *data is created in top sections of this notebook*
#
# 1. candidate_ids
# 2. committee_ids

# %%
# for all functions, use lists of candidate ids or committee ids here: 
congress = pd.read_csv('./datasets/congress.csv')
candidate_ids = congress['candidate_id'].values.tolist()

committee = pd.read_csv('./datasets/committees.csv')
committee_ids = committee['committee_id'].values.tolist()

# %% [markdown]
# _______________________________________________________________________________________________

# %% [markdown]
# ### Creating a reference table of registered committees - Independent Committees, Super PACs, etc
#
# **Conditions for filters**
# 1. Cycle - 2012
# 2. Designation - All
# 3. Organization Type - All
# 4. Committee Type - All except:
#    - Delegate
#    - Presidential
#    - Senate
#    - National Party Non-Federal Account
#
# **Steps**
# 1. Set up blank list and for loop for API pagination
# 2. Get request from API with above filters added to url
# 3. Extend all pages pulled into one list and convert to DataFrame

# %%
# pull first page of api request to confirm results are as desired and find the number of pages in request
committees_rq = rq.get(f'https://api.open.fec.gov/v1/committees/?page=1&per_page=100&cycle=2012&sort=name&sort_hide_null=false&sort_null_only=false&sort_nulls_last=false&api_key={api_key_fec}')

print(committees_rq.status_code)
committees = committees_rq.json()
committees['pagination']
# Out:
# 200
# {'count': 14444, 'page': 1, 'pages': 145, 'per_page': 100}

# %%
def committee_dataframe(pages):
    committees_all_pages = []
    count = 0
    
    for i in range(1, pages+1):
        committees_rq = rq.get(f'https://api.open.fec.gov/v1/committees/?page={i}&per_page=100&cycle=2012&sort=name&sort_hide_null=false&sort_null_only=false&sort_nulls_last=false&api_key={api_key_fec}')

        # output confirmation during pull request
        clear_output(wait=True)
        count += 1
        print(f'On page {count} out of {pages}!')
        committees_rq.raise_for_status()

        # push data into open list
        committees = committees_rq.json()
        committees_all_pages.append(committees)

        time.sleep(.5)

    #merge all results into one DF
    blank_list = []
    
    for i in range(0, pages):
        blank_list.extend(committees_all_pages[i]['results'] )  

    return pd.DataFrame(blank_list)

# %%
committees_df = committee_dataframe(145)
# Out:
# On page 145 out of 145!

# %%
committees_df.head(2)
# Out:
#   affiliated_committee_name candidate_ids committee_id committee_type  \
# 0                      None   [P20001954]    C00462390              P
# 1                      None            []    C00408286              X
#
#     committee_type_full                                cycles designation  \
# 0          Presidential              [2010, 2012, 2014, 2016]           P
# 1  Party - Nonqualified  [2004, 2006, 2008, 2010, 2012, 2014]           U
#
#                designation_full filing_frequency first_f1_date  ...  \
# 0  Principal campaign committee                A    2009-05-28  ...
# 1                  Unauthorized                A    2004-12-02  ...
#
#   last_file_date                                         name  \
# 0     2015-08-10                      007 GO GODWIN COMMITTEE
# 1     2013-04-08  10TH CONGRESSIONAL DISTRICT DEMOCRATIC COMM
#
#   organization_type organization_type_full party        party_full  \
# 0              None                   None   DEM  DEMOCRATIC PARTY
# 1              None                   None   DEM  DEMOCRATIC PARTY
#
#   sponsor_candidate_ids sponsor_candidate_list state  treasurer_name
# 0                  None                     []    VA   EDEAN BUNDICK
# 1                  None                     []    MI  CONLEY BARNETT
#
# [2 rows x 22 columns]

# %%
committees_df.shape
# Out:
# (14444, 8)

# %% [markdown]
# #### Committee Referential Table Clean-Up
#
# 1. Dropping unnecessary columns (blank/mostly null or not relevant to analysis)
# 2. Renaming remaining columns
# 3. Checking for any nulls, exploring basic description of data before export
# 4. Saving as csv
# 5. Create list of committee ids for funding API requests

# %%
committees_df.columns
# Out:
# Index(['affiliated_committee_name', 'candidate_ids', 'committee_id',
#        'committee_type', 'designation_type', 'name', 'organization_type',
#        'state'],
#       dtype='object')

# %%
# dropping columns: 

committees_df.drop(columns=['first_f1_date','first_file_date','last_f1_date','last_file_date','sponsor_candidate_ids','sponsor_candidate_list','filing_frequency','party','party_full','committee_type','organization_type','designation','cycles','treasurer_name'],inplace=True)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[51], line 3
#       1 # dropping columns:
# ----> 3 committees_df.drop(columns=['first_f1_date','first_file_date','last_f1_date','last_file_date','sponsor_candidate_ids','sponsor_candidate_list','filing_frequency','party','party_full','committee_type','organization_type','designation','cycles','treasurer_name'],inplace=True)
#
# File C:\tools\Anaconda3\lib\site-packages\pandas\util\_decorators.py:331, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     325 if len(args) > num_allow_args:
#     326     warnings.warn(
#     327         msg.format(arguments=_format_argument_list(allow_args)),
#     328         FutureWarning,
#     329         stacklevel=find_stack_level(),
#     330     )
# --> 331 return func(*args, **kwargs)
#
# File C:\tools\Anaconda3\lib\site-packages\pandas\core\frame.py:5399, in DataFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    5251 @deprecate_nonkeyword_arguments(version=None, allowed_args=["self", "labels"])
#    5252 def drop(  # type: ignore[override]
#    5253     self,
#    (...)
#    5260     errors: IgnoreRaise = "raise",
#    5261 ) -> DataFrame | None:
#    5262     """
#    5263     Drop specified labels from rows or columns.
#    5264
#    (...)
#    5397             weight  1.0     0.8
#    5398     """
# -> 5399     return super().drop(
#    5400         labels=labels,
#    5401         axis=axis,
#    5402         index=index,
#    5403         columns=columns,
#    5404         level=level,
#    5405         inplace=inplace,
#    5406         errors=errors,
#    5407     )
#
# File C:\tools\Anaconda3\lib\site-packages\pandas\util\_decorators.py:331, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     325 if len(args) > num_allow_args:
#     326     warnings.warn(
#     327         msg.format(arguments=_format_argument_list(allow_args)),
#     328         FutureWarning,
#     329         stacklevel=find_stack_level(),
#     330     )
# --> 331 return func(*args, **kwargs)
#
# File C:\tools\Anaconda3\lib\site-packages\pandas\core\generic.py:4505, in NDFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    4503 for axis, labels in axes.items():
#    4504     if labels is not None:
# -> 4505         obj = obj._drop_axis(labels, axis, level=level, errors=errors)
#    4507 if inplace:
#    4508     self._update_inplace(obj)
#
# File C:\tools\Anaconda3\lib\site-packages\pandas\core\generic.py:4546, in NDFrame._drop_axis(self, labels, axis, level, errors, only_slice)
#    4544         new_axis = axis.drop(labels, level=level, errors=errors)
#    4545     else:
# -> 4546         new_axis = axis.drop(labels, errors=errors)
#    4547     indexer = axis.get_indexer(new_axis)
#    4549 # Case for non-unique axis
#    4550 else:
#
# File C:\tools\Anaconda3\lib\site-packages\pandas\core\indexes\base.py:6934, in Index.drop(self, labels, errors)
#    6932 if mask.any():
#    6933     if errors != "ignore":
# -> 6934         raise KeyError(f"{list(labels[mask])} not found in axis")
#    6935     indexer = indexer[~mask]
#    6936 return self.delete(indexer)
#
# KeyError: "['first_f1_date', 'first_file_date', 'last_f1_date', 'last_file_date', 'sponsor_candidate_ids', 'sponsor_candidate_list', 'filing_frequency', 'party', 'party_full', 'designation', 'cycles', 'treasurer_name'] not found in axis"

# %%
# renaming column names 
committees_df.columns = ['affiliated_committee_name', 'candidate_ids', 'committee_id', 'committee_type', 'designation_type', 'name', 'organization_type', 'state']

# %%
committees_df.reset_index()
# Out:
#        index                 affiliated_committee_name candidate_ids  \
# 0          1                                      None            []
# 1          2                                      None            []
# 2          3          REPUBLICAN PARTY OF VIRGINIA INC   [H6VA10134]
# 3          4                                      None            []
# 4          5  1199 SEIU UNITED HEALTHCARE WORKERS EAST            []
# ...      ...                                       ...           ...
# 13003  14438                                      NONE            []
# 13004  14440                           ENDEAVOR ACTION            []
# 13005  14441                                      None   [H0OH12088]
# 13006  14442   ZURICH HOLDING COMPANY OF AMERICA, INC.            []
# 13007  14443                                      None            []
#
#       committee_id                                   committee_type  \
# 0        C00408286                             Party - Nonqualified
# 1        C00486647                               PAC - Nonqualified
# 2        C00005462                                Party - Qualified
# 3        C90013426  Independent expenditure filer (not a committee)
# 4        C00348540                                  PAC - Qualified
# ...            ...                                              ...
# 13003    C00462754                               PAC - Nonqualified
# 13004    C00459693                                  PAC - Qualified
# 13005    C00472332                                            House
# 13006    C00235036                                  PAC - Qualified
# 13007    C30001184                     Electioneering Communication
#
#                    designation_type  \
# 0                      Unauthorized
# 1                      Unauthorized
# 2                      Unauthorized
# 3                      Unauthorized
# 4                      Unauthorized
# ...                             ...
# 13003                  Unauthorized
# 13004                  Unauthorized
# 13005  Principal campaign committee
# 13006       Lobbyist/Registrant PAC
# 13007                  Unauthorized
#
#                                                     name   organization_type  \
# 0            10TH CONGRESSIONAL DISTRICT DEMOCRATIC COMM                None
# 1                                  10TH CONSTITUTION PAC                None
# 2       10TH DISTRICT REPUBLICAN CONGRESSIONAL COMMITTEE                None
# 3                1199SEIU UNITED HEALTHCARE WORKERS EAST                None
# 4      1199 SEIU UNITED HEALTHCARE WORKERS EAST FEDER...  Labor Organization
# ...                                                  ...                 ...
# 13003                                            ZR FPAC                None
# 13004                  ZUFFA POLITICAL ACTION COMMMITTEE                None
# 13005                              ZUKOWSKI FOR CONGRESS                None
# 13006  ZURICH HOLDING COMPANY OF AMERICA, INC. COMMIT...         Corporation
# 13007                                               None                None
#
#       state
# 0        MI
# 1        MA
# 2        VA
# 3        NY
# 4        NY
# ...     ...
# 13003    MN
# 13004    DC
# 13005    OH
# 13006    DC
# 13007    DC
#
# [13008 rows x 9 columns]

# %%
committees_df['committee_type'].value_counts()
# Out:
# House                                                        3628
# PAC - Qualified                                              3523
# PAC - Nonqualified                                           2875
# Super PAC (Independent Expenditure-Only)                     1275
# Independent expenditure filer (not a committee)               933
# Party - Qualified                                             295
# Party - Nonqualified                                          205
# Electioneering Communication                                   99
# Single Candidate Independent Expenditure                       69
# Hybrid PAC (with Non-Contribution Account) - Nonqualified      61
# Hybrid PAC (with Non-Contribution Account) - Qualified         45
# Name: committee_type, dtype: int64

# %%
committees_to_keep = ['House', 'PAC - Qualified', 'PAC - Nonqualified', 'Super PAC (Independent Expenditure-Only)', 'Independent expenditure filer (not a committee)', 'Party - Qualified', 'Party - Nonqualified', 'Electioneering Communication', 'Single Candidate Independent Expenditure', 'Hybrid PAC (with Non-Contribution Account) - Nonqualified', 'Hybrid PAC (with Non-Contribution Account) - Qualified']
committees_df = committees_df.apply(lambda row: row[committees_df['committee_type'].isin(committees_to_keep)])

# %%
committees_df.to_csv('./datasets/committees.csv')

# %% [markdown]
# ***

# %% [markdown]
# ### Match Names from Members and Candidates
#
# **Note that this method assumes that both datasets have matching districts and states. After the initial runthrough 9/433 members in the voteview 'c113m' dataframe had incorrect districts and were manually revised**
#
# *This uses the candidate master flat file instead of api as it includes additional total raised information not as easily accessible through request version. Additional details from the API are merged afterwards*
#
# 1. Link members of the 113th congress to their candidate information from the FEC
#    - use district and state as exact matches and names as fuzzy matches (to filter out unelected candidates in same races as members)
# 2. Add congress id to candidate table as a foreign key
# 3. Filter candidate table down to only member-matching rows

# %%
cn = pd.read_csv('./datasets/cn2.txt', sep='|', names=['candidate_id', 'name', 'ici', 'pty_cd', 'party', 'ttl_receipts', 'trans_from_comm', 'ttl_disb', 'trans_to_comm', 'coh_bop', 'coh_cop', 'cand_contrib', 'cand_loans', 'other_loans', 'cand_loan_repay', 'other_loan_repay', 'debts_owed_by', 'ttl_indiv_contrib', 'state', 'district', 'spec_election', 'prim_election', 'run_election', 'gen_election', 'gen_election_precent', 'other_pol_cmte_contrib', 'pol_pty_contrib', 'cvg_end_dt', 'indiv_refunds', 'cmte_refunds'])
members = pd.read_csv('./datasets/c113m.csv')

# %%
#change null values to 0, then convert data type to integer 
cn['district'] = cn['district'].fillna(0)
cn['district'] = cn['district'].astype(int)

# convert data type to integer
members['district'] = members['district'].astype(int)

# %%
# make all letters lowercase in both table names for future fuzzy matching
cn['name'] = cn['name'].str.lower()
members['name'] = members['name'].str.lower()

# %%
members.columns
# Out:
# Index(['chamber', 'icpsr', 'district', 'state', 'party', 'name', 'congress_id',
#        'NOMINATE_dim1', 'NOMINATE_dim2'],
#       dtype='object')

# %%
# creates dataframe that links all candidates to members who match on district and state ** this still includes all challengers who lost!
cn_match = pd.merge(members, cn, how='left', on=['state', 'district'])
cn_match.shape
# Out:
# (2487, 37)

# %%
cn_match.columns
# Out:
# Index(['chamber', 'icpsr', 'district', 'state', 'party_x', 'name_x',
#        'congress_id', 'NOMINATE_dim1', 'NOMINATE_dim2', 'candidate_id',
#        'name_y', 'ici', 'pty_cd', 'party_y', 'ttl_receipts', 'trans_from_comm',
#        'ttl_disb', 'trans_to_comm', 'coh_bop', 'coh_cop', 'cand_contrib',
#        'cand_loans', 'other_loans', 'cand_loan_repay', 'other_loan_repay',
#        'debts_owed_by', 'ttl_indiv_contrib', 'spec_election', 'prim_election',
#        'run_election', 'gen_election', 'gen_election_precent',
#        'other_pol_cmte_contrib', 'pol_pty_contrib', 'cvg_end_dt',
#        'indiv_refunds', 'cmte_refunds'],
#       dtype='object')

# %%
# apply fuzzy matching on new dataframe to compare the name_x column (the candidates) to name_y (the congress members)
# use token_sort_ratio as it will sort and compare each section of a string (to better match first and last names)
cn_match['matching_ratio'] = cn_match.apply(lambda x: fuzz.token_set_ratio(x['name_x'], x['name_y']), axis=1)

# %%
# pull the highest matching ratio for each congress member, and then create a new dataframe with results
msk = cn_match.groupby(['congress_id'])['matching_ratio'].transform('max') == cn_match['matching_ratio']
out = cn_match.loc[msk, ['matching_ratio', 'chamber', 'icpsr', 'district', 'state', 'party_x', 'name_x', 'congress_id', 'NOMINATE_dim1', 'NOMINATE_dim2', 'candidate_id', 'name_y', 'ici', 'pty_cd', 'party_y', 'ttl_receipts', 'trans_from_comm', 'ttl_disb', 'trans_to_comm', 'coh_bop', 'coh_cop', 'cand_contrib', 'cand_loans', 'other_loans', 'cand_loan_repay', 'other_loan_repay', 'debts_owed_by', 'ttl_indiv_contrib', 'state', 'district', 'spec_election', 'prim_election', 'run_election', 'gen_election', 'gen_election_precent', 'other_pol_cmte_contrib', 'pol_pty_contrib', 'cvg_end_dt', 'indiv_refunds', 'cmte_refunds']]

# %%
# manually check results are accurate
# incorrect from first runthrough: YOUNG, Donald Edwin; SANCHEZ, Linda T; CARNEY, John C. Jr.; DAINES, Steve; GRIMM, Michael G.; CRAMER, Kevin; NOEM, Kristi; WELCH, Peter; LUMMIS, Cynthia M. 
# 98% accurate - will manually fix the missing 9 member info
pd.set_option('display.max_column', None)
pd.set_option('display.max_row', None)
out
# Out:
#       matching_ratio chamber  icpsr  district state  party_x  \
# 1                 83   House  20300         1    AL      200
# 9                 87   House  20301         3    AL      200
# 11                69   House  21102         7    AL      100
# 17               100   House  21192         2    AL      200
# 27               100   House  21193         5    AL      200
# 31               100   House  29301         6    AL      200
# 35               100   House  29701         4    AL      200
# 36                92   House  14066         1    AK      200
# 44               100   House  20304         8    AZ      200
# 49                97   House  20305         3    AZ      100
# 59               100   House  20902         1    AZ      100
# 69               100   House  21103         4    AZ      200
# 80               100   House  21105         6    AZ      200
# 84                87   House  21199         2    AZ      100
# 92               100   House  21300         9    AZ      100
# 102              100   House  29101         7    AZ      100
# 112               71   House  29500         5    AZ      200
# 122              100   House  21106         1    AR      200
# 130               78   House  21107         2    AR      200
# 135              100   House  21108         3    AR      200
# 144               87   House  21301         4    AR      200
# 148              100   House  14256        11    CA      100
# 154               92   House  14280        33    CA      100
# 162              100   House  15448        12    CA      100
# 169              100   House  15621        48    CA      200
# 171              100   House  20103        17    CA      100
# 174              100   House  20104        28    CA      100
# 179              100   House  20107        49    CA      200
# 181              100   House  20108        53    CA      100
# 185              100   House  20307        22    CA      200
# 187               28   House  20310        38    CA      100
# 189              100   House  20501        16    CA      100
# 194              100   House  20538         6    CA      100
# 201               79   House  20539        45    CA      200
# 202              100   House  20702         9    CA      100
# 208              100   House  20703        23    CA      200
# 211              100   House  20762        14    CA      100
# 219               90   House  20903         4    CA      200
# 221              100   House  20955        27    CA      100
# 225              100   House  20958         3    CA      100
# 234               93   House  20963        50    CA      200
# 238              100   House  21109        10    CA      200
# 240              100   House  21110        37    CA      100
# 247              100   House  21195        44    CA      100
# 258              100   House  21302         1    CA      200
# 266              100   House  21303         2    CA      100
# 274               80   House  21304         7    CA      100
# 283              100   House  21305         8    CA      200
# 291              100   House  21306        15    CA      100
# 298              100   House  21307        21    CA      200
# 300              100   House  21308        26    CA      100
# 312               96   House  21309        29    CA      100
# 316              100   House  21310        35    CA      100
# 322              100   House  21311        36    CA      100
# 333              100   House  21312        41    CA      100
# 338              100   House  21313        47    CA      100
# 351              100   House  21314        51    CA      100
# 358              100   House  21315        52    CA      100
# 366              100   House  29106        43    CA      100
# 369              100   House  29312        18    CA      100
# 372              100   House  29313        20    CA      100
# 380              100   House  29315        25    CA      200
# 383              100   House  29316        34    CA      100
# 385              100   House  29317        40    CA      100
# 389               92   House  29321        39    CA      200
# 396               79   House  29323        42    CA      200
# 397              100   House  29504        19    CA      100
# 403              100   House  29707        30    CA      100
# 413              100   House  29709        46    CA      100
# 424              100   House  29774        24    CA      100
# 432              100   House  29778        13    CA      100
# 434               75   House  29901         5    CA      100
# 440              100   House  29903        32    CA      100
# 448              100   House  29905        31    CA      200
# 452               89   House  20704         5    CO      200
# 455               87   House  20705         7    CO      100
# 460              100   House  20904         2    CO      100
# 467               81   House  20906         6    CO      200
# 474              100   House  21111         3    CO      200
# 481              100   House  21112         4    CO      200
# 484              100   House  29710         1    CO      100
# 487               83   House  20706         2    CT      100
# 494               73   House  20907         4    CT      100
# 503              100   House  21316         5    CT      100
# 517              100   House  29109         3    CT      100
# 522              100   House  29908         1    CT      100
# 528               93   House  21113         1    DE      100
# 534               83   House  13047        13    FL      200
# 537              100   House  15634        27    FL      200
# 539              100   House  20110         1    FL      200
# 543              100   House  20111         4    FL      200
# 549              100   House  20316        25    FL      200
# 553              100   House  20504        23    FL      100
# 560              100   House  20708        14    FL      100
# 572              100   House  20709        16    FL      200
# 578              100   House  20758        12    FL      200
# 582              100   House  20908         9    FL      100
# 597              100   House  20909         8    FL      200
# 607               80   House  20910        17    FL      200
# 608               86   House  20959        21    FL      100
# 617              100   House  21114         2    FL      200
# 623              100   House  21115        11    FL      200
# 631              100   House  21116        10    FL      200
# 633              100   House  21117        15    FL      200
# 635              100   House  21118        24    FL      100
# 644               67   House  21317         3    FL      200
# 654               83   House  21318         6    FL      200
# 659              100   House  21319        18    FL      100
# 672               67   House  21320        19    FL      200
# 674              100   House  21321        22    FL      100
# 681              100   House  21322        26    FL      100
# 688              100   House  29328         5    FL      100
# 694              100   House  29331         7    FL      200
# 697               93   House  29337        20    FL      100
# 703              100   House  15431         5    GA      100
# 707               83   House  20319        11    GA      200
# 710              100   House  20321        13    GA      100
# 716               71   House  20505         6    GA      200
# 720              100   House  20506         3    GA      200
# 721              100   House  20507        12    GA      100
# 737              100   House  20712         4    GA      100
# 745               80   House  20753        10    GA      200
# 748               75   House  20962        14    GA      200
# 756              100   House  21122         7    GA      200
# 758              100   House  21123         8    GA      200
# 764               74   House  21323         9    GA      200
# 771              100   House  29338         1    GA      200
# 772               94   House  29339         2    GA      100
# 778              100   House  21124         1    HI      100
# 785              100   House  21324         2    HI      100
# 797               89   House  21125         1    ID      200
# 805              100   House  29910         2    ID      200
# 808              100   House  20508         3    IL      100
# 817              100   House  20715         6    IL      200
# 821              100   House  20749        11    IL      100
# 824              100   House  20914        18    IL      200
# 826              100   House  20954         5    IL      100
# 832              100   House  21128        16    IL      200
# 836              100   House  21129        14    IL      200
# 840              100   House  21325         8    IL      100
# 848               78   House  21326        10    IL      100
# 858               71   House  21327        12    IL      100
# 871              100   House  21328        13    IL      200
# 875              100   House  21329        17    IL      100
# 882              100   House  29346         1    IL      100
# 887               97   House  29348         4    IL      100
# 892              100   House  29717         7    IL      100
# 895              100   House  29718        15    IL      200
# 896              100   House  29911         9    IL      100
# 898              100   House  15124         1    IN      100
# 905               96   House  20757         7    IN      100
# 919              100   House  21100         3    IN      200
# 924               71   House  21131         4    IN      200
# 934              100   House  21132         8    IN      200
# 941              100   House  21133         9    IN      200
# 946              100   House  21330         2    IN      200
# 953              100   House  21331         5    IN      200
# 965               71   House  21332         6    IN      200
# 975              100   House  20325         4    IA      200
# 976              100   House  20719         1    IA      100
# 984               79   House  20720         2    IA      100
# 993              100   House  29522         3    IA      200
# 998              100   House  20915         2    KS      200
# 1004              82   House  21134         1    KS      200
# 1008             100   House  21135         3    KS      200
# 1019              71   House  21136         4    KS      200
# 1023             100   House  14854         5    KY      200
# 1024             100   House  20723         3    KY      100
# 1029             100   House  20916         2    KY      200
# 1032             100   House  21333         6    KY      200
# 1034             100   House  29525         1    KY      200
# 1039             100   House  31102         4    KY      200
# 1050             100   House  20514         3    LA      200
# 1053             100   House  20759         1    LA      200
# 1060             100   House  20918         4    LA      200
# 1062              81   House  20919         6    LA      200
# 1069             100   House  21137         2    LA      100
# 1078             100   House  90327         5    LA      200
# 1079             100   House  20328         2    ME      100
# 1083             100   House  20920         1    ME      100
# 1088             100   House  14873         5    MD      100
# 1094             100   House  20329         2    MD      100
# 1099              84   House  20330         8    MD      100
# 1106             100   House  20724         3    MD      100
# 1111             100   House  20763         4    MD      100
# 1119              77   House  21139         1    MD      200
# 1125             100   House  21334         6    MD      100
# 1137              94   House  29587         7    MD      100
# 1141             100   House  14435         5    MA      100
# 1152              83   House  15616         1    MA      100
# 1155             100   House  20119         8    MA      100
# 1160             100   House  20754         3    MA      100
# 1167              94   House  21140         9    MA      100
# 1177             100   House  21335         4    MA      100
# 1184              80   House  29729         2    MA      100
# 1188             100   House  29730         6    MA      100
# 1194              94   House  29919         7    MA      100
# 1198              84   House   2605        12    MI      100
# 1206             100   House  10713        13    MI      100
# 1209              83   House  15033         9    MI      100
# 1219             100   House  15446         6    MI      200
# 1222              74   House  20120         8    MI      200
# 1227             100   House  20331        10    MI      200
# 1233              78   House  20725         7    MI      200
# 1238             100   House  20923        14    MI      100
# 1241              80   House  21141         1    MI      200
# 1246              77   House  21142         2    MI      200
# 1254             100   House  21143         3    MI      200
# 1265             100   House  21336        11    MI      200
# 1270              86   House  21372         5    MI      100
# 1277             100   House  29124         4    MI      200
# 1282             100   House  14263         8    MN      100
# 1287             100   House  20122         4    MN      100
# 1291             100   House  20333         2    MN      200
# 1296              73   House  20726         1    MN      100
# 1304             100   House  20727         5    MN      100
# 1311             100   House  20728         6    MN      200
# 1317             100   House  20924         3    MN      200
# 1323             100   House  29127         7    MN      100
# 1326             100   House  20925         3    MS      200
# 1328             100   House  21147         1    MS      200
# 1336             100   House  21148         4    MS      200
# 1339             100   House  29368         2    MS      100
# 1349             100   House  20124         6    MO      200
# 1351             100   House  20147         1    MO      100
# 1353             100   House  20517         5    MO      100
# 1358             100   House  20926         3    MO      200
# 1360             100   House  21149         4    MO      200
# 1367             100   House  21150         7    MO      200
# 1376             100   House  21337         2    MO      200
# 1380              81   House  29736         8    MO      200
# 1381              96   House  21338         1    MT      200
# 1385              91   House  20518         1    NE      200
# 1387             100   House  20729         3    NE      200
# 1395             100   House  29921         2    NE      200
# 1397             100   House  20927         1    NV      100
# 1407             100   House  21151         3    NV      200
# 1414              92   House  21196         2    NV      200
# 1419             100   House  21339         4    NV      100
# 1428             100   House  20731         1    NH      100
# 1435             100   House  21340         2    NH      100
# 1446              94   House  14863         4    NJ      200
# 1448             100   House  15454         6    NJ      100
# 1456             100   House  20336         5    NJ      200
# 1459             100   House  20542         8    NJ      100
# 1468             100   House  20929         7    NJ      200
# 1472             100   House  21153         3    NJ      200
# 1475              85   House  29132         1    NJ      100
# 1479             100   House  29539         2    NJ      200
# 1485             100   House  29541        11    NJ      200
# 1487             100   House  29741         9    NJ      100
# 1492             100   House  29923        12    NJ      100
# 1500             100   House  31103        10    NJ      100
# 1505              88   House  20337         2    NM      200
# 1508              77   House  20932         3    NM      100
# 1515             100   House  21341         1    NM      100
# 1528             100   House  13035        13    NY      100
# 1533              94   House  15444        25    NY      100
# 1535              92   House  15603        16    NY      100
# 1537             100   House  15612        17    NY      100
# 1541             100   House  20129         3    NY      100
# 1545             100   House  20338         1    NY      100
# 1552             100   House  20519        26    NY      100
# 1561              93   House  20733         9    NY      100
# 1566             100   House  20934        20    NY      100
# 1571              93   House  20935        24    NY      100
# 1574             100   House  20957        21    NY      100
# 1582             100   House  21101        23    NY      200
# 1585             100   House  21154        11    NY      200
# 1593             100   House  21156        19    NY      200
# 1601             100   House  21157        22    NY      200
# 1602             100   House  21342         6    NY      100
# 1609             100   House  21343         8    NY      100
# 1617             100   House  21344        18    NY      100
# 1625              76   House  21345        27    NY      200
# 1629              96   House  29134        15    NY      100
# 1634             100   House  29375         2    NY      200
# 1636              85   House  29377        10    NY      100
# 1638              97   House  29378         7    NY      100
# 1641              94   House  29379        12    NY      100
# 1644             100   House  29744         4    NY      100
# 1654             100   House  29776         5    NY      100
# 1657             100   House  29925        14    NY      100
# 1665             100   House  15092         6    NC      200
# 1666             100   House  15438         4    NC      100
# 1670             100   House  20340         1    NC      100
# 1677             100   House  20521         5    NC      200
# 1684              94   House  20522        10    NC      200
# 1688             100   House  21159         2    NC      200
# 1699             100   House  21346         8    NC      200
# 1713             100   House  21347         9    NC      200
# 1724             100   House  21348        11    NC      200
# 1735             100   House  21349        13    NC      200
# 1738             100   House  29383        12    NC      100
# 1743              92   House  29546         3    NC      200
# 1745             100   House  29746         7    NC      100
# 1748             100   House  21350         1    ND      200
# 1749              80   House  15029         9    OH      100
# 1757              93   House  20130        12    OH      200
# 1764             100   House  20342        10    OH      200
# 1768             100   House  20343        13    OH      100
# 1775              75   House  20738         4    OH      200
# 1777              92   House  20755         5    OH      200
# 1779             100   House  20941        11    OH      100
# 1783             100   House  21162         6    OH      200
# 1788             100   House  21163        15    OH      200
# 1791              78   House  21164        16    OH      200
# 1798             100   House  21165         7    OH      200
# 1804             100   House  21351         2    OH      200
# 1810             100   House  21352         3    OH      100
# 1817             100   House  21353        14    OH      200
# 1822              92   House  29137         8    OH      200
# 1826             100   House  29550         1    OH      200
# 1829             100   House  20344         4    OK      200
# 1834             100   House  21166         5    OK      200
# 1843              85   House  21354         1    OK      200
# 1849             100   House  21355         2    OK      200
# 1857             100   House  29393         3    OK      200
# 1859              93   House  15410         4    OR      100
# 1862             100   House  20944         5    OR      100
# 1870             100   House  21198         1    OR      100
# 1877             100   House  29588         3    OR      100
# 1882              73   House  29932         2    OR      200
# 1884              91   House  20134         9    PA      200
# 1889             100   House  20345         6    PA      200
# 1893              83   House  20346        18    PA      200
# 1898             100   House  20524         8    PA      200
# 1900             100   House  20525        13    PA      100
# 1909             100   House  20526        15    PA      200
# 1913             100   House  20946         5    PA      200
# 1917              67   House  21167         3    PA      200
# 1923             100   House  21168         7    PA      200
# 1927              93   House  21170        10    PA      200
# 1934             100   House  21171        11    PA      200
# 1938             100   House  21356         4    PA      200
# 1947             100   House  21357        12    PA      200
# 1951              86   House  21358        17    PA      100
# 1954             100   House  29559         2    PA      100
# 1958              72   House  29561        14    PA      100
# 1963             100   House  29752        16    PA      200
# 1966             100   House  29777         1    PA      100
# 1968             100   House  20136         2    RI      100
# 1972             100   House  21172         1    RI      100
# 1982             100   House  20138         2    SC      200
# 1986             100   House  21174         3    SC      200
# 1995             100   House  21175         4    SC      200
# 1999             100   House  21176         5    SC      200
# 2008             100   House  21359         7    SC      200
# 2016              93   House  39301         6    SC      100
# 2019             100   House  21177         1    SD      200
# 2020              86   House  15019         5    TN      100
# 2028             100   House  15455         2    TN      200
# 2030             100   House  20351         7    TN      200
# 2036             100   House  20748         9    TN      100
# 2042              83   House  20947         1    TN      200
# 2047              79   House  21178         3    TN      200
# 2056             100   House  21179         4    TN      200
# 2063             100   House  21180         6    TN      200
# 2068              75   House  21181         8    TN      200
# 2079             100   House  15085         6    TX      200
# 2086             100   House  15445        21    TX      200
# 2091             100   House  20139         7    TX      200
# 2094             100   House  20352         5    TX      200
# 2096             100   House  20353        19    TX      200
# 2100             100   House  20355        26    TX      200
# 2103             100   House  20356        31    TX      200
# 2106             100   House  20527         1    TX      200
# 2110             100   House  20528         2    TX      200
# 2114              77   House  20529         9    TX      100
# 2120             100   House  20530        10    TX      200
# 2124              94   House  20531        11    TX      200
# 2128             100   House  20532        24    TX      200
# 2129             100   House  20533        28    TX      100
# 2139              87   House  20948        22    TX      200
# 2142             100   House  21182        17    TX      200
# 2150             100   House  21184        27    TX      200
# 2164             100   House  21360        14    TX      200
# 2170             100   House  21361        16    TX      100
# 2174             100   House  21362        20    TX      100
# 2180             100   House  21363        23    TX      100
# 2195             100   House  21364        25    TX      200
# 2202             100   House  21365        33    TX      100
# 2215             100   House  21366        34    TX      100
# 2222              78   House  29143         3    TX      200
# 2236             100   House  29570        36    TX      200
# 2240             100   House  29571        35    TX      100
# 2246             100   House  29572        13    TX      200
# 2247             100   House  29573        18    TX      100
# 2253             100   House  29759        32    TX      200
# 2258             100   House  29760         8    TX      200
# 2262             100   House  29762        12    TX      200
# 2265              90   House  29763        15    TX      100
# 2272              95   House  39304        29    TX      100
# 2274             100   House  39305        30    TX      100
# 2280             100   House  94828         4    TX      200
# 2287              93   House  20140         4    UT      100
# 2296             100   House  20357         1    UT      200
# 2303             100   House  20949         3    UT      200
# 2314             100   House  21367         2    UT      200
# 2319             100   House  20750         1    VT      100
# 2323              91   House  14869        10    VA      200
# 2326             100   House  20143         4    VA      200
# 2332             100   House  20144         7    VA      200
# 2337              81   House  20756         1    VA      200
# 2339             100   House  20952        11    VA      100
# 2351              92   House  21185         2    VA      200
# 2361             100   House  21186         5    VA      200
# 2367             100   House  21191         9    VA      200
# 2368             100   House  29149         8    VA      100
# 2373             100   House  39307         3    VA      100
# 2380              94   House  39308         6    VA      200
# 2385             100   House  15613         7    WA      100
# 2387             100   House  20145         2    WA      100
# 2393             100   House  20535         5    WA      200
# 2397              83   House  20536         8    WA      200
# 2403             100   House  21187         3    WA      200
# 2404             100   House  21368         6    WA      100
# 2412              86   House  21369        10    WA      100
# 2419             100   House  29580         4    WA      200
# 2423             100   House  29768         9    WA      100
# 2425             100   House  31101         1    WA      100
# 2438             100   House  14448         3    WV      100
# 2448             100   House  20146         2    WV      200
# 2453             100   House  21188         1    WV      200
# 2454              96   House  14657         5    WI      200
# 2456             100   House  14675         6    WI      200
# 2459             100   House  20537         4    WI      100
# 2464             100   House  21189         7    WI      200
# 2468             100   House  21190         8    WI      200
# 2470             100   House  21370         2    WI      100
# 2479             100   House  29769         3    WI      100
# 2485             100   House  29939         1    WI      200
# 2486              93   House  20953         1    WY      200
#
#                                           name_x congress_id  NOMINATE_dim1  \
# 1                bonner, jr., josiah robins (jo)     B001244          0.367
# 9                            rogers, mike dennis     R000575          0.363
# 11                                 sewell, terri     S001185         -0.396
# 17                                  roby, martha     R000591          0.362
# 27                                    brooks, mo     B001274          0.652
# 31                       bachus, spencer t., iii     B000013          0.387
# 35                              aderholt, robert     A000055          0.386
# 36                           young, donald edwin     Y000033          0.283
# 44                                 franks, trent     F000448          0.749
# 49                             grijalva, raúl m.     G000551         -0.598
# 59                              kirkpatrick, ann     K000368         -0.169
# 69                                   gosar, paul     G000565          0.699
# 80                             schweikert, david     S001183          0.571
# 84                                   barber, ron     B001279         -0.123
# 92                               sinema, kyrsten     S001191         -0.105
# 102                                   pastor, ed     P000099         -0.421
# 112                        salmon, matthew james     S000018          0.673
# 122                               crawford, rick     C001087          0.445
# 130                                 griffin, tim     G000567          0.410
# 135                                womack, steve     W000809          0.352
# 144                                  cotton, tom     C001095          0.599
# 148                               miller, george     M000725         -0.552
# 154                         waxman, henry arnold     W000215         -0.473
# 162                                pelosi, nancy     P000197         -0.490
# 169                            rohrabacher, dana     R000409          0.626
# 171                                  honda, mike     H001034         -0.529
# 174                                 schiff, adam     S001150         -0.350
# 179                                issa, darrell     I000056          0.490
# 181                              davis, susan a.     D000598         -0.343
# 185                                 nunes, devin     N000181          0.450
# 187                            sánchez, linda t.     S001156         -0.508
# 189                                   costa, jim     C001059         -0.195
# 194                                matsui, doris     M001163         -0.435
# 201               campbell, john (of california)     C001064          0.748
# 202                              mcnerney, jerry     M001166         -0.263
# 208                              mccarthy, kevin     M001165          0.456
# 211   speier, karen lorraine jacqueline (jackie)     S001175         -0.381
# 219                              mcclintock, tom     M001177          0.687
# 221                                    chu, judy     C001080         -0.488
# 225                              garamendi, john     G000559         -0.309
# 234                         hunter, duncan duane     H001048          0.539
# 238                                 denham, jeff     D000612          0.306
# 240                                  bass, karen     B001270         -0.584
# 247                                 hahn, janice     H001063         -0.390
# 258                                lamalfa, doug     L000578          0.534
# 266                               huffman, jared     H001068         -0.430
# 274                                    bera, ami     B001287         -0.238
# 283                                   cook, paul     C001094          0.372
# 291                               swalwell, eric     S001193         -0.362
# 298                            valadao, david g.     V000129          0.267
# 300                              brownley, julia     B001285         -0.291
# 312                               cárdenas, tony     C001097         -0.390
# 316                       negrete mcleod, gloria     N000187         -0.437
# 322                                   ruiz, raul     R000599         -0.249
# 333                                 takano, mark     T000472         -0.464
# 338                              lowenthal, alan     L000579         -0.449
# 351                                 vargas, juan     V000130         -0.403
# 358                                peters, scott     P000608         -0.186
# 366                               waters, maxine     W000187         -0.656
# 369                          eshoo, anna georges     E000215         -0.380
# 372                                    farr, sam     F000030         -0.455
# 380                     mckeon, howard p. (buck)     M000508          0.396
# 383                              becerra, xavier     B000287         -0.512
# 385                       roybal-allard, lucille     R000486         -0.469
# 389                        royce, edward randall     R000487          0.657
# 396                                 calvert, ken     C000059          0.349
# 397                                 lofgren, zoe     L000397         -0.400
# 403                                sherman, brad     S000344         -0.344
# 413                             sanchez, loretta     S000030         -0.367
# 424                                  capps, lois     C001036         -0.389
# 432                                 lee, barbara     L000551         -0.677
# 434                            thompson, michael     T000460         -0.393
# 440                     napolitano, grace flores     N000179         -0.448
# 448                              miller, gary g.     M001139          0.478
# 452                                lamborn, doug     L000564          0.666
# 455                               perlmutter, ed     P000593         -0.282
# 460                                 polis, jared     P000598         -0.278
# 467                                coffman, mike     C001077          0.492
# 474                                tipton, scott     T000470          0.451
# 481                                gardner, cory     G000562          0.444
# 484                               degette, diana     D000197         -0.431
# 487                                courtney, joe     C001069         -0.342
# 494                              himes, james a.     H001047         -0.239
# 503                              esty, elizabeth     E000293         -0.315
# 517                             delauro, rosa l.     D000216         -0.414
# 522                              larson, john b.     L000557         -0.396
# 528                         carney, john c., jr.     C001083         -0.256
# 534                young, charles william (bill)     Y000031          0.325
# 537                         ros-lehtinen, ileana     R000435          0.244
# 539                  miller, jefferson b. (jeff)     M001144          0.633
# 543                              crenshaw, ander     C001045          0.333
# 549                           diaz-balart, mario     D000600          0.286
# 553                    wasserman schultz, debbie     W000797         -0.418
# 560                                castor, kathy     C001066         -0.438
# 572                          buchanan, vernon g.     B001260          0.362
# 578                               bilirakis, gus     B001257          0.410
# 582                                grayson, alan     G000556         -0.363
# 597                                  posey, bill     P000599          0.527
# 607                            rooney, thomas j.     R000583          0.458
# 608                    deutch, theodore e. (ted)     D000610         -0.401
# 617                           southerland, steve     S001186          0.560
# 623                              nugent, richard     N000185          0.483
# 631                           webster, daniel a.     W000806          0.527
# 633                                 ross, dennis     R000593          0.531
# 635                            wilson, frederica     W000808         -0.480
# 644                                    yoho, ted     Y000065          0.704
# 654                                desantis, ron     D000621          0.663
# 659                              murphy, patrick     M001191         -0.186
# 672                                  radel, trey     R000596          0.702
# 674                                frankel, lois     F000462         -0.402
# 681                                  garcia, joe     G000573         -0.204
# 688                               brown, corrine     B000911         -0.429
# 694                                mica, john l.     M000689          0.453
# 697                        hastings, alcee lamar     H000324         -0.564
# 703                               lewis, john r.     L000287         -0.589
# 707                                gingrey, phil     G000550          0.561
# 710                                 scott, david     S001157         -0.304
# 716                                   price, tom     P000591          0.644
# 720                        westmoreland, lynn a.     W000796          0.672
# 721                                 barrow, john     B001252         -0.119
# 737                                johnson, hank     J000288         -0.470
# 745                          broun, paul c., jr.     B001262          0.913
# 748                                  graves, tom     G000560          0.716
# 756                                 woodall, rob     W000810          0.593
# 758                                scott, austin     S001189          0.558
# 764                                collins, doug     C001093          0.610
# 771                               kingston, jack     K000220          0.540
# 772                   bishop, sanford dixon, jr.     B000490         -0.284
# 778                            hanabusa, colleen     H001050         -0.370
# 785                               gabbard, tulsi     G000571         -0.274
# 797                            labrador, raúl r.     L000573          0.735
# 805                          simpson, michael k.     S001148          0.301
# 808                             lipinski, daniel     L000563         -0.227
# 817                                roskam, peter     R000580          0.429
# 821                                 foster, bill     F000454         -0.232
# 824                                schock, aaron     S001179          0.311
# 826                                quigley, mike     Q000023         -0.323
# 832                              kinzinger, adam     K000378          0.234
# 836                              hultgren, randy     H001059          0.490
# 840                             duckworth, tammy     D000622         -0.336
# 848                              schneider, brad     S001190         -0.185
# 858                                 enyart, bill     E000292         -0.251
# 871                                davis, rodney     D000619          0.279
# 875                                bustos, cheri     B001286         -0.239
# 882                               rush, bobby l.     R000515         -0.479
# 887                           gutiérrez, luis v.     G000535         -0.487
# 892                              davis, danny k.     D000096         -0.486
# 895                             shimkus, john m.     S000364          0.375
# 896                        schakowsky, janice d.     S001145         -0.603
# 898                             visclosky, peter     V000108         -0.402
# 905                                carson, andré     C001072         -0.428
# 919                             stutzman, marlin     S001188          0.742
# 924                                 rokita, todd     R000592          0.602
# 934                               bucshon, larry     B001275          0.408
# 941                                  young, todd     Y000064          0.449
# 946                             walorski, jackie     W000813          0.436
# 953                                brooks, susan     B001284          0.352
# 965                                 messer, luke     M001189          0.563
# 975                                  king, steve     K000362          0.613
# 976                                braley, bruce     B001259         -0.310
# 984                               loebsack, dave     L000565         -0.276
# 993                               latham, thomas     L000111          0.302
# 998                                jenkins, lynn     J000290          0.523
# 1004                              huelskamp, tim     H001057          0.744
# 1008                                yoder, kevin     Y000063          0.558
# 1019                                pompeo, mike     P000602          0.660
# 1023                 rogers, harold dallas (hal)     R000395          0.339
# 1024                               yarmuth, john     Y000062         -0.378
# 1029                              guthrie, brett     G000558          0.418
# 1032                  barr, garland h. (andy) iv     B001282          0.476
# 1034                whitfield, wayne edward (ed)     W000413          0.303
# 1039                              massie, thomas     M001184          0.678
# 1050                        boustany, charles w.     B001255          0.392
# 1053                              scalise, steve     S001176          0.555
# 1060                               fleming, john     F000456          0.590
# 1062                               cassidy, bill     C001075          0.469
# 1069                            richmond, cedric     R000588         -0.486
# 1078                           alexander, rodney     A000361          0.331
# 1079                         michaud, michael h.     M001149         -0.283
# 1083                            pingree, chellie     P000597         -0.420
# 1088                       hoyer, steny hamilton     H000874         -0.381
# 1094                ruppersberger, c. a. (dutch)     R000576         -0.296
# 1099                     van hollen, christopher     V000128         -0.392
# 1106                              sarbanes, john     S001168         -0.467
# 1111                           edwards, donna f.     E000290         -0.562
# 1119                                harris, andy     H001052          0.673
# 1125                               delaney, john     D000620         -0.276
# 1137                     cummings, elijah eugene     C000984         -0.438
# 1141                         markey, edward john     M000133         -0.514
# 1152                        neal, richard edmund     N000015         -0.417
# 1155                           lynch, stephen f.     L000562         -0.349
# 1160                   tsongas, nicola s. (niki)     T000465         -0.396
# 1167                         keating, william r.     K000375         -0.332
# 1177                      kennedy, joseph p. iii     K000379         -0.421
# 1184                          mcgovern, james p.     M000312         -0.538
# 1188                            tierney, john f.     T000266         -0.488
# 1194                    capuano, michael everett     C001037         -0.580
# 1198                    dingell, john david, jr.     D000355         -0.448
# 1206                          conyers, john, jr.     C000714         -0.658
# 1209                        levin, sander martin     L000263         -0.379
# 1219                    upton, frederick stephen     U000031          0.320
# 1222                                rogers, mike     R000572          0.400
# 1227                          miller, candice s.     M001150          0.343
# 1233                                walberg, tim     W000798          0.508
# 1238                             peters, gary c.     P000595         -0.246
# 1241                               benishek, dan     B001271          0.491
# 1246                              huizenga, bill     H001058          0.550
# 1254                               amash, justin     A000367          0.654
# 1265                           bentivolio, kerry     B001280          0.723
# 1270                                 kildee, dan     K000380         -0.374
# 1277                             camp, david lee     C000071          0.385
# 1282                      nolan, richard michael     N000127         -0.372
# 1287                             mccollum, betty     M001143         -0.417
# 1291                                 kline, john     K000363          0.490
# 1296                                   walz, tim     W000799         -0.275
# 1304                              ellison, keith     E000288         -0.537
# 1311                           bachmann, michele     B001256          0.584
# 1317                               paulsen, erik     P000594          0.402
# 1323                      peterson, collin clark     P000258         -0.148
# 1326                               harper, gregg     H001045          0.384
# 1328                              nunnelee, alan     N000186          0.488
# 1336                             palazzo, steven     P000601          0.535
# 1339                            thompson, bennie     T000193         -0.517
# 1349                              graves, samuel     G000546          0.438
# 1351                     clay, william lacy, jr.     C001049         -0.481
# 1353                        cleaver, emanuel, ii     C001061         -0.453
# 1358                         luetkemeyer, blaine     L000569          0.444
# 1360                             hartzler, vicky     H001053          0.478
# 1367                                 long, billy     L000576          0.544
# 1376                                 wagner, ann     W000812          0.416
# 1380                             emerson, jo ann     E000172          0.269
# 1381                               daines, steve     D000618          0.585
# 1385                           fortenberry, jeff     F000449          0.304
# 1387                               smith, adrian     S001172          0.515
# 1395                          terry, lee raymond     T000459          0.426
# 1397                         titus, alice (dina)     T000468         -0.301
# 1407                                   heck, joe     H001055          0.324
# 1414                             amodei, mark e.     A000369          0.384
# 1419                            horsford, steven     H001066         -0.347
# 1428                          shea-porter, carol     S001170         -0.315
# 1435                          kuster, ann mclane     K000382         -0.260
# 1446                    smith, christopher henry     S000522          0.173
# 1448                         pallone, frank, jr.     P000034         -0.405
# 1456                              garrett, scott     G000548          0.688
# 1459                                sires, albio     S001165         -0.404
# 1468                              lance, leonard     L000567          0.329
# 1472                                 runyan, jon     R000594          0.222
# 1475                      andrews, robert ernest     A000210         -0.297
# 1479                          lobiondo, frank a.     L000554          0.211
# 1485                    frelinghuysen, rodney p.     F000372          0.292
# 1487                   pascrell, william j., jr.     P000096         -0.368
# 1492                                  holt, rush     H001032         -0.463
# 1500                          payne, donald, jr.     P000604         -0.521
# 1505                              pearce, stevan     P000588          0.472
# ...
# 1137             0.00  12/31/2012           0.00          0.00
# 1141             0.00  12/31/2012        5200.00          0.00
# 1152             0.00  12/31/2012           0.00          0.00
# 1155             0.00  12/31/2012           0.00          0.00
# 1160          1314.93  12/31/2012        4040.85          0.00
# 1167           643.14  12/31/2012        6100.00          0.00
# 1177             0.00  12/31/2012        9175.00          0.00
# 1184          1174.41  12/31/2012        1300.00          0.00
# 1188         12264.12  12/31/2012        3500.00      10000.00
# 1194          2150.00  12/31/2012         200.00          0.00
# 1198          2500.00  12/31/2012        1000.00          0.00
# 1206             0.00  12/31/2012        3823.62       4000.00
# 1209             0.00  12/31/2012        3900.00          0.00
# 1219           500.00  12/31/2012        3000.00      12000.00
# 1222           300.00  12/31/2012        2750.00          0.00
# 1227             0.00  12/31/2012           0.00          0.00
# 1233          3699.00  12/31/2012        6300.00          0.00
# 1238          2944.60  12/31/2012       18100.00          0.00
# 1241         28014.52  12/31/2012        3800.00        200.00
# 1246             0.00  12/31/2012           0.00       1500.00
# 1254           500.00  12/31/2012        2913.00       3000.00
# 1265         16750.00  12/31/2012        2500.00          0.00
# 1270          5000.00  12/31/2012        4100.00      12000.00
# 1277           745.00  12/31/2012        6695.00          0.00
# 1282          9934.38  12/31/2012        1951.00          0.00
# 1287             0.00  12/31/2012           0.00       5800.00
# 1291           150.00  12/31/2012        6000.00          0.00
# 1296          7610.28  12/31/2012        6976.09       1000.00
# 1304             5.71  12/31/2012        4375.00        500.00
# 1311          5200.00  12/31/2012       97985.00          0.00
# 1317          3255.99  12/31/2012        9000.00          0.00
# 1323          6213.50  12/31/2012           0.00          0.00
# 1326             0.00  12/31/2012        5100.00       1000.00
# 1328             0.00  12/31/2012       11575.00        500.00
# 1336             0.00  12/31/2012        2800.00      12250.00
# 1339             0.00  12/31/2012           0.00       5000.00
# 1349             0.00  12/31/2012          48.00       2000.00
# 1351             0.00  12/31/2012           0.00       1000.00
# 1353             0.00  12/31/2012        1100.00          0.00
# 1358             0.00  12/31/2012           0.00        500.00
# 1360          1500.00  12/31/2012        6525.00      11500.00
# 1367             0.00  12/31/2012        2600.00       2500.00
# 1376             0.00  12/31/2012        9325.00        500.00
# 1380           700.00  12/31/2012        1305.00          0.00
# 1381          6400.00  12/31/2012       11883.04          0.00
# 1385             0.00  12/31/2012           0.00          0.00
# 1387          1500.00  12/31/2012           0.00       2000.00
# 1395          1350.00  12/31/2012           0.00          0.00
# 1397           153.63  12/31/2012        1500.00          0.00
# 1407          6217.00  12/31/2012       23335.00      11500.00
# 1414         29000.00  12/31/2012        1350.00       1000.00
# 1419          1794.15  12/31/2012          32.51          0.00
# 1428          5434.38  12/31/2012        7607.15       3000.00
# 1435          9595.78  12/31/2012        6910.00       1000.00
# 1446          1300.00  12/31/2012           0.00          0.00
# 1448           322.16  12/31/2012        3000.00       1000.00
# 1456           650.00  12/31/2012        6650.00       4400.00
# 1459             0.00  12/31/2012         500.00          0.00
# 1468             0.00  12/31/2012        1400.00       3500.00
# 1472             0.00  12/31/2012        4450.00       1250.00
# 1475             0.00  12/31/2012       17000.00       2500.00
# 1479             0.00  12/31/2012        6000.00      10450.00
# 1485          8025.00  12/31/2012           0.00          0.00
# 1487          5157.76  12/31/2012        4500.00       5800.00
# 1492          1833.04  12/31/2012        2775.00       8000.00
# 1500          1000.00  12/31/2012        8650.00          0.00
# 1505            38.38  12/31/2012           0.00          0.00
# 1508            13.40  12/31/2012           0.00       3000.00
# 1515          5350.65  12/31/2012        8152.50          0.00
# 1528          2696.10  12/31/2012       21841.94       2000.00
# 1533             0.00  12/31/2012        3356.00       6000.00
# 1535           300.00  12/31/2012           0.00          0.00
# 1537           145.25  12/31/2012        2500.00          0.00
# 1541             0.00  12/31/2012       11285.00          0.00
# 1545         20587.19  12/31/2012        7200.00      10000.00
# 1552           720.00  12/31/2012           0.00        500.00
# 1561             5.63  12/31/2012         500.00          0.00
# 1566             0.00  12/31/2012        6300.00       8250.00
# 1571          8784.06  12/31/2012        3100.00          0.00
# 1574          7038.41  12/31/2012        3604.00          0.00
# 1582         23178.00  12/31/2012         636.00          0.00
# 1585          7050.00  12/31/2012       18155.00       2000.00
# 1593         21155.00  12/31/2012        1070.00       3500.00
# 1601             0.00  12/31/2012        6635.00       2500.00
# 1602             0.00  12/31/2012        2000.00          0.00
# 1609             0.00  12/31/2012        1310.00          0.00
# 1617          1450.00  12/31/2012       12652.50       4500.00
# 1625         15250.00  12/31/2012           0.00          0.00
# 1629             0.00  12/31/2012        2000.00          0.00
# 1634          1000.00  12/31/2012           0.00          0.00
# 1636           302.64  12/31/2012          80.00          0.00
# 1638             0.00  12/31/2012           0.00          0.00
# 1641           367.69  12/31/2012       15400.00       2500.00
# 1644           250.00  12/31/2012        4335.00          0.00
# 1654             0.00  12/31/2012        2500.00       6600.00
# 1657           311.41  12/31/2012       13504.33       6500.00
# 1665          2025.00  12/31/2012           0.00          0.00
# 1666             0.00  12/31/2012           0.00        154.95
# 1670             5.79  12/31/2012           0.00          0.00
# 1677           300.00  12/31/2012        1500.00          0.00
# 1684             0.00  12/31/2012        2500.00       9500.00
# 1688            50.00  12/31/2012        5250.00          0.00
# 1699         10000.00  12/31/2012        1067.36       4000.00
# 1713          1000.00  12/31/2012        3600.00          0.00
# 1724             0.00  12/31/2012          25.00          0.00
# 1735          2500.00  12/31/2012        4510.00          0.00
# 1738           200.00  12/31/2012           0.00       2500.00
# 1743             0.00  12/31/2012           0.00       4500.00
# 1745          9852.32  12/31/2012         750.00       1000.00
# 1748          5000.00  12/31/2012        7500.00       7500.00
# 1749           350.00  12/31/2012           0.00       5000.00
# 1757             0.00  12/31/2012        1000.00       8200.00
# 1764             0.00  12/31/2012        7325.00       5000.00
# 1768          2636.00  12/31/2012        6370.00       4925.00
# 1775          1625.00  12/31/2012        4000.00          0.00
# 1777           250.00  12/31/2012        1500.00          0.00
# 1779          2000.00  12/31/2012         530.00          0.00
# 1783          5000.00  12/31/2012        3000.00          0.00
# 1788          1000.00  12/31/2012       12150.00       4500.00
# 1791         55923.00  12/31/2012      101914.48       3200.00
# 1798             0.00  12/31/2012        3000.00       2000.00
# 1804             0.00  12/31/2012        5270.00          0.00
# 1810             0.00  12/31/2012         100.00         25.00
# 1817          7100.00  12/31/2012           0.00       1000.00
# 1822           100.00  12/31/2012       65245.00      18500.00
# 1826             0.00  12/31/2012        9000.00       2500.00
# 1829             0.00  12/31/2012        2000.00       6000.00
# 1834             0.00  12/31/2012        5600.00        500.00
# 1843             0.00  12/31/2012           0.00          0.00
# 1849         14750.00  12/31/2012       29725.00       1000.00
# 1857             0.00  12/31/2012           0.00       2000.00
# 1859            30.00  12/31/2012        3100.00          0.00
# 1862          5933.24  12/31/2012        1687.00       4600.00
# 1870          6031.03  12/31/2012        7100.00          0.00
# 1877             6.65  12/31/2012        1825.00       5000.00
# 1882             0.00  12/31/2012        1000.00       1028.75
# 1884             0.00  12/31/2012         750.00       3000.00
# 1889          1300.00  12/31/2012        4756.23       1000.00
# 1893           300.00  12/31/2012         300.00       6000.00
# 1898         11440.02  12/31/2012        7560.00       2000.00
# 1900           684.79  12/31/2012       17440.00       1500.00
# 1909             0.00  12/31/2012        1045.00          0.00
# 1913             0.00  12/31/2012           0.00       1000.00
# 1917             0.00  12/31/2012        1000.00       1000.00
# 1923          7460.00  12/31/2012        2800.00       3000.00
# 1927             0.00  12/31/2012        2500.00          0.00
# 1934             0.00  12/31/2012        8490.00          0.00
# 1938          3000.00  12/31/2012           0.00          0.00
# 1947           426.00  12/31/2012       20750.00       3500.00
# 1951          2100.00  12/31/2012           0.00          0.00
# 1954            16.59  12/31/2012        7600.00          0.00
# 1958             0.00  12/31/2012           0.00       2500.00
# 1963           250.00  12/31/2012           0.00       1000.00
# 1966             0.00  12/31/2012           0.00       1500.00
# 1968            97.72  12/31/2012           0.00          0.00
# 1972         14604.94  12/31/2012        4200.00          0.00
# 1982             0.00  12/31/2012        1710.00          0.00
# 1986             0.00  12/31/2012           0.00       4000.00
# 1995             0.00  12/31/2012        1100.00          0.00
# 1999             0.00  12/31/2012       10033.18       1000.00
# 2008             0.00  12/31/2012        1000.00       2500.00
# 2016             0.00  12/31/2012        1500.00          0.00
# 2019          4850.00  12/31/2012       31964.00       1000.00
# 2020             0.00  12/31/2012        5050.00       1500.00
# 2028             0.00  12/31/2012           0.00       3500.00
# 2030             0.00  12/31/2012       11000.00       1000.00
# 2036            30.02  12/31/2012         350.00          0.00
# 2042             0.00  12/31/2012        2400.00          0.00
# 2047          1500.00  12/31/2012       11650.00          0.00
# 2056          5000.00  12/31/2012        1692.31       2384.61
# 2063          4500.00  12/31/2012        8850.00       1000.00
# 2068           250.00  12/31/2012       33250.00      18450.00
# 2079             0.00  12/31/2012        2500.00        124.93
# 2086             0.00  12/31/2012        9700.00       1000.00
# 2091             0.00  12/31/2012        4800.00       2500.00
# 2094             0.00  12/31/2012       12726.84       4150.00
# 2096             0.00  12/31/2012       24252.00       1000.00
# 2100             0.00  12/31/2012        1500.00       2500.00
# 2103             0.00  12/31/2012        8077.00       6000.00
# 2106          3100.00  12/31/2012        9500.00          0.00
# 2110             0.00  12/31/2012        8000.00          0.00
# 2114          1000.00  12/31/2012           0.00          0.00
# 2120             0.00  12/31/2012        2900.00          0.00
# 2124             0.00  12/31/2012           0.00          0.00
# 2128             0.00  12/31/2012           0.00          0.00
# 2129           330.17  12/31/2012        7546.00          0.00
# 2139             0.00  12/31/2012        2700.00       1000.00
# 2142             0.00  12/31/2012           0.00          0.00
# 2150             0.00  12/31/2012        3000.00          0.00
# 2164          5000.00  12/31/2012        2000.00          0.00
# 2170          5200.00  12/31/2012         620.00          0.00
# 2174             0.00  12/31/2012        5650.00       5000.00
# 2180          6743.26  12/31/2012        8550.00       5000.00
# 2195             0.00  12/31/2012       61521.00       1500.00
# 2202          5200.00  12/31/2012        9000.00       7500.00
# 2215             0.00  12/31/2012         500.00          0.00
# 2222             0.00  12/31/2012         500.00          0.00
# 2236             0.00  12/31/2012           0.00          0.00
# 2240          5175.28  12/31/2012           0.00          0.00
# 2246             0.00  12/31/2012           0.00       2500.00
# 2247             0.00  12/31/2012           0.00          0.00
# 2253             0.00  12/31/2012        3000.00          0.00
# 2258             0.00  12/31/2012           0.00          0.00
# 2262             0.00  12/31/2012        2800.00       2300.00
# 2265             0.00  12/31/2012           0.00          0.00
# 2272          2600.00  12/31/2012           0.00       1000.00
# 2274            11.50  12/31/2012           0.00          0.00
# 2280             0.00  12/31/2012           0.00       4500.00
# 2287          9748.62  12/31/2012           0.00       6500.00
# 2296           500.00  12/31/2012           0.00       1500.00
# 2303             0.00  12/31/2012        2435.00       3000.00
# 2314          5500.00  12/31/2012        6752.67          0.00
# 2319            68.81  12/31/2012         100.00       2500.00
# 2323             0.00  12/31/2012        3100.00          0.00
# 2326           500.00  12/31/2012           0.00          0.00
# 2332             0.00  12/31/2012       11500.00      21010.00
# 2337             0.00  12/31/2012         100.00          0.00
# 2339         19482.53  12/31/2012        3600.00          0.00
# 2351          5350.00  12/31/2012        2985.00       1440.64
# 2361          1000.00  12/31/2012        4800.00       1000.00
# 2367             0.00  12/31/2012        2400.00       8000.00
# 2368          5000.00  12/31/2012        2500.00          0.00
# 2373           500.00  12/31/2012        1000.00          0.00
# 2380           760.00  12/31/2012        2500.00       7500.00
# 2385           350.00  12/31/2012           0.00          0.00
# 2387          4668.50  12/31/2012         900.00          0.00
# 2393             0.00  12/31/2012        9515.00        500.00
# 2397          1000.00  12/31/2012        7025.00          0.00
# 2403             0.00  12/31/2012         750.00          0.00
# 2404          7090.22  12/31/2012        2750.00          0.00
# 2412          5013.80  12/31/2012        1650.00          0.00
# 2419             0.00  12/31/2012        2950.00          0.00
# 2423          1935.79  12/31/2012         450.00       2500.00
# 2425         10035.63  12/31/2012        1000.00          0.00
# 2438          5000.00  12/31/2012         625.00       5500.00
# 2448           100.00  12/31/2012         600.00       5000.00
# 2453           450.00  12/31/2012        4800.00       1500.00
# 2454          5000.00  12/31/2012           0.00          0.00
# 2456             0.00  12/31/2012        -537.77       2000.00
# 2459           156.52  12/31/2012         900.00       5250.00
# 2464         11378.77  12/31/2012       16153.00      14000.00
# 2468          4787.56  12/31/2012        2650.00       1000.00
# 2470          2500.00  12/31/2012        1510.00       1000.00
# 2479            94.50  12/31/2012           0.00       4500.00
# 2485          5000.00  12/31/2012        7725.00       1000.00
# 2486           200.00  12/31/2012           0.00          0.00

# %%
# #second runthrough pulled steven daines senatorial race id as a second match - dropping here
# out.drop(1430, axis=0, inplace=True)

# %%
# clean up reference table so it only includes necessary columns 

congress = out.drop(columns=['matching_ratio', 'chamber', 'name_x', 'pty_cd', 'party_y', 'other_loans', 'other_loan_repay', 'cand_loan_repay', 'debts_owed_by', 'spec_election', 'prim_election', 'run_election', 'gen_election', 'gen_election_precent', 'cvg_end_dt', 'indiv_refunds', 'cmte_refunds'])

# %%
congress.columns
# Out:
# Index(['icpsr', 'district', 'state', 'party_x', 'congress_id', 'NOMINATE_dim1',
#        'NOMINATE_dim2', 'candidate_id', 'name_y', 'ici', 'ttl_receipts',
#        'trans_from_comm', 'ttl_disb', 'trans_to_comm', 'coh_bop', 'coh_cop',
#        'cand_contrib', 'cand_loans', 'ttl_indiv_contrib', 'state', 'district',
#        'other_pol_cmte_contrib', 'pol_pty_contrib'],
#       dtype='object')

# %%
congress.columns = ['icpsr', 'district', 'state', 'party', 'congress_id', 'NOMINATE_dim1', 'NOMINATE_dim2', 'candidate_id', 'name', 'ici', 'ttl_receipts', 'comm_receipts', 'ttl_disb', 'comm_disb', 'start_cash', 'end_cash', 'cand_contrib', 'cand_loans', 'ind_contrib', 'district', 'state', 'other_comm_contrib', 'pty_contrib']

# %%
congress.to_csv('./datasets/congress.csv',sep=',',index=False)

# %% [markdown]
# ### Creating a reference table of registered candidates by connected committee
#
# **Filters for Candidate Search API**
# 1. Cycle - 2012
# 2. Election Year - 2012
# 3. Office - H
# 4. Year - 2012
# 5. Party - DEM, REP (elected officials only from these two parties)
#
# Principal Committee ID and information will be merged with member table

# %%
# to get a dataframe of all committees principally connected to candidates 

def candidates_dataframe(candidate_id_list, candidate_num):
    candidates_all_pages = []
    count = 0

    # cycles through each provided candidate id in list and requests the candidate API information
    for ids in candidate_id_list:
        candidates_rq = rq.get(f'https://api.open.fec.gov/v1/candidates/search/?page=1&per_page=100&candidate_id={ids}&cycle=2012&sort=name&sort_hide_null=false&sort_null_only=false&sort_nulls_last=false&api_key={api_key_fec}')

        # uncomment to debug ---> did each id request go through?
        # print(candidates_rq.status_code)
        
        # output confirmation during pull request
        clear_output(wait=True)
        count += 1
        print(f'Pulling candidate {ids}, on {count} out of {candidate_num}!')
        candidates_rq.raise_for_status()

        # push data into open list
        candidates = candidates_rq.json()

        # uncomment to debug  ---> did each id request have the correct keys?
        # print(candidates.keys())
        
        candidates_all_pages.append(candidates)

        time.sleep(.5)

    return pull_sub_dict(candidates_all_pages)

# %%
# test pull
test_list = ['H0OH08029', 'H8CA05035']

test_df = candidates_dataframe(test_list, 2)
test_df
# Out:
# Pulling candidate H8CA05035, on 2 out of 2!
#    affiliated_committee_name candidate_ids committee_id committee_type  \
# 0       FREEDOM PROJECT; THE   [H0OH08029]    C00237198              Q
# 1  NANCY PELOSI VICTORY FUND   [H8CA05035]    C00213512              H
#
#   committee_type_full                                             cycles  \
# 0     PAC - Qualified  [1990, 1992, 1994, 1996, 1998, 2000, 2002, 200...
# 1               House  [1986, 1988, 1990, 1992, 1994, 1996, 1998, 200...
#
#   designation              designation_full filing_frequency first_f1_date  \
# 0           U                  Unauthorized                T    1989-06-26
# 1           P  Principal campaign committee                Q    1987-02-18
#
#   first_file_date last_f1_date last_file_date                       name  \
# 0      1989-06-26   2016-12-09     2017-02-07    FRIENDS OF JOHN BOEHNER
# 1      1987-02-18   2023-04-28     2023-08-15  NANCY PELOSI FOR CONGRESS
#
#   organization_type organization_type_full party        party_full state  \
# 0              None                   None   REP  REPUBLICAN PARTY    VA
# 1              None                   None   DEM  DEMOCRATIC PARTY    DC
#
#   treasurer_name
# 0   LISKER, LISA
# 1   SWIG, STEVEN

# %%
candidates_df = candidates_dataframe(candidate_ids, 433)
# Out:
# Pulling candidate H8WY00148, on 433 out of 433!

# %%
one_string_in_list(candidates_df, 'candidate_ids')
# Out:
#                    affiliated_committee_name candidate_ids committee_id  \
# 0                    GULF COAST VICTORY FUND     H2AL01077    C00375220
# 1                                       NONE     H2AL03032    C00367862
# 2                                       NONE     H0AL07086    C00458976
# 3                     TEAM ROBY VICTORY FUND     H0AL02087    C00462143
# 4                                       NONE     H0AL05163    C00464149
# ..                                       ...           ...          ...
# 537  RIBBLE RESPONSIBLE GOVERNMENT COMMITTEE     H0WI08075    C00463620
# 538        MINNESOTA -WISCONSIN VICTORY FUND     H2WI02124    C00502179
# 539                 BADGER VICTORY FUND 2020     H6WI03099    C00312017
# 540                    PROSPERITY ACTION INC     H8WI01024    C00330894
# 541   FINANCIAL INNOVATION VICTORY COMMITTEE     H8WY00148    C00443580
#
#     committee_type committee_type_full  \
# 0                H               House
# 1                H               House
# 2                H               House
# 3                H               House
# 4                S              Senate
# ..             ...                 ...
# 537              H               House
# 538              H               House
# 539              H               House
# 540              Q     PAC - Qualified
# 541              S              Senate
#
#                                                 cycles designation  \
# 0           [2002, 2004, 2006, 2008, 2010, 2012, 2014]           P
# 1    [2002, 2004, 2006, 2008, 2010, 2012, 2014, 201...           P
# 2     [2010, 2012, 2014, 2016, 2018, 2020, 2022, 2024]           P
# 3           [2010, 2012, 2014, 2016, 2018, 2020, 2022]           P
# 4     [2010, 2012, 2014, 2016, 2018, 2020, 2022, 2024]           P
# ..                                                 ...         ...
# 537                     [2010, 2012, 2014, 2016, 2018]           P
# 538         [2012, 2014, 2016, 2018, 2020, 2022, 2024]           P
# 539  [1996, 1998, 2000, 2002, 2004, 2006, 2008, 201...           P
# 540  [1998, 2000, 2002, 2004, 2006, 2008, 2010, 201...           U
# 541  [2008, 2010, 2012, 2014, 2016, 2018, 2020, 202...           P
#
#                  designation_full filing_frequency first_f1_date  \
# 0    Principal campaign committee                T    2002-03-25
# 1    Principal campaign committee                Q    2001-07-20
# 2    Principal campaign committee                Q    2009-02-10
# 3    Principal campaign committee                T    2009-05-20
# 4    Principal campaign committee                T    2009-07-09
# ..                            ...              ...           ...
# 537  Principal campaign committee                T    2009-07-07
# 538  Principal campaign committee                Q    2011-09-15
# 539  Principal campaign committee                Q    1996-01-30
# 540                  Unauthorized                Q    1997-10-28
# 541  Principal campaign committee                Q    2008-01-15
#
#     first_file_date last_f1_date last_file_date  \
# 0        2002-03-25   2012-12-28     2014-08-01
# 1        2001-07-20   2023-07-13     2023-07-14
# 2        2009-02-10   2018-10-29     2023-07-14
# 3        2009-05-20   2018-12-14     2021-05-16
# 4        2009-07-09   2021-03-21     2023-02-09
# ..              ...          ...            ...
# 537      2009-07-07   2014-02-04     2017-02-24
# 538      2011-09-15   2020-07-23     2023-07-15
# 539      1996-01-30   2021-06-30     2023-07-15
# 540      1997-10-28   2019-10-01     2023-07-06
# 541      2008-01-15   2022-06-28     2023-08-09
#
#                                  name organization_type  \
# 0    JO BONNER FOR CONGRESS COMMITTEE              None
# 1            MIKE ROGERS FOR CONGRESS              None
# 2           TERRI SEWELL FOR CONGRESS              None
# 3            MARTHA ROBY FOR CONGRESS              None
# 4                MO BROOKS FOR SENATE              None
# ..                                ...               ...
# 537               RIBBLE FOR CONGRESS              None
# 538           MARK POCAN FOR CONGRESS              None
# 539       KIND FOR CONGRESS COMMITTEE              None
# 540           RYAN FOR CONGRESS, INC.              None
# 541           LUMMIS FOR WYOMING INC.              None
#
#     organization_type_full party        party_full state  \
# 0                     None   REP  REPUBLICAN PARTY    AL
# 1                     None   REP  REPUBLICAN PARTY    AL
# 2                     None   DEM  DEMOCRATIC PARTY    AL
# 3                     None   REP  REPUBLICAN PARTY    AL
# 4                     None   REP  REPUBLICAN PARTY    AL
# ..                     ...   ...               ...   ...
# 537                   None   REP  REPUBLICAN PARTY    WI
# 538                   None   DEM  DEMOCRATIC PARTY    WI
# 539                   None   DEM  DEMOCRATIC PARTY    WI
# 540                   None   REP  REPUBLICAN PARTY    WI
# 541                   None   REP  REPUBLICAN PARTY    WY
#
#               treasurer_name
# 0          LILES, MARY BURKE
# 1           JACKSON, WILLIAM
# 2    ANGERHOLZER, LINDSAY F.
# 3              SLAWSON, LEAH
# 4             BROOKS, MARTHA
# ..                       ...
# 537       MURPHY, TODD M MR.
# 538              POPE, SONDY
# 539             SMITH, BRENT
# 540               MAIR, PAUL
# 541    CUBIN, WILLIAM R. MR.
#
# [542 rows x 20 columns]

# %%
candidates_df
# Out:
#                    affiliated_committee_name candidate_ids committee_id  \
# 0                    GULF COAST VICTORY FUND     H2AL01077    C00375220
# 1                                       NONE     H2AL03032    C00367862
# 2                                       NONE     H0AL07086    C00458976
# 3                     TEAM ROBY VICTORY FUND     H0AL02087    C00462143
# 4                                       NONE     H0AL05163    C00464149
# ..                                       ...           ...          ...
# 537  RIBBLE RESPONSIBLE GOVERNMENT COMMITTEE     H0WI08075    C00463620
# 538        MINNESOTA -WISCONSIN VICTORY FUND     H2WI02124    C00502179
# 539                 BADGER VICTORY FUND 2020     H6WI03099    C00312017
# 540                    PROSPERITY ACTION INC     H8WI01024    C00330894
# 541   FINANCIAL INNOVATION VICTORY COMMITTEE     H8WY00148    C00443580
#
#     committee_type committee_type_full  \
# 0                H               House
# 1                H               House
# 2                H               House
# 3                H               House
# 4                S              Senate
# ..             ...                 ...
# 537              H               House
# 538              H               House
# 539              H               House
# 540              Q     PAC - Qualified
# 541              S              Senate
#
#                                                 cycles designation  \
# 0           [2002, 2004, 2006, 2008, 2010, 2012, 2014]           P
# 1    [2002, 2004, 2006, 2008, 2010, 2012, 2014, 201...           P
# 2     [2010, 2012, 2014, 2016, 2018, 2020, 2022, 2024]           P
# 3           [2010, 2012, 2014, 2016, 2018, 2020, 2022]           P
# 4     [2010, 2012, 2014, 2016, 2018, 2020, 2022, 2024]           P
# ..                                                 ...         ...
# 537                     [2010, 2012, 2014, 2016, 2018]           P
# 538         [2012, 2014, 2016, 2018, 2020, 2022, 2024]           P
# 539  [1996, 1998, 2000, 2002, 2004, 2006, 2008, 201...           P
# 540  [1998, 2000, 2002, 2004, 2006, 2008, 2010, 201...           U
# 541  [2008, 2010, 2012, 2014, 2016, 2018, 2020, 202...           P
#
#                  designation_full filing_frequency first_f1_date  \
# 0    Principal campaign committee                T    2002-03-25
# 1    Principal campaign committee                Q    2001-07-20
# 2    Principal campaign committee                Q    2009-02-10
# 3    Principal campaign committee                T    2009-05-20
# 4    Principal campaign committee                T    2009-07-09
# ..                            ...              ...           ...
# 537  Principal campaign committee                T    2009-07-07
# 538  Principal campaign committee                Q    2011-09-15
# 539  Principal campaign committee                Q    1996-01-30
# 540                  Unauthorized                Q    1997-10-28
# 541  Principal campaign committee                Q    2008-01-15
#
#     first_file_date last_f1_date last_file_date  \
# 0        2002-03-25   2012-12-28     2014-08-01
# 1        2001-07-20   2023-07-13     2023-07-14
# 2        2009-02-10   2018-10-29     2023-07-14
# 3        2009-05-20   2018-12-14     2021-05-16
# 4        2009-07-09   2021-03-21     2023-02-09
# ..              ...          ...            ...
# 537      2009-07-07   2014-02-04     2017-02-24
# 538      2011-09-15   2020-07-23     2023-07-15
# 539      1996-01-30   2021-06-30     2023-07-15
# 540      1997-10-28   2019-10-01     2023-07-06
# 541      2008-01-15   2022-06-28     2023-08-09
#
#                                  name organization_type  \
# 0    JO BONNER FOR CONGRESS COMMITTEE              None
# 1            MIKE ROGERS FOR CONGRESS              None
# 2           TERRI SEWELL FOR CONGRESS              None
# 3            MARTHA ROBY FOR CONGRESS              None
# 4                MO BROOKS FOR SENATE              None
# ..                                ...               ...
# 537               RIBBLE FOR CONGRESS              None
# 538           MARK POCAN FOR CONGRESS              None
# 539       KIND FOR CONGRESS COMMITTEE              None
# 540           RYAN FOR CONGRESS, INC.              None
# 541           LUMMIS FOR WYOMING INC.              None
#
#     organization_type_full party        party_full state  \
# 0                     None   REP  REPUBLICAN PARTY    AL
# 1                     None   REP  REPUBLICAN PARTY    AL
# 2                     None   DEM  DEMOCRATIC PARTY    AL
# 3                     None   REP  REPUBLICAN PARTY    AL
# 4                     None   REP  REPUBLICAN PARTY    AL
# ..                     ...   ...               ...   ...
# 537                   None   REP  REPUBLICAN PARTY    WI
# 538                   None   DEM  DEMOCRATIC PARTY    WI
# 539                   None   DEM  DEMOCRATIC PARTY    WI
# 540                   None   REP  REPUBLICAN PARTY    WI
# 541                   None   REP  REPUBLICAN PARTY    WY
#
#               treasurer_name
# 0          LILES, MARY BURKE
# 1           JACKSON, WILLIAM
# 2    ANGERHOLZER, LINDSAY F.
# 3              SLAWSON, LEAH
# 4             BROOKS, MARTHA
# ..                       ...
# 537       MURPHY, TODD M MR.
# 538              POPE, SONDY
# 539             SMITH, BRENT
# 540               MAIR, PAUL
# 541    CUBIN, WILLIAM R. MR.
#
# [542 rows x 20 columns]

# %%
candidates_df['committee_type'].value_counts()
# Out:
# H    465
# Q     26
# N     22
# Name: committee_type, dtype: int64

# %%
committees_to_keep = ['H', 'Q', 'N']

# %%
candidates_df = candidates_df.apply(lambda row: row[candidates_df['committee_type'].isin(committees_to_keep)])

# %%
candidates_df.drop(columns=['committee_type_full', 'cycles', 'designation_full', 'filing_frequency', 'first_f1_date', 'first_file_date', 'last_f1_date', 'last_file_date', 'organization_type_full', 'party', 'party_full', 'state', 'treasurer_name'],inplace=True)

# %%
candidates_df.columns = ['affiliated_org', 'candidate_id', 'committee_id', 'committee_type', 'designation', 'name', 'org_type']

# %%
candidates_df.columns
# Out:
# Index(['affiliated_org', 'candidate_id', 'committee_id', 'committee_type',
#        'designation', 'name', 'org_type'],
#       dtype='object')

# %%
candidates_df.shape
# Out:
# (513, 7)

# %%
candidates_df
# Out:
#                               affiliated_org candidate_id committee_id  \
# 0                    GULF COAST VICTORY FUND    H2AL01077    C00375220
# 1                                       NONE    H2AL03032    C00367862
# 2                                       NONE    H0AL07086    C00458976
# 3                     TEAM ROBY VICTORY FUND    H0AL02087    C00462143
# 5                                       None    H2AL06035    C00260547
# ..                                       ...          ...          ...
# 536                       DUFFY VICTORY FUND    H0WI07051    C00464339
# 537  RIBBLE RESPONSIBLE GOVERNMENT COMMITTEE    H0WI08075    C00463620
# 538        MINNESOTA -WISCONSIN VICTORY FUND    H2WI02124    C00502179
# 539                 BADGER VICTORY FUND 2020    H6WI03099    C00312017
# 540                    PROSPERITY ACTION INC    H8WI01024    C00330894
#
#     committee_type designation                              name org_type
# 0                H           P  JO BONNER FOR CONGRESS COMMITTEE     None
# 1                H           P          MIKE ROGERS FOR CONGRESS     None
# 2                H           P         TERRI SEWELL FOR CONGRESS     None
# 3                H           P          MARTHA ROBY FOR CONGRESS     None
# 5                H           P     BACHUS FOR CONGRESS COMMITTEE     None
# ..             ...         ...                               ...      ...
# 536              H           P               DUFFY FOR WISCONSIN     None
# 537              H           P               RIBBLE FOR CONGRESS     None
# 538              H           P           MARK POCAN FOR CONGRESS     None
# 539              H           P       KIND FOR CONGRESS COMMITTEE     None
# 540              Q           U           RYAN FOR CONGRESS, INC.     None
#
# [513 rows x 7 columns]

# %%
candidates_df.to_csv('./datasets/candidate_committees.csv',sep=',',index=False)

# %% [markdown]
# ____________________________________________________________________________________________________________________

# %% [markdown]
# ### API Funding Requests
#
# **Conditions for Schedule A Filters**
# 1. Contributor Type - Committee
# 2. Two Year Transaction Period - 2012 (end of election cycle)
# 3. Recipient Committee Type - House, Senate
#
# **Conditions for Schedule B Filters**
# 1. Cycle - 2012
#
# **Conditions for Schedule E Filters**
# 1. Cycle - 2012
# 2. Election Full - True

# %% [markdown]
# #### Schedule A - Candidate Receipts
#
# **Steps**
# 1. Pull list of candidate committee ids
#    - Every candidate has a distinct committee connected to their election campaign which is necessary to pull donation receipts

# %%
# function to pull variables for disbursement date and index needed for main disbursement api pull 

def pagination_pull():
    first_request = rq.get(f'https://api.open.fec.gov/v1/schedules/schedule_b/?committee_id=C00053553&spender_committee_designation=A&spender_committee_designation=J&spender_committee_designation=P&spender_committee_designation=B&spender_committee_designation=D&spender_committee_org_type=C&spender_committee_org_type=L&spender_committee_org_type=M&spender_committee_org_type=T&spender_committee_org_type=V&spender_committee_org_type=W&spender_committee_type=C&spender_committee_type=D&spender_committee_type=E&spender_committee_type=H&spender_committee_type=I&spender_committee_type=N&spender_committee_type=O&spender_committee_type=P&spender_committee_type=Q&spender_committee_type=S&spender_committee_type=U&spender_committee_type=V&spender_committee_type=W&two_year_transaction_period=2012&per_page=100&sort=-disbursement_date&sort_hide_null=false&sort_null_only=false&api_key={api_key_fec}')

print(nra_rq.status_code)
nra_json = nra_rq.json()

nra_page_test = nra_json['pagination']
nra_index_test = nra_page_test['last_indexes']
nra_index_test['last_index']
nra_index_test['last_disbursement_date']

# %%
# loop through all candidate ids to get a master list of all receipts by congress person

def receipts_master_pull(cand_id_list):  # add list of FEC candidate ids
    receipts_all_pages = []
    count = 0
    
    # cycle through the first page of each rq to find the length of each expenditure list by candidate
    for ids in cand_id_list:
        receipts_rq = rq.get(f'https://api.open.fec.gov/v1/schedules/schedule_e/by_candidate/?page=1&per_page=100&cycle=2012&election_full=true&candidate_id={ids}&sort_hide_null=false&sort_null_only=false&sort_nulls_last=false&api_key={api_key_fec}')
        pgone_rq = expenditures_rq.json()
        time.sleep(.5)
        
        # uncomment to debug 
        # print(pgone_rq.keys())   
        
        try:
            qty_pages = page_count(pgone_rq)
            count += 1

        except KeyError:
            print(f'API Request for candidate {ids} could not be found. Here\'s what was pulled:')
            print(pgone_rq)

        except JSONDecodeError:
            print(expenditures_rq.status_code)
            print(pgone_rq.keys())
            
        # with length of rq pull, loop through each page for every candidate and append to a blank list
        for i in range(1, qty_pages+1):
            all_expenditures_rq = rq.get(f'https://api.open.fec.gov/v1/schedules/schedule_e/by_candidate/?page={i}&per_page=100&cycle=2012&election_full=true&candidate_id={ids}&sort_hide_null=false&sort_null_only=false&sort_nulls_last=false&api_key={api_key_fec}')
            
            # upgraded FEC api key can pull a max of 120 calls a minute
            time.sleep(.5)
            
            try:
                all_expenditures_json = all_expenditures_rq.json()
                results = all_expenditures_json['results']
                expenditures_all_pages.append(results)

            except JSONDecodeError:
                print(all_expenditures_rq.status_code)
            
        # check status during pull
        clear_output(wait=True)
        print(f'Pulling expenditures from {ids}, on number {count} out of 433!')
        expenditures_rq.raise_for_status()
        
    
    return expenditures_all_pages

# %%
boehner_json

# %%
boehner_list = boehner_json['results']
boehner_list

# %%
boehner_dict1 = boehner_list[0]

# %%
boehner_dict1

# %%
# create while loop for pagination capture

# variables set by first page request, count set to track number of pages requested
last_contribution_receipt_date = '2012-09-21'
last_index = '4102220121167751830'
count = 1

while True:
    try:
        # api request that inserts api key variable, as well as the last index and disbursement date from the first page request
        boehner_rq_loop = rq.get(f'https://api.open.fec.gov/v1/schedules/schedule_a/?contributor_id=C00053553&contributor_type=committee&two_year_transaction_period=2012&recipient_committee_type=H&recipient_committee_type=S&per_page=100&sort=-contribution_receipt_date&sort_hide_null=false&sort_null_only=false&api_key={api_key_fec}&last_disbursement_date={last_contribution_receipt_date}')

        # check status during while loop
        print(f'Requesting page {count}')
        boehner_rq_loop.raise_for_status()

        # convert request into json file
        boehner_json_loop = boehner_rq_loop.json()

        # move through json to pull new last index and disbursement dates
        boehner_page_loop = boehner_json_loop['pagination']
        boehner_index_loop = boehner_page_loop['last_indexes']
        boehner_index = boehner_index_loop['last_index']
        boehner_contribution_date = boehner_index_loop['last_contribution_receipt_date']
       
        # convert loop into a list and append to boehner_list
        boehner_list_loop = list(boehner_json_loop)
        boehner_list.append(boehner_list_loop)
        
        # add to counter
        count += 1
        
    except TypeError:
        print('No more valid pages to loop through')
        break

# %% [markdown]
# #### Schedule B - Disbursements by Committee

# %%
# loop through all committee ids to get a master list of all committee disbursements

def disbursements_master_pull(committee_id_list):  # add list of FEC candidate ids
    disbursements_all_pages = []
    count = 0
    
    # cycle through the first page of each rq to find the length of each expenditure list by candidate
    for ids in committee_id_list:
        disbursements_rq = rq.get(f'https://api.open.fec.gov/v1/schedules/schedule_b/by_recipient_id/?page=1&per_page=100&cycle=2012&recipient_id={ids}&sort_hide_null=false&sort_null_only=false&sort_nulls_last=false&api_key={api_key_fec}')
        time.sleep(.5)
        
        # uncomment to debug
        # print(disbursements_rq)
        # print(pgone_rq.keys())
        try:
            pgone_rq = disbursements_rq.json()
            qty_pages = page_count(pgone_rq)
            count += 1

        except KeyError:
            print(f'API Request for committee {ids} could not be found. Here\'s what was pulled:')
            print(pgone_rq)

        except:
            print('JSON Decoder Error')
            continue
            
        # with length of rq pull, loop through each page for every candidate and append to a blank list
        for i in range(1, qty_pages+1):
            all_disbursements_rq = rq.get(f'https://api.open.fec.gov/v1/schedules/schedule_b/by_recipient_id/?page={i}&per_page=100&cycle=2012&recipient_id={ids}&sort_hide_null=false&sort_null_only=false&sort_nulls_last=false&api_key={api_key_fec}')
            
            # upgraded FEC api key can pull a max of 120 calls a minute
            time.sleep(.5)
            
            try:
                all_disbursements_json = all_disbursements_rq.json()
                results = all_disbursements_json['results']
                disbursements_all_pages.append(results)

            except:
                print(all_disbursements_rq.status_code)
                continue
                
        # check status during pull
        clear_output(wait=True)
        print(f'Pulling disbursements from {ids}, on number {count} out of {13008}!')
        disbursements_rq.raise_for_status()
        
    
    return disbursements_all_pages

# %%
disbursements = disbursements_master_pull(committee_ids)
# Out:
# Pulling disbursements from C30001184, on number 12989 out of 13008!

# %%
# #uncomment to troubleshoot errors in api requests


# problem_id = 'H4GA06087'

# problem_rq = rq.get(f'https://api.open.fec.gov/v1/schedules/schedule_b/by_recipient_id/?page={i}&per_page=100&cycle=2012&recipient_id={ids}&sort_hide_null=false&sort_null_only=false&sort_nulls_last=false&api_key={api_key_fec}')

# print(problem_rq.status_code)
# problem_json = problem_rq.json()

# problem_json

# %%
disbursements
# Out:
# [[{'committee_id': 'C00004036',
#    'committee_name': 'SEIU COPE (SERVICE EMPLOYEES INTERNATIONAL UNION COMMITTEE ON POLITICAL EDUCATION)',
#    'count': 1,
#    'cycle': 2012,
#    'memo_count': 0,
#    'memo_total': 0.0,
#    'recipient_id': 'C00348540',
#    'recipient_name': "1199 SERVICE EMPLOYEES INT'L UNION FEDERAL POLITICAL ACTION FUND",
#    'total': 125000.0}],
#  [{'committee_id': 'C00348540',
#    'committee_name': '1199 SEIU UNITED HEALTHCARE WORKERS EAST FEDERAL POLITICAL ACTION FUND',
#    'count': 1,
#    'cycle': 2012,
#    'memo_count': 0,
#    'memo_total': 0.0,
#    'recipient_id': 'C00344531',
#    'recipient_name': '1199 32BJ/144 SERVICE EMPLOYEES INTERNATIONAL UNION HOME CARE POLITICAL ACTION FUND',
#    'total': 3546.0}],
#  [{'committee_id': 'C00330720',
#    'committee_name': 'TRUST PAC TEAM REPUBLICANS FOR UTILIZING SENSIBLE TACTICS',
#    'count': 1,
#    'cycle': 2012,
#    'memo_count': 0,
#    'memo_total': 0.0,
#    'recipient_id': 'C00040279',
#    'recipient_name': 'ABBOTT LABORATORIES EMPLOYEE POLITICAL ACTION COMMITTEE',
#    'total': 1000.0},
#   {'committee_id': 'C00432401',
#    'committee_name': 'BEN NELSON 2012',
#    'count': 3,
#    'cycle': 2012,
#    'memo_count': 0,
#    'memo_total': 0.0,
#    'recipient_id': 'C00040279',
#    'recipient_name': 'ABBOTT LABORATORIES EMPLOYEE POLITICAL ACTION COMMITTEE',
#    'total': 7000.0},
#   {'committee_id': 'C00467233',
#    'committee_name': 'FISCAL RESPONSIBILITY PAC',
#    'count': 1,
#    'cycle': 2012,
#    'memo_count': 0,
#    'memo_total': 0.0,
#    'recipient_id': 'C00040279',
#    'recipient_name': 'ABBOTT LABORATORIES EMPLOYEE POLITICAL ACTION COMMITTEE',
#    'total': 500.0}],
#  [{'committee_id': 'C00040279',
#    'committee_name': 'ABBOTT LABORATORIES EMPLOYEE POLITICAL ACTION COMMITTEE',
#    'count': 1,
#    'cycle': 2012,
#    'memo_count': 0,
#    'memo_total': 0.0,
#    'recipient_id': 'C00536573',
#    'recipient_name': 'ABBVIE PAC',
#    'total': 235400.0}],
#  [{'committee_id': 'C00494294',
#    'committee_name': 'SCOTT BROWN VICTORY COMMITTEE',
#    'count': 1,
#    'cycle': 2012,
#    'memo_count': 0,
#    'memo_total': 0.0,
#    'recipient_id': 'C00426445',
#    'recipient_name': 'ABIOMED INC POLITICAL ACTION COMMITTEE (ABIOMED PAC)',
#    'total': 4350.0}],
#  [{'committee_id': 'C00491985',
#    'committee_name': 'CAJUN POLITICAL ACTION COMMITTEE (CAJUNPAC)',
#    'count': 1,
#    'cycle': 2012,
#    'memo_count': 0,
#    'memo_total': 0.0,
#    'recipient_id': 'C00335570',
#    'recipient_name': 'ACADIAN AMBULANCE SERVICE, INC. EMPLOYEE PAC',
#    'total': 2500.0}],
#  [{'committee_id': 'C00432401',
#    'committee_name': 'BEN NELSON 2012',
#    'count': 1,
#    'cycle': 2012,
#    'memo_count': 0,
#    'memo_total': 0.0,
#    'recipient_id': 'C00300707',
#    'recipient_name': 'ACCENTURE INC. POLITICAL ACTION COMMITTEE',
#    'total': 1500.0}],
#  [{'committee_id': 'C00458463',
#    'committee_name': 'PORTMAN FOR SENATE COMMITTEE',
#    'count': 1,
#    'cycle': 2012,
#    'memo_count': 0,
#    'memo_total': 0.0,
#    'recipient_id': 'C00034785',
#    'recipient_name': 'ACPAC ACA INTERNATIONAL POLITICAL ACTION COMMITTEE',
#    'total': 2500.0},
#   {'committee_id': 'C00304758',
#    'committee_name': 'MISSOURI FRB PAC',
#    'count': 1,
#    'cycle': 2012,
#    'memo_count': 0,
#    'memo_total': 0.0,
#    'recipient_id': 'C00034785',
#    'recipient_name': 'ACPAC ACA INTERNATIONAL POLITICAL ACTION COMMITTEE',
#    'total': 2000.0}],
#  [{'committee_id': 'C00002972',
#    'committee_name': "THE NATIONAL RURAL ELECTRIC COOPERATIVE ASSOCIATION ACTION COMMITTEE FOR RURAL ELECTRIFICATION (AMERICA'S ELECTRIC COOPERATIVES PAC)",
#    'count': 7,
#    'cycle': 2012,
#    'memo_count': 0,
#    'memo_total': 0.0,
#    'recipient_id': 'C00008169',
#    'recipient_name': 'ACTION COMMITTEE FOR RURAL ELECTRIFICATION/MISSOURI COOPERATIVES (FKA MISSOURI ACRE)',
#    'total': 39327.0}],
#  [{'committee_id': 'C00410183',
#    'committee_name': 'DEMOCRACY FOR NYC, INC.',
#    'count': 2,
#    'cycle': 2012,
#    'memo_count': 0,
#    'memo_total': 0.0,
#    'recipient_id': 'C00422485',
#    'recipient_name': 'ACT NOW PAC INC',
#    'total': 545.0}],
#  [{'committee_id': 'C00096156',
#    'committee_name': 'HONEYWELL INTERNATIONAL POLITICAL ACTION COMMITTEE',
#    'count': 1,
#    'cycle': 2012,
#    'memo_count': 0,
#    'memo_total': 0.0,
#    'recipient_id': 'C00508929',
#    'recipient_name': 'ADIRONDACK JOBS PAC',
#    'total': 2500.0},
#   {'committee_id': 'C00040998',
#    'committee_name': 'NATIONAL AUTOMOBILE DEALERS ASSOCIATION POLITICAL ACTION COMMITTEE',
#    'count': 1,
#    'cycle': 2012,
#    'memo_count': 0,
#    'memo_total': 0.0,
#    'recipient_id': 'C00508929',
#    'recipient_name': 'ADIRONDACK JOBS PAC',
#    'total': 5000.0},
#   {'committee_id': 'C00012476',
#    'committee_name': 'UA UNION PLUMBERS & PIPEFITTERS VOTE! PAC (UNITED ASSOCIATION OF JOURNEYMEN AND APPRENTICES OF THE PLUMBING & PIPEFITTING INDUSTRY OF THE UNITED STATES AND CANADA)',
#    'count': 1,
#    'cycle': 2012,
#    'memo_count': 0,
#    'memo_total': 0.0,
#    'recipient_id': 'C00508929',
#    'recipient_name': 'ADIRONDACK JOBS PAC',
#    'total': 5000.0},
#   {'committee_id': 'C00027342',
#    'committee_name': 'INTERNATIONAL BROTHERHOOD OF ELECTRICAL WORKERS POLITICAL ACTION COMMITTEE',
#    'count': 1,
#    'cycle': 2012,
#    'memo_count': 0,
#    'memo_total': 0.0,
#    'recipient_id': 'C00508929',
#    'recipient_name': 'ADIRONDACK JOBS PAC',
#    'total': 5000.0}],
#  [{'committee_id': 'C00492231',
#    'committee_name': 'FRIENDS OF MIKE H',
#    'count': 1,
#    'cycle': 2012,
#    'memo_count': 0,
#    'memo_total': 0.0,
#    'recipient_id': 'C00213231',
#    'recipient_name': 'A DUDA & SONS, INC. POLITICAL ACTION COMMITTEE',
#    'total': 2500.0}],
#  [{'committee_id': 'C00332833',
#    'committee_name': 'CARDINAL HEALTH INC. PAC',
#    'count': 1,
#    'cycle': 2012,
#    'memo_count': 0,
#    'memo_total': 0.0,
#    'recipient_id': 'C00340356',
#    'recipient_name': 'ADVANCED MEDICAL TECHNOLOGY ASSOCIATION POLITICAL ACTION COMMITTEE',
#    'total': 5000.0},
#   {'committee_id': 'C00040279',
#    'committee_name': 'ABBOTT LABORATORIES EMPLOYEE POLITICAL ACTION COMMITTEE',
#    'count': 4,
#    'cycle': 2012,
#    'memo_count': 0,
#    'memo_total': 0.0,
#    'recipient_id': 'C00340356',
#    'recipient_name': 'ADVANCED MEDICAL TECHNOLOGY ASSOCIATION POLITICAL ACTION COMMITTEE',
#    'total': 10000.0},
#   {'committee_id': 'C00357863',
#    'committee_name': 'BOSTON SCIENTIFIC CORPORATION POLITICAL ACTION COMMITTEE (BSC PAC)',
#    'count': 2,
#    'cycle': 2012,
#    'memo_count': 0,
#    'memo_total': 0.0,
#    'recipient_id': 'C00340356',
#    'recipient_name': 'ADVANCED MEDICAL TECHNOLOGY ASSOCIATION POLITICAL ACTION COMMITTEE',
#    'total': 5000.0},
#   {'committee_id': 'C00359125',
#    'committee_name': 'C. R. BARD INC. ACTIVE CITIZENSHIP COMMITTEE',
#    'count': 2,
#    'cycle': 2012,
#    'memo_count': 0,
#    'memo_total': 0.0,
#    'recipient_id': 'C00340356',
#    'recipient_name': 'ADVANCED MEDICAL TECHNOLOGY ASSOCIATION POLITICAL ACTION COMMITTEE',
#    'total': 10000.0},
#   {'committee_id': 'C00368720',
#    'committee_name': 'STERIS CORPORATION EMPLOYEE POLITICAL ACTION COMMITTEE (A.K.A. STERIS EMPLOYEE PAC)',
#    'count': 2,
#    'cycle': 2012,
#    'memo_count': 0,
#    'memo_total': 0.0,
#    'recipient_id': 'C00340356',
#    'recipient_name': 'ADVANCED MEDICAL TECHNOLOGY ASSOCIATION POLITICAL ACTION COMMITTEE',
#    'total': 10000.0},
#   {'committee_id': 'C00388652',
#    'committee_name': 'TERUMO BCT, INC.',
#    'count': 2,
#    'cycle': 2012,
#    'memo_count': 0,
#    'memo_total': 0.0,
#    'recipient_id': 'C00340356',
#    'recipient_name': 'ADVANCED MEDICAL TECHNOLOGY ASSOCIATION POLITICAL ACTION COMMITTEE',
#    'total': 10000.0},
#   {'committee_id': 'C00411900',
#    'committee_name': 'EDWARDS LIFESCIENCES POLITICAL ACTION COMMITTEE (A.K.A. EDWARDS PAC)',
#    'count': 2,
#    'cycle': 2012,
#    'memo_count': 0,
#    'memo_total': 0.0,
#    'recipient_id': 'C00340356',
#    'recipient_name': 'ADVANCED MEDICAL TECHNOLOGY ASSOCIATION POLITICAL ACTION COMMITTEE',
#    'total': 10000.0},
#   {'committee_id': 'C00426445',
#    'committee_name': 'ABIOMED INC POLITICAL ACTION COMMITTEE (ABIOMED PAC)',
#    'count': 2,
#    'cycle': 2012,
#    'memo_count': 0,
#    'memo_total': 0.0,
#    'recipient_id': 'C00340356',
#    'recipient_name': 'ADVANCED MEDICAL TECHNOLOGY ASSOCIATION POLITICAL ACTION COMMITTEE',
#    'total': 5000.0},
#   {'committee_id': 'C00448993',
#    'committee_name': 'HILL-ROM HOLDINGS, INC. POLITICAL ACTION COMMITTEE (HRPAC)',
#    'count': 2,
#    'cycle': 2012,
#    'memo_count': 0,
#    'memo_total': 0.0,
#    'recipient_id': 'C00340356',
#    'recipient_name': 'ADVANCED MEDICAL TECHNOLOGY ASSOCIATION POLITICAL ACTION COMMITTEE',
#    'total': 4000.0},
#   {'committee_id': 'C00281162',
#    'committee_name': 'BAYER US LLC EMPLOYEE POLITICAL ACTION COMMITTEE (BAYERPAC)',
#    'count': 1,
#    'cycle': 2012,
#    'memo_count': 0,
#    'memo_total': 0.0,
#    'recipient_id': 'C00340356',
#    'recipient_name': 'ADVANCED MEDICAL TECHNOLOGY ASSOCIATION POLITICAL ACTION COMMITTEE',
#    'total': 1000.0},
#   {'committee_id': 'C00311878',
#    'committee_name': 'MEDTRONIC INC. PAC',
#    'count': 2,
#    'cycle': 2012,
#    'memo_count': 0,
#    'memo_total': 0.0,
#    'recipient_id': 'C00340356',
#    'recipient_name': 'ADVANCED MEDICAL TECHNOLOGY ASSOCIATION POLITICAL ACTION COMMITTEE',
#    'total': 10000.0}],
#  [{'committee_id': 'C00055582',
#    'committee_name': 'NY REPUBLICAN FEDERAL CAMPAIGN COMMITTEE',
#    'count': 1,
#    'cycle': 2012,
#    'memo_count': 0,
#    'memo_total': 0.0,
#    'recipient_id': 'C00374447',
#    'recipient_name': 'AECOM US FEDERAL PAC',
#    'total': 10000.0}],
#  [{'committee_id': 'C00035683',
#    'committee_name': 'RAYTHEON TECHNOLOGIES CORPORATION PAC (FORMERLY UTC PAC)',
#    'count': 1,
#    'cycle': 2012,
#    'memo_count': 0,
#    'memo_total': 0.0,
#    'recipient_id': 'C00464453',
#    'recipient_name': 'AEROSPACE INDUSTRIES ASSOCIATION OF AMERICA INC POLITICAL ACTION COMMITTEE (AIAPAC)',
#    'total': 5000.0}],
#  [{'committee_id': 'C00432401',
#    'committee_name': 'BEN NELSON 2012',
#    'count': 1,
#    'cycle': 2012,
#    'memo_count': 0,
#    'memo_total': 0.0,
#    'recipient_id': 'C00181826',
#    'recipient_name': 'AETNA INC. POLITICAL ACTION COMMITTEE',
#    'total': 5000.0},
#   {'committee_id': 'C00279521',
#    'committee_name': 'ARIZONA FUND',
#    'count': 1,
#    'cycle': 2012,
#    'memo_count': 0,
#    'memo_total': 0.0,
#    'recipient_id': 'C00181826',
#    'recipient_name': 'AETNA INC. POLITICAL ACTION COMMITTEE',
#    'total': 500.0}],
#  [{'committee_id': 'C00412304',
#    'committee_name': 'MONTANANS FOR TESTER',
#    'count': 3,
#    'cycle': 2012,
#    'memo_count': 0,
#    'memo_total': 0.0,
#    'recipient_id': 'C00034157',
#    'recipient_name': 'AFLAC PAC',
#    'total': 1000.0},
#   {'committee_id': 'C00417550',
#    'committee_name': 'FRIENDS OF DAN MAFFEI',
#    'count': 1,
#    'cycle': 2012,
#    'memo_count': 0,
#    'memo_total': 0.0,
#    'recipient_id': 'C00034157',
#    'recipient_name': 'AFLAC PAC',
#    'total': 2000.0},
#   {'committee_id': 'C00432401',
#    'committee_name': 'BEN NELSON 2012',
#    'count': 1,
#    'cycle': 2012,
#    'memo_count': 0,
#    'memo_total': 0.0,
#    'recipient_id': 'C00034157',
#    'recipient_name': 'AFLAC PAC',
#    'total': 5000.0},
#   {'committee_id': 'C00291955',
#    'committee_name': "OLYMPIA'S LIST",
#    'count': 2,
#    'cycle': 2012,
#    'memo_count': 0,
#    'memo_total': 0.0,
#    'recipient_id': 'C00034157',
#    'recipient_name': 'AFLAC PAC',
#    'total': 4500.0}],
#  [{'committee_id': 'C00003590',
#    'committee_name': 'UNITED STEELWORKERS POLITICAL ACTION FUND',
#    'count': 1,
#    'cycle': 2012,
#    'memo_count': 0,
#    'memo_total': 0.0,
#    'recipient_id': 'C00003806',
#    'recipient_name': 'AFL-CIO COPE POLITICAL CONTRIBUTIONS COMMITTEE',
#    'total': 5000.0},
#   {'committee_id': 'C00011114',
#    'committee_name': 'AMERICAN FEDERATION OF STATE COUNTY & MUNICIPAL EMPLOYEES  P E O P L E',
#    'count': 1,
#    'cycle': 2012,
#    'memo_count': 0,
#    'memo_total': 0.0,
#    'recipient_id': 'C00003806',
#    'recipient_name': 'AFL-CIO COPE POLITICAL CONTRIBUTIONS COMMITTEE',
#    'total': 5000.0},
#   {'committee_id': 'C00027342',
#    'committee_name': 'INTERNATIONAL BROTHERHOOD OF ELECTRICAL WORKERS POLITICAL ACTION COMMITTEE',
#    'count': 3,
#    'cycle': 2012,
#    'memo_count': 0,
#    'memo_total': 0.0,
#    'recipient_id': 'C00003806',
#    'recipient_name': 'AFL-CIO COPE POLITICAL CONTRIBUTIONS COMMITTEE',
#    'total': 5500.0},
#   {'committee_id': 'C00028860',
#    'committee_name': 'AMERICAN FEDERATION OF TEACHERS, AFL-CIO COMMITTEE ON POLITICAL EDUCATION',
#    'count': 1,
#    'cycle': 2012,
#    'memo_count': 0,
#    'memo_total': 0.0,
#    'recipient_id': 'C00003806',
#    'recipient_name': 'AFL-CIO COPE POLITICAL CONTRIBUTIONS COMMITTEE',
#    'total': 175000.0}],
#  [{'committee_id': 'C00498907',
#    'committee_name': 'DEB FISCHER FOR US SENATE',
#    'count': 1,
#    'cycle': 2012,
#    'memo_count': 0,
#    'memo_total': 0.0,
#    'recipient_id': 'C00207308',
#    'recipient_name': 'AG PROCESSING INC POLITICAL ACTION COMMITTEE, AGPAC',
#    'total': 5000.0}],
#  [{'committee_id': 'C00248849',
#    'committee_name': 'CROPLIFE AMERICA POLITICAL ACTION COMMITTEE',
#    'count': 1,
#    'cycle': 2012,
#    'memo_count': 0,
#    'memo_total': 0.0,
#    'recipient_id': 'C00264770',
#    'recipient_name': 'AGRICULTURAL RETAILERS ASSOCIATION POLITICAL ACTION COMMITTE',
#    'total': 275.0}],
#  [{'committee_id': 'C00096156',
#    'committee_name': 'HONEYWELL INTERNATIONAL POLITICAL ACTION COMMITTEE',
#    'count': 1,
#    'cycle': 2012,
#    'memo_count': 0,
#    'memo_total': 0.0,
#    'recipient_id': 'C00131185',
#    'recipient_name': 'AIRCRAFT OWNERS AND PILOTS ASSOCIATION POLITICAL ACTION COMMITTEE',
#    'total': 1500.0},
#   {'committee_id': 'C00432401',
#    'committee_name': 'BEN NELSON 2012',
#    'count': 1,
#    'cycle': 2012,
#    'memo_count': 0,
#    'memo_total': 0.0,
#    'recipient_id': 'C00131185',
#    'recipient_name': 'AIRCRAFT OWNERS AND PILOTS ASSOCIATION POLITICAL ACTION COMMITTEE',
#    'total': 3500.0}],
#  [{'committee_id': 'C00238725',
#    'committee_name': 'NATIONAL AIR TRAFFIC CONTROLLERS ASSOCIATION PAC',
#    'count': 1,
#    'cycle': 2012,
#    'memo_count': 0,
#    'memo_total': 0.0,
#    'recipient_id': 'C00035451',
#    'recipient_name': 'AIR LINE PILOTS ASSOCIATION PAC',
#    'total': 5000.0},
#   {'committee_id': 'C00114439',
#    'committee_name': 'WASHINGTON STATE DEMOCRATIC CENTRAL COMMITTEE',
#    'count': 1,
#    'cycle': 2012,
#    'memo_count': 0,
#    'memo_total': 0.0,
#    'recipient_id': 'C00035451',
#    'recipient_name': 'AIR LINE PILOTS ASSOCIATION PAC',
#    'total': 2500.0}],
#  [{'committee_id': 'C00064766',
#    'committee_name': 'UNITED PARCEL SERVICE INC. PAC',
#    'count': 2,
#    'cycle': 2012,
#    'memo_count': 0,
#    'memo_total': 0.0,
#    'recipient_id': 'C00114694',
#    'recipient_name': 'AIRLINES FOR AMERICA (A4A) POLITICAL ACTION COMMITTEE',
#    'total': 10000.0},
#   {'committee_id': 'C00478099',
#    'committee_name': 'ATLAS AIR WORLDWIDE HOLDINGS, INC. POLITICAL ACTION COMMITTEE',
#    'count': 1,
#    'cycle': 2012,
#    'memo_count': 0,
#    'memo_total': 0.0,
#    'recipient_id': 'C00114694',
#    'recipient_name': 'AIRLINES FOR AMERICA (A4A) POLITICAL ACTION COMMITTEE',
#    'total': 5000.0}],
#  [{'committee_id': 'C00039578',
#    'committee_name': 'THE COUNCIL OF INSURANCE AGENTS & BROKERS POLITICAL ACTION COMMITTEE',
#    'count': 1,
#    'cycle': 2012,
#    'memo_count': 0,
#    'memo_total': 0.0,
#    'recipient_id': 'C00341800',
#    'recipient_name': 'AIRPORTS COUNCIL INTERNATIONAL-NORTH AMERICA POLITICAL ACTION COMMITTEE (AIRPORT PAC)',
#    'total': 2000.0},
#   {'committee_id': 'C00207969',
#    'committee_name': 'NATIONAL CUSTOMS BROKERS & FORWARDERS ASSOCIATION PAC',
#    'count': 1,
#    'cycle': 2012,
#    'memo_count': 0,
#    'memo_total': 0.0,
#    'recipient_id': 'C00341800',
#    'recipient_name': 'AIRPORTS COUNCIL INTERNATIONAL-NORTH AMERICA POLITICAL ACTION COMMITTEE (AIRPORT PAC)',
#    'total': 1000.0},
#   {'committee_id': 'C00291955',
#    'committee_name': "OLYMPIA'S LIST",
#    'count': 1,
#    'cycle': 2012,
#    'memo_count': 0,
#    'memo_total': 0.0,
#    'recipient_id': 'C00341800',
#    'recipient_name': 'AIRPORTS COUNCIL INTERNATIONAL-NORTH AMERICA POLITICAL ACTION COMMITTEE (AIRPORT PAC)',
#    'total': 1000.0},
#   {'committee_id': 'C00325332',
#    'committee_name': 'AMERICAN SENIORS HOUSING ASSOCIATION (SENIORS HOUSING PAC)',
#    'count': 2,
#    'cycle': 2012,
#    'memo_count': 0,
#    'memo_total': 0.0,
#    'recipient_id': 'C00341800',
#    'recipient_name': 'AIRPORTS COUNCIL INTERNATIONAL-NORTH AMERICA POLITICAL ACTION COMMITTEE (AIRPORT PAC)',
#    'total': 10000.0}],
#  [{'committee_id': 'C00478354',
#    'committee_name': 'BOEHNER FOR SPEAKER',
#    'count': 1,
#    'cycle': 2012,
#    'memo_count': 0,
#    'memo_total': 0.0,
#    'recipient_id': 'C00280008',
#    'recipient_name': 'AKERMAN SENTERFITT & EIDSON PA - PAC',
#    'total': 3500.0}],
#  [{'committee_id': 'C00183962',
#    'committee_name': 'CADENCE BANK PAC',
#    'count': 1,
#    'cycle': 2012,
#    'memo_count': 0,
#    'memo_total': 0.0,
#    'recipient_id': 'C00367094',
#    'recipient_name': 'ALABAMA BANKERS ASSOCIATION FEDERAL PAC AL BANKPAC',
#    'total': 2500.0},
#   {'committee_id': 'C00048181',
#    'committee_name': 'WISCONSIN BANKERS ASSOCIATION (WISBANKPAC)',
#    'count': 1,
#    'cycle': 2012,
#    'memo_count': 0,
#    'memo_total': 0.0,
#    'recipient_id': 'C00367094',
#    'recipient_name': 'ALABAMA BANKERS ASSOCIATION FEDERAL PAC AL BANKPAC',
#    'total': 20000.0},
#   {'committee_id': 'C00228858',
#    'committee_name': 'BANCTRUST FINANCIAL GROUP, INC. PAC',
#    'count': 2,
#    'cycle': 2012,
#    'memo_count': 0,
#    'memo_total': 0.0,
#    'recipient_id': 'C00367094',
#    'recipient_name': 'ALABAMA BANKERS ASSOCIATION FEDERAL PAC AL BANKPAC',
#    'total': 2000.0},
#   {'committee_id': 'C00432252',
#    'committee_name': 'REGIONS FINANCIAL CORPORATION POLITICAL ACTION COMMITTEE',
#    'count': 1,
#    'cycle': 2012,
#    'memo_count': 0,
#    'memo_total': 0.0,
#    'recipient_id': 'C00367094',
#    'recipient_name': 'ALABAMA BANKERS ASSOCIATION FEDERAL PAC AL BANKPAC',
#    'total': 5000.0},
#   {'committee_id': 'C00142596',
#    'committee_name': 'BBVA PAC OF THE PNC FINANCIAL SERVICES GROUP, INC.',
#    'count': 2,
#    'cycle': 2012,
#    'memo_count': 0,
#    'memo_total': 0.0,
#    'recipient_id': 'C00367094',
#    'recipient_name': 'ALABAMA BANKERS ASSOCIATION FEDERAL PAC AL BANKPAC',
#    'total': 10000.0}],
#  [{'committee_id': 'C00400705',
#    'committee_name': 'PUBLIX SUPER MARKETS, INC. ASSOCIATES POLITICAL ACTION COMMITTEE',
#    'count': 1,
#    'cycle': 2012,
#    'memo_count': 0,
#    'memo_total': 0.0,
#    'recipient_id': 'C00511014',
#    'recipient_name': 'ALABAMA RETAIL ASSOCIATION PAC',
#    'total': 5000.0}],
#  [{'committee_id': 'C00432401',
#    'committee_name': 'BEN NELSON 2012',
#    'count': 1,
#    'cycle': 2012,
#    'memo_count': 0,
#    'memo_total': 0.0,
#    'recipient_id': 'C00377333',
#    'recipient_name': 'ALBEMARLE CORPORATION POLITICAL ACTION COMMITTEE',
#    'total': 2500.0}],
#  [{'committee_id': 'C00067231',
#    'committee_name': 'HCA HEALTHCARE, INC. GOOD GOVERNMENT FUND',
#    'count': 1,
#    'cycle': 2012,
#    'memo_count': 0,
#    'memo_total': 0.0,
#    'recipient_id': 'C00017681',
#    'recipient_name': 'ALEXANDER AND BALDWIN INC FEDPAC',
#    'total': 5000.0}],
#  [{'committee_id': 'C00430686',
#    'committee_name': 'WEBB FOR SENATE',
#    'count': 1,
#    'cycle': 2012,
#    'memo_count': 0,
#    'memo_total': 0.0,
#    'recipient_id': 'C00335232',
#    'recipient_name': 'ALLEGHENY ENERGY INC. FEDERAL POLITICAL ACTION COMMITTEE',
#    'total': 1000.0}],
#  [{'committee_id': 'C00492108',
#    'committee_name': 'BRUNING FOR SENATE INCORPORATED',
#    'count': 1,
#    'cycle': 2012,
#    'memo_count': 0,
#    'memo_total': 0.0,
#    'recipient_id': 'C00330233',
#    'recipient_name': 'ALLIANCE COAL, LLC PAC',
#    'total': 5000.0}],
#  [{'committee_id': 'C00046474',
#    'committee_name': 'FORD MOTOR COMPANY CIVIC ACTION FUND',
#    'count': 1,
#    'cycle': 2012,
#    'memo_count': 0,
#    'memo_total': 0.0,
#    'recipient_id': 'C00516526',
#    'recipient_name': 'ALLIANCE OF AUTOMOBILE MANUFACTURERS INC POLITICAL ACTION COMMITTEE',
#    'total': 5000.0}],
#  [{'committee_id': 'C00398826',
#    'committee_name': 'SUN HEALTHCARE GROUP, INC. POLITICAL ACTION COMMITTEE D/B/A SUN HEALTHCARE P.A.C.',
#    'count': 1,
#    'cycle': 2012,
#    'memo_count': 0,
#    'memo_total': 0.0,
#    'recipient_id': 'C00432336',
#    'recipient_name': 'ALLIANCE FOR QUALITY NURSING HOME CARE INC. POLITICAL ACTION COMMITTEE (AQNHC PAC)',
#    'total': 5000.0},
#   {'committee_id': 'C00409516',
#    'committee_name': 'DIRECT SUPPLY, INC. PARTNERS PAC (DSI PARTNERS PAC)',
#    'count': 2,
#    'cycle': 2012,
#    'memo_count': 0,
#    'memo_total': 0.0,
#    'recipient_id': 'C00432336',
#    'recipient_name': 'ALLIANCE FOR QUALITY NURSING HOME CARE INC. POLITICAL ACTION COMMITTEE (AQNHC PAC)',
#    'total': 10000.0},
#   {'committee_id': 'C00242271',
#    'committee_name': 'KINDRED HEALTHCARE, INC. PAC',
#    'count': 1,
#    'cycle': 2012,
#    'memo_count': 0,
#    'memo_total': 0.0,
#    'recipient_id': 'C00432336',
#    'recipient_name': 'ALLIANCE FOR QUALITY NURSING HOME CARE INC. POLITICAL ACTION COMMITTEE (AQNHC PAC)',
#    'total': 5000.0},
#   {'committee_id': 'C00421735',
#    'committee_name': 'DIVERSICARE HEALTHCARE INC. POLITICAL ACTION COMMITTEE',
#    'count': 2,
#    'cycle': 2012,
#    'memo_count': 0,
#    'memo_total': 0.0,
#    'recipient_id': 'C00432336',
#    'recipient_name': 'ALLIANCE FOR QUALITY NURSING HOME CARE INC. POLITICAL ACTION COMMITTEE (AQNHC PAC)',
#    'total': 10000.0},
#   {'committee_id': 'C00260141',
#    'committee_name': 'HCR MANOR CARE PAC',
#    'count': 2,
#    'cycle': 2012,
#    'memo_count': 0,
#    'memo_total': 0.0,
#    'recipient_id': 'C00432336',
#    'recipient_name': 'ALLIANCE FOR QUALITY NURSING HOME CARE INC. POLITICAL ACTION COMMITTEE (AQNHC PAC)',
#    'total': 10000.0},
#   {'committee_id': 'C00467639',
#    'committee_name': 'MFA PAC',
#    'count': 2,
#    'cycle': 2012,
#    'memo_count': 0,
#    'memo_total': 0.0,
#    'recipient_id': 'C00432336',
#    'recipient_name': 'ALLIANCE FOR QUALITY NURSING HOME CARE INC. POLITICAL ACTION COMMITTEE (AQNHC PAC)',
#    'total': 10000.0}],
#  [{'committee_id': 'C00115527',
#    'committee_name': 'INTERNATIONAL ASSOCIATION OF HEAT AND FROST INSULATORS AND ALLIED WORKERS POLITICAL ACTION COMMITTEE',
#    'count': 1,
#    'cycle': 2012,
#    'memo_count': 0,
#    'memo_total': 0.0,
#    'recipient_id': 'C00436188',
#    'recipient_name': 'ALLIANCE FOR RETIRED AMERICANS POLITICAL ACTION FUND',
#    'total': 3000.0}],
#  [{'committee_id': 'C00391029',
#    'committee_name': 'JIM COSTA FOR CONGRESS',
#    'count': 0,
#    'cycle': 2012,
#    'memo_count': 1,
#    'memo_total': 937.0,
#    'recipient_id': 'C00119388',
#    'recipient_name': 'ALLIED GRAPE GROWERS PAC',
#    'total': 0.0}],
#  [{'committee_id': 'C00432401',
#    'committee_name': 'BEN NELSON 2012',
#    'count': 1,
#    'cycle': 2012,
#    'memo_count': 0,
#    'memo_total': 0.0,
#    'recipient_id': 'C00040253',
#    'recipient_name': 'ALLSTATE INSURANCE COMPANY PAC',
#    'total': 2000.0}],
#  [{'committee_id': 'C00291955',
#    'committee_name': "OLYMPIA'S LIST",
#    'count': 1,
#    'cycle': 2012,
#    'memo_count': 0,
#    'memo_total': 0.0,
#    'recipient_id': 'C00428094',
#    'recipient_name': 'INTEGRAPAC OF INTEGRA TELECOM HOLDINGS INC.',
#    'total': 500.0}],
#  [{'committee_id': 'C00155358',
#    'committee_name': 'A.T. MASSEY COAL COMPANY, INC., PAC',
#    'count': 2,
#    'cycle': 2012,
#    'memo_count': 0,
#    'memo_total': 0.0,
#    'recipient_id': 'C00348524',
#    'recipient_name': 'ALPHA NATURAL RESOURCES, INC. POLITICAL ACTION COMMITTEE',
#    'total': 3925.0}],
#  [{'committee_id': 'C00201871',
#    'committee_name': 'NATIONAL PORK PRODUCERS COUNCIL PORK PAC',
#    'count': 1,
#    'cycle': 2012,
#    'memo_count': 0,
#    'memo_total': 0.0,
#    'recipient_id': 'C00422832',
#    'recipient_name': 'ALSTOM PAC INC POLITICAL ACTION COMMITTEE',
#    'total': 2500.0},
#   {'committee_id': 'C00013342',
#    'committee_name': 'UNITED MINE WORKERS OF AMERICA - COAL MINERS POLITICAL ACTION COMMITTEE',
#    'count': 1,
#    'cycle': 2012,
#    'memo_count': 0,
#    'memo_total': 0.0,
#    'recipient_id': 'C00422832',
#    'recipient_name': 'ALSTOM PAC INC POLITICAL ACTION COMMITTEE',
#    'total': 1000.0},
#   {'committee_id': 'C00163048',
#    'committee_name': 'CAP-PAC SEPARATE SEGREGATED FUND OF THE NATIONAL COMMUNITY ACTION FOUNDATION INC',
#    'count': 1,
#    'cycle': 2012,
#    'memo_count': 0,
#    'memo_total': 0.0,
#    'recipient_id': 'C00422832',
#    'recipient_name': 'ALSTOM PAC INC POLITICAL ACTION COMMITTEE',
#    'total': 5000.0}],
#  [{'committee_id': 'C00291955',
#    'committee_name': "OLYMPIA'S LIST",
#    'count': 1,
#    'cycle': 2012,
#    'memo_count': 0,
#    'memo_total': 0.0,
#    'recipient_id': 'C00197863',
#    'recipient_name': 'CABLEVISION SYSTEMS CORPORATION POLITICAL ACTION COMMITTEE',
#    'total': 1000.0}],
#  [{'committee_id': 'C00432401',
#    'committee_name': 'BEN NELSON 2012',
#    'count': 1,
#    'cycle': 2012,
#    'memo_count': 0,
#    'memo_total': 0.0,
#    'recipient_id': 'C00089136',
#    'recipient_name': 'ALTRIA GROUP, INC. POLITICAL ACTION COMMITTEE (ALTRIAPAC)',
#    'total': 2000.0},
#   {'committee_id': 'C00270421',
#    'committee_name': 'STE. MICHELLE WINE ESTATES LTD. POLITICAL ACTION COMMITTEE',
#    'count': 2,
#    'cycle': 2012,
#    'memo_count': 0,
#    'memo_total': 0.0,
#    'recipient_id': 'C00089136',
#    'recipient_name': 'ALTRIA GROUP, INC. POLITICAL ACTION COMMITTEE (ALTRIAPAC)',
#    'total': 1250.0},
#   {'committee_id': 'C00164418',
#    'committee_name': 'NEW JERSEY REPUBLICAN STATE COMMITTEE',
#    'count': 1,
#    'cycle': 2012,
#    'memo_count': 0,
#    'memo_total': 0.0,
#    'recipient_id': 'C00089136',
#    'recipient_name': 'ALTRIA GROUP, INC. POLITICAL ACTION COMMITTEE (ALTRIAPAC)',
#    'total': 5000.0}],
#  [{'committee_id': 'C00431171',
#    'committee_name': 'ROMNEY FOR PRESIDENT, INC.',
#    'count': 2,
#    'cycle': 2012,
#    'memo_count': 0,
#    'memo_total': 0.0,
#    'recipient_id': 'C00489948',
#    'recipient_name': 'ALVAREZ & MARSAL HOLDINGS, LLC PAC',
#    'total': 5000.0}],
#  [{'committee_id': 'C00329292',
#    'committee_name': 'EDUCATION & OPPORTUNITY FUND II',
#    'count': 1,
#    'cycle': 2012,
#    'memo_count': 0,
#    'memo_total': 0.0,
#    'recipient_id': 'C00032995',
#    'recipient_name': 'AMALGAMATED TRANSIT UNION - COPE',
#    'total': 1000.0}],
#  [{'committee_id': 'C00204370',
#    'committee_name': 'FRIENDS FOR HARRY REID',
#    'count': 1,
#    'cycle': 2012,
#    'memo_count': 0,
#    'memo_total': 0.0,
#    'recipient_id': 'C00424788',
#    'recipient_name': 'AMBULATORY SURGERY CENTER ASSOCIATION PAC (ASCAPAC)',
#    'total': 2500.0},
#   {'committee_id': 'C00484410',
#    'committee_name': 'AMSURG CORP. GOOD GOVERNMENT FUND',
#    'count': 1,
#    'cycle': 2012,
#    'memo_count': 0,
#    'memo_total': 0.0,
#    'recipient_id': 'C00424788',
#    'recipient_name': 'AMBULATORY SURGERY CENTER ASSOCIATION PAC (ASCAPAC)',
#    'total': 5000.0}],
#  [{'committee_id': 'C00431304',
#    'committee_name': 'GET STUFF DONE',
#    'count': 2,
#    'cycle': 2012,
#    'memo_count': 0,
#    'memo_total': 0.0,
#    'recipient_id': 'C00206136',
#    'recipient_name': 'AMEREN FEDERAL POLITICAL ACTION COMMITTEE (AMERENFED PAC)',
#    'total': 7000.0}],
#  [{'committee_id': 'C00291955',
#    'committee_name': "OLYMPIA'S LIST",
#    'count': 1,
#    'cycle': 2012,
#    'memo_count': 0,
#    'memo_total': 0.0,
#    'recipient_id': 'C00435933',
#    'recipient_name': 'AMERICAN ACADEMY OF NEUROLOGY BRAINPAC',
#    'total': 400.0}],
#  [{'committee_id': 'C00432401',
#    'committee_name': 'BEN NELSON 2012',
#    'count': 1,
#    'cycle': 2012,
#    'memo_count': 0,
#    'memo_total': 0.0,
#    'recipient_id': 'C00196246',
#    'recipient_name': 'AMERICAN ACADEMY OF OPHTHALMOLOGY INC POLITICAL COMMITTEE (OPHTHPAC)',
#    'total': 1000.0},
#   {'committee_id': 'C00473132',
#    'committee_name': 'MCKINLEY FOR CONGRESS',
#    'count': 1,
#    'cycle': 2012,
#    'memo_count': 0,
#    'memo_total': 0.0,
#    'recipient_id': 'C00196246',
#    'recipient_name': 'AMERICAN ACADEMY OF OPHTHALMOLOGY INC POLITICAL COMMITTEE (OPHTHPAC)',
#    'total': 1000.0},
#   {'committee_id': 'C00280206',
#    'committee_name': 'CITIZENS FOR ARLEN SPECTER',
#    'count': 1,
#    'cycle': 2012,
#    'memo_count': 0,
#    'memo_total': 0.0,
#    'recipient_id': 'C00196246',
#    'recipient_name': 'AMERICAN ACADEMY OF OPHTHALMOLOGY INC POLITICAL COMMITTEE (OPHTHPAC)',
#    'total': -500.0}],
#  [{'committee_id': 'C00411348',
#    'committee_name': 'SISTER-ACT COMMITTEE',
#    'count': 0,
#    'cycle': 2012,
#    'memo_count': 1,
#    'memo_total': 1000.0,
#    'recipient_id': 'C00365965',
#    'recipient_name': 'AMERICAN ACADEMY OF PEDIATRIC DENTISTRY POLITICAL ACTION COMMITTEE',
#    'total': 0.0},
#   {'committee_id': 'C00432732',
#    'committee_name': 'DAN INOUYE FOR US SENATE',
#    'count': 1,
#    'cycle': 2012,
#    'memo_count': 0,
#    'memo_total': 0.0,
#    'recipient_id': 'C00365965',
#    'recipient_name': 'AMERICAN ACADEMY OF PEDIATRIC DENTISTRY POLITICAL ACTION COMMITTEE',
#    'total': 5000.0}],
#  [{'committee_id': 'C00350785',
#    'committee_name': 'ILLINOIS LINCOLN PAC',
#    'count': 1,
#    'cycle': 2012,
#    'memo_count': 0,
#    'memo_total': 0.0,
#    'recipient_id': 'C00107300',
#    'recipient_name': 'AMERICAN AIRLINES POLITICAL ACTION COMMITTEE',
#    'total': 5000.0}],
#  [{'committee_id': 'C00202754',
#    'committee_name': 'FRIENDS OF KENT CONRAD',
#    'count': 1,
#    'cycle': 2012,
#    'memo_count': 0,
#    'memo_total': 0.0,
#    'recipient_id': 'C00168070',
#    'recipient_name': 'AMERICAN AMBULANCE ASSOCIATION FEDERAL PAC (AKA AMBU-PAC)',
#    'total': 1000.0},
#   {'committee_id': 'C00400317',
#    'committee_name': 'FULTON FINANCIAL CORPORATION PAC',
#    'count': 1,
#    'cycle': 2012,
#    'memo_count': 0,
#    'memo_total': 0.0,
#    'recipient_id': 'C00168070',
#    'recipient_name': 'AMERICAN AMBULANCE ASSOCIATION FEDERAL PAC (AKA AMBU-PAC)',
#    'total': 5000.0}],
#  [{'committee_id': 'C00388132',
#    'committee_name': 'PRIDE MOBILITY PRODUCTS CORP PAC',
#    'count': 1,
#    'cycle': 2012,
#    'memo_count': 0,
#    'memo_total': 0.0,
#    'recipient_id': 'C00357129',
#    'recipient_name': 'AMERICAN ASSOCIATION FOR HOMECARE POLITICAL ACTION COMMITTEE (AAHOMECARE PAC)',
#    'total': 1000.0},
#   {'committee_id': 'C00240218',
#    'committee_name': 'APRIA HEALTHCARE LLC POLITICAL ACTION COMMITTEE',
#    'count': 1,
#    'cycle': 2012,
#    'memo_count': 0,
#    'memo_total': 0.0,
#    'recipient_id': 'C00357129',
#    'recipient_name': 'AMERICAN ASSOCIATION FOR HOMECARE POLITICAL ACTION COMMITTEE (AAHOMECARE PAC)',
#    'total': 5000.0},
#   {'committee_id': 'C00249896',
#    'committee_name': 'INVACARE CORPORATION POLITICAL ACTION COMMITTEE AKA INVA PAC',
#    'count': 1,
#    'cycle': 2012,
#    'memo_count': 0,
#    'memo_total': 0.0,
#    'recipient_id': 'C00357129',
#    'recipient_name': 'AMERICAN ASSOCIATION FOR HOMECARE POLITICAL ACTION COMMITTEE (AAHOMECARE PAC)',
#    'total': 2500.0},
#   {'committee_id': 'C00436097',
#    'committee_name': 'SUNRISE MEDICAL (US) LLC POLITICAL ACTION COMMITTEE',
#    'count': 1,
#    'cycle': 2012,
#    'memo_count': 0,
#    'memo_total': 0.0,
#    'recipient_id': 'C00357129',
#    'recipient_name': 'AMERICAN ASSOCIATION FOR HOMECARE POLITICAL ACTION COMMITTEE (AAHOMECARE PAC)',
#    'total': 1500.0},
#   {'committee_id': 'C00448530',
#    'committee_name': 'THE ROHO GROUP, INC. PAC (ROHO PAC)',
#    'count': 1,
#    'cycle': 2012,
#    'memo_count': 0,
#    'memo_total': 0.0,
#    'recipient_id': 'C00357129',
#    'recipient_name': 'AMERICAN ASSOCIATION FOR HOMECARE POLITICAL ACTION COMMITTEE (AAHOMECARE PAC)',
#    'total': 1500.0}],
#  [{'committee_id': 'C00388694',
#    'committee_name': 'PRIORITY PAC',
#    'count': 1,
#    'cycle': 2012,
#    'memo_count': 0,
#    'memo_total': 0.0,
#    'recipient_id': 'C00024521',
#    'recipient_name': 'AMERICAN ASSOCIATION FOR JUSTICE POLITICAL ACTION COMMITTEE (AAJ PAC)',
#    'total': -5000.0},
#   {'committee_id': 'C00275909',
#    'committee_name': 'ROBINS KAPLAN PAC',
#    'count': 6,
#    'cycle': 2012,
#    'memo_count': 0,
#    'memo_total': 0.0,
#    'recipient_id': 'C00024521',
#    'recipient_name': 'AMERICAN ASSOCIATION FOR JUSTICE POLITICAL ACTION COMMITTEE (AAJ PAC)',
#    'total': 12500.0}],
#  [{'committee_id': 'C00202754',
#    'committee_name': 'FRIENDS OF KENT CONRAD',
#    'count': 1,
#    'cycle': 2012,
#    'memo_count': 0,
#    'memo_total': 0.0,
#    'recipient_id': 'C00172833',
#    'recipient_name': 'AMERICAN ASSOCIATION OF CROP INSURERS POLITICAL ACTION COMMITTEE (AACI PAC)',
#    'total': 2500.0},
#   {'committee_id': 'C00432401',
#    'committee_name': 'BEN NELSON 2012',
#    'count': 1,
#    'cycle': 2012,
#    'memo_count': 0,
#    'memo_total': 0.0,
#    'recipient_id': 'C00172833',
#    'recipient_name': 'AMERICAN ASSOCIATION OF CROP INSURERS POLITICAL ACTION COMMITTEE (AACI PAC)',
#    'total': 5000.0},
#   {'committee_id': 'C00457234',
#    'committee_name': 'MARSH & MCLENNAN COMPANIES, INC. POLITICAL ACTION COMMITTEE (MMCPAC)',
#    'count': 1,
#    'cycle': 2012,
#    'memo_count': 0,
#    'memo_total': 0.0,
#    'recipient_id': 'C00172833',
#    'recipient_name': 'AMERICAN ASSOCIATION OF CROP INSURERS POLITICAL ACTION COMMITTEE (AACI PAC)',
#    'total': 2000.0},
#   {'committee_id': 'C00279505',
#    'committee_name': 'RAIN AND HAIL INSURANCE SOCIETY POLITICAL ACTION COMMITTEE',
#    'count': 1,
#    'cycle': 2012,
#    'memo_count': 0,
#    'memo_total': 0.0,
#    'recipient_id': 'C00172833',
#    'recipient_name': 'AMERICAN ASSOCIATION OF CROP INSURERS POLITICAL ACTION COMMITTEE (AACI PAC)',
#    'total': 5000.0},
#   {'committee_id': 'C00523696',
#    'committee_name': 'ARMTECH CROP INSURANCE PAC',
#    'count': 1,
#    'cycle': 2012,
#    'memo_count': 0,
#    'memo_total': 0.0,
#    'recipient_id': 'C00172833',
#    'recipient_name': 'AMERICAN ASSOCIATION OF CROP INSURERS POLITICAL ACTION COMMITTEE (AACI PAC)',
#    'total': 1500.0}],
#  [{'committee_id': 'C00104752',
#    'committee_name': 'HATCH ELECTION COMMITTEE INC',
#    'count': 1,
#    'cycle': 2012,
#    'memo_count': 0,
#    'memo_total': 0.0,
#    'recipient_id': 'C00173153',
#    'recipient_name': 'AMERICAN ASSOCIATION OF NURSE ANESTHETISTS SEPARATE SEGREGATED FUND (CRNA-PAC)',
#    'total': 1500.0},
#   {'committee_id': 'C00202754',
#    'committee_name': 'FRIENDS OF KENT CONRAD',
#    'count': 1,
#    'cycle': 2012,
#    'memo_count': 0,
#    'memo_total': 0.0,
#    'recipient_id': 'C00173153',
#    'recipient_name': 'AMERICAN ASSOCIATION OF NURSE ANESTHETISTS SEPARATE SEGREGATED FUND (CRNA-PAC)',
#    'total': 3500.0},
#   {'committee_id': 'C00432401',
#    'committee_name': 'BEN NELSON 2012',
#    'count': 1,
#    'cycle': 2012,
#    'memo_count': 0,
#    'memo_total': 0.0,
#    'recipient_id': 'C00173153',
#    'recipient_name': 'AMERICAN ASSOCIATION OF NURSE ANESTHETISTS SEPARATE SEGREGATED FUND (CRNA-PAC)',
#    'total': 2000.0}],
#  [{'committee_id': 'C00349217',
#    'committee_name': 'CARPER FOR SENATE',
#    'count': 1,
#    'cycle': 2012,
#    'memo_count': 0,
#    'memo_total': 0.0,
#    'recipient_id': 'C00293910',
#    'recipient_name': 'AMERICAN ASSOCIATION OF ORTHODONTISTS POLITICAL ACTION COMMITTEE',
#    'total': 1000.0},
#   {'committee_id': 'C00202754',
#    'committee_name': 'FRIENDS OF KENT CONRAD',
#    'count': 1,
#    'cycle': 2012,
#    'memo_count': 0,
#    'memo_total': 0.0,
#    'recipient_id': 'C00293910',
#    'recipient_name': 'AMERICAN ASSOCIATION OF ORTHODONTISTS POLITICAL ACTION COMMITTEE',
#    'total': 2500.0},
#   {'committee_id': 'C00411587',
#    'committee_name': 'BEN CARDIN FOR SENATE, INC.',
#    'count': 1,
#    'cycle': 2012,
#    'memo_count': 0,
#    'memo_total': 0.0,
#    'recipient_id': 'C00293910',
#    'recipient_name': 'AMERICAN ASSOCIATION OF ORTHODONTISTS POLITICAL ACTION COMMITTEE',
#    'total': 5000.0},
#   {'committee_id': 'C00291955',
#    'committee_name': "OLYMPIA'S LIST",
#    'count': 1,
#    'cycle': 2012,
#    'memo_count': 0,
#    'memo_total': 0.0,
#    'recipient_id': 'C00293910',
#    'recipient_name': 'AMERICAN ASSOCIATION OF ORTHODONTISTS POLITICAL ACTION COMMITTEE',
#    'total': 2000.0}],
#  [{'committee_id': 'C00033555',
#    'committee_name': 'FLOWERS FOODS, INC. POLITICAL ACTION COMMITTEE',
#    'count': 2,
#    'cycle': 2012,
#    'memo_count': 0,
#    'memo_total': 0.0,
#    'recipient_id': 'C00016386',
#    'recipient_name': 'AMERICAN BAKERS ASSOCIATION AMERICAN BAKERS POLITICAL ACTION COMMITTEE',
#    'total': 10000.0},
#   {'committee_id': 'C00099754',
#    'committee_name': 'BAKEPAC - THE POLITICAL ACTION COMMITTEE OF THE INDEPENDENT BAKERS ASSOCIATION',
#    'count': 1,
#    'cycle': 2012,
#    'memo_count': 0,
#    'memo_total': 0.0,
#    'recipient_id': 'C00016386',
#    'recipient_name': 'AMERICAN BAKERS ASSOCIATION AMERICAN BAKERS POLITICAL ACTION COMMITTEE',
#    'total': 600.0},
#   {'committee_id': 'C00415166',
#    'committee_name': 'CAMPBELL SOUP COMPANY PAC CAMPBELL PAC',
#    'count': 1,
#    'cycle': 2012,
#    'memo_count': 0,
#    'memo_total': 0.0,
#    'recipient_id': 'C00016386',
#    'recipient_name': 'AMERICAN BAKERS ASSOCIATION AMERICAN BAKERS POLITICAL ACTION COMMITTEE',
#    'total': 4000.0}],
#  [{'committee_id': 'C00094896',
#    'committee_name': 'PENNSYLVANIA BANKERS ASSOCIATION PUBLIC AFFAIRS COMMITTEE (FEDERAL)',
#    'count': 4,
#    'cycle': 2012,
#    'memo_count': 0,
#    'memo_total': 0.0,
#    'recipient_id': 'C00004275',
#    'recipient_name': 'AMERICAN BANKERS ASSOCIATION PAC (BANKPAC)',
#    'total': 160531.0},
#   {'committee_id': 'C00033423',
#    'committee_name': 'HSBC NORTH AMERICA FEDERAL, STATE AND LOCAL POLITICAL ACTION COMMITTEE (HSBC COMBINED PAC)',
#    'count': 2,
#    'cycle': 2012,
#    'memo_count': 0,
#    'memo_total': 0.0,
#    'recipient_id': 'C00004275',
#    'recipient_name': 'AMERICAN BANKERS ASSOCIATION PAC (BANKPAC)',
#    'total': 5000.0},
#   {'committee_id': 'C00326595',
#    'committee_name': 'CAPITAL ONE FINANCIAL CORP. ASSOC. POLITICAL FUND',
#    'count': 1,
#    'cycle': 2012,
#    'memo_count': 0,
#    'memo_total': 0.0,
#    'recipient_id': 'C00004275',
#    'recipient_name': 'AMERICAN BANKERS ASSOCIATION PAC (BANKPAC)',
#    'total': 5000.0},
#   {'committee_id': 'C00328278',
#    'committee_name': 'ARKANSAS BANKERS ASSOCIATION PAC INC',
#    'count': 2,
#    'cycle': 2012,
#    'memo_count': 0,
#    'memo_total': 0.0,
#    'recipient_id': 'C00004275',
#    'recipient_name': 'AMERICAN BANKERS ASSOCIATION PAC (BANKPAC)',
#    'total': 60000.0},
#   {'committee_id': 'C00172494',
#    'committee_name': 'MISSOURI BANKERS ASSOCIATION FEDERAL PAC',
#    'count': 4,
#    'cycle': 2012,
#    'memo_count': 0,
#    'memo_total': 0.0,
#    'recipient_id': 'C00004275',
#    'recipient_name': 'AMERICAN BANKERS ASSOCIATION PAC (BANKPAC)',
#    'total': 127250.0},
#   {'committee_id': 'C00101626',
#    'committee_name': 'VIRGINIA BANKERS ASSOCIATION FEDERAL PAC',
#    'count': 2,
#    'cycle': 2012,
#    'memo_count': 0,
#    'memo_total': 0.0,
#    'recipient_id': 'C00004275',
#    'recipient_name': 'AMERICAN BANKERS ASSOCIATION PAC (BANKPAC)',
#    'total': 210000.0},
#   {'committee_id': 'C00102731',
#    'committee_name': 'COLORADO BANKERS ASSOCIATION POLITICAL ACTION COMMITTEE',
#    'count': 2,
#    'cycle': 2012,
#    'memo_count': 0,
#    'memo_total': 0.0,
#    'recipient_id': 'C00004275',
#    'recipient_name': 'AMERICAN BANKERS ASSOCIATION PAC (BANKPAC)',
#    'total': 57866.0},
#   {'committee_id': 'C00334193',
#    'committee_name': 'FIRST CITIZENS BANCSHARES INC POLITICAL ACTION COMMITTEE (FIRST CITIZENS BANCSHARES PAC)',
#    'count': 1,
#    'cycle': 2012,
#    'memo_count': 0,
#    'memo_total': 0.0,
#    'recipient_id': 'C00004275',
#    'recipient_name': 'AMERICAN BANKERS ASSOCIATION PAC (BANKPAC)',
#    'total': 1500.0},
#   {'committee_id': 'C00035253',
#    'committee_name': 'OREGON BANKERS ASSOCIATION POLITICAL ACTION COMMITTEE',
#    'count': 2,
#    'cycle': 2012,
#    'memo_count': 0,
#    'memo_total': 0.0,
#    'recipient_id': 'C00004275',
#    'recipient_name': 'AMERICAN BANKERS ASSOCIATION PAC (BANKPAC)',
#    'total': 53000.0},
#   {'committee_id': 'C00178012',
#    'committee_name': "PEOPLE'S BANK FEDERAL POLITICAL ACTION COMMITTEE",
#    'count': 1,
#    'cycle': 2012,
#    'memo_count': 0,
#    'memo_total': 0.0,
#    'recipient_id': 'C00004275',
#    'recipient_name': 'AMERICAN BANKERS ASSOCIATION PAC (BANKPAC)',
#    'total': 5000.0},
#   {'committee_id': 'C00103861',
#    'committee_name': 'SOUTH CAROLINA BANKERS POLITICAL ACTION COMMITTE',
#    'count': 2,
#    'cycle': 2012,
#    'memo_count': 0,
#    'memo_total': 0.0,
#    'recipient_id': 'C00004275',
#    'recipient_name': 'AMERICAN BANKERS ASSOCIATION PAC (BANKPAC)',
#    'total': 20960.0},
#   {'committee_id': 'C00106716',
#    'committee_name': 'MISSISSIPPI BANKERS POLITICAL ACTION COMMITTEE-FEDERAL FUND',
#    'count': 4,
#    'cycle': 2012,
#    'memo_count': 0,
#    'memo_total': 0.0,
#    'recipient_id': 'C00004275',
#    'recipient_name': 'AMERICAN BANKERS ASSOCIATION PAC (BANKPAC)',
#    'total': 34500.0},
#   {'committee_id': 'C00194191',
#    'committee_name': 'NBSC PAC',
#    'count': 1,
#    'cycle': 2012,
#    'memo_count': 0,
#    'memo_total': 0.0,
#    'recipient_id': 'C00004275',
#    'recipient_name': 'AMERICAN BANKERS ASSOCIATION PAC (BANKPAC)',
#    'total': 1500.0},
#   {'committee_id': 'C00039941',
#    'committee_name': 'ARIZONA BANKERS ASSOCIATION POLITICAL ACTION COMMITTEE',
#    'count': 2,
#    'cycle': 2012,
#    'memo_count': 0,
#    'memo_total': 0.0,
#    'recipient_id': 'C00004275',
#    'recipient_name': 'AMERICAN BANKERS ASSOCIATION PAC (BANKPAC)',
#    'total': 26000.0},
#   {'committee_id': 'C00196444',
#    'committee_name': 'TEXAS BANKERS ASSOCIATION-BANKERS POLITICAL ACTION COMMITTEE',
#    'count': 4,
#    'cycle': 2012,
#    'memo_count': 0,
#    'memo_total': 0.0,
#    'recipient_id': 'C00004275',
#    'recipient_name': 'AMERICAN BANKERS ASSOCIATION PAC (BANKPAC)',
#    'total': 244600.0},
#   {'committee_id': 'C00197095',
#    'committee_name': 'THE NORTHWESTERN MUTUAL LIFE INSURANCE CO. FEDERAL PAC (NORTHWESTERN MUTUAL FEDERAL PAC)',
#    'count': 2,
#    'cycle': 2012,
#    'memo_count': 0,
#    'memo_total': 0.0,
#    'recipient_id': 'C00004275',
#    'recipient_name': 'AMERICAN BANKERS ASSOCIATION PAC (BANKPAC)',
#    'total': 6000.0},
#   {'committee_id': 'C00108605',
#    'committee_name': 'CONNECTICUT BANKERS ASSOCIATION POLITICAL ACTION COMMITTEE (CBA FED PAC)',
#    'count': 2,
#    'cycle': 2012,
#    'memo_count': 0,
#    'memo_total': 0.0,
#    'recipient_id': 'C00004275',
#    'recipient_name': 'AMERICAN BANKERS ASSOCIATION PAC (BANKPAC)',
#    'total': 30000.0},
#   {'committee_id': 'C00109678',
#    'committee_name': 'NEW HAMPSHIRE BANKERS ASSOCIATION FEDERAL BANKPAC',
#    'count': 3,
#    'cycle': 2012,
#    'memo_count': 0,
#    'memo_total': 0.0,
#    'recipient_id': 'C00004275',
#    'recipient_name': 'AMERICAN BANKERS ASSOCIATION PAC (BANKPAC)',
#    'total': 22433.0},
#   {'committee_id': 'C00366633',
#    'committee_name': 'STAR FINANCIAL BANK PAC',
#    'count': 2,
#    'cycle': 2012,
#    'memo_count': 0,
#    'memo_total': 0.0,
#    'recipient_id': 'C00004275',
#    'recipient_name': 'AMERICAN BANKERS ASSOCIATION PAC (BANKPAC)',
#    'total': 2000.0},
#   {'committee_id': 'C00367094',
#    'committee_name': 'ALABAMA BANKERS ASSOCIATION, INC. PAC',
#    'count': 3,
#    'cycle': 2012,
#    'memo_count': 0,
#    'memo_total': 0.0,
#    'recipient_id': 'C00004275',
#    'recipient_name': 'AMERICAN BANKERS ASSOCIATION PAC (BANKPAC)',
#    'total': 45147.0},
#   {'committee_id': 'C00374371',
#    'committee_name': 'UTAH BANKERS ASSOCIATION ACTION PAC',
#    'count': 4,
#    'cycle': 2012,
#    'memo_count': 0,
#    'memo_total': 0.0,
#    'recipient_id': 'C00004275',
#    'recipient_name': 'AMERICAN BANKERS ASSOCIATION PAC (BANKPAC)',
#    'total': 36300.0},
#   {'committee_id': 'C00114090',
#    'committee_name': 'WASHINGTON BANKERS ASSOCIATION POLITICAL ACTION COMMITTEE',
#    'count': 3,
#    'cycle': 2012,
#    'memo_count': 0,
#    'memo_total': 0.0,
#    'recipient_id': 'C00004275',
#    'recipient_name': 'AMERICAN BANKERS ASSOCIATION PAC (BANKPAC)',
#    'total': 39000.0},
#   {'committee_id': 'C00048181',
#    'committee_name': 'WISCONSIN BANKERS ASSOCIATION (WISBANKPAC)',
#    'count': 3,
#    'cycle': 2012,
#    'memo_count': 0,
#    'memo_total': 0.0,
#    'recipient_id': 'C00004275',
#    'recipient_name': 'AMERICAN BANKERS ASSOCIATION PAC (BANKPAC)',
#    'total': 54500.0},
#   {'committee_id': 'C00114447',
#    'committee_name': 'TENNESSEE BANKERS ASSOCIATION FEDERAL POLITICAL ACTION COMMITTEE',
#    'count': 2,
#    'cycle': 2012,
#    'memo_count': 0,
#    'memo_total': 0.0,
#    'recipient_id': 'C00004275',
#    'recipient_name': 'AMERICAN BANKERS ASSOCIATION PAC (BANKPAC)',
#    'total': 85961.0},
#   {'committee_id': 'C00115832',
#    'committee_name': 'INDIANA BANKERS ASSOCIATION INDIANA BANKPAC - FEDERAL',
#    'count': 5,
#    'cycle': 2012,
#    'memo_count': 0,
#    'memo_total': 0.0,
#    'recipient_id': 'C00004275',
#    'recipient_name': 'AMERICAN BANKERS ASSOCIATION PAC (BANKPAC)',
#    'total': 56000.0},
#   {'committee_id': 'C00056523',
#    'committee_name': 'IDAHO BANKERS POLITICAL ACTION COMMITTEE',
#    'count': 3,
#    'cycle': 2012,
#    'memo_count': 0,
#    'memo_total': 0.0,
#    'recipient_id': 'C00004275',
#    'recipient_name': 'AMERICAN BANKERS ASSOCIATION PAC (BANKPAC)',
#    'total': 35294.0},
#   {'committee_id': 'C00116988',
#    'committee_name': 'SAVINGS ASSOCIATIONS VOLUNTARY POLITICAL ACTION COMMITTEE-WASHINGTON FINANCIAL LEAGUE',
#    'count': 1,
#    'cycle': 2012,
#    'memo_count': 0,
#    'memo_total': 0.0,
#    'recipient_id': 'C00004275',
#    'recipient_name': 'AMERICAN BANKERS ASSOCIATION PAC (BANKPAC)',
#    'total': 5000.0},
#   {'committee_id': 'C00221507',
#    'committee_name': 'MASSACHUSETTS BANKERS PAC-FEDERAL FUND',
#    'count': 4,
#    'cycle': 2012,
#    'memo_count': 0,
#    'memo_total': 0.0,
#    'recipient_id': 'C00004275',
#    'recipient_name': 'AMERICAN BANKERS ASSOCIATION PAC (BANKPAC)',
#    'total': 44000.0},
#   {'committee_id': 'C00117911',
#    'committee_name': 'NORTH DAKOTA BANKERS ASSOCIATION POLITICAL ACTION COMMITTEE',
#    'count': 5,
#    'cycle': 2012,
#    'memo_count': 0,
#    'memo_total': 0.0,
#    'recipient_id': 'C00004275',
#    'recipient_name': 'AMERICAN BANKERS ASSOCIATION PAC (BANKPAC)',
#    'total': 29000.0},
#   {'committee_id': 'C00062836',
#    'committee_name': 'KENTUCKY BANKERS ASSOCIATION POLITICAL ACTION COMMITTEE',
#    'count': 2,
#    'cycle': 2012,
#    'memo_count': 0,
#    'memo_total': 0.0,
#    'recipient_id': 'C00004275',
#    'recipient_name': 'AMERICAN BANKERS ASSOCIATION PAC (BANKPAC)',
#    'total': 63909.0},
#   {'committee_id': 'C00011627',
#    'committee_name': 'MINNESOTA BANKERS POLITICAL ACTION COMMITTEE',
#    'count': 1,
#    'cycle': 2012,
#    'memo_count': 0,
#    'memo_total': 0.0,
#    'recipient_id': 'C00004275',
#    'recipient_name': 'AMERICAN BANKERS ASSOCIATION PAC (BANKPAC)',
#    'total': 38436.0},
#   {'committee_id': 'C00012484',
#    'committee_name': 'FLORIDA BANKERS ASSOCIATION POLITICAL ACTION COMMITTEE',
#    'count': 2,
#    'cycle': 2012,
#    'memo_count': 0,
#    'memo_total': 0.0,
#    'recipient_id': 'C00004275',
#    'recipient_name': 'AMERICAN BANKERS ASSOCIATION PAC (BANKPAC)',
#    'total': 115000.0},
#   {'committee_id': 'C00127910',
#    'committee_name': 'DELAWARE BANKERS ASSOCIATION DELBANKPAC - F FUND',
#    'count': 5,
#    'cycle': 2012,
#    'memo_count': 0,
#    'memo_total': 0.0,
#    'recipient_id': 'C00004275',
#    'recipient_name': 'AMERICAN BANKERS ASSOCIATION PAC (BANKPAC)',
#    'total': 13600.0},
#   {'committee_id': 'C00128512',
#    'committee_name': 'JPMORGAN CHASE & CO. PAC',
#    'count': 2,
#    'cycle': 2012,
#    'memo_count': 0,
#    'memo_total': 0.0,
#    'recipient_id': 'C00004275',
#    'recipient_name': 'AMERICAN BANKERS ASSOCIATION PAC (BANKPAC)',
#    'total': 10000.0},
#   {'committee_id': 'C00128918',
#    'committee_name': 'PRINCIPAL LIFE INSURANCE COMPANY POLITICAL ACTION COMMITTEE',
#    'count': 2,
#    'cycle': 2012,
#    'memo_count': 0,
#    'memo_total': 0.0,
#    'recipient_id': 'C00004275',
#    'recipient_name': 'AMERICAN BANKERS ASSOCIATION PAC (BANKPAC)',
#    'total': 6000.0},
#   {'committee_id': 'C00074799',
#    'committee_name': 'OHIO BANKERS LEAGUE POLITICAL ACTION COMMITTEE (FEDERAL)',
#    'count': 7,
#    'cycle': 2012,
#    'memo_count': 0,
#    'memo_total': 0.0,
#    'recipient_id': 'C00004275',
#    'recipient_name': 'AMERICAN BANKERS ASSOCIATION PAC (BANKPAC)',
#    'total': 82000.0},
#   {'committee_id': 'C00130385',
#    'committee_name': 'CENTRAL PACIFIC BANK FED PAC AKA; CPB PAC-FED',
#    'count': 1,
#    'cycle': 2012,
#    'memo_count': 0,
#    'memo_total': 0.0,
#    'recipient_id': 'C00004275',
#    'recipient_name': 'AMERICAN BANKERS ASSOCIATION PAC (BANKPAC)',
#    'total': 2630.0},
#   {'committee_id': 'C00414508',
#    'committee_name': 'MB FINANCIAL INC POLITICAL ACTION COMMITTEE',
#    'count': 1,
#    'cycle': 2012,
#    'memo_count': 0,
#    'memo_total': 0.0,
#    'recipient_id': 'C00004275',
#    'recipient_name': 'AMERICAN BANKERS ASSOCIATION PAC (BANKPAC)',
#    'total': 5000.0},
#   {'committee_id': 'C00018036',
# ...
#    'recipient_id': 'C00186288',
#    'recipient_name': 'VERIZON COMMUNICATIONS INC./VERIZON WIRELESS GOOD GOVERNMENT CLUB (VERIZON/VERIZON WIRELESS PAC)',
#    'total': 2000.0},
#   {'committee_id': 'C00476374',
#    'committee_name': 'HOOSIERS FOR CONSERVATIVE GOVERNMENT',
#    'count': 1,
#    'cycle': 2012,
#    'memo_count': 0,
#    'memo_total': 0.0,
#    'recipient_id': 'C00186288',
#    'recipient_name': 'VERIZON COMMUNICATIONS INC./VERIZON WIRELESS GOOD GOVERNMENT CLUB (VERIZON/VERIZON WIRELESS PAC)',
#    'total': 1000.0},
#   {'committee_id': 'C00291955',
#    'committee_name': "OLYMPIA'S LIST",
#    'count': 1,
#    'cycle': 2012,
#    'memo_count': 0,
#    'memo_total': 0.0,
#    'recipient_id': 'C00186288',
#    'recipient_name': 'VERIZON COMMUNICATIONS INC./VERIZON WIRELESS GOOD GOVERNMENT CLUB (VERIZON/VERIZON WIRELESS PAC)',
#    'total': 5000.0}],
#  [{'committee_id': 'C00369470',
#    'committee_name': 'GEOFF DAVIS FOR CONGRESS',
#    'count': 1,
#    'cycle': 2012,
#    'memo_count': 0,
#    'memo_total': 0.0,
#    'recipient_id': 'C00521393',
#    'recipient_name': 'VETERANS FOR NATIONAL SECURITY FOUNDATION REPUBLICAN PAC; THE',
#    'total': 2000.0}],
#  [{'committee_id': 'C00334193',
#    'committee_name': 'FIRST CITIZENS BANCSHARES INC POLITICAL ACTION COMMITTEE (FIRST CITIZENS BANCSHARES PAC)',
#    'count': 2,
#    'cycle': 2012,
#    'memo_count': 0,
#    'memo_total': 0.0,
#    'recipient_id': 'C00101626',
#    'recipient_name': 'VIRGINIA BANKERS ASSOCIATION FEDERAL PAC',
#    'total': 2000.0},
#   {'committee_id': 'C00400317',
#    'committee_name': 'FULTON FINANCIAL CORPORATION PAC',
#    'count': 3,
#    'cycle': 2012,
#    'memo_count': 0,
#    'memo_total': 0.0,
#    'recipient_id': 'C00101626',
#    'recipient_name': 'VIRGINIA BANKERS ASSOCIATION FEDERAL PAC',
#    'total': 5500.0}],
#  [{'committee_id': 'C00155952',
#    'committee_name': 'DEMOCRATIC PARTY OF VIRGINIA',
#    'count': 1,
#    'cycle': 2012,
#    'memo_count': 0,
#    'memo_total': 0.0,
#    'recipient_id': 'C00299511',
#    'recipient_name': 'VIRGINIA PARTISANS POLITICAL ACTION COMMITTEE',
#    'total': 140.0}],
#  [{'committee_id': 'C00492462',
#    'committee_name': 'GEORGE ALLEN FOR US SENATE',
#    'count': 1,
#    'cycle': 2012,
#    'memo_count': 0,
#    'memo_total': 0.0,
#    'recipient_id': 'C00519603',
#    'recipient_name': 'VIRGINIA POULTRY GROWERS COOPERATIVE INC POLITICAL ACTION COMMITTEE',
#    'total': 500.0}],
#  [{'committee_id': 'C00314617',
#    'committee_name': 'PLANNED PARENTHOOD ACTION FUND INC PAC, DBA PLANNED PARENTHOOD FEDERAL PAC',
#    'count': 2,
#    'cycle': 2012,
#    'memo_count': 0,
#    'memo_total': 0.0,
#    'recipient_id': 'C00109355',
#    'recipient_name': 'VOTERS FOR CHOICE/FRIENDS OF FAMILY PLANNING',
#    'total': 10000.0}],
#  [{'committee_id': 'C00122176',
#    'committee_name': 'FRIENDS OF DICK LUGAR INC',
#    'count': 1,
#    'cycle': 2012,
#    'memo_count': 0,
#    'memo_total': 0.0,
#    'recipient_id': 'C00093054',
#    'recipient_name': 'WAL-MART STORES INC. PAC FOR RESPONSIBLE GOVERNMENT',
#    'total': 2500.0},
#   {'committee_id': 'C00411348',
#    'committee_name': 'SISTER-ACT COMMITTEE',
#    'count': 0,
#    'cycle': 2012,
#    'memo_count': 1,
#    'memo_total': 1500.0,
#    'recipient_id': 'C00093054',
#    'recipient_name': 'WAL-MART STORES INC. PAC FOR RESPONSIBLE GOVERNMENT',
#    'total': 0.0},
#   {'committee_id': 'C00496760',
#    'committee_name': 'AMODEI FOR NEVADA',
#    'count': 1,
#    'cycle': 2012,
#    'memo_count': 0,
#    'memo_total': 0.0,
#    'recipient_id': 'C00093054',
#    'recipient_name': 'WAL-MART STORES INC. PAC FOR RESPONSIBLE GOVERNMENT',
#    'total': 220.0},
#   {'committee_id': 'C00499350',
#    'committee_name': 'DEWHURST FOR TEXAS',
#    'count': 1,
#    'cycle': 2012,
#    'memo_count': 0,
#    'memo_total': 0.0,
#    'recipient_id': 'C00093054',
#    'recipient_name': 'WAL-MART STORES INC. PAC FOR RESPONSIBLE GOVERNMENT',
#    'total': 7500.0}],
#  [{'committee_id': 'C00478354',
#    'committee_name': 'BOEHNER FOR SPEAKER',
#    'count': 1,
#    'cycle': 2012,
#    'memo_count': 0,
#    'memo_total': 0.0,
#    'recipient_id': 'C00339291',
#    'recipient_name': 'TIME WARNER INC. PAC',
#    'total': 1000.0}],
#  [{'committee_id': 'C00172205',
#    'committee_name': 'MUFG AMERICAS HOLDINGS CORPORATION POLITICAL ACTION COMMITTEE',
#    'count': 1,
#    'cycle': 2012,
#    'memo_count': 0,
#    'memo_total': 0.0,
#    'recipient_id': 'C00114090',
#    'recipient_name': 'WASHINGTON BANKERS ASSOCIATION POLITICAL ACTION COMMITTEE',
#    'total': 2000.0}],
#  [{'committee_id': 'C00076737',
#    'committee_name': 'SOUTHWEST GAS CORPORATION POLITICAL ACTION COMMITTEE',
#    'count': 1,
#    'cycle': 2012,
#    'memo_count': 0,
#    'memo_total': 0.0,
#    'recipient_id': 'C00102152',
#    'recipient_name': 'WASHINGTON GAS LIGHT COMPANY PAC',
#    'total': 3000.0},
#   {'committee_id': 'C00430686',
#    'committee_name': 'WEBB FOR SENATE',
#    'count': 1,
#    'cycle': 2012,
#    'memo_count': 0,
#    'memo_total': 0.0,
#    'recipient_id': 'C00102152',
#    'recipient_name': 'WASHINGTON GAS LIGHT COMPANY PAC',
#    'total': 2000.0}],
#  [{'committee_id': 'C00492462',
#    'committee_name': 'GEORGE ALLEN FOR US SENATE',
#    'count': 1,
#    'cycle': 2012,
#    'memo_count': 0,
#    'memo_total': 0.0,
#    'recipient_id': 'C00142307',
#    'recipient_name': 'WATKINS ASSOCIATED INDUSTRIES INC EMPLOYEES FOR GOOD GOVERNMENT COMMITTEE (WATKINS-PAC)',
#    'total': 1000.0}],
#  [{'committee_id': 'C00520874',
#    'committee_name': 'HORTON FOR CONGRESS',
#    'count': 1,
#    'cycle': 2012,
#    'memo_count': 0,
#    'memo_total': 0.0,
#    'recipient_id': 'C00148510',
#    'recipient_name': 'WAWA, INC. POLITICAL ACTION COMMITTEE',
#    'total': 20.0}],
#  [{'committee_id': 'C00432401',
#    'committee_name': 'BEN NELSON 2012',
#    'count': 1,
#    'cycle': 2012,
#    'memo_count': 0,
#    'memo_total': 0.0,
#    'recipient_id': 'C00034595',
#    'recipient_name': 'WELLS FARGO AND COMPANY EMPLOYEE PAC (AKA WELLS FARGO EMPLOYEE PAC)',
#    'total': 3000.0}],
#  [{'committee_id': 'C00331769',
#    'committee_name': 'BARBARA LEE FOR CONGRESS',
#    'count': 1,
#    'cycle': 2012,
#    'memo_count': 0,
#    'memo_total': 0.0,
#    'recipient_id': 'C00404525',
#    'recipient_name': 'WELLSTONE DEMOCRATIC RENEWAL CLUB - PAC',
#    'total': 750.0}],
#  [{'committee_id': 'C00481192',
#    'committee_name': 'WHITING PETROLEUM CORPORATION POLITICAL ACTION COMMITTEE',
#    'count': 1,
#    'cycle': 2012,
#    'memo_count': 0,
#    'memo_total': 0.0,
#    'recipient_id': 'C00426569',
#    'recipient_name': 'WESTERN ENERGY ALLIANCE PAC',
#    'total': 1000.0},
#   {'committee_id': 'C00485730',
#    'committee_name': 'QEP RESOURCES INC POLITICAL ACTION COMMITTEE',
#    'count': 2,
#    'cycle': 2012,
#    'memo_count': 0,
#    'memo_total': 0.0,
#    'recipient_id': 'C00426569',
#    'recipient_name': 'WESTERN ENERGY ALLIANCE PAC',
#    'total': 2000.0},
#   {'committee_id': 'C00286856',
#    'committee_name': 'FRIENDS OF DOC HASTINGS',
#    'count': 1,
#    'cycle': 2012,
#    'memo_count': 0,
#    'memo_total': 0.0,
#    'recipient_id': 'C00426569',
#    'recipient_name': 'WESTERN ENERGY ALLIANCE PAC',
#    'total': 284.0}],
#  [{'committee_id': 'C00213231',
#    'committee_name': 'A DUDA & SONS, INC POLITICAL ACTION COMMITTEE',
#    'count': 1,
#    'cycle': 2012,
#    'memo_count': 0,
#    'memo_total': 0.0,
#    'recipient_id': 'C00193979',
#    'recipient_name': 'WESTERN GROWERS POLITICAL ACTION COMMITTEE',
#    'total': 1000.0}],
#  [{'committee_id': 'C00431056',
#    'committee_name': 'BOB CASEY FOR SENATE INC',
#    'count': 1,
#    'cycle': 2012,
#    'memo_count': 0,
#    'memo_total': 0.0,
#    'recipient_id': 'C00251843',
#    'recipient_name': 'WESTON SOLUTIONS INC. POLITICAL ACTION COMMITTEE (WESTON PAC)',
#    'total': 1000.0}],
#  [{'committee_id': 'C00363556',
#    'committee_name': 'ROCK-TENN COMPANY POLITICAL ACTION COMMITTEE',
#    'count': 1,
#    'cycle': 2012,
#    'memo_count': 0,
#    'memo_total': 0.0,
#    'recipient_id': 'C00117424',
#    'recipient_name': 'ROCKTENN POLITICAL ACTION COMMITTEE',
#    'total': 1850.0},
#   {'committee_id': 'C00458844',
#    'committee_name': 'MARCO RUBIO FOR PRESIDENT',
#    'count': 1,
#    'cycle': 2012,
#    'memo_count': 0,
#    'memo_total': 0.0,
#    'recipient_id': 'C00117424',
#    'recipient_name': 'ROCKTENN POLITICAL ACTION COMMITTEE',
#    'total': 500.0}],
#  [{'committee_id': 'C00075291',
#    'committee_name': 'TRUIST FINANCIAL CORPORATION POLITICAL ACTION COMMITTEE (FORMERLY BRANCH BANK AND TRUST POLITICAL ACTION COMMITTEE)',
#    'count': 1,
#    'cycle': 2012,
#    'memo_count': 0,
#    'memo_total': 0.0,
#    'recipient_id': 'C00450072',
#    'recipient_name': 'WEST VIRGINIA BANKERS ASSOCIATION PAC',
#    'total': 1000.0}],
#  [{'committee_id': 'C00473132',
#    'committee_name': 'MCKINLEY FOR CONGRESS',
#    'count': 1,
#    'cycle': 2012,
#    'memo_count': 0,
#    'memo_total': 0.0,
#    'recipient_id': 'C00157537',
#    'recipient_name': 'WEST VIRGINIANS FOR LIFE INC POLITICAL ACTION COMMITTEE',
#    'total': 1000.0}],
#  [{'committee_id': 'C00239038',
#    'committee_name': 'ROCKET CITY PAC',
#    'count': 1,
#    'cycle': 2012,
#    'memo_count': 0,
#    'memo_total': 0.0,
#    'recipient_id': 'C00248195',
#    'recipient_name': 'WEXLER & WALKER PUBLIC POLICY ASSOCIATES PAC (A UNIT OF HILL & KNOWLTON)',
#    'total': 5000.0},
#   {'committee_id': 'C00280206',
#    'committee_name': 'CITIZENS FOR ARLEN SPECTER',
#    'count': 1,
#    'cycle': 2012,
#    'memo_count': 0,
#    'memo_total': 0.0,
#    'recipient_id': 'C00248195',
#    'recipient_name': 'WEXLER & WALKER PUBLIC POLICY ASSOCIATES PAC (A UNIT OF HILL & KNOWLTON)',
#    'total': -1000.0}],
#  [{'committee_id': 'C00076174',
#    'committee_name': 'NATIONWIDE MUTUAL INSURANCE COMPANY POLITICAL ACTION COMMITTEE',
#    'count': 2,
#    'cycle': 2012,
#    'memo_count': 0,
#    'memo_total': 0.0,
#    'recipient_id': 'C00417634',
#    'recipient_name': 'NATIONAL ASSOCIATION OF PROFESSIONAL SURPLUS LINES OFFICES (NAPSLO) PAC',
#    'total': 10000.0}],
#  [{'committee_id': 'C00469825',
#    'committee_name': 'JELD-WEN, INC. EMPLOYEE POLITICAL ACTION COMMITTEE',
#    'count': 2,
#    'cycle': 2012,
#    'memo_count': 0,
#    'memo_total': 0.0,
#    'recipient_id': 'C00492041',
#    'recipient_name': 'WINDOW AND DOOR MANUFACTURERS ASSOCIATION POLITICAL ACTION COMMITTEE',
#    'total': 2450.0}],
#  [{'committee_id': 'C00450510',
#    'committee_name': 'PAETEC HOLDING CORPORATION POLITICAL ACTION COMMITTEE',
#    'count': 1,
#    'cycle': 2012,
#    'memo_count': 0,
#    'memo_total': 0.0,
#    'recipient_id': 'C00425975',
#    'recipient_name': 'WINDSTREAM CORPORATION POLITICAL ACTION COMMITTEE',
#    'total': 34514.0}],
#  [{'committee_id': 'C00304832',
#    'committee_name': 'CONSTELLATION BRANDS INC POLITICAL ACTION COMMITTEE',
#    'count': 1,
#    'cycle': 2012,
#    'memo_count': 0,
#    'memo_total': 0.0,
#    'recipient_id': 'C00173369',
#    'recipient_name': 'WINEAMERICA PAC',
#    'total': 2500.0}],
#  [{'committee_id': 'C00217877',
#    'committee_name': "SOUTHERN GLAZER'S WINE AND SPIRITS PAC",
#    'count': 2,
#    'cycle': 2012,
#    'memo_count': 0,
#    'memo_total': 0.0,
#    'recipient_id': 'C00147173',
#    'recipient_name': 'WINE AND SPIRITS WHOLESALERS OF AMERICA, INC. POLITICAL ACTION COMMITTEE',
#    'total': 10000.0},
#   {'committee_id': 'C00436386',
#    'committee_name': 'FRIENDS OF JOHN BARRASSO',
#    'count': 1,
#    'cycle': 2012,
#    'memo_count': 0,
#    'memo_total': 0.0,
#    'recipient_id': 'C00147173',
#    'recipient_name': 'WINE AND SPIRITS WHOLESALERS OF AMERICA, INC. POLITICAL ACTION COMMITTEE',
#    'total': 2500.0}],
#  [{'committee_id': 'C00059733',
#    'committee_name': 'BROWN-FORMAN CORPORATION NON-PARTISAN COMMITTEE FOR RESPONSIBLE GOVERNMENT',
#    'count': 1,
#    'cycle': 2012,
#    'memo_count': 0,
#    'memo_total': 0.0,
#    'recipient_id': 'C00065219',
#    'recipient_name': 'WINE INSTITUTE POLITICAL ACTION COMMITTEE',
#    'total': 5000.0},
#   {'committee_id': 'C00409219',
#    'committee_name': 'MATSUI FOR CONGRESS',
#    'count': 1,
#    'cycle': 2012,
#    'memo_count': 0,
#    'memo_total': 0.0,
#    'recipient_id': 'C00065219',
#    'recipient_name': 'WINE INSTITUTE POLITICAL ACTION COMMITTEE',
#    'total': 320.0},
#   {'committee_id': 'C00304832',
#    'committee_name': 'CONSTELLATION BRANDS INC POLITICAL ACTION COMMITTEE',
#    'count': 1,
#    'cycle': 2012,
#    'memo_count': 0,
#    'memo_total': 0.0,
#    'recipient_id': 'C00065219',
#    'recipient_name': 'WINE INSTITUTE POLITICAL ACTION COMMITTEE',
#    'total': 5000.0}],
#  [{'committee_id': 'C00018036',
#    'committee_name': 'U.S. BANCORP POLITICAL PARTICIPATION PROGRAM',
#    'count': 1,
#    'cycle': 2012,
#    'memo_count': 0,
#    'memo_total': 0.0,
#    'recipient_id': 'C00048181',
#    'recipient_name': 'WISCONSIN BANKERS ASSOCIATION (WISBANKPAC)',
#    'total': 1500.0},
#   {'committee_id': 'C00205138',
#    'committee_name': 'NORTH SHORE BANK PAC',
#    'count': 2,
#    'cycle': 2012,
#    'memo_count': 0,
#    'memo_total': 0.0,
#    'recipient_id': 'C00048181',
#    'recipient_name': 'WISCONSIN BANKERS ASSOCIATION (WISBANKPAC)',
#    'total': 5500.0}],
#  [{'committee_id': 'C00010322',
#    'committee_name': 'AMERICAN POSTAL WORKERS UNION COMMITTEE ON POLITICAL ACTION',
#    'count': 4,
#    'cycle': 2012,
#    'memo_count': 0,
#    'memo_total': 0.0,
#    'recipient_id': 'C00424150',
#    'recipient_name': "WOMEN'S CAMPAIGN FORUM",
#    'total': 10000.0},
#   {'committee_id': 'C00011114',
#    'committee_name': 'AMERICAN FEDERATION OF STATE COUNTY & MUNICIPAL EMPLOYEES  P E O P L E',
#    'count': 1,
#    'cycle': 2012,
#    'memo_count': 0,
#    'memo_total': 0.0,
#    'recipient_id': 'C00424150',
#    'recipient_name': "WOMEN'S CAMPAIGN FORUM",
#    'total': 5000.0},
#   {'committee_id': 'C00024521',
#    'committee_name': 'AMERICAN ASSOCIATION FOR JUSTICE POLITICAL ACTION COMMITTEE (AAJ PAC)',
#    'count': 1,
#    'cycle': 2012,
#    'memo_count': 0,
#    'memo_total': 0.0,
#    'recipient_id': 'C00424150',
#    'recipient_name': "WOMEN'S CAMPAIGN FORUM",
#    'total': 5000.0}],
#  [{'committee_id': 'C00040394',
#    'committee_name': 'THE WILLIAMS COMPANIES, INC. POLITICAL ACTION COMMITTEE',
#    'count': 1,
#    'cycle': 2012,
#    'memo_count': 0,
#    'memo_total': 0.0,
#    'recipient_id': 'C00502518',
#    'recipient_name': 'WPX ENERGY, INC. POLITICAL ACTION COMMITTEE',
#    'total': 69577.0}],
#  [{'committee_id': 'C00503615',
#    'committee_name': 'SHAYS FOR SENATE',
#    'count': 1,
#    'cycle': 2012,
#    'memo_count': 0,
#    'memo_total': 0.0,
#    'recipient_id': 'C00383307',
#    'recipient_name': 'W R BERKLEY CORPORATION POLITICAL ACTION COMMITTEE',
#    'total': 5000.0}],
#  [{'committee_id': 'C00264697',
#    'committee_name': 'FRIENDS OF SHERROD BROWN',
#    'count': 2,
#    'cycle': 2012,
#    'memo_count': 0,
#    'memo_total': 0.0,
#    'recipient_id': 'C00287003',
#    'recipient_name': 'PARSONS BRINCKERHOFF GROUP INC. PAC',
#    'total': 2000.0}],
#  [{'committee_id': 'C00002972',
#    'committee_name': "THE NATIONAL RURAL ELECTRIC COOPERATIVE ASSOCIATION ACTION COMMITTEE FOR RURAL ELECTRIFICATION (AMERICA'S ELECTRIC COOPERATIVES PAC)",
#    'count': 5,
#    'cycle': 2012,
#    'memo_count': 0,
#    'memo_total': 0.0,
#    'recipient_id': 'C00276485',
#    'recipient_name': 'WYOMING RURAL ELECTRIC ASSOCIATION PAC',
#    'total': 5482.0}],
#  [{'committee_id': 'C00202754',
#    'committee_name': 'FRIENDS OF KENT CONRAD',
#    'count': 1,
#    'cycle': 2012,
#    'memo_count': 0,
#    'memo_total': 0.0,
#    'recipient_id': 'C00107771',
#    'recipient_name': 'XCEL ENERGY EMPLOYEE POLITICAL ACTION COMMITTEE (XPAC)',
#    'total': 3000.0}],
#  [{'committee_id': 'C00248245',
#    'committee_name': 'AFFILIATED COMPUTER SERVICES INC. GOOD GOVERNMENT COMMITTEE',
#    'count': 1,
#    'cycle': 2012,
#    'memo_count': 0,
#    'memo_total': 0.0,
#    'recipient_id': 'C00207258',
#    'recipient_name': 'XEROX CORPORATION POLITICAL ACTION COMMITTEE (XPAC)',
#    'total': 29899.0}],
#  [{'committee_id': 'C00432401',
#    'committee_name': 'BEN NELSON 2012',
#    'count': 1,
#    'cycle': 2012,
#    'memo_count': 0,
#    'memo_total': 0.0,
#    'recipient_id': 'C00279455',
#    'recipient_name': 'ZENECA INC. POLITICAL ACTION COMMITTEE',
#    'total': 5000.0}],
#  [{'committee_id': 'C00105973',
#    'committee_name': 'UTAH STATE DEMOCRATIC COMMITTEE',
#    'count': 1,
#    'cycle': 2012,
#    'memo_count': 0,
#    'memo_total': 0.0,
#    'recipient_id': 'C00275230',
#    'recipient_name': 'ZIONS BANCORPORATION POLITICAL ACTION COMMITTEE',
#    'total': 5000.0}]]

# %%
disbursements_df = pull_list_of_dicts(disbursements)
disbursements_df.head()
# Out:
#   committee_id                                     committee_name  count  \
# 0    C00277335      FAIRFAX COUNTY REPUBLICAN COMMITTEE (FEDERAL)      1
# 1    C00004036  SEIU COPE (SERVICE EMPLOYEES INTERNATIONAL UNI...      1
# 2    C00348540  1199 SEIU UNITED HEALTHCARE WORKERS EAST FEDER...      1
# 3    C00189100                  7TH DISTRICT REPUBLICAN COMMITTEE      1
# 4    C00236489  KOCH INDUSTRIES, INC. POLITICAL ACTION COMMITT...      1
#
#    cycle  memo_count  memo_total recipient_id  \
# 0   2012           0         0.0    C00005462
# 1   2012           0         0.0    C00348540
# 2   2012           0         0.0    C00344531
# 3   2012           0         0.0    C00273755
# 4   2012           0         0.0    C00273755
#
#                                       recipient_name     total
# 0   10TH DISTRICT REPUBLICAN CONGRESSIONAL COMMITTEE    4940.0
# 1  1199 SERVICE EMPLOYEES INT'L UNION FEDERAL POL...  125000.0
# 2  1199 32BJ/144 SERVICE EMPLOYEES INTERNATIONAL ...    3546.0
# 3  11TH CONGRESSIONAL DISTRICT OF VIRGINIA REPUBL...    2247.0
# 4  11TH CONGRESSIONAL DISTRICT OF VIRGINIA REPUBL...    5000.0

# %%
disbursements_df.drop(columns=['cycle', 'memo_count', 'memo_total'], inplace=True)

# %%
disbursements_df.shape
# Out:
# (139263, 6)

# %%
disbursements_df.to_csv('./datasets/disbursements.csv',sep=',',index=False)

# %% [markdown]
# #### Schedule B - Draft Coding Run

# %%
# testing schedule b pull request for one committee id --> NRA : C00053553

nra_rq = rq.get(f'https://api.open.fec.gov/v1/schedules/schedule_b/?committee_id=C00053553&spender_committee_designation=A&spender_committee_designation=J&spender_committee_designation=P&spender_committee_designation=B&spender_committee_designation=D&spender_committee_org_type=C&spender_committee_org_type=L&spender_committee_org_type=M&spender_committee_org_type=T&spender_committee_org_type=V&spender_committee_org_type=W&spender_committee_type=C&spender_committee_type=D&spender_committee_type=E&spender_committee_type=H&spender_committee_type=I&spender_committee_type=N&spender_committee_type=O&spender_committee_type=P&spender_committee_type=Q&spender_committee_type=S&spender_committee_type=U&spender_committee_type=V&spender_committee_type=W&two_year_transaction_period=2012&per_page=100&sort=-disbursement_date&sort_hide_null=false&sort_null_only=false&api_key={api_key_fec}')

print(nra_rq.status_code)
nra_json = nra_rq.json()
# Out:
# 200

# %%
# create while loop for pagination capture

# variables set by first page request, count set to track number of pages requested
last_disbursement_date = '2012-10-31'
last_index = '4040220131185979472'
count = 1

while True:
    try:
        # api request that inserts api key variable, as well as the last index and disbursement date from the first page request
        nra_rq_loop = rq.get(f'https://api.open.fec.gov/v1/schedules/schedule_b/?committee_id=C00053553&spender_committee_designation=A&spender_committee_designation=J&spender_committee_designation=P&spender_committee_designation=B&spender_committee_designation=D&spender_committee_org_type=C&spender_committee_org_type=L&spender_committee_org_type=M&spender_committee_org_type=T&spender_committee_org_type=V&spender_committee_org_type=W&spender_committee_type=C&spender_committee_type=D&spender_committee_type=E&spender_committee_type=H&spender_committee_type=I&spender_committee_type=N&spender_committee_type=O&spender_committee_type=P&spender_committee_type=Q&spender_committee_type=S&spender_committee_type=U&spender_committee_type=V&spender_committee_type=W&two_year_transaction_period=2012&per_page=100&sort=-disbursement_date&sort_hide_null=false&sort_null_only=false&api_key={api_key_fec}&last_index={last_index}&last_disbursement_date={last_disbursement_date}')

        # check status during while loop
        print(f'Requesting page {count}')
        nra_rq_loop.raise_for_status()

        # convert request into json file
        nra_json_loop = nra_rq_loop.json()

        # move through json to pull new last index and disbursement dates
        nra_page_loop = nra_json_loop['pagination']
        nra_index_loop = nra_page_loop['last_indexes']
        last_index = nra_index_loop['last_index']
        last_disbursement_date = nra_index_loop['last_disbursement_date']
       
        # convert loop into a list and append to nra_list
        nra_list_loop = list(nra_json_loop)
        nra_list.append(nra_list_loop)
        
        # add to counter
        count += 1
        
    except TypeError:
        print('No more valid pages to loop through')
        break

# %%
nra_page_test = nra_json['pagination']
nra_index_test = nra_page_test['last_indexes']
nra_index_test['last_index']
nra_index_test['last_disbursement_date']

# %%
nra_list = nra_json['results']
nra_list
# Out:
# [{'amendment_indicator': 'A',
#   'amendment_indicator_desc': 'ADD',
#   'back_reference_schedule_id': None,
#   'back_reference_transaction_id': None,
#   'beneficiary_committee_name': None,
#   'candidate_first_name': None,
#   'candidate_id': None,
#   'candidate_last_name': None,
#   'candidate_middle_name': None,
#   'candidate_name': None,
#   'candidate_office': None,
#   'candidate_office_description': None,
#   'candidate_office_district': None,
#   'candidate_office_state': None,
#   'candidate_office_state_full': None,
#   'candidate_prefix': None,
#   'candidate_suffix': None,
#   'category_code': '001',
#   'category_code_full': 'Administrative/Salary/Overhead Expenses ',
#   'comm_dt': None,
#   'committee': {'affiliated_committee_name': 'THE NATIONAL RIFLE ASSOCIATION OF AMERICA',
#    'candidate_ids': [],
#    'city': 'FAIRFAX',
#    'committee_id': 'C00053553',
#    'committee_type': 'Q',
#    'committee_type_full': 'PAC - Qualified',
#    'cycle': 2012,
#    'cycles': [1976,
#     1978,
#     1980,
#     1982,
#     1984,
#     1986,
#     1988,
#     1990,
#     1992,
#     1994,
#     1996,
#     1998,
#     2000,
#     2002,
#     2004,
#     2006,
#     2008,
#     2010,
#     2012,
#     2014,
#     2016,
#     2018,
#     2020,
#     2022,
#     2024],
#    'cycles_has_activity': [1976,
#     1978,
#     1980,
#     1982,
#     1984,
#     1986,
#     1988,
#     1990,
#     1992,
#     1994,
#     1996,
#     1998,
#     2000,
#     2002,
#     2004,
#     2006,
#     2008,
#     2010,
#     2012,
#     2014,
#     2016,
#     2018,
#     2020,
#     2022,
#     2024],
#    'cycles_has_financial': [1976,
#     1978,
#     1980,
#     1982,
#     1984,
#     1986,
#     1988,
#     1990,
#     1992,
#     1994,
#     1996,
#     1998,
#     2000,
#     2002,
#     2004,
#     2006,
#     2008,
#     2010,
#     2012,
#     2014,
#     2016,
#     2018,
#     2020,
#     2022,
#     2024],
#    'designation': 'B',
#    'designation_full': 'Lobbyist/Registrant PAC',
#    'filing_frequency': 'M',
#    'first_f1_date': '1976-07-28',
#    'first_file_date': '1976-07-28',
#    'is_active': True,
#    'last_cycle_has_activity': 2024,
#    'last_cycle_has_financial': 2024,
#    'last_f1_date': '2023-04-20',
#    'last_file_date': '2023-07-31',
#    'name': 'NATIONAL RIFLE ASSOCIATION OF AMERICA POLITICAL VICTORY FUND',
#    'organization_type': 'M',
#    'organization_type_full': 'Membership Organization',
#    'party': 'UNK',
#    'party_full': 'UNKNOWN',
#    'state': 'VA',
#    'state_full': 'Virginia',
#    'street_1': '11250 WAPLES MILL ROAD',
#    'street_2': None,
#    'treasurer_name': 'ADKINS, MARY ROSE',
#    'zip': '22030'},
#   'committee_id': 'C00053553',
#   'conduit_committee_city': None,
#   'conduit_committee_name': None,
#   'conduit_committee_state': None,
#   'conduit_committee_street1': None,
#   'conduit_committee_street2': None,
#   'conduit_committee_zip': None,
#   'disbursement_amount': 49.64,
#   'disbursement_date': '2012-12-31',
#   'disbursement_description': 'CREDIT CARD FEES',
#   'disbursement_purpose_category': 'OTHER',
#   'disbursement_type': None,
#   'disbursement_type_description': None,
#   'election_type': None,
#   'election_type_full': None,
#   'entity_type': 'ORG',
#   'entity_type_desc': 'ORGANIZATION',
#   'fec_election_type_desc': None,
#   'fec_election_year': None,
#   'file_number': 852382,
#   'filing_form': 'F3X',
#   'image_number': '13960611624',
#   'line_number': '21B',
#   'line_number_label': 'Other Federal Operating Expenditures',
#   'link_id': 4013120131180363071,
#   'load_date': '2017-05-31T20:12:38.059660',
#   'memo_code': None,
#   'memo_code_full': None,
#   'memo_text': 'CREDIT CARD FEES',
#   'memoed_subtotal': False,
#   'national_committee_nonfederal_account': None,
#   'original_sub_id': None,
#   'payee_employer': None,
#   'payee_first_name': None,
#   'payee_last_name': None,
#   'payee_middle_name': None,
#   'payee_occupation': None,
#   'payee_prefix': None,
#   'payee_suffix': None,
#   'pdf_url': 'http://docquery.fec.gov/cgi-bin/fecimg/?13960611624',
#   'recipient_city': 'SALEM',
#   'recipient_committee': None,
#   'recipient_committee_id': None,
#   'recipient_name': 'PAYMENTECH, INC.',
#   'recipient_state': 'NH',
#   'recipient_zip': '03079',
#   'ref_disp_excess_flg': None,
#   'report_type': 'YE',
#   'report_year': '2012',
#   'schedule_type': 'SB',
#   'schedule_type_full': 'ITEMIZED DISBURSEMENTS',
#   'semi_annual_bundled_refund': '0.00',
#   'spender_committee_designation': 'B',
#   'spender_committee_org_type': 'M',
#   'spender_committee_type': 'Q',
#   'sub_id': '4020520131180774329',
#   'transaction_id': '49465437',
#   'two_year_transaction_period': 2012,
#   'unused_recipient_committee_id': None},
#  {'amendment_indicator': 'A',
#   'amendment_indicator_desc': 'ADD',
#   'back_reference_schedule_id': None,
#   'back_reference_transaction_id': None,
#   'beneficiary_committee_name': None,
#   'candidate_first_name': None,
#   'candidate_id': None,
#   'candidate_last_name': None,
#   'candidate_middle_name': None,
#   'candidate_name': None,
#   'candidate_office': None,
#   'candidate_office_description': None,
#   'candidate_office_district': None,
#   'candidate_office_state': None,
#   'candidate_office_state_full': None,
#   'candidate_prefix': None,
#   'candidate_suffix': None,
#   'category_code': '001',
#   'category_code_full': 'Administrative/Salary/Overhead Expenses ',
#   'comm_dt': None,
#   'committee': {'affiliated_committee_name': 'THE NATIONAL RIFLE ASSOCIATION OF AMERICA',
#    'candidate_ids': [],
#    'city': 'FAIRFAX',
#    'committee_id': 'C00053553',
#    'committee_type': 'Q',
#    'committee_type_full': 'PAC - Qualified',
#    'cycle': 2012,
#    'cycles': [1976,
#     1978,
#     1980,
#     1982,
#     1984,
#     1986,
#     1988,
#     1990,
#     1992,
#     1994,
#     1996,
#     1998,
#     2000,
#     2002,
#     2004,
#     2006,
#     2008,
#     2010,
#     2012,
#     2014,
#     2016,
#     2018,
#     2020,
#     2022,
#     2024],
#    'cycles_has_activity': [1976,
#     1978,
#     1980,
#     1982,
#     1984,
#     1986,
#     1988,
#     1990,
#     1992,
#     1994,
#     1996,
#     1998,
#     2000,
#     2002,
#     2004,
#     2006,
#     2008,
#     2010,
#     2012,
#     2014,
#     2016,
#     2018,
#     2020,
#     2022,
#     2024],
#    'cycles_has_financial': [1976,
#     1978,
#     1980,
#     1982,
#     1984,
#     1986,
#     1988,
#     1990,
#     1992,
#     1994,
#     1996,
#     1998,
#     2000,
#     2002,
#     2004,
#     2006,
#     2008,
#     2010,
#     2012,
#     2014,
#     2016,
#     2018,
#     2020,
#     2022,
#     2024],
#    'designation': 'B',
#    'designation_full': 'Lobbyist/Registrant PAC',
#    'filing_frequency': 'M',
#    'first_f1_date': '1976-07-28',
#    'first_file_date': '1976-07-28',
#    'is_active': True,
#    'last_cycle_has_activity': 2024,
#    'last_cycle_has_financial': 2024,
#    'last_f1_date': '2023-04-20',
#    'last_file_date': '2023-07-31',
#    'name': 'NATIONAL RIFLE ASSOCIATION OF AMERICA POLITICAL VICTORY FUND',
#    'organization_type': 'M',
#    'organization_type_full': 'Membership Organization',
#    'party': 'UNK',
#    'party_full': 'UNKNOWN',
#    'state': 'VA',
#    'state_full': 'Virginia',
#    'street_1': '11250 WAPLES MILL ROAD',
#    'street_2': None,
#    'treasurer_name': 'ADKINS, MARY ROSE',
#    'zip': '22030'},
#   'committee_id': 'C00053553',
#   'conduit_committee_city': None,
#   'conduit_committee_name': None,
#   'conduit_committee_state': None,
#   'conduit_committee_street1': None,
#   'conduit_committee_street2': None,
#   'conduit_committee_zip': None,
#   'disbursement_amount': 4.03,
#   'disbursement_date': '2012-12-31',
#   'disbursement_description': 'CREDIT CARD FEES',
#   'disbursement_purpose_category': 'OTHER',
#   'disbursement_type': None,
#   'disbursement_type_description': None,
#   'election_type': None,
#   'election_type_full': None,
#   'entity_type': 'ORG',
#   'entity_type_desc': 'ORGANIZATION',
#   'fec_election_type_desc': None,
#   'fec_election_year': None,
#   'file_number': 852382,
#   'filing_form': 'F3X',
#   'image_number': '13960611623',
#   'line_number': '21B',
#   'line_number_label': 'Other Federal Operating Expenditures',
#   'link_id': 4013120131180363071,
#   'load_date': '2017-05-31T20:12:38.059660',
#   'memo_code': None,
#   'memo_code_full': None,
#   'memo_text': 'CREDIT CARD FEES',
#   'memoed_subtotal': False,
#   'national_committee_nonfederal_account': None,
#   'original_sub_id': None,
#   'payee_employer': None,
#   'payee_first_name': None,
#   'payee_last_name': None,
#   'payee_middle_name': None,
#   'payee_occupation': None,
#   'payee_prefix': None,
#   'payee_suffix': None,
#   'pdf_url': 'http://docquery.fec.gov/cgi-bin/fecimg/?13960611623',
#   'recipient_city': 'PHOENIX',
#   'recipient_committee': None,
#   'recipient_committee_id': None,
#   'recipient_name': 'AMERICAN EXPRESS COMPANY',
#   'recipient_state': 'AZ',
#   'recipient_zip': '85072',
#   'ref_disp_excess_flg': None,
#   'report_type': 'YE',
#   'report_year': '2012',
#   'schedule_type': 'SB',
#   'schedule_type_full': 'ITEMIZED DISBURSEMENTS',
#   'semi_annual_bundled_refund': '0.00',
#   'spender_committee_designation': 'B',
#   'spender_committee_org_type': 'M',
#   'spender_committee_type': 'Q',
#   'sub_id': '4020520131180774328',
#   'transaction_id': '49465436',
#   'two_year_transaction_period': 2012,
#   'unused_recipient_committee_id': None},
#  {'amendment_indicator': 'A',
#   'amendment_indicator_desc': 'ADD',
#   'back_reference_schedule_id': None,
#   'back_reference_transaction_id': None,
#   'beneficiary_committee_name': None,
#   'candidate_first_name': None,
#   'candidate_id': None,
#   'candidate_last_name': None,
#   'candidate_middle_name': None,
#   'candidate_name': None,
#   'candidate_office': None,
#   'candidate_office_description': None,
#   'candidate_office_district': None,
#   'candidate_office_state': None,
#   'candidate_office_state_full': None,
#   'candidate_prefix': None,
#   'candidate_suffix': None,
#   'category_code': '001',
#   'category_code_full': 'Administrative/Salary/Overhead Expenses ',
#   'comm_dt': None,
#   'committee': {'affiliated_committee_name': 'THE NATIONAL RIFLE ASSOCIATION OF AMERICA',
#    'candidate_ids': [],
#    'city': 'FAIRFAX',
#    'committee_id': 'C00053553',
#    'committee_type': 'Q',
#    'committee_type_full': 'PAC - Qualified',
#    'cycle': 2012,
#    'cycles': [1976,
#     1978,
#     1980,
#     1982,
#     1984,
#     1986,
#     1988,
#     1990,
#     1992,
#     1994,
#     1996,
#     1998,
#     2000,
#     2002,
#     2004,
#     2006,
#     2008,
#     2010,
#     2012,
#     2014,
#     2016,
#     2018,
#     2020,
#     2022,
#     2024],
#    'cycles_has_activity': [1976,
#     1978,
#     1980,
#     1982,
#     1984,
#     1986,
#     1988,
#     1990,
#     1992,
#     1994,
#     1996,
#     1998,
#     2000,
#     2002,
#     2004,
#     2006,
#     2008,
#     2010,
#     2012,
#     2014,
#     2016,
#     2018,
#     2020,
#     2022,
#     2024],
#    'cycles_has_financial': [1976,
#     1978,
#     1980,
#     1982,
#     1984,
#     1986,
#     1988,
#     1990,
#     1992,
#     1994,
#     1996,
#     1998,
#     2000,
#     2002,
#     2004,
#     2006,
#     2008,
#     2010,
#     2012,
#     2014,
#     2016,
#     2018,
#     2020,
#     2022,
#     2024],
#    'designation': 'B',
#    'designation_full': 'Lobbyist/Registrant PAC',
#    'filing_frequency': 'M',
#    'first_f1_date': '1976-07-28',
#    'first_file_date': '1976-07-28',
#    'is_active': True,
#    'last_cycle_has_activity': 2024,
#    'last_cycle_has_financial': 2024,
#    'last_f1_date': '2023-04-20',
#    'last_file_date': '2023-07-31',
#    'name': 'NATIONAL RIFLE ASSOCIATION OF AMERICA POLITICAL VICTORY FUND',
#    'organization_type': 'M',
#    'organization_type_full': 'Membership Organization',
#    'party': 'UNK',
#    'party_full': 'UNKNOWN',
#    'state': 'VA',
#    'state_full': 'Virginia',
#    'street_1': '11250 WAPLES MILL ROAD',
#    'street_2': None,
#    'treasurer_name': 'ADKINS, MARY ROSE',
#    'zip': '22030'},
#   'committee_id': 'C00053553',
#   'conduit_committee_city': None,
#   'conduit_committee_name': None,
#   'conduit_committee_state': None,
#   'conduit_committee_street1': None,
#   'conduit_committee_street2': None,
#   'conduit_committee_zip': None,
#   'disbursement_amount': 2.0,
#   'disbursement_date': '2012-12-31',
#   'disbursement_description': 'BANK FEE',
#   'disbursement_purpose_category': 'OTHER',
#   'disbursement_type': None,
#   'disbursement_type_description': None,
#   'election_type': None,
#   'election_type_full': None,
#   'entity_type': 'ORG',
#   'entity_type_desc': 'ORGANIZATION',
#   'fec_election_type_desc': None,
#   'fec_election_year': None,
#   'file_number': 852382,
#   'filing_form': 'F3X',
#   'image_number': '13960611623',
#   'line_number': '21B',
#   'line_number_label': 'Other Federal Operating Expenditures',
#   'link_id': 4013120131180363071,
#   'load_date': '2017-05-31T20:12:38.059660',
#   'memo_code': None,
#   'memo_code_full': None,
#   'memo_text': 'BANK FEE',
#   'memoed_subtotal': False,
#   'national_committee_nonfederal_account': None,
#   'original_sub_id': None,
#   'payee_employer': None,
#   'payee_first_name': None,
#   'payee_last_name': None,
#   'payee_middle_name': None,
#   'payee_occupation': None,
#   'payee_prefix': None,
#   'payee_suffix': None,
#   'pdf_url': 'http://docquery.fec.gov/cgi-bin/fecimg/?13960611623',
#   'recipient_city': 'FAIRFAX',
#   'recipient_committee': None,
#   'recipient_committee_id': None,
#   'recipient_name': 'BB&T BANK',
#   'recipient_state': 'VA',
#   'recipient_zip': '22030',
#   'ref_disp_excess_flg': None,
#   'report_type': 'YE',
#   'report_year': '2012',
#   'schedule_type': 'SB',
#   'schedule_type_full': 'ITEMIZED DISBURSEMENTS',
#   'semi_annual_bundled_refund': '0.00',
#   'spender_committee_designation': 'B',
#   'spender_committee_org_type': 'M',
#   'spender_committee_type': 'Q',
#   'sub_id': '4020520131180774327',
#   'transaction_id': '49465435',
#   'two_year_transaction_period': 2012,
#   'unused_recipient_committee_id': None},
#  {'amendment_indicator': 'A',
#   'amendment_indicator_desc': 'ADD',
#   'back_reference_schedule_id': None,
#   'back_reference_transaction_id': None,
#   'beneficiary_committee_name': None,
#   'candidate_first_name': None,
#   'candidate_id': None,
#   'candidate_last_name': None,
#   'candidate_middle_name': None,
#   'candidate_name': None,
#   'candidate_office': None,
#   'candidate_office_description': None,
#   'candidate_office_district': None,
#   'candidate_office_state': None,
#   'candidate_office_state_full': None,
#   'candidate_prefix': None,
#   'candidate_suffix': None,
#   'category_code': '001',
#   'category_code_full': 'Administrative/Salary/Overhead Expenses ',
#   'comm_dt': None,
#   'committee': {'affiliated_committee_name': 'THE NATIONAL RIFLE ASSOCIATION OF AMERICA',
#    'candidate_ids': [],
#    'city': 'FAIRFAX',
#    'committee_id': 'C00053553',
#    'committee_type': 'Q',
#    'committee_type_full': 'PAC - Qualified',
#    'cycle': 2012,
#    'cycles': [1976,
#     1978,
#     1980,
#     1982,
#     1984,
#     1986,
#     1988,
#     1990,
#     1992,
#     1994,
#     1996,
#     1998,
#     2000,
#     2002,
#     2004,
#     2006,
#     2008,
#     2010,
#     2012,
#     2014,
#     2016,
#     2018,
#     2020,
#     2022,
#     2024],
#    'cycles_has_activity': [1976,
#     1978,
#     1980,
#     1982,
#     1984,
#     1986,
#     1988,
#     1990,
#     1992,
#     1994,
#     1996,
#     1998,
#     2000,
#     2002,
#     2004,
#     2006,
#     2008,
#     2010,
#     2012,
#     2014,
#     2016,
#     2018,
#     2020,
#     2022,
#     2024],
#    'cycles_has_financial': [1976,
#     1978,
#     1980,
#     1982,
#     1984,
#     1986,
#     1988,
#     1990,
#     1992,
#     1994,
#     1996,
#     1998,
#     2000,
#     2002,
#     2004,
#     2006,
#     2008,
#     2010,
#     2012,
#     2014,
#     2016,
#     2018,
#     2020,
#     2022,
#     2024],
#    'designation': 'B',
#    'designation_full': 'Lobbyist/Registrant PAC',
#    'filing_frequency': 'M',
#    'first_f1_date': '1976-07-28',
#    'first_file_date': '1976-07-28',
#    'is_active': True,
#    'last_cycle_has_activity': 2024,
#    'last_cycle_has_financial': 2024,
#    'last_f1_date': '2023-04-20',
#    'last_file_date': '2023-07-31',
#    'name': 'NATIONAL RIFLE ASSOCIATION OF AMERICA POLITICAL VICTORY FUND',
#    'organization_type': 'M',
#    'organization_type_full': 'Membership Organization',
#    'party': 'UNK',
#    'party_full': 'UNKNOWN',
#    'state': 'VA',
#    'state_full': 'Virginia',
#    'street_1': '11250 WAPLES MILL ROAD',
#    'street_2': None,
#    'treasurer_name': 'ADKINS, MARY ROSE',
#    'zip': '22030'},
#   'committee_id': 'C00053553',
#   'conduit_committee_city': None,
#   'conduit_committee_name': None,
#   'conduit_committee_state': None,
#   'conduit_committee_street1': None,
#   'conduit_committee_street2': None,
#   'conduit_committee_zip': None,
#   'disbursement_amount': 3.0,
#   'disbursement_date': '2012-12-31',
#   'disbursement_description': 'BANK FEE',
#   'disbursement_purpose_category': 'OTHER',
#   'disbursement_type': None,
#   'disbursement_type_description': None,
#   'election_type': None,
#   'election_type_full': None,
#   'entity_type': 'ORG',
#   'entity_type_desc': 'ORGANIZATION',
#   'fec_election_type_desc': None,
#   'fec_election_year': None,
#   'file_number': 852382,
#   'filing_form': 'F3X',
#   'image_number': '13960611622',
#   'line_number': '21B',
#   'line_number_label': 'Other Federal Operating Expenditures',
#   'link_id': 4013120131180363071,
#   'load_date': '2017-05-31T20:12:38.059660',
#   'memo_code': None,
#   'memo_code_full': None,
#   'memo_text': 'BANK FEE',
#   'memoed_subtotal': False,
#   'national_committee_nonfederal_account': None,
#   'original_sub_id': None,
#   'payee_employer': None,
#   'payee_first_name': None,
#   'payee_last_name': None,
#   'payee_middle_name': None,
#   'payee_occupation': None,
#   'payee_prefix': None,
#   'payee_suffix': None,
#   'pdf_url': 'http://docquery.fec.gov/cgi-bin/fecimg/?13960611622',
#   'recipient_city': 'ST. LOUIS',
#   'recipient_committee': None,
#   'recipient_committee_id': None,
#   'recipient_name': 'BANK OF AMERICA - MO',
#   'recipient_state': 'MO',
#   'recipient_zip': '63106',
#   'ref_disp_excess_flg': None,
#   'report_type': 'YE',
#   'report_year': '2012',
#   'schedule_type': 'SB',
#   'schedule_type_full': 'ITEMIZED DISBURSEMENTS',
#   'semi_annual_bundled_refund': '0.00',
#   'spender_committee_designation': 'B',
#   'spender_committee_org_type': 'M',
#   'spender_committee_type': 'Q',
#   'sub_id': '4020520131180774325',
#   'transaction_id': '49465433',
#   'two_year_transaction_period': 2012,
#   'unused_recipient_committee_id': None},
#  {'amendment_indicator': 'A',
#   'amendment_indicator_desc': 'ADD',
#   'back_reference_schedule_id': None,
#   'back_reference_transaction_id': None,
#   'beneficiary_committee_name': None,
#   'candidate_first_name': None,
#   'candidate_id': None,
#   'candidate_last_name': None,
#   'candidate_middle_name': None,
#   'candidate_name': None,
#   'candidate_office': None,
#   'candidate_office_description': None,
#   'candidate_office_district': None,
#   'candidate_office_state': None,
#   'candidate_office_state_full': None,
#   'candidate_prefix': None,
#   'candidate_suffix': None,
#   'category_code': '001',
#   'category_code_full': 'Administrative/Salary/Overhead Expenses ',
#   'comm_dt': None,
#   'committee': {'affiliated_committee_name': 'THE NATIONAL RIFLE ASSOCIATION OF AMERICA',
#    'candidate_ids': [],
#    'city': 'FAIRFAX',
#    'committee_id': 'C00053553',
#    'committee_type': 'Q',
#    'committee_type_full': 'PAC - Qualified',
#    'cycle': 2012,
#    'cycles': [1976,
#     1978,
#     1980,
#     1982,
#     1984,
#     1986,
#     1988,
#     1990,
#     1992,
#     1994,
#     1996,
#     1998,
#     2000,
#     2002,
#     2004,
#     2006,
#     2008,
#     2010,
#     2012,
#     2014,
#     2016,
#     2018,
#     2020,
#     2022,
#     2024],
#    'cycles_has_activity': [1976,
#     1978,
#     1980,
#     1982,
#     1984,
#     1986,
#     1988,
#     1990,
#     1992,
#     1994,
#     1996,
#     1998,
#     2000,
#     2002,
#     2004,
#     2006,
#     2008,
#     2010,
#     2012,
#     2014,
#     2016,
#     2018,
#     2020,
#     2022,
#     2024],
#    'cycles_has_financial': [1976,
#     1978,
#     1980,
#     1982,
#     1984,
#     1986,
#     1988,
#     1990,
#     1992,
#     1994,
#     1996,
#     1998,
#     2000,
#     2002,
#     2004,
#     2006,
#     2008,
#     2010,
#     2012,
#     2014,
#     2016,
#     2018,
#     2020,
#     2022,
#     2024],
#    'designation': 'B',
#    'designation_full': 'Lobbyist/Registrant PAC',
#    'filing_frequency': 'M',
#    'first_f1_date': '1976-07-28',
#    'first_file_date': '1976-07-28',
#    'is_active': True,
#    'last_cycle_has_activity': 2024,
#    'last_cycle_has_financial': 2024,
#    'last_f1_date': '2023-04-20',
#    'last_file_date': '2023-07-31',
#    'name': 'NATIONAL RIFLE ASSOCIATION OF AMERICA POLITICAL VICTORY FUND',
#    'organization_type': 'M',
#    'organization_type_full': 'Membership Organization',
#    'party': 'UNK',
#    'party_full': 'UNKNOWN',
#    'state': 'VA',
#    'state_full': 'Virginia',
#    'street_1': '11250 WAPLES MILL ROAD',
#    'street_2': None,
#    'treasurer_name': 'ADKINS, MARY ROSE',
#    'zip': '22030'},
#   'committee_id': 'C00053553',
#   'conduit_committee_city': None,
#   'conduit_committee_name': None,
#   'conduit_committee_state': None,
#   'conduit_committee_street1': None,
#   'conduit_committee_street2': None,
#   'conduit_committee_zip': None,
#   'disbursement_amount': 12.0,
#   'disbursement_date': '2012-12-31',
#   'disbursement_description': 'BANK FEE',
#   'disbursement_purpose_category': 'OTHER',
#   'disbursement_type': None,
#   'disbursement_type_description': None,
#   'election_type': None,
#   'election_type_full': None,
#   'entity_type': 'ORG',
#   'entity_type_desc': 'ORGANIZATION',
#   'fec_election_type_desc': None,
#   'fec_election_year': None,
#   'file_number': 852382,
#   'filing_form': 'F3X',
#   'image_number': '13960611621',
#   'line_number': '21B',
#   'line_number_label': 'Other Federal Operating Expenditures',
#   'link_id': 4013120131180363071,
#   'load_date': '2017-05-31T20:12:38.059660',
#   'memo_code': None,
#   'memo_code_full': None,
#   'memo_text': 'BANK FEE',
#   'memoed_subtotal': False,
#   'national_committee_nonfederal_account': None,
#   'original_sub_id': None,
#   'payee_employer': None,
#   'payee_first_name': None,
#   'payee_last_name': None,
#   'payee_middle_name': None,
#   'payee_occupation': None,
#   'payee_prefix': None,
#   'payee_suffix': None,
#   'pdf_url': 'http://docquery.fec.gov/cgi-bin/fecimg/?13960611621',
#   'recipient_city': 'ALLIANCE',
#   'recipient_committee': None,
#   'recipient_committee_id': None,
#   'recipient_name': 'BANK OF THE WEST',
#   'recipient_state': 'NE',
#   'recipient_zip': '69301',
#   'ref_disp_excess_flg': None,
#   'report_type': 'YE',
#   'report_year': '2012',
#   'schedule_type': 'SB',
#   'schedule_type_full': 'ITEMIZED DISBURSEMENTS',
#   'semi_annual_bundled_refund': '0.00',
#   'spender_committee_designation': 'B',
#   'spender_committee_org_type': 'M',
#   'spender_committee_type': 'Q',
#   'sub_id': '4020520131180774321',
#   'transaction_id': '49465429',
#   'two_year_transaction_period': 2012,
#   'unused_recipient_committee_id': None},
#  {'amendment_indicator': 'A',
#   'amendment_indicator_desc': 'ADD',
#   'back_reference_schedule_id': None,
#   'back_reference_transaction_id': None,
#   'beneficiary_committee_name': None,
#   'candidate_first_name': None,
#   'candidate_id': None,
#   'candidate_last_name': None,
#   'candidate_middle_name': None,
#   'candidate_name': None,
#   'candidate_office': None,
#   'candidate_office_description': None,
#   'candidate_office_district': None,
#   'candidate_office_state': None,
#   'candidate_office_state_full': None,
#   'candidate_prefix': None,
#   'candidate_suffix': None,
#   'category_code': '011',
#   'category_code_full': 'Political Contributions',
#   'comm_dt': None,
#   'committee': {'affiliated_committee_name': 'THE NATIONAL RIFLE ASSOCIATION OF AMERICA',
#    'candidate_ids': [],
#    'city': 'FAIRFAX',
#    'committee_id': 'C00053553',
#    'committee_type': 'Q',
#    'committee_type_full': 'PAC - Qualified',
#    'cycle': 2012,
#    'cycles': [1976,
#     1978,
#     1980,
#     1982,
#     1984,
#     1986,
#     1988,
#     1990,
#     1992,
#     1994,
#     1996,
#     1998,
#     2000,
#     2002,
#     2004,
#     2006,
#     2008,
#     2010,
#     2012,
#     2014,
#     2016,
#     2018,
#     2020,
#     2022,
#     2024],
#    'cycles_has_activity': [1976,
#     1978,
#     1980,
#     1982,
#     1984,
#     1986,
#     1988,
#     1990,
#     1992,
#     1994,
#     1996,
#     1998,
#     2000,
#     2002,
#     2004,
#     2006,
#     2008,
#     2010,
#     2012,
#     2014,
#     2016,
#     2018,
#     2020,
#     2022,
#     2024],
#    'cycles_has_financial': [1976,
#     1978,
#     1980,
#     1982,
#     1984,
#     1986,
#     1988,
#     1990,
#     1992,
#     1994,
#     1996,
#     1998,
#     2000,
#     2002,
#     2004,
#     2006,
#     2008,
#     2010,
#     2012,
#     2014,
#     2016,
#     2018,
#     2020,
#     2022,
#     2024],
#    'designation': 'B',
#    'designation_full': 'Lobbyist/Registrant PAC',
#    'filing_frequency': 'M',
#    'first_f1_date': '1976-07-28',
#    'first_file_date': '1976-07-28',
#    'is_active': True,
#    'last_cycle_has_activity': 2024,
#    'last_cycle_has_financial': 2024,
#    'last_f1_date': '2023-04-20',
#    'last_file_date': '2023-07-31',
#    'name': 'NATIONAL RIFLE ASSOCIATION OF AMERICA POLITICAL VICTORY FUND',
#    'organization_type': 'M',
#    'organization_type_full': 'Membership Organization',
#    'party': 'UNK',
#    'party_full': 'UNKNOWN',
#    'state': 'VA',
#    'state_full': 'Virginia',
#    'street_1': '11250 WAPLES MILL ROAD',
#    'street_2': None,
#    'treasurer_name': 'ADKINS, MARY ROSE',
#    'zip': '22030'},
#   'committee_id': 'C00053553',
#   'conduit_committee_city': None,
#   'conduit_committee_name': None,
#   'conduit_committee_state': None,
#   'conduit_committee_street1': None,
#   'conduit_committee_street2': None,
#   'conduit_committee_zip': None,
#   'disbursement_amount': 1000.0,
#   'disbursement_date': '2012-12-31',
#   'disbursement_description': None,
#   'disbursement_purpose_category': 'OTHER',
#   'disbursement_type': None,
#   'disbursement_type_description': None,
#   'election_type': None,
#   'election_type_full': None,
#   'entity_type': 'COM',
#   'entity_type_desc': 'OTHER COMMITTEE',
#   'fec_election_type_desc': None,
#   'fec_election_year': None,
#   'file_number': 852382,
#   'filing_form': 'F3X',
#   'image_number': '13960611630',
#   'line_number': '29',
#   'line_number_label': 'Other Disbursements',
#   'link_id': 4013120131180363071,
#   'load_date': '2017-05-31T20:12:38.059660',
#   'memo_code': None,
#   'memo_code_full': None,
#   'memo_text': None,
#   'memoed_subtotal': False,
#   'national_committee_nonfederal_account': None,
#   'original_sub_id': None,
#   'payee_employer': None,
#   'payee_first_name': None,
#   'payee_last_name': None,
#   'payee_middle_name': None,
#   'payee_occupation': None,
#   'payee_prefix': None,
#   'payee_suffix': None,
#   'pdf_url': 'http://docquery.fec.gov/cgi-bin/fecimg/?13960611630',
#   'recipient_city': 'COLONIAL HEIGHTS',
#   'recipient_committee': None,
#   'recipient_committee_id': None,
#   'recipient_name': 'MAJORITY LEADER PAC',
#   'recipient_state': 'VA',
#   'recipient_zip': '23834',
#   'ref_disp_excess_flg': None,
#   'report_type': 'YE',
#   'report_year': '2012',
#   'schedule_type': 'SB',
#   'schedule_type_full': 'ITEMIZED DISBURSEMENTS',
#   'semi_annual_bundled_refund': '0.00',
#   'spender_committee_designation': 'B',
#   'spender_committee_org_type': 'M',
#   'spender_committee_type': 'Q',
#   'sub_id': '4020520131180774317',
#   'transaction_id': '49256205',
#   'two_year_transaction_period': 2012,
#   'unused_recipient_committee_id': None},
#  {'amendment_indicator': 'A',
#   'amendment_indicator_desc': 'ADD',
#   'back_reference_schedule_id': None,
#   'back_reference_transaction_id': None,
#   'beneficiary_committee_name': None,
#   'candidate_first_name': 'THOMAS',
#   'candidate_id': None,
#   'candidate_last_name': 'GREASON',
#   'candidate_middle_name': 'A',
#   'candidate_name': 'GREASON, THOMAS A',
#   'candidate_office': 'H',
#   'candidate_office_description': 'HOUSE',
#   'candidate_office_district': '32',
#   'candidate_office_state': 'VA',
#   'candidate_office_state_full': 'VIRGINIA ',
#   'candidate_prefix': None,
#   'candidate_suffix': None,
#   'category_code': '011',
#   'category_code_full': 'Political Contributions',
#   'comm_dt': None,
#   'committee': {'affiliated_committee_name': 'THE NATIONAL RIFLE ASSOCIATION OF AMERICA',
#    'candidate_ids': [],
#    'city': 'FAIRFAX',
#    'committee_id': 'C00053553',
#    'committee_type': 'Q',
#    'committee_type_full': 'PAC - Qualified',
#    'cycle': 2012,
#    'cycles': [1976,
#     1978,
#     1980,
#     1982,
#     1984,
#     1986,
#     1988,
#     1990,
#     1992,
#     1994,
#     1996,
#     1998,
#     2000,
#     2002,
#     2004,
#     2006,
#     2008,
#     2010,
#     2012,
#     2014,
#     2016,
#     2018,
#     2020,
#     2022,
#     2024],
#    'cycles_has_activity': [1976,
#     1978,
#     1980,
#     1982,
#     1984,
#     1986,
#     1988,
#     1990,
#     1992,
#     1994,
#     1996,
#     1998,
#     2000,
#     2002,
#     2004,
#     2006,
#     2008,
#     2010,
#     2012,
#     2014,
#     2016,
#     2018,
#     2020,
#     2022,
#     2024],
#    'cycles_has_financial': [1976,
#     1978,
#     1980,
#     1982,
#     1984,
#     1986,
#     1988,
#     1990,
#     1992,
#     1994,
#     1996,
#     1998,
#     2000,
#     2002,
#     2004,
#     2006,
#     2008,
#     2010,
#     2012,
#     2014,
#     2016,
#     2018,
#     2020,
#     2022,
#     2024],
#    'designation': 'B',
#    'designation_full': 'Lobbyist/Registrant PAC',
#    'filing_frequency': 'M',
#    'first_f1_date': '1976-07-28',
#    'first_file_date': '1976-07-28',
#    'is_active': True,
#    'last_cycle_has_activity': 2024,
#    'last_cycle_has_financial': 2024,
#    'last_f1_date': '2023-04-20',
#    'last_file_date': '2023-07-31',
#    'name': 'NATIONAL RIFLE ASSOCIATION OF AMERICA POLITICAL VICTORY FUND',
#    'organization_type': 'M',
#    'organization_type_full': 'Membership Organization',
#    'party': 'UNK',
#    'party_full': 'UNKNOWN',
#    'state': 'VA',
#    'state_full': 'Virginia',
#    'street_1': '11250 WAPLES MILL ROAD',
#    'street_2': None,
#    'treasurer_name': 'ADKINS, MARY ROSE',
#    'zip': '22030'},
#   'committee_id': 'C00053553',
#   'conduit_committee_city': None,
#   'conduit_committee_name': None,
#   'conduit_committee_state': None,
#   'conduit_committee_street1': None,
#   'conduit_committee_street2': None,
#   'conduit_committee_zip': None,
#   'disbursement_amount': 1000.0,
#   'disbursement_date': '2012-12-31',
#   'disbursement_description': 'THOMAS GREASON, STATE HOUSE 32ND VA',
#   'disbursement_purpose_category': 'OTHER',
#   'disbursement_type': None,
#   'disbursement_type_description': None,
#   'election_type': 'G2013',
#   'election_type_full': None,
#   'entity_type': 'COM',
#   'entity_type_desc': 'OTHER COMMITTEE',
#   'fec_election_type_desc': 'GENERAL',
#   'fec_election_year': '2013',
#   'file_number': 852382,
#   'filing_form': 'F3X',
#   'image_number': '13960611630',
#   'line_number': '29',
#   'line_number_label': 'Other Disbursements',
#   'link_id': 4013120131180363071,
#   'load_date': '2017-05-31T20:12:38.059660',
#   'memo_code': None,
#   'memo_code_full': None,
#   'memo_text': 'THOMAS GREASON, STATE HOUSE 32ND VA',
#   'memoed_subtotal': False,
#   'national_committee_nonfederal_account': None,
#   'original_sub_id': None,
#   'payee_employer': None,
#   'payee_first_name': None,
#   'payee_last_name': None,
#   'payee_middle_name': None,
#   'payee_occupation': None,
#   'payee_prefix': None,
#   'payee_suffix': None,
#   'pdf_url': 'http://docquery.fec.gov/cgi-bin/fecimg/?13960611630',
#   'recipient_city': 'POTOMAC FALLS',
#   'recipient_committee': None,
#   'recipient_committee_id': None,
#   'recipient_name': 'FRIENDS OF TAG GREASON',
#   'recipient_state': 'VA',
#   'recipient_zip': '20165',
#   'ref_disp_excess_flg': None,
#   'report_type': 'YE',
#   'report_year': '2012',
#   'schedule_type': 'SB',
#   'schedule_type_full': 'ITEMIZED DISBURSEMENTS',
#   'semi_annual_bundled_refund': '0.00',
#   'spender_committee_designation': 'B',
#   'spender_committee_org_type': 'M',
#   'spender_committee_type': 'Q',
#   'sub_id': '4020520131180774316',
#   'transaction_id': '49255981',
#   'two_year_transaction_period': 2012,
#   'unused_recipient_committee_id': None},
#  {'amendment_indicator': 'A',
#   'amendment_indicator_desc': 'ADD',
#   'back_reference_schedule_id': None,
#   'back_reference_transaction_id': None,
#   'beneficiary_committee_name': None,
#   'candidate_first_name': 'DAVID',
#   'candidate_id': None,
#   'candidate_last_name': 'RAMADAN',
#   'candidate_middle_name': None,
#   'candidate_name': 'RAMADAN, DAVID',
#   'candidate_office': 'H',
#   'candidate_office_description': 'HOUSE',
#   'candidate_office_district': '87',
#   'candidate_office_state': 'VA',
#   'candidate_office_state_full': 'VIRGINIA ',
#   'candidate_prefix': None,
#   'candidate_suffix': None,
#   'category_code': '011',
#   'category_code_full': 'Political Contributions',
#   'comm_dt': None,
#   'committee': {'affiliated_committee_name': 'THE NATIONAL RIFLE ASSOCIATION OF AMERICA',
#    'candidate_ids': [],
#    'city': 'FAIRFAX',
#    'committee_id': 'C00053553',
#    'committee_type': 'Q',
#    'committee_type_full': 'PAC - Qualified',
#    'cycle': 2012,
#    'cycles': [1976,
#     1978,
#     1980,
#     1982,
#     1984,
#     1986,
#     1988,
#     1990,
#     1992,
#     1994,
#     1996,
#     1998,
#     2000,
#     2002,
#     2004,
#     2006,
#     2008,
#     2010,
#     2012,
#     2014,
#     2016,
#     2018,
#     2020,
#     2022,
#     2024],
#    'cycles_has_activity': [1976,
#     1978,
#     1980,
#     1982,
#     1984,
#     1986,
#     1988,
#     1990,
#     1992,
#     1994,
#     1996,
#     1998,
#     2000,
#     2002,
#     2004,
#     2006,
#     2008,
#     2010,
#     2012,
#     2014,
#     2016,
#     2018,
#     2020,
#     2022,
#     2024],
#    'cycles_has_financial': [1976,
#     1978,
#     1980,
#     1982,
#     1984,
#     1986,
#     1988,
#     1990,
#     1992,
#     1994,
#     1996,
#     1998,
#     2000,
#     2002,
#     2004,
#     2006,
#     2008,
#     2010,
#     2012,
#     2014,
#     2016,
#     2018,
#     2020,
#     2022,
#     2024],
#    'designation': 'B',
#    'designation_full': 'Lobbyist/Registrant PAC',
#    'filing_frequency': 'M',
#    'first_f1_date': '1976-07-28',
#    'first_file_date': '1976-07-28',
#    'is_active': True,
#    'last_cycle_has_activity': 2024,
#    'last_cycle_has_financial': 2024,
#    'last_f1_date': '2023-04-20',
#    'last_file_date': '2023-07-31',
#    'name': 'NATIONAL RIFLE ASSOCIATION OF AMERICA POLITICAL VICTORY FUND',
#    'organization_type': 'M',
#    'organization_type_full': 'Membership Organization',
#    'party': 'UNK',
#    'party_full': 'UNKNOWN',
#    'state': 'VA',
#    'state_full': 'Virginia',
#    'street_1': '11250 WAPLES MILL ROAD',
#    'street_2': None,
#    'treasurer_name': 'ADKINS, MARY ROSE',
#    'zip': '22030'},
#   'committee_id': 'C00053553',
#   'conduit_committee_city': None,
#   'conduit_committee_name': None,
#   'conduit_committee_state': None,
#   'conduit_committee_street1': None,
#   'conduit_committee_street2': None,
#   'conduit_committee_zip': None,
#   'disbursement_amount': 500.0,
#   'disbursement_date': '2012-12-31',
#   'disbursement_description': 'DAVID RAMADAN, STATE HOUSE 87TH VA',
#   'disbursement_purpose_category': 'OTHER',
#   'disbursement_type': None,
#   'disbursement_type_description': None,
#   'election_type': 'G2013',
#   'election_type_full': None,
#   'entity_type': 'COM',
#   'entity_type_desc': 'OTHER COMMITTEE',
#   'fec_election_type_desc': 'GENERAL',
#   'fec_election_year': '2013',
#   'file_number': 852382,
#   'filing_form': 'F3X',
#   'image_number': '13960611630',
#   'line_number': '29',
#   'line_number_label': 'Other Disbursements',
#   'link_id': 4013120131180363071,
#   'load_date': '2017-05-31T20:12:38.059660',
#   'memo_code': None,
#   'memo_code_full': None,
#   'memo_text': 'DAVID RAMADAN, STATE HOUSE 87TH VA',
#   'memoed_subtotal': False,
#   'national_committee_nonfederal_account': None,
#   'original_sub_id': None,
#   'payee_employer': None,
#   'payee_first_name': None,
#   'payee_last_name': None,
#   'payee_middle_name': None,
#   'payee_occupation': None,
#   'payee_prefix': None,
#   'payee_suffix': None,
#   'pdf_url': 'http://docquery.fec.gov/cgi-bin/fecimg/?13960611630',
#   'recipient_city': 'CHANTILLY',
#   'recipient_committee': None,
#   'recipient_committee_id': None,
#   'recipient_name': 'FRIENDS OF DAVID RAMADAN',
#   'recipient_state': 'VA',
#   'recipient_zip': '20152',
#   'ref_disp_excess_flg': None,
#   'report_type': 'YE',
#   'report_year': '2012',
#   'schedule_type': 'SB',
#   'schedule_type_full': 'ITEMIZED DISBURSEMENTS',
#   'semi_annual_bundled_refund': '0.00',
#   'spender_committee_designation': 'B',
#   'spender_committee_org_type': 'M',
#   'spender_committee_type': 'Q',
#   'sub_id': '4020520131180774315',
#   'transaction_id': '49255175',
#   'two_year_transaction_period': 2012,
#   'unused_recipient_committee_id': None},
#  {'amendment_indicator': 'A',
#   'amendment_indicator_desc': 'ADD',
#   'back_reference_schedule_id': None,
#   'back_reference_transaction_id': None,
#   'beneficiary_committee_name': None,
#   'candidate_first_name': 'RICHARD',
#   'candidate_id': None,
#   'candidate_last_name': 'ANDERSON',
#   'candidate_middle_name': None,
#   'candidate_name': 'ANDERSON, RICHARD VA DEL.',
#   'candidate_office': 'H',
#   'candidate_office_description': 'HOUSE',
#   'candidate_office_district': '51',
#   'candidate_office_state': 'VA',
#   'candidate_office_state_full': 'VIRGINIA ',
#   'candidate_prefix': 'VA DEL.',
#   'candidate_suffix': None,
#   'category_code': '011',
#   'category_code_full': 'Political Contributions',
#   'comm_dt': None,
#   'committee': {'affiliated_committee_name': 'THE NATIONAL RIFLE ASSOCIATION OF AMERICA',
#    'candidate_ids': [],
#    'city': 'FAIRFAX',
#    'committee_id': 'C00053553',
#    'committee_type': 'Q',
#    'committee_type_full': 'PAC - Qualified',
#    'cycle': 2012,
#    'cycles': [1976,
#     1978,
#     1980,
#     1982,
#     1984,
#     1986,
#     1988,
#     1990,
#     1992,
#     1994,
#     1996,
#     1998,
#     2000,
#     2002,
#     2004,
#     2006,
#     2008,
#     2010,
#     2012,
#     2014,
#     2016,
#     2018,
#     2020,
#     2022,
#     2024],
#    'cycles_has_activity': [1976,
#     1978,
#     1980,
#     1982,
#     1984,
#     1986,
#     1988,
#     1990,
#     1992,
#     1994,
#     1996,
#     1998,
#     2000,
#     2002,
#     2004,
#     2006,
#     2008,
#     2010,
#     2012,
#     2014,
#     2016,
#     2018,
#     2020,
#     2022,
#     2024],
#    'cycles_has_financial': [1976,
#     1978,
#     1980,
#     1982,
#     1984,
#     1986,
#     1988,
#     1990,
#     1992,
#     1994,
#     1996,
#     1998,
#     2000,
#     2002,
#     2004,
#     2006,
#     2008,
#     2010,
#     2012,
#     2014,
#     2016,
#     2018,
#     2020,
#     2022,
#     2024],
#    'designation': 'B',
#    'designation_full': 'Lobbyist/Registrant PAC',
#    'filing_frequency': 'M',
#    'first_f1_date': '1976-07-28',
#    'first_file_date': '1976-07-28',
#    'is_active': True,
#    'last_cycle_has_activity': 2024,
#    'last_cycle_has_financial': 2024,
#    'last_f1_date': '2023-04-20',
#    'last_file_date': '2023-07-31',
#    'name': 'NATIONAL RIFLE ASSOCIATION OF AMERICA POLITICAL VICTORY FUND',
#    'organization_type': 'M',
#    'organization_type_full': 'Membership Organization',
#    'party': 'UNK',
#    'party_full': 'UNKNOWN',
#    'state': 'VA',
#    'state_full': 'Virginia',
#    'street_1': '11250 WAPLES MILL ROAD',
#    'street_2': None,
#    'treasurer_name': 'ADKINS, MARY ROSE',
#    'zip': '22030'},
#   'committee_id': 'C00053553',
#   'conduit_committee_city': None,
#   'conduit_committee_name': None,
#   'conduit_committee_state': None,
#   'conduit_committee_street1': None,
#   'conduit_committee_street2': None,
#   'conduit_committee_zip': None,
#   'disbursement_amount': 250.0,
#   'disbursement_date': '2012-12-31',
#   'disbursement_description': 'RICHARD ANDERSON, STATE HOUSE 51ST VA',
#   'disbursement_purpose_category': 'OTHER',
#   'disbursement_type': None,
#   'disbursement_type_description': None,
#   'election_type': 'G2013',
#   'election_type_full': None,
#   'entity_type': 'COM',
#   'entity_type_desc': 'OTHER COMMITTEE',
#   'fec_election_type_desc': 'GENERAL',
#   'fec_election_year': '2013',
#   'file_number': 852382,
#   'filing_form': 'F3X',
#   'image_number': '13960611629',
#   'line_number': '29',
#   'line_number_label': 'Other Disbursements',
#   'link_id': 4013120131180363071,
#   'load_date': '2017-05-31T20:12:38.059660',
#   'memo_code': None,
#   'memo_code_full': None,
#   'memo_text': 'RICHARD ANDERSON, STATE HOUSE 51ST VA',
#   'memoed_subtotal': False,
#   'national_committee_nonfederal_account': None,
#   'original_sub_id': None,
#   'payee_employer': None,
#   'payee_first_name': None,
#   'payee_last_name': None,
#   'payee_middle_name': None,
#   'payee_occupation': None,
#   'payee_prefix': None,
#   'payee_suffix': None,
#   'pdf_url': 'http://docquery.fec.gov/cgi-bin/fecimg/?13960611629',
#   'recipient_city': 'WOODBRIDGE',
#   'recipient_committee': None,
#   'recipient_committee_id': None,
#   'recipient_name': 'FRIENDS OF RICH ANDERSON',
#   'recipient_state': 'VA',
#   'recipient_zip': '22195',
#   'ref_disp_excess_flg': None,
#   'report_type': 'YE',
#   'report_year': '2012',
#   'schedule_type': 'SB',
#   'schedule_type_full': 'ITEMIZED DISBURSEMENTS',
#   'semi_annual_bundled_refund': '0.00',
#   'spender_committee_designation': 'B',
#   'spender_committee_org_type': 'M',
#   'spender_committee_type': 'Q',
#   'sub_id': '4020520131180774314',
#   'transaction_id': '49255173',
#   'two_year_transaction_period': 2012,
#   'unused_recipient_committee_id': None},
#  {'amendment_indicator': 'A',
#   'amendment_indicator_desc': 'ADD',
#   'back_reference_schedule_id': None,
#   'back_reference_transaction_id': None,
#   'beneficiary_committee_name': None,
#   'candidate_first_name': None,
#   'candidate_id': None,
#   'candidate_last_name': None,
#   'candidate_middle_name': None,
#   'candidate_name': None,
#   'candidate_office': None,
#   'candidate_office_description': None,
#   'candidate_office_district': None,
#   'candidate_office_state': None,
#   'candidate_office_state_full': None,
#   'candidate_prefix': None,
#   'candidate_suffix': None,
#   'category_code': '011',
#   'category_code_full': 'Political Contributions',
#   'comm_dt': None,
#   'committee': {'affiliated_committee_name': 'THE NATIONAL RIFLE ASSOCIATION OF AMERICA',
#    'candidate_ids': [],
#    'city': 'FAIRFAX',
#    'committee_id': 'C00053553',
#    'committee_type': 'Q',
#    'committee_type_full': 'PAC - Qualified',
#    'cycle': 2012,
#    'cycles': [1976,
#     1978,
#     1980,
#     1982,
#     1984,
#     1986,
#     1988,
#     1990,
#     1992,
#     1994,
#     1996,
#     1998,
#     2000,
#     2002,
#     2004,
#     2006,
#     2008,
#     2010,
#     2012,
#     2014,
#     2016,
#     2018,
#     2020,
#     2022,
#     2024],
#    'cycles_has_activity': [1976,
#     1978,
#     1980,
#     1982,
#     1984,
#     1986,
#     1988,
#     1990,
#     1992,
#     1994,
#     1996,
#     1998,
#     2000,
#     2002,
#     2004,
#     2006,
#     2008,
#     2010,
#     2012,
#     2014,
#     2016,
#     2018,
#     2020,
#     2022,
#     2024],
#    'cycles_has_financial': [1976,
#     1978,
#     1980,
#     1982,
#     1984,
#     1986,
#     1988,
#     1990,
#     1992,
#     1994,
#     1996,
#     1998,
#     2000,
#     2002,
#     2004,
#     2006,
#     2008,
#     2010,
#     2012,
#     2014,
#     2016,
#     2018,
#     2020,
#     2022,
#     2024],
#    'designation': 'B',
#    'designation_full': 'Lobbyist/Registrant PAC',
#    'filing_frequency': 'M',
#    'first_f1_date': '1976-07-28',
#    'first_file_date': '1976-07-28',
#    'is_active': True,
#    'last_cycle_has_activity': 2024,
#    'last_cycle_has_financial': 2024,
#    'last_f1_date': '2023-04-20',
#    'last_file_date': '2023-07-31',
#    'name': 'NATIONAL RIFLE ASSOCIATION OF AMERICA POLITICAL VICTORY FUND',
#    'organization_type': 'M',
#    'organization_type_full': 'Membership Organization',
#    'party': 'UNK',
#    'party_full': 'UNKNOWN',
#    'state': 'VA',
#    'state_full': 'Virginia',
#    'street_1': '11250 WAPLES MILL ROAD',
#    'street_2': None,
#    'treasurer_name': 'ADKINS, MARY ROSE',
#    'zip': '22030'},
#   'committee_id': 'C00053553',
#   'conduit_committee_city': None,
#   'conduit_committee_name': None,
#   'conduit_committee_state': None,
#   'conduit_committee_street1': None,
#   'conduit_committee_street2': None,
#   'conduit_committee_zip': None,
#   'disbursement_amount': 500.0,
#   'disbursement_date': '2012-12-31',
#   'disbursement_description': None,
#   'disbursement_purpose_category': 'OTHER',
#   'disbursement_type': None,
#   'disbursement_type_description': None,
#   'election_type': None,
#   'election_type_full': None,
#   'entity_type': 'PTY',
#   'entity_type_desc': 'POLITICAL PARTY COMMITTEE',
#   'fec_election_type_desc': None,
#   'fec_election_year': None,
#   'file_number': 852382,
#   'filing_form': 'F3X',
#   'image_number': '13960611629',
#   'line_number': '29',
#   'line_number_label': 'Other Disbursements',
#   'link_id': 4013120131180363071,
#   'load_date': '2017-05-31T20:12:38.059660',
#   'memo_code': None,
#   'memo_code_full': None,
#   'memo_text': None,
#   'memoed_subtotal': False,
#   'national_committee_nonfederal_account': None,
#   'original_sub_id': None,
#   'payee_employer': None,
#   'payee_first_name': None,
#   'payee_last_name': None,
#   'payee_middle_name': None,
#   'payee_occupation': None,
#   'payee_prefix': None,
#   'payee_suffix': None,
#   'pdf_url': 'http://docquery.fec.gov/cgi-bin/fecimg/?13960611629',
#   'recipient_city': 'WILLIAMSBURG',
#   'recipient_committee': None,
#   'recipient_committee_id': None,
#   'recipient_name': 'VIRGINIA SENATE REPUBLICAN CAUCUS',
#   'recipient_state': 'VA',
#   'recipient_zip': '23187',
#   'ref_disp_excess_flg': None,
#   'report_type': 'YE',
#   'report_year': '2012',
#   'schedule_type': 'SB',
#   'schedule_type_full': 'ITEMIZED DISBURSEMENTS',
#   'semi_annual_bundled_refund': '0.00',
#   'spender_committee_designation': 'B',
#   'spender_committee_org_type': 'M',
#   'spender_committee_type': 'Q',
#   'sub_id': '4020520131180774313',
#   'transaction_id': '49255172',
#   'two_year_transaction_period': 2012,
#   'unused_recipient_committee_id': None},
#  {'amendment_indicator': 'A',
#   'amendment_indicator_desc': 'ADD',
#   'back_reference_schedule_id': None,
#   'back_reference_transaction_id': None,
#   'beneficiary_committee_name': None,
#   'candidate_first_name': None,
#   'candidate_id': None,
#   'candidate_last_name': None,
#   'candidate_middle_name': None,
#   'candidate_name': None,
#   'candidate_office': None,
#   'candidate_office_description': None,
#   'candidate_office_district': None,
#   'candidate_office_state': None,
#   'candidate_office_state_full': None,
#   'candidate_prefix': None,
#   'candidate_suffix': None,
#   'category_code': '011',
#   'category_code_full': 'Political Contributions',
#   'comm_dt': None,
#   'committee': {'affiliated_committee_name': 'THE NATIONAL RIFLE ASSOCIATION OF AMERICA',
#    'candidate_ids': [],
#    'city': 'FAIRFAX',
#    'committee_id': 'C00053553',
#    'committee_type': 'Q',
#    'committee_type_full': 'PAC - Qualified',
#    'cycle': 2012,
#    'cycles': [1976,
#     1978,
#     1980,
#     1982,
#     1984,
#     1986,
#     1988,
#     1990,
#     1992,
#     1994,
#     1996,
#     1998,
#     2000,
#     2002,
#     2004,
#     2006,
#     2008,
#     2010,
#     2012,
#     2014,
#     2016,
#     2018,
#     2020,
#     2022,
#     2024],
#    'cycles_has_activity': [1976,
#     1978,
#     1980,
#     1982,
#     1984,
#     1986,
#     1988,
#     1990,
#     1992,
#     1994,
#     1996,
#     1998,
#     2000,
#     2002,
#     2004,
#     2006,
#     2008,
#     2010,
#     2012,
#     2014,
#     2016,
#     2018,
#     2020,
#     2022,
#     2024],
#    'cycles_has_financial': [1976,
#     1978,
#     1980,
#     1982,
#     1984,
#     1986,
#     1988,
#     1990,
#     1992,
#     1994,
#     1996,
#     1998,
#     2000,
#     2002,
#     2004,
#     2006,
#     2008,
#     2010,
#     2012,
#     2014,
#     2016,
#     2018,
#     2020,
#     2022,
#     2024],
#    'designation': 'B',
#    'designation_full': 'Lobbyist/Registrant PAC',
#    'filing_frequency': 'M',
#    'first_f1_date': '1976-07-28',
#    'first_file_date': '1976-07-28',
#    'is_active': True,
#    'last_cycle_has_activity': 2024,
#    'last_cycle_has_financial': 2024,
#    'last_f1_date': '2023-04-20',
#    'last_file_date': '2023-07-31',
#    'name': 'NATIONAL RIFLE ASSOCIATION OF AMERICA POLITICAL VICTORY FUND',
#    'organization_type': 'M',
#    'organization_type_full': 'Membership Organization',
#    'party': 'UNK',
#    'party_full': 'UNKNOWN',
#    'state': 'VA',
#    'state_full': 'Virginia',
#    'street_1': '11250 WAPLES MILL ROAD',
#    'street_2': None,
#    'treasurer_name': 'ADKINS, MARY ROSE',
#    'zip': '22030'},
#   'committee_id': 'C00053553',
#   'conduit_committee_city': None,
#   'conduit_committee_name': None,
#   'conduit_committee_state': None,
#   'conduit_committee_street1': None,
#   'conduit_committee_street2': None,
#   'conduit_committee_zip': None,
#   'disbursement_amount': 500.0,
#   'disbursement_date': '2012-12-31',
#   'disbursement_description': None,
#   'disbursement_purpose_category': 'OTHER',
#   'disbursement_type': None,
#   'disbursement_type_description': None,
#   'election_type': None,
#   'election_type_full': None,
#   'entity_type': 'ORG',
#   'entity_type_desc': 'ORGANIZATION',
#   'fec_election_type_desc': None,
#   'fec_election_year': None,
#   'file_number': 852382,
#   'filing_form': 'F3X',
#   'image_number': '13960611629',
#   'line_number': '29',
#   'line_number_label': 'Other Disbursements',
#   'link_id': 4013120131180363071,
#   'load_date': '2017-05-31T20:12:38.059660',
#   'memo_code': None,
#   'memo_code_full': None,
#   'memo_text': None,
#   'memoed_subtotal': False,
#   'national_committee_nonfederal_account': None,
#   'original_sub_id': None,
#   'payee_employer': None,
# ...
#    'first_f1_date': '1976-07-28',
#    'first_file_date': '1976-07-28',
#    'is_active': True,
#    'last_cycle_has_activity': 2024,
#    'last_cycle_has_financial': 2024,
#    'last_f1_date': '2023-04-20',
#    'last_file_date': '2023-07-31',
#    'name': 'NATIONAL RIFLE ASSOCIATION OF AMERICA POLITICAL VICTORY FUND',
#    'organization_type': 'M',
#    'organization_type_full': 'Membership Organization',
#    'party': 'UNK',
#    'party_full': 'UNKNOWN',
#    'state': 'VA',
#    'state_full': 'Virginia',
#    'street_1': '11250 WAPLES MILL ROAD',
#    'street_2': None,
#    'treasurer_name': 'ADKINS, MARY ROSE',
#    'zip': '22030'},
#   'committee_id': 'C00053553',
#   'conduit_committee_city': None,
#   'conduit_committee_name': None,
#   'conduit_committee_state': None,
#   'conduit_committee_street1': None,
#   'conduit_committee_street2': None,
#   'conduit_committee_zip': None,
#   'disbursement_amount': 5607.59,
#   'disbursement_date': '2012-10-31',
#   'disbursement_description': 'CREDIT CARD FEES',
#   'disbursement_purpose_category': 'OTHER',
#   'disbursement_type': None,
#   'disbursement_type_description': None,
#   'election_type': None,
#   'election_type_full': None,
#   'entity_type': 'ORG',
#   'entity_type_desc': 'ORGANIZATION',
#   'fec_election_type_desc': None,
#   'fec_election_year': None,
#   'file_number': 863519,
#   'filing_form': 'F3X',
#   'image_number': '13961233935',
#   'line_number': '21B',
#   'line_number_label': 'Other Federal Operating Expenditures',
#   'link_id': 4032920131185865923,
#   'load_date': '2017-05-31T20:12:38.059660',
#   'memo_code': None,
#   'memo_code_full': None,
#   'memo_text': 'CREDIT CARD FEES',
#   'memoed_subtotal': False,
#   'national_committee_nonfederal_account': None,
#   'original_sub_id': None,
#   'payee_employer': None,
#   'payee_first_name': None,
#   'payee_last_name': None,
#   'payee_middle_name': None,
#   'payee_occupation': None,
#   'payee_prefix': None,
#   'payee_suffix': None,
#   'pdf_url': 'http://docquery.fec.gov/cgi-bin/fecimg/?13961233935',
#   'recipient_city': 'SALEM',
#   'recipient_committee': None,
#   'recipient_committee_id': None,
#   'recipient_name': 'PAYMENTECH, INC.',
#   'recipient_state': 'NH',
#   'recipient_zip': '03079',
#   'ref_disp_excess_flg': None,
#   'report_type': '30G',
#   'report_year': '2012',
#   'schedule_type': 'SB',
#   'schedule_type_full': 'ITEMIZED DISBURSEMENTS',
#   'semi_annual_bundled_refund': '0.00',
#   'spender_committee_designation': 'B',
#   'spender_committee_org_type': 'M',
#   'spender_committee_type': 'Q',
#   'sub_id': '4040220131185979476',
#   'transaction_id': '48698309',
#   'two_year_transaction_period': 2012,
#   'unused_recipient_committee_id': None},
#  {'amendment_indicator': 'N',
#   'amendment_indicator_desc': 'NO CHANGE',
#   'back_reference_schedule_id': None,
#   'back_reference_transaction_id': None,
#   'beneficiary_committee_name': None,
#   'candidate_first_name': None,
#   'candidate_id': None,
#   'candidate_last_name': None,
#   'candidate_middle_name': None,
#   'candidate_name': None,
#   'candidate_office': None,
#   'candidate_office_description': None,
#   'candidate_office_district': None,
#   'candidate_office_state': None,
#   'candidate_office_state_full': None,
#   'candidate_prefix': None,
#   'candidate_suffix': None,
#   'category_code': '001',
#   'category_code_full': 'Administrative/Salary/Overhead Expenses ',
#   'comm_dt': None,
#   'committee': {'affiliated_committee_name': 'THE NATIONAL RIFLE ASSOCIATION OF AMERICA',
#    'candidate_ids': [],
#    'city': 'FAIRFAX',
#    'committee_id': 'C00053553',
#    'committee_type': 'Q',
#    'committee_type_full': 'PAC - Qualified',
#    'cycle': 2012,
#    'cycles': [1976,
#     1978,
#     1980,
#     1982,
#     1984,
#     1986,
#     1988,
#     1990,
#     1992,
#     1994,
#     1996,
#     1998,
#     2000,
#     2002,
#     2004,
#     2006,
#     2008,
#     2010,
#     2012,
#     2014,
#     2016,
#     2018,
#     2020,
#     2022,
#     2024],
#    'cycles_has_activity': [1976,
#     1978,
#     1980,
#     1982,
#     1984,
#     1986,
#     1988,
#     1990,
#     1992,
#     1994,
#     1996,
#     1998,
#     2000,
#     2002,
#     2004,
#     2006,
#     2008,
#     2010,
#     2012,
#     2014,
#     2016,
#     2018,
#     2020,
#     2022,
#     2024],
#    'cycles_has_financial': [1976,
#     1978,
#     1980,
#     1982,
#     1984,
#     1986,
#     1988,
#     1990,
#     1992,
#     1994,
#     1996,
#     1998,
#     2000,
#     2002,
#     2004,
#     2006,
#     2008,
#     2010,
#     2012,
#     2014,
#     2016,
#     2018,
#     2020,
#     2022,
#     2024],
#    'designation': 'B',
#    'designation_full': 'Lobbyist/Registrant PAC',
#    'filing_frequency': 'M',
#    'first_f1_date': '1976-07-28',
#    'first_file_date': '1976-07-28',
#    'is_active': True,
#    'last_cycle_has_activity': 2024,
#    'last_cycle_has_financial': 2024,
#    'last_f1_date': '2023-04-20',
#    'last_file_date': '2023-07-31',
#    'name': 'NATIONAL RIFLE ASSOCIATION OF AMERICA POLITICAL VICTORY FUND',
#    'organization_type': 'M',
#    'organization_type_full': 'Membership Organization',
#    'party': 'UNK',
#    'party_full': 'UNKNOWN',
#    'state': 'VA',
#    'state_full': 'Virginia',
#    'street_1': '11250 WAPLES MILL ROAD',
#    'street_2': None,
#    'treasurer_name': 'ADKINS, MARY ROSE',
#    'zip': '22030'},
#   'committee_id': 'C00053553',
#   'conduit_committee_city': None,
#   'conduit_committee_name': None,
#   'conduit_committee_state': None,
#   'conduit_committee_street1': None,
#   'conduit_committee_street2': None,
#   'conduit_committee_zip': None,
#   'disbursement_amount': 917.66,
#   'disbursement_date': '2012-10-31',
#   'disbursement_description': 'CREDIT CARD FEES',
#   'disbursement_purpose_category': 'OTHER',
#   'disbursement_type': None,
#   'disbursement_type_description': None,
#   'election_type': None,
#   'election_type_full': None,
#   'entity_type': 'ORG',
#   'entity_type_desc': 'ORGANIZATION',
#   'fec_election_type_desc': None,
#   'fec_election_year': None,
#   'file_number': 863519,
#   'filing_form': 'F3X',
#   'image_number': '13961233935',
#   'line_number': '21B',
#   'line_number_label': 'Other Federal Operating Expenditures',
#   'link_id': 4032920131185865923,
#   'load_date': '2017-05-31T20:12:38.059660',
#   'memo_code': None,
#   'memo_code_full': None,
#   'memo_text': 'CREDIT CARD FEES',
#   'memoed_subtotal': False,
#   'national_committee_nonfederal_account': None,
#   'original_sub_id': None,
#   'payee_employer': None,
#   'payee_first_name': None,
#   'payee_last_name': None,
#   'payee_middle_name': None,
#   'payee_occupation': None,
#   'payee_prefix': None,
#   'payee_suffix': None,
#   'pdf_url': 'http://docquery.fec.gov/cgi-bin/fecimg/?13961233935',
#   'recipient_city': 'PHOENIX',
#   'recipient_committee': None,
#   'recipient_committee_id': None,
#   'recipient_name': 'AMERICAN EXPRESS COMPANY',
#   'recipient_state': 'AZ',
#   'recipient_zip': '85072',
#   'ref_disp_excess_flg': None,
#   'report_type': '30G',
#   'report_year': '2012',
#   'schedule_type': 'SB',
#   'schedule_type_full': 'ITEMIZED DISBURSEMENTS',
#   'semi_annual_bundled_refund': '0.00',
#   'spender_committee_designation': 'B',
#   'spender_committee_org_type': 'M',
#   'spender_committee_type': 'Q',
#   'sub_id': '4040220131185979475',
#   'transaction_id': '48698308',
#   'two_year_transaction_period': 2012,
#   'unused_recipient_committee_id': None},
#  {'amendment_indicator': 'N',
#   'amendment_indicator_desc': 'NO CHANGE',
#   'back_reference_schedule_id': None,
#   'back_reference_transaction_id': None,
#   'beneficiary_committee_name': None,
#   'candidate_first_name': None,
#   'candidate_id': None,
#   'candidate_last_name': None,
#   'candidate_middle_name': None,
#   'candidate_name': None,
#   'candidate_office': None,
#   'candidate_office_description': None,
#   'candidate_office_district': None,
#   'candidate_office_state': None,
#   'candidate_office_state_full': None,
#   'candidate_prefix': None,
#   'candidate_suffix': None,
#   'category_code': '001',
#   'category_code_full': 'Administrative/Salary/Overhead Expenses ',
#   'comm_dt': None,
#   'committee': {'affiliated_committee_name': 'THE NATIONAL RIFLE ASSOCIATION OF AMERICA',
#    'candidate_ids': [],
#    'city': 'FAIRFAX',
#    'committee_id': 'C00053553',
#    'committee_type': 'Q',
#    'committee_type_full': 'PAC - Qualified',
#    'cycle': 2012,
#    'cycles': [1976,
#     1978,
#     1980,
#     1982,
#     1984,
#     1986,
#     1988,
#     1990,
#     1992,
#     1994,
#     1996,
#     1998,
#     2000,
#     2002,
#     2004,
#     2006,
#     2008,
#     2010,
#     2012,
#     2014,
#     2016,
#     2018,
#     2020,
#     2022,
#     2024],
#    'cycles_has_activity': [1976,
#     1978,
#     1980,
#     1982,
#     1984,
#     1986,
#     1988,
#     1990,
#     1992,
#     1994,
#     1996,
#     1998,
#     2000,
#     2002,
#     2004,
#     2006,
#     2008,
#     2010,
#     2012,
#     2014,
#     2016,
#     2018,
#     2020,
#     2022,
#     2024],
#    'cycles_has_financial': [1976,
#     1978,
#     1980,
#     1982,
#     1984,
#     1986,
#     1988,
#     1990,
#     1992,
#     1994,
#     1996,
#     1998,
#     2000,
#     2002,
#     2004,
#     2006,
#     2008,
#     2010,
#     2012,
#     2014,
#     2016,
#     2018,
#     2020,
#     2022,
#     2024],
#    'designation': 'B',
#    'designation_full': 'Lobbyist/Registrant PAC',
#    'filing_frequency': 'M',
#    'first_f1_date': '1976-07-28',
#    'first_file_date': '1976-07-28',
#    'is_active': True,
#    'last_cycle_has_activity': 2024,
#    'last_cycle_has_financial': 2024,
#    'last_f1_date': '2023-04-20',
#    'last_file_date': '2023-07-31',
#    'name': 'NATIONAL RIFLE ASSOCIATION OF AMERICA POLITICAL VICTORY FUND',
#    'organization_type': 'M',
#    'organization_type_full': 'Membership Organization',
#    'party': 'UNK',
#    'party_full': 'UNKNOWN',
#    'state': 'VA',
#    'state_full': 'Virginia',
#    'street_1': '11250 WAPLES MILL ROAD',
#    'street_2': None,
#    'treasurer_name': 'ADKINS, MARY ROSE',
#    'zip': '22030'},
#   'committee_id': 'C00053553',
#   'conduit_committee_city': None,
#   'conduit_committee_name': None,
#   'conduit_committee_state': None,
#   'conduit_committee_street1': None,
#   'conduit_committee_street2': None,
#   'conduit_committee_zip': None,
#   'disbursement_amount': 55.0,
#   'disbursement_date': '2012-10-31',
#   'disbursement_description': 'ACCOUNT ANALYSIS FEES',
#   'disbursement_purpose_category': 'OTHER',
#   'disbursement_type': None,
#   'disbursement_type_description': None,
#   'election_type': None,
#   'election_type_full': None,
#   'entity_type': 'ORG',
#   'entity_type_desc': 'ORGANIZATION',
#   'fec_election_type_desc': None,
#   'fec_election_year': None,
#   'file_number': 863519,
#   'filing_form': 'F3X',
#   'image_number': '13961233934',
#   'line_number': '21B',
#   'line_number_label': 'Other Federal Operating Expenditures',
#   'link_id': 4032920131185865923,
#   'load_date': '2017-05-31T20:12:38.059660',
#   'memo_code': None,
#   'memo_code_full': None,
#   'memo_text': 'ACCOUNT ANALYSIS FEES',
#   'memoed_subtotal': False,
#   'national_committee_nonfederal_account': None,
#   'original_sub_id': None,
#   'payee_employer': None,
#   'payee_first_name': None,
#   'payee_last_name': None,
#   'payee_middle_name': None,
#   'payee_occupation': None,
#   'payee_prefix': None,
#   'payee_suffix': None,
#   'pdf_url': 'http://docquery.fec.gov/cgi-bin/fecimg/?13961233934',
#   'recipient_city': 'MCLEAN',
#   'recipient_committee': None,
#   'recipient_committee_id': None,
#   'recipient_name': 'WELLS FARGO BANK, N.A.',
#   'recipient_state': 'VA',
#   'recipient_zip': '22101',
#   'ref_disp_excess_flg': None,
#   'report_type': '30G',
#   'report_year': '2012',
#   'schedule_type': 'SB',
#   'schedule_type_full': 'ITEMIZED DISBURSEMENTS',
#   'semi_annual_bundled_refund': '0.00',
#   'spender_committee_designation': 'B',
#   'spender_committee_org_type': 'M',
#   'spender_committee_type': 'Q',
#   'sub_id': '4040220131185979473',
#   'transaction_id': '48697760',
#   'two_year_transaction_period': 2012,
#   'unused_recipient_committee_id': None},
#  {'amendment_indicator': 'N',
#   'amendment_indicator_desc': 'NO CHANGE',
#   'back_reference_schedule_id': None,
#   'back_reference_transaction_id': None,
#   'beneficiary_committee_name': None,
#   'candidate_first_name': None,
#   'candidate_id': None,
#   'candidate_last_name': None,
#   'candidate_middle_name': None,
#   'candidate_name': None,
#   'candidate_office': None,
#   'candidate_office_description': None,
#   'candidate_office_district': None,
#   'candidate_office_state': None,
#   'candidate_office_state_full': None,
#   'candidate_prefix': None,
#   'candidate_suffix': None,
#   'category_code': '001',
#   'category_code_full': 'Administrative/Salary/Overhead Expenses ',
#   'comm_dt': None,
#   'committee': {'affiliated_committee_name': 'THE NATIONAL RIFLE ASSOCIATION OF AMERICA',
#    'candidate_ids': [],
#    'city': 'FAIRFAX',
#    'committee_id': 'C00053553',
#    'committee_type': 'Q',
#    'committee_type_full': 'PAC - Qualified',
#    'cycle': 2012,
#    'cycles': [1976,
#     1978,
#     1980,
#     1982,
#     1984,
#     1986,
#     1988,
#     1990,
#     1992,
#     1994,
#     1996,
#     1998,
#     2000,
#     2002,
#     2004,
#     2006,
#     2008,
#     2010,
#     2012,
#     2014,
#     2016,
#     2018,
#     2020,
#     2022,
#     2024],
#    'cycles_has_activity': [1976,
#     1978,
#     1980,
#     1982,
#     1984,
#     1986,
#     1988,
#     1990,
#     1992,
#     1994,
#     1996,
#     1998,
#     2000,
#     2002,
#     2004,
#     2006,
#     2008,
#     2010,
#     2012,
#     2014,
#     2016,
#     2018,
#     2020,
#     2022,
#     2024],
#    'cycles_has_financial': [1976,
#     1978,
#     1980,
#     1982,
#     1984,
#     1986,
#     1988,
#     1990,
#     1992,
#     1994,
#     1996,
#     1998,
#     2000,
#     2002,
#     2004,
#     2006,
#     2008,
#     2010,
#     2012,
#     2014,
#     2016,
#     2018,
#     2020,
#     2022,
#     2024],
#    'designation': 'B',
#    'designation_full': 'Lobbyist/Registrant PAC',
#    'filing_frequency': 'M',
#    'first_f1_date': '1976-07-28',
#    'first_file_date': '1976-07-28',
#    'is_active': True,
#    'last_cycle_has_activity': 2024,
#    'last_cycle_has_financial': 2024,
#    'last_f1_date': '2023-04-20',
#    'last_file_date': '2023-07-31',
#    'name': 'NATIONAL RIFLE ASSOCIATION OF AMERICA POLITICAL VICTORY FUND',
#    'organization_type': 'M',
#    'organization_type_full': 'Membership Organization',
#    'party': 'UNK',
#    'party_full': 'UNKNOWN',
#    'state': 'VA',
#    'state_full': 'Virginia',
#    'street_1': '11250 WAPLES MILL ROAD',
#    'street_2': None,
#    'treasurer_name': 'ADKINS, MARY ROSE',
#    'zip': '22030'},
#   'committee_id': 'C00053553',
#   'conduit_committee_city': None,
#   'conduit_committee_name': None,
#   'conduit_committee_state': None,
#   'conduit_committee_street1': None,
#   'conduit_committee_street2': None,
#   'conduit_committee_zip': None,
#   'disbursement_amount': 419.25,
#   'disbursement_date': '2012-10-31',
#   'disbursement_description': 'ACCOUNT ANALYSIS FEES',
#   'disbursement_purpose_category': 'OTHER',
#   'disbursement_type': None,
#   'disbursement_type_description': None,
#   'election_type': None,
#   'election_type_full': None,
#   'entity_type': 'ORG',
#   'entity_type_desc': 'ORGANIZATION',
#   'fec_election_type_desc': None,
#   'fec_election_year': None,
#   'file_number': 863519,
#   'filing_form': 'F3X',
#   'image_number': '13961233934',
#   'line_number': '21B',
#   'line_number_label': 'Other Federal Operating Expenditures',
#   'link_id': 4032920131185865923,
#   'load_date': '2017-05-31T20:12:38.059660',
#   'memo_code': None,
#   'memo_code_full': None,
#   'memo_text': 'ACCOUNT ANALYSIS FEES',
#   'memoed_subtotal': False,
#   'national_committee_nonfederal_account': None,
#   'original_sub_id': None,
#   'payee_employer': None,
#   'payee_first_name': None,
#   'payee_last_name': None,
#   'payee_middle_name': None,
#   'payee_occupation': None,
#   'payee_prefix': None,
#   'payee_suffix': None,
#   'pdf_url': 'http://docquery.fec.gov/cgi-bin/fecimg/?13961233934',
#   'recipient_city': 'ST. LOUIS',
#   'recipient_committee': None,
#   'recipient_committee_id': None,
#   'recipient_name': 'BANK OF AMERICA - MO',
#   'recipient_state': 'MO',
#   'recipient_zip': '63106',
#   'ref_disp_excess_flg': None,
#   'report_type': '30G',
#   'report_year': '2012',
#   'schedule_type': 'SB',
#   'schedule_type_full': 'ITEMIZED DISBURSEMENTS',
#   'semi_annual_bundled_refund': '0.00',
#   'spender_committee_designation': 'B',
#   'spender_committee_org_type': 'M',
#   'spender_committee_type': 'Q',
#   'sub_id': '4040220131185979472',
#   'transaction_id': '48697759',
#   'two_year_transaction_period': 2012,
#   'unused_recipient_committee_id': None}]

# %%
# create while loop for pagination capture

# variables set by first page request, count set to track number of pages requested
last_disbursement_date = '2012-10-31'
last_index = '4040220131185979472'
count = 1

while True:
    try:
        # api request that inserts api key variable, as well as the last index and disbursement date from the first page request
        nra_rq_loop = rq.get(f'https://api.open.fec.gov/v1/schedules/schedule_b/?committee_id=C00053553&spender_committee_designation=A&spender_committee_designation=J&spender_committee_designation=P&spender_committee_designation=B&spender_committee_designation=D&spender_committee_org_type=C&spender_committee_org_type=L&spender_committee_org_type=M&spender_committee_org_type=T&spender_committee_org_type=V&spender_committee_org_type=W&spender_committee_type=C&spender_committee_type=D&spender_committee_type=E&spender_committee_type=H&spender_committee_type=I&spender_committee_type=N&spender_committee_type=O&spender_committee_type=P&spender_committee_type=Q&spender_committee_type=S&spender_committee_type=U&spender_committee_type=V&spender_committee_type=W&two_year_transaction_period=2012&per_page=100&sort=-disbursement_date&sort_hide_null=false&sort_null_only=false&api_key={api_key_fec}&last_index={last_index}&last_disbursement_date={last_disbursement_date}')

        # check status during while loop
        print(f'Requesting page {count}')
        nra_rq_loop.raise_for_status()

        # convert request into json file
        nra_json_loop = nra_rq_loop.json()

        # move through json to pull new last index and disbursement dates
        nra_page_loop = nra_json_loop['pagination']
        nra_index_loop = nra_page_loop['last_indexes']
        last_index = nra_index_loop['last_index']
        last_disbursement_date = nra_index_loop['last_disbursement_date']
       
        # convert loop into a list and append to nra_list
        nra_list_loop = list(nra_json_loop)
        nra_list.append(nra_list_loop)
        
        # add to counter
        count += 1
        
    except TypeError:
        print('No more valid pages to loop through')
        break
# Out:
# Requesting page 1
# Requesting page 2
# Requesting page 3
# Requesting page 4
# Requesting page 5
# Requesting page 6
# Requesting page 7
# Requesting page 8
# Requesting page 9
# Requesting page 10
# Requesting page 11
# Requesting page 12
# Requesting page 13
# Requesting page 14
# Requesting page 15
# Requesting page 16
# Requesting page 17
# Requesting page 18
# Requesting page 19
# Requesting page 20
# Requesting page 21
# Requesting page 22
# Requesting page 23
# Requesting page 24
# Requesting page 25
# Requesting page 26
# Requesting page 27
# Requesting page 28
# Requesting page 29
# No more valid pages to loop through

# %%
nra_list
# Out:
# [{'amendment_indicator': 'A',
#   'amendment_indicator_desc': 'ADD',
#   'back_reference_schedule_id': None,
#   'back_reference_transaction_id': None,
#   'beneficiary_committee_name': None,
#   'candidate_first_name': None,
#   'candidate_id': None,
#   'candidate_last_name': None,
#   'candidate_middle_name': None,
#   'candidate_name': None,
#   'candidate_office': None,
#   'candidate_office_description': None,
#   'candidate_office_district': None,
#   'candidate_office_state': None,
#   'candidate_office_state_full': None,
#   'candidate_prefix': None,
#   'candidate_suffix': None,
#   'category_code': '001',
#   'category_code_full': 'Administrative/Salary/Overhead Expenses ',
#   'comm_dt': None,
#   'committee': {'affiliated_committee_name': 'THE NATIONAL RIFLE ASSOCIATION OF AMERICA',
#    'candidate_ids': [],
#    'city': 'FAIRFAX',
#    'committee_id': 'C00053553',
#    'committee_type': 'Q',
#    'committee_type_full': 'PAC - Qualified',
#    'cycle': 2012,
#    'cycles': [1976,
#     1978,
#     1980,
#     1982,
#     1984,
#     1986,
#     1988,
#     1990,
#     1992,
#     1994,
#     1996,
#     1998,
#     2000,
#     2002,
#     2004,
#     2006,
#     2008,
#     2010,
#     2012,
#     2014,
#     2016,
#     2018,
#     2020,
#     2022,
#     2024],
#    'cycles_has_activity': [1976,
#     1978,
#     1980,
#     1982,
#     1984,
#     1986,
#     1988,
#     1990,
#     1992,
#     1994,
#     1996,
#     1998,
#     2000,
#     2002,
#     2004,
#     2006,
#     2008,
#     2010,
#     2012,
#     2014,
#     2016,
#     2018,
#     2020,
#     2022,
#     2024],
#    'cycles_has_financial': [1976,
#     1978,
#     1980,
#     1982,
#     1984,
#     1986,
#     1988,
#     1990,
#     1992,
#     1994,
#     1996,
#     1998,
#     2000,
#     2002,
#     2004,
#     2006,
#     2008,
#     2010,
#     2012,
#     2014,
#     2016,
#     2018,
#     2020,
#     2022,
#     2024],
#    'designation': 'B',
#    'designation_full': 'Lobbyist/Registrant PAC',
#    'filing_frequency': 'M',
#    'first_f1_date': '1976-07-28',
#    'first_file_date': '1976-07-28',
#    'is_active': True,
#    'last_cycle_has_activity': 2024,
#    'last_cycle_has_financial': 2024,
#    'last_f1_date': '2023-04-20',
#    'last_file_date': '2023-07-31',
#    'name': 'NATIONAL RIFLE ASSOCIATION OF AMERICA POLITICAL VICTORY FUND',
#    'organization_type': 'M',
#    'organization_type_full': 'Membership Organization',
#    'party': 'UNK',
#    'party_full': 'UNKNOWN',
#    'state': 'VA',
#    'state_full': 'Virginia',
#    'street_1': '11250 WAPLES MILL ROAD',
#    'street_2': None,
#    'treasurer_name': 'ADKINS, MARY ROSE',
#    'zip': '22030'},
#   'committee_id': 'C00053553',
#   'conduit_committee_city': None,
#   'conduit_committee_name': None,
#   'conduit_committee_state': None,
#   'conduit_committee_street1': None,
#   'conduit_committee_street2': None,
#   'conduit_committee_zip': None,
#   'disbursement_amount': 49.64,
#   'disbursement_date': '2012-12-31',
#   'disbursement_description': 'CREDIT CARD FEES',
#   'disbursement_purpose_category': 'OTHER',
#   'disbursement_type': None,
#   'disbursement_type_description': None,
#   'election_type': None,
#   'election_type_full': None,
#   'entity_type': 'ORG',
#   'entity_type_desc': 'ORGANIZATION',
#   'fec_election_type_desc': None,
#   'fec_election_year': None,
#   'file_number': 852382,
#   'filing_form': 'F3X',
#   'image_number': '13960611624',
#   'line_number': '21B',
#   'line_number_label': 'Other Federal Operating Expenditures',
#   'link_id': 4013120131180363071,
#   'load_date': '2017-05-31T20:12:38.059660',
#   'memo_code': None,
#   'memo_code_full': None,
#   'memo_text': 'CREDIT CARD FEES',
#   'memoed_subtotal': False,
#   'national_committee_nonfederal_account': None,
#   'original_sub_id': None,
#   'payee_employer': None,
#   'payee_first_name': None,
#   'payee_last_name': None,
#   'payee_middle_name': None,
#   'payee_occupation': None,
#   'payee_prefix': None,
#   'payee_suffix': None,
#   'pdf_url': 'http://docquery.fec.gov/cgi-bin/fecimg/?13960611624',
#   'recipient_city': 'SALEM',
#   'recipient_committee': None,
#   'recipient_committee_id': None,
#   'recipient_name': 'PAYMENTECH, INC.',
#   'recipient_state': 'NH',
#   'recipient_zip': '03079',
#   'ref_disp_excess_flg': None,
#   'report_type': 'YE',
#   'report_year': '2012',
#   'schedule_type': 'SB',
#   'schedule_type_full': 'ITEMIZED DISBURSEMENTS',
#   'semi_annual_bundled_refund': '0.00',
#   'spender_committee_designation': 'B',
#   'spender_committee_org_type': 'M',
#   'spender_committee_type': 'Q',
#   'sub_id': '4020520131180774329',
#   'transaction_id': '49465437',
#   'two_year_transaction_period': 2012,
#   'unused_recipient_committee_id': None},
#  {'amendment_indicator': 'A',
#   'amendment_indicator_desc': 'ADD',
#   'back_reference_schedule_id': None,
#   'back_reference_transaction_id': None,
#   'beneficiary_committee_name': None,
#   'candidate_first_name': None,
#   'candidate_id': None,
#   'candidate_last_name': None,
#   'candidate_middle_name': None,
#   'candidate_name': None,
#   'candidate_office': None,
#   'candidate_office_description': None,
#   'candidate_office_district': None,
#   'candidate_office_state': None,
#   'candidate_office_state_full': None,
#   'candidate_prefix': None,
#   'candidate_suffix': None,
#   'category_code': '001',
#   'category_code_full': 'Administrative/Salary/Overhead Expenses ',
#   'comm_dt': None,
#   'committee': {'affiliated_committee_name': 'THE NATIONAL RIFLE ASSOCIATION OF AMERICA',
#    'candidate_ids': [],
#    'city': 'FAIRFAX',
#    'committee_id': 'C00053553',
#    'committee_type': 'Q',
#    'committee_type_full': 'PAC - Qualified',
#    'cycle': 2012,
#    'cycles': [1976,
#     1978,
#     1980,
#     1982,
#     1984,
#     1986,
#     1988,
#     1990,
#     1992,
#     1994,
#     1996,
#     1998,
#     2000,
#     2002,
#     2004,
#     2006,
#     2008,
#     2010,
#     2012,
#     2014,
#     2016,
#     2018,
#     2020,
#     2022,
#     2024],
#    'cycles_has_activity': [1976,
#     1978,
#     1980,
#     1982,
#     1984,
#     1986,
#     1988,
#     1990,
#     1992,
#     1994,
#     1996,
#     1998,
#     2000,
#     2002,
#     2004,
#     2006,
#     2008,
#     2010,
#     2012,
#     2014,
#     2016,
#     2018,
#     2020,
#     2022,
#     2024],
#    'cycles_has_financial': [1976,
#     1978,
#     1980,
#     1982,
#     1984,
#     1986,
#     1988,
#     1990,
#     1992,
#     1994,
#     1996,
#     1998,
#     2000,
#     2002,
#     2004,
#     2006,
#     2008,
#     2010,
#     2012,
#     2014,
#     2016,
#     2018,
#     2020,
#     2022,
#     2024],
#    'designation': 'B',
#    'designation_full': 'Lobbyist/Registrant PAC',
#    'filing_frequency': 'M',
#    'first_f1_date': '1976-07-28',
#    'first_file_date': '1976-07-28',
#    'is_active': True,
#    'last_cycle_has_activity': 2024,
#    'last_cycle_has_financial': 2024,
#    'last_f1_date': '2023-04-20',
#    'last_file_date': '2023-07-31',
#    'name': 'NATIONAL RIFLE ASSOCIATION OF AMERICA POLITICAL VICTORY FUND',
#    'organization_type': 'M',
#    'organization_type_full': 'Membership Organization',
#    'party': 'UNK',
#    'party_full': 'UNKNOWN',
#    'state': 'VA',
#    'state_full': 'Virginia',
#    'street_1': '11250 WAPLES MILL ROAD',
#    'street_2': None,
#    'treasurer_name': 'ADKINS, MARY ROSE',
#    'zip': '22030'},
#   'committee_id': 'C00053553',
#   'conduit_committee_city': None,
#   'conduit_committee_name': None,
#   'conduit_committee_state': None,
#   'conduit_committee_street1': None,
#   'conduit_committee_street2': None,
#   'conduit_committee_zip': None,
#   'disbursement_amount': 4.03,
#   'disbursement_date': '2012-12-31',
#   'disbursement_description': 'CREDIT CARD FEES',
#   'disbursement_purpose_category': 'OTHER',
#   'disbursement_type': None,
#   'disbursement_type_description': None,
#   'election_type': None,
#   'election_type_full': None,
#   'entity_type': 'ORG',
#   'entity_type_desc': 'ORGANIZATION',
#   'fec_election_type_desc': None,
#   'fec_election_year': None,
#   'file_number': 852382,
#   'filing_form': 'F3X',
#   'image_number': '13960611623',
#   'line_number': '21B',
#   'line_number_label': 'Other Federal Operating Expenditures',
#   'link_id': 4013120131180363071,
#   'load_date': '2017-05-31T20:12:38.059660',
#   'memo_code': None,
#   'memo_code_full': None,
#   'memo_text': 'CREDIT CARD FEES',
#   'memoed_subtotal': False,
#   'national_committee_nonfederal_account': None,
#   'original_sub_id': None,
#   'payee_employer': None,
#   'payee_first_name': None,
#   'payee_last_name': None,
#   'payee_middle_name': None,
#   'payee_occupation': None,
#   'payee_prefix': None,
#   'payee_suffix': None,
#   'pdf_url': 'http://docquery.fec.gov/cgi-bin/fecimg/?13960611623',
#   'recipient_city': 'PHOENIX',
#   'recipient_committee': None,
#   'recipient_committee_id': None,
#   'recipient_name': 'AMERICAN EXPRESS COMPANY',
#   'recipient_state': 'AZ',
#   'recipient_zip': '85072',
#   'ref_disp_excess_flg': None,
#   'report_type': 'YE',
#   'report_year': '2012',
#   'schedule_type': 'SB',
#   'schedule_type_full': 'ITEMIZED DISBURSEMENTS',
#   'semi_annual_bundled_refund': '0.00',
#   'spender_committee_designation': 'B',
#   'spender_committee_org_type': 'M',
#   'spender_committee_type': 'Q',
#   'sub_id': '4020520131180774328',
#   'transaction_id': '49465436',
#   'two_year_transaction_period': 2012,
#   'unused_recipient_committee_id': None},
#  {'amendment_indicator': 'A',
#   'amendment_indicator_desc': 'ADD',
#   'back_reference_schedule_id': None,
#   'back_reference_transaction_id': None,
#   'beneficiary_committee_name': None,
#   'candidate_first_name': None,
#   'candidate_id': None,
#   'candidate_last_name': None,
#   'candidate_middle_name': None,
#   'candidate_name': None,
#   'candidate_office': None,
#   'candidate_office_description': None,
#   'candidate_office_district': None,
#   'candidate_office_state': None,
#   'candidate_office_state_full': None,
#   'candidate_prefix': None,
#   'candidate_suffix': None,
#   'category_code': '001',
#   'category_code_full': 'Administrative/Salary/Overhead Expenses ',
#   'comm_dt': None,
#   'committee': {'affiliated_committee_name': 'THE NATIONAL RIFLE ASSOCIATION OF AMERICA',
#    'candidate_ids': [],
#    'city': 'FAIRFAX',
#    'committee_id': 'C00053553',
#    'committee_type': 'Q',
#    'committee_type_full': 'PAC - Qualified',
#    'cycle': 2012,
#    'cycles': [1976,
#     1978,
#     1980,
#     1982,
#     1984,
#     1986,
#     1988,
#     1990,
#     1992,
#     1994,
#     1996,
#     1998,
#     2000,
#     2002,
#     2004,
#     2006,
#     2008,
#     2010,
#     2012,
#     2014,
#     2016,
#     2018,
#     2020,
#     2022,
#     2024],
#    'cycles_has_activity': [1976,
#     1978,
#     1980,
#     1982,
#     1984,
#     1986,
#     1988,
#     1990,
#     1992,
#     1994,
#     1996,
#     1998,
#     2000,
#     2002,
#     2004,
#     2006,
#     2008,
#     2010,
#     2012,
#     2014,
#     2016,
#     2018,
#     2020,
#     2022,
#     2024],
#    'cycles_has_financial': [1976,
#     1978,
#     1980,
#     1982,
#     1984,
#     1986,
#     1988,
#     1990,
#     1992,
#     1994,
#     1996,
#     1998,
#     2000,
#     2002,
#     2004,
#     2006,
#     2008,
#     2010,
#     2012,
#     2014,
#     2016,
#     2018,
#     2020,
#     2022,
#     2024],
#    'designation': 'B',
#    'designation_full': 'Lobbyist/Registrant PAC',
#    'filing_frequency': 'M',
#    'first_f1_date': '1976-07-28',
#    'first_file_date': '1976-07-28',
#    'is_active': True,
#    'last_cycle_has_activity': 2024,
#    'last_cycle_has_financial': 2024,
#    'last_f1_date': '2023-04-20',
#    'last_file_date': '2023-07-31',
#    'name': 'NATIONAL RIFLE ASSOCIATION OF AMERICA POLITICAL VICTORY FUND',
#    'organization_type': 'M',
#    'organization_type_full': 'Membership Organization',
#    'party': 'UNK',
#    'party_full': 'UNKNOWN',
#    'state': 'VA',
#    'state_full': 'Virginia',
#    'street_1': '11250 WAPLES MILL ROAD',
#    'street_2': None,
#    'treasurer_name': 'ADKINS, MARY ROSE',
#    'zip': '22030'},
#   'committee_id': 'C00053553',
#   'conduit_committee_city': None,
#   'conduit_committee_name': None,
#   'conduit_committee_state': None,
#   'conduit_committee_street1': None,
#   'conduit_committee_street2': None,
#   'conduit_committee_zip': None,
#   'disbursement_amount': 2.0,
#   'disbursement_date': '2012-12-31',
#   'disbursement_description': 'BANK FEE',
#   'disbursement_purpose_category': 'OTHER',
#   'disbursement_type': None,
#   'disbursement_type_description': None,
#   'election_type': None,
#   'election_type_full': None,
#   'entity_type': 'ORG',
#   'entity_type_desc': 'ORGANIZATION',
#   'fec_election_type_desc': None,
#   'fec_election_year': None,
#   'file_number': 852382,
#   'filing_form': 'F3X',
#   'image_number': '13960611623',
#   'line_number': '21B',
#   'line_number_label': 'Other Federal Operating Expenditures',
#   'link_id': 4013120131180363071,
#   'load_date': '2017-05-31T20:12:38.059660',
#   'memo_code': None,
#   'memo_code_full': None,
#   'memo_text': 'BANK FEE',
#   'memoed_subtotal': False,
#   'national_committee_nonfederal_account': None,
#   'original_sub_id': None,
#   'payee_employer': None,
#   'payee_first_name': None,
#   'payee_last_name': None,
#   'payee_middle_name': None,
#   'payee_occupation': None,
#   'payee_prefix': None,
#   'payee_suffix': None,
#   'pdf_url': 'http://docquery.fec.gov/cgi-bin/fecimg/?13960611623',
#   'recipient_city': 'FAIRFAX',
#   'recipient_committee': None,
#   'recipient_committee_id': None,
#   'recipient_name': 'BB&T BANK',
#   'recipient_state': 'VA',
#   'recipient_zip': '22030',
#   'ref_disp_excess_flg': None,
#   'report_type': 'YE',
#   'report_year': '2012',
#   'schedule_type': 'SB',
#   'schedule_type_full': 'ITEMIZED DISBURSEMENTS',
#   'semi_annual_bundled_refund': '0.00',
#   'spender_committee_designation': 'B',
#   'spender_committee_org_type': 'M',
#   'spender_committee_type': 'Q',
#   'sub_id': '4020520131180774327',
#   'transaction_id': '49465435',
#   'two_year_transaction_period': 2012,
#   'unused_recipient_committee_id': None},
#  {'amendment_indicator': 'A',
#   'amendment_indicator_desc': 'ADD',
#   'back_reference_schedule_id': None,
#   'back_reference_transaction_id': None,
#   'beneficiary_committee_name': None,
#   'candidate_first_name': None,
#   'candidate_id': None,
#   'candidate_last_name': None,
#   'candidate_middle_name': None,
#   'candidate_name': None,
#   'candidate_office': None,
#   'candidate_office_description': None,
#   'candidate_office_district': None,
#   'candidate_office_state': None,
#   'candidate_office_state_full': None,
#   'candidate_prefix': None,
#   'candidate_suffix': None,
#   'category_code': '001',
#   'category_code_full': 'Administrative/Salary/Overhead Expenses ',
#   'comm_dt': None,
#   'committee': {'affiliated_committee_name': 'THE NATIONAL RIFLE ASSOCIATION OF AMERICA',
#    'candidate_ids': [],
#    'city': 'FAIRFAX',
#    'committee_id': 'C00053553',
#    'committee_type': 'Q',
#    'committee_type_full': 'PAC - Qualified',
#    'cycle': 2012,
#    'cycles': [1976,
#     1978,
#     1980,
#     1982,
#     1984,
#     1986,
#     1988,
#     1990,
#     1992,
#     1994,
#     1996,
#     1998,
#     2000,
#     2002,
#     2004,
#     2006,
#     2008,
#     2010,
#     2012,
#     2014,
#     2016,
#     2018,
#     2020,
#     2022,
#     2024],
#    'cycles_has_activity': [1976,
#     1978,
#     1980,
#     1982,
#     1984,
#     1986,
#     1988,
#     1990,
#     1992,
#     1994,
#     1996,
#     1998,
#     2000,
#     2002,
#     2004,
#     2006,
#     2008,
#     2010,
#     2012,
#     2014,
#     2016,
#     2018,
#     2020,
#     2022,
#     2024],
#    'cycles_has_financial': [1976,
#     1978,
#     1980,
#     1982,
#     1984,
#     1986,
#     1988,
#     1990,
#     1992,
#     1994,
#     1996,
#     1998,
#     2000,
#     2002,
#     2004,
#     2006,
#     2008,
#     2010,
#     2012,
#     2014,
#     2016,
#     2018,
#     2020,
#     2022,
#     2024],
#    'designation': 'B',
#    'designation_full': 'Lobbyist/Registrant PAC',
#    'filing_frequency': 'M',
#    'first_f1_date': '1976-07-28',
#    'first_file_date': '1976-07-28',
#    'is_active': True,
#    'last_cycle_has_activity': 2024,
#    'last_cycle_has_financial': 2024,
#    'last_f1_date': '2023-04-20',
#    'last_file_date': '2023-07-31',
#    'name': 'NATIONAL RIFLE ASSOCIATION OF AMERICA POLITICAL VICTORY FUND',
#    'organization_type': 'M',
#    'organization_type_full': 'Membership Organization',
#    'party': 'UNK',
#    'party_full': 'UNKNOWN',
#    'state': 'VA',
#    'state_full': 'Virginia',
#    'street_1': '11250 WAPLES MILL ROAD',
#    'street_2': None,
#    'treasurer_name': 'ADKINS, MARY ROSE',
#    'zip': '22030'},
#   'committee_id': 'C00053553',
#   'conduit_committee_city': None,
#   'conduit_committee_name': None,
#   'conduit_committee_state': None,
#   'conduit_committee_street1': None,
#   'conduit_committee_street2': None,
#   'conduit_committee_zip': None,
#   'disbursement_amount': 3.0,
#   'disbursement_date': '2012-12-31',
#   'disbursement_description': 'BANK FEE',
#   'disbursement_purpose_category': 'OTHER',
#   'disbursement_type': None,
#   'disbursement_type_description': None,
#   'election_type': None,
#   'election_type_full': None,
#   'entity_type': 'ORG',
#   'entity_type_desc': 'ORGANIZATION',
#   'fec_election_type_desc': None,
#   'fec_election_year': None,
#   'file_number': 852382,
#   'filing_form': 'F3X',
#   'image_number': '13960611622',
#   'line_number': '21B',
#   'line_number_label': 'Other Federal Operating Expenditures',
#   'link_id': 4013120131180363071,
#   'load_date': '2017-05-31T20:12:38.059660',
#   'memo_code': None,
#   'memo_code_full': None,
#   'memo_text': 'BANK FEE',
#   'memoed_subtotal': False,
#   'national_committee_nonfederal_account': None,
#   'original_sub_id': None,
#   'payee_employer': None,
#   'payee_first_name': None,
#   'payee_last_name': None,
#   'payee_middle_name': None,
#   'payee_occupation': None,
#   'payee_prefix': None,
#   'payee_suffix': None,
#   'pdf_url': 'http://docquery.fec.gov/cgi-bin/fecimg/?13960611622',
#   'recipient_city': 'ST. LOUIS',
#   'recipient_committee': None,
#   'recipient_committee_id': None,
#   'recipient_name': 'BANK OF AMERICA - MO',
#   'recipient_state': 'MO',
#   'recipient_zip': '63106',
#   'ref_disp_excess_flg': None,
#   'report_type': 'YE',
#   'report_year': '2012',
#   'schedule_type': 'SB',
#   'schedule_type_full': 'ITEMIZED DISBURSEMENTS',
#   'semi_annual_bundled_refund': '0.00',
#   'spender_committee_designation': 'B',
#   'spender_committee_org_type': 'M',
#   'spender_committee_type': 'Q',
#   'sub_id': '4020520131180774325',
#   'transaction_id': '49465433',
#   'two_year_transaction_period': 2012,
#   'unused_recipient_committee_id': None},
#  {'amendment_indicator': 'A',
#   'amendment_indicator_desc': 'ADD',
#   'back_reference_schedule_id': None,
#   'back_reference_transaction_id': None,
#   'beneficiary_committee_name': None,
#   'candidate_first_name': None,
#   'candidate_id': None,
#   'candidate_last_name': None,
#   'candidate_middle_name': None,
#   'candidate_name': None,
#   'candidate_office': None,
#   'candidate_office_description': None,
#   'candidate_office_district': None,
#   'candidate_office_state': None,
#   'candidate_office_state_full': None,
#   'candidate_prefix': None,
#   'candidate_suffix': None,
#   'category_code': '001',
#   'category_code_full': 'Administrative/Salary/Overhead Expenses ',
#   'comm_dt': None,
#   'committee': {'affiliated_committee_name': 'THE NATIONAL RIFLE ASSOCIATION OF AMERICA',
#    'candidate_ids': [],
#    'city': 'FAIRFAX',
#    'committee_id': 'C00053553',
#    'committee_type': 'Q',
#    'committee_type_full': 'PAC - Qualified',
#    'cycle': 2012,
#    'cycles': [1976,
#     1978,
#     1980,
#     1982,
#     1984,
#     1986,
#     1988,
#     1990,
#     1992,
#     1994,
#     1996,
#     1998,
#     2000,
#     2002,
#     2004,
#     2006,
#     2008,
#     2010,
#     2012,
#     2014,
#     2016,
#     2018,
#     2020,
#     2022,
#     2024],
#    'cycles_has_activity': [1976,
#     1978,
#     1980,
#     1982,
#     1984,
#     1986,
#     1988,
#     1990,
#     1992,
#     1994,
#     1996,
#     1998,
#     2000,
#     2002,
#     2004,
#     2006,
#     2008,
#     2010,
#     2012,
#     2014,
#     2016,
#     2018,
#     2020,
#     2022,
#     2024],
#    'cycles_has_financial': [1976,
#     1978,
#     1980,
#     1982,
#     1984,
#     1986,
#     1988,
#     1990,
#     1992,
#     1994,
#     1996,
#     1998,
#     2000,
#     2002,
#     2004,
#     2006,
#     2008,
#     2010,
#     2012,
#     2014,
#     2016,
#     2018,
#     2020,
#     2022,
#     2024],
#    'designation': 'B',
#    'designation_full': 'Lobbyist/Registrant PAC',
#    'filing_frequency': 'M',
#    'first_f1_date': '1976-07-28',
#    'first_file_date': '1976-07-28',
#    'is_active': True,
#    'last_cycle_has_activity': 2024,
#    'last_cycle_has_financial': 2024,
#    'last_f1_date': '2023-04-20',
#    'last_file_date': '2023-07-31',
#    'name': 'NATIONAL RIFLE ASSOCIATION OF AMERICA POLITICAL VICTORY FUND',
#    'organization_type': 'M',
#    'organization_type_full': 'Membership Organization',
#    'party': 'UNK',
#    'party_full': 'UNKNOWN',
#    'state': 'VA',
#    'state_full': 'Virginia',
#    'street_1': '11250 WAPLES MILL ROAD',
#    'street_2': None,
#    'treasurer_name': 'ADKINS, MARY ROSE',
#    'zip': '22030'},
#   'committee_id': 'C00053553',
#   'conduit_committee_city': None,
#   'conduit_committee_name': None,
#   'conduit_committee_state': None,
#   'conduit_committee_street1': None,
#   'conduit_committee_street2': None,
#   'conduit_committee_zip': None,
#   'disbursement_amount': 12.0,
#   'disbursement_date': '2012-12-31',
#   'disbursement_description': 'BANK FEE',
#   'disbursement_purpose_category': 'OTHER',
#   'disbursement_type': None,
#   'disbursement_type_description': None,
#   'election_type': None,
#   'election_type_full': None,
#   'entity_type': 'ORG',
#   'entity_type_desc': 'ORGANIZATION',
#   'fec_election_type_desc': None,
#   'fec_election_year': None,
#   'file_number': 852382,
#   'filing_form': 'F3X',
#   'image_number': '13960611621',
#   'line_number': '21B',
#   'line_number_label': 'Other Federal Operating Expenditures',
#   'link_id': 4013120131180363071,
#   'load_date': '2017-05-31T20:12:38.059660',
#   'memo_code': None,
#   'memo_code_full': None,
#   'memo_text': 'BANK FEE',
#   'memoed_subtotal': False,
#   'national_committee_nonfederal_account': None,
#   'original_sub_id': None,
#   'payee_employer': None,
#   'payee_first_name': None,
#   'payee_last_name': None,
#   'payee_middle_name': None,
#   'payee_occupation': None,
#   'payee_prefix': None,
#   'payee_suffix': None,
#   'pdf_url': 'http://docquery.fec.gov/cgi-bin/fecimg/?13960611621',
#   'recipient_city': 'ALLIANCE',
#   'recipient_committee': None,
#   'recipient_committee_id': None,
#   'recipient_name': 'BANK OF THE WEST',
#   'recipient_state': 'NE',
#   'recipient_zip': '69301',
#   'ref_disp_excess_flg': None,
#   'report_type': 'YE',
#   'report_year': '2012',
#   'schedule_type': 'SB',
#   'schedule_type_full': 'ITEMIZED DISBURSEMENTS',
#   'semi_annual_bundled_refund': '0.00',
#   'spender_committee_designation': 'B',
#   'spender_committee_org_type': 'M',
#   'spender_committee_type': 'Q',
#   'sub_id': '4020520131180774321',
#   'transaction_id': '49465429',
#   'two_year_transaction_period': 2012,
#   'unused_recipient_committee_id': None},
#  {'amendment_indicator': 'A',
#   'amendment_indicator_desc': 'ADD',
#   'back_reference_schedule_id': None,
#   'back_reference_transaction_id': None,
#   'beneficiary_committee_name': None,
#   'candidate_first_name': None,
#   'candidate_id': None,
#   'candidate_last_name': None,
#   'candidate_middle_name': None,
#   'candidate_name': None,
#   'candidate_office': None,
#   'candidate_office_description': None,
#   'candidate_office_district': None,
#   'candidate_office_state': None,
#   'candidate_office_state_full': None,
#   'candidate_prefix': None,
#   'candidate_suffix': None,
#   'category_code': '011',
#   'category_code_full': 'Political Contributions',
#   'comm_dt': None,
#   'committee': {'affiliated_committee_name': 'THE NATIONAL RIFLE ASSOCIATION OF AMERICA',
#    'candidate_ids': [],
#    'city': 'FAIRFAX',
#    'committee_id': 'C00053553',
#    'committee_type': 'Q',
#    'committee_type_full': 'PAC - Qualified',
#    'cycle': 2012,
#    'cycles': [1976,
#     1978,
#     1980,
#     1982,
#     1984,
#     1986,
#     1988,
#     1990,
#     1992,
#     1994,
#     1996,
#     1998,
#     2000,
#     2002,
#     2004,
#     2006,
#     2008,
#     2010,
#     2012,
#     2014,
#     2016,
#     2018,
#     2020,
#     2022,
#     2024],
#    'cycles_has_activity': [1976,
#     1978,
#     1980,
#     1982,
#     1984,
#     1986,
#     1988,
#     1990,
#     1992,
#     1994,
#     1996,
#     1998,
#     2000,
#     2002,
#     2004,
#     2006,
#     2008,
#     2010,
#     2012,
#     2014,
#     2016,
#     2018,
#     2020,
#     2022,
#     2024],
#    'cycles_has_financial': [1976,
#     1978,
#     1980,
#     1982,
#     1984,
#     1986,
#     1988,
#     1990,
#     1992,
#     1994,
#     1996,
#     1998,
#     2000,
#     2002,
#     2004,
#     2006,
#     2008,
#     2010,
#     2012,
#     2014,
#     2016,
#     2018,
#     2020,
#     2022,
#     2024],
#    'designation': 'B',
#    'designation_full': 'Lobbyist/Registrant PAC',
#    'filing_frequency': 'M',
#    'first_f1_date': '1976-07-28',
#    'first_file_date': '1976-07-28',
#    'is_active': True,
#    'last_cycle_has_activity': 2024,
#    'last_cycle_has_financial': 2024,
#    'last_f1_date': '2023-04-20',
#    'last_file_date': '2023-07-31',
#    'name': 'NATIONAL RIFLE ASSOCIATION OF AMERICA POLITICAL VICTORY FUND',
#    'organization_type': 'M',
#    'organization_type_full': 'Membership Organization',
#    'party': 'UNK',
#    'party_full': 'UNKNOWN',
#    'state': 'VA',
#    'state_full': 'Virginia',
#    'street_1': '11250 WAPLES MILL ROAD',
#    'street_2': None,
#    'treasurer_name': 'ADKINS, MARY ROSE',
#    'zip': '22030'},
#   'committee_id': 'C00053553',
#   'conduit_committee_city': None,
#   'conduit_committee_name': None,
#   'conduit_committee_state': None,
#   'conduit_committee_street1': None,
#   'conduit_committee_street2': None,
#   'conduit_committee_zip': None,
#   'disbursement_amount': 1000.0,
#   'disbursement_date': '2012-12-31',
#   'disbursement_description': None,
#   'disbursement_purpose_category': 'OTHER',
#   'disbursement_type': None,
#   'disbursement_type_description': None,
#   'election_type': None,
#   'election_type_full': None,
#   'entity_type': 'COM',
#   'entity_type_desc': 'OTHER COMMITTEE',
#   'fec_election_type_desc': None,
#   'fec_election_year': None,
#   'file_number': 852382,
#   'filing_form': 'F3X',
#   'image_number': '13960611630',
#   'line_number': '29',
#   'line_number_label': 'Other Disbursements',
#   'link_id': 4013120131180363071,
#   'load_date': '2017-05-31T20:12:38.059660',
#   'memo_code': None,
#   'memo_code_full': None,
#   'memo_text': None,
#   'memoed_subtotal': False,
#   'national_committee_nonfederal_account': None,
#   'original_sub_id': None,
#   'payee_employer': None,
#   'payee_first_name': None,
#   'payee_last_name': None,
#   'payee_middle_name': None,
#   'payee_occupation': None,
#   'payee_prefix': None,
#   'payee_suffix': None,
#   'pdf_url': 'http://docquery.fec.gov/cgi-bin/fecimg/?13960611630',
#   'recipient_city': 'COLONIAL HEIGHTS',
#   'recipient_committee': None,
#   'recipient_committee_id': None,
#   'recipient_name': 'MAJORITY LEADER PAC',
#   'recipient_state': 'VA',
#   'recipient_zip': '23834',
#   'ref_disp_excess_flg': None,
#   'report_type': 'YE',
#   'report_year': '2012',
#   'schedule_type': 'SB',
#   'schedule_type_full': 'ITEMIZED DISBURSEMENTS',
#   'semi_annual_bundled_refund': '0.00',
#   'spender_committee_designation': 'B',
#   'spender_committee_org_type': 'M',
#   'spender_committee_type': 'Q',
#   'sub_id': '4020520131180774317',
#   'transaction_id': '49256205',
#   'two_year_transaction_period': 2012,
#   'unused_recipient_committee_id': None},
#  {'amendment_indicator': 'A',
#   'amendment_indicator_desc': 'ADD',
#   'back_reference_schedule_id': None,
#   'back_reference_transaction_id': None,
#   'beneficiary_committee_name': None,
#   'candidate_first_name': 'THOMAS',
#   'candidate_id': None,
#   'candidate_last_name': 'GREASON',
#   'candidate_middle_name': 'A',
#   'candidate_name': 'GREASON, THOMAS A',
#   'candidate_office': 'H',
#   'candidate_office_description': 'HOUSE',
#   'candidate_office_district': '32',
#   'candidate_office_state': 'VA',
#   'candidate_office_state_full': 'VIRGINIA ',
#   'candidate_prefix': None,
#   'candidate_suffix': None,
#   'category_code': '011',
#   'category_code_full': 'Political Contributions',
#   'comm_dt': None,
#   'committee': {'affiliated_committee_name': 'THE NATIONAL RIFLE ASSOCIATION OF AMERICA',
#    'candidate_ids': [],
#    'city': 'FAIRFAX',
#    'committee_id': 'C00053553',
#    'committee_type': 'Q',
#    'committee_type_full': 'PAC - Qualified',
#    'cycle': 2012,
#    'cycles': [1976,
#     1978,
#     1980,
#     1982,
#     1984,
#     1986,
#     1988,
#     1990,
#     1992,
#     1994,
#     1996,
#     1998,
#     2000,
#     2002,
#     2004,
#     2006,
#     2008,
#     2010,
#     2012,
#     2014,
#     2016,
#     2018,
#     2020,
#     2022,
#     2024],
#    'cycles_has_activity': [1976,
#     1978,
#     1980,
#     1982,
#     1984,
#     1986,
#     1988,
#     1990,
#     1992,
#     1994,
#     1996,
#     1998,
#     2000,
#     2002,
#     2004,
#     2006,
#     2008,
#     2010,
#     2012,
#     2014,
#     2016,
#     2018,
#     2020,
#     2022,
#     2024],
#    'cycles_has_financial': [1976,
#     1978,
#     1980,
#     1982,
#     1984,
#     1986,
#     1988,
#     1990,
#     1992,
#     1994,
#     1996,
#     1998,
#     2000,
#     2002,
#     2004,
#     2006,
#     2008,
#     2010,
#     2012,
#     2014,
#     2016,
#     2018,
#     2020,
#     2022,
#     2024],
#    'designation': 'B',
#    'designation_full': 'Lobbyist/Registrant PAC',
#    'filing_frequency': 'M',
#    'first_f1_date': '1976-07-28',
#    'first_file_date': '1976-07-28',
#    'is_active': True,
#    'last_cycle_has_activity': 2024,
#    'last_cycle_has_financial': 2024,
#    'last_f1_date': '2023-04-20',
#    'last_file_date': '2023-07-31',
#    'name': 'NATIONAL RIFLE ASSOCIATION OF AMERICA POLITICAL VICTORY FUND',
#    'organization_type': 'M',
#    'organization_type_full': 'Membership Organization',
#    'party': 'UNK',
#    'party_full': 'UNKNOWN',
#    'state': 'VA',
#    'state_full': 'Virginia',
#    'street_1': '11250 WAPLES MILL ROAD',
#    'street_2': None,
#    'treasurer_name': 'ADKINS, MARY ROSE',
#    'zip': '22030'},
#   'committee_id': 'C00053553',
#   'conduit_committee_city': None,
#   'conduit_committee_name': None,
#   'conduit_committee_state': None,
#   'conduit_committee_street1': None,
#   'conduit_committee_street2': None,
#   'conduit_committee_zip': None,
#   'disbursement_amount': 1000.0,
#   'disbursement_date': '2012-12-31',
#   'disbursement_description': 'THOMAS GREASON, STATE HOUSE 32ND VA',
#   'disbursement_purpose_category': 'OTHER',
#   'disbursement_type': None,
#   'disbursement_type_description': None,
#   'election_type': 'G2013',
#   'election_type_full': None,
#   'entity_type': 'COM',
#   'entity_type_desc': 'OTHER COMMITTEE',
#   'fec_election_type_desc': 'GENERAL',
#   'fec_election_year': '2013',
#   'file_number': 852382,
#   'filing_form': 'F3X',
#   'image_number': '13960611630',
#   'line_number': '29',
#   'line_number_label': 'Other Disbursements',
#   'link_id': 4013120131180363071,
#   'load_date': '2017-05-31T20:12:38.059660',
#   'memo_code': None,
#   'memo_code_full': None,
#   'memo_text': 'THOMAS GREASON, STATE HOUSE 32ND VA',
#   'memoed_subtotal': False,
#   'national_committee_nonfederal_account': None,
#   'original_sub_id': None,
#   'payee_employer': None,
#   'payee_first_name': None,
#   'payee_last_name': None,
#   'payee_middle_name': None,
#   'payee_occupation': None,
#   'payee_prefix': None,
#   'payee_suffix': None,
#   'pdf_url': 'http://docquery.fec.gov/cgi-bin/fecimg/?13960611630',
#   'recipient_city': 'POTOMAC FALLS',
#   'recipient_committee': None,
#   'recipient_committee_id': None,
#   'recipient_name': 'FRIENDS OF TAG GREASON',
#   'recipient_state': 'VA',
#   'recipient_zip': '20165',
#   'ref_disp_excess_flg': None,
#   'report_type': 'YE',
#   'report_year': '2012',
#   'schedule_type': 'SB',
#   'schedule_type_full': 'ITEMIZED DISBURSEMENTS',
#   'semi_annual_bundled_refund': '0.00',
#   'spender_committee_designation': 'B',
#   'spender_committee_org_type': 'M',
#   'spender_committee_type': 'Q',
#   'sub_id': '4020520131180774316',
#   'transaction_id': '49255981',
#   'two_year_transaction_period': 2012,
#   'unused_recipient_committee_id': None},
#  {'amendment_indicator': 'A',
#   'amendment_indicator_desc': 'ADD',
#   'back_reference_schedule_id': None,
#   'back_reference_transaction_id': None,
#   'beneficiary_committee_name': None,
#   'candidate_first_name': 'DAVID',
#   'candidate_id': None,
#   'candidate_last_name': 'RAMADAN',
#   'candidate_middle_name': None,
#   'candidate_name': 'RAMADAN, DAVID',
#   'candidate_office': 'H',
#   'candidate_office_description': 'HOUSE',
#   'candidate_office_district': '87',
#   'candidate_office_state': 'VA',
#   'candidate_office_state_full': 'VIRGINIA ',
#   'candidate_prefix': None,
#   'candidate_suffix': None,
#   'category_code': '011',
#   'category_code_full': 'Political Contributions',
#   'comm_dt': None,
#   'committee': {'affiliated_committee_name': 'THE NATIONAL RIFLE ASSOCIATION OF AMERICA',
#    'candidate_ids': [],
#    'city': 'FAIRFAX',
#    'committee_id': 'C00053553',
#    'committee_type': 'Q',
#    'committee_type_full': 'PAC - Qualified',
#    'cycle': 2012,
#    'cycles': [1976,
#     1978,
#     1980,
#     1982,
#     1984,
#     1986,
#     1988,
#     1990,
#     1992,
#     1994,
#     1996,
#     1998,
#     2000,
#     2002,
#     2004,
#     2006,
#     2008,
#     2010,
#     2012,
#     2014,
#     2016,
#     2018,
#     2020,
#     2022,
#     2024],
#    'cycles_has_activity': [1976,
#     1978,
#     1980,
#     1982,
#     1984,
#     1986,
#     1988,
#     1990,
#     1992,
#     1994,
#     1996,
#     1998,
#     2000,
#     2002,
#     2004,
#     2006,
#     2008,
#     2010,
#     2012,
#     2014,
#     2016,
#     2018,
#     2020,
#     2022,
#     2024],
#    'cycles_has_financial': [1976,
#     1978,
#     1980,
#     1982,
#     1984,
#     1986,
#     1988,
#     1990,
#     1992,
#     1994,
#     1996,
#     1998,
#     2000,
#     2002,
#     2004,
#     2006,
#     2008,
#     2010,
#     2012,
#     2014,
#     2016,
#     2018,
#     2020,
#     2022,
#     2024],
#    'designation': 'B',
#    'designation_full': 'Lobbyist/Registrant PAC',
#    'filing_frequency': 'M',
#    'first_f1_date': '1976-07-28',
#    'first_file_date': '1976-07-28',
#    'is_active': True,
#    'last_cycle_has_activity': 2024,
#    'last_cycle_has_financial': 2024,
#    'last_f1_date': '2023-04-20',
#    'last_file_date': '2023-07-31',
#    'name': 'NATIONAL RIFLE ASSOCIATION OF AMERICA POLITICAL VICTORY FUND',
#    'organization_type': 'M',
#    'organization_type_full': 'Membership Organization',
#    'party': 'UNK',
#    'party_full': 'UNKNOWN',
#    'state': 'VA',
#    'state_full': 'Virginia',
#    'street_1': '11250 WAPLES MILL ROAD',
#    'street_2': None,
#    'treasurer_name': 'ADKINS, MARY ROSE',
#    'zip': '22030'},
#   'committee_id': 'C00053553',
#   'conduit_committee_city': None,
#   'conduit_committee_name': None,
#   'conduit_committee_state': None,
#   'conduit_committee_street1': None,
#   'conduit_committee_street2': None,
#   'conduit_committee_zip': None,
#   'disbursement_amount': 500.0,
#   'disbursement_date': '2012-12-31',
#   'disbursement_description': 'DAVID RAMADAN, STATE HOUSE 87TH VA',
#   'disbursement_purpose_category': 'OTHER',
#   'disbursement_type': None,
#   'disbursement_type_description': None,
#   'election_type': 'G2013',
#   'election_type_full': None,
#   'entity_type': 'COM',
#   'entity_type_desc': 'OTHER COMMITTEE',
#   'fec_election_type_desc': 'GENERAL',
#   'fec_election_year': '2013',
#   'file_number': 852382,
#   'filing_form': 'F3X',
#   'image_number': '13960611630',
#   'line_number': '29',
#   'line_number_label': 'Other Disbursements',
#   'link_id': 4013120131180363071,
#   'load_date': '2017-05-31T20:12:38.059660',
#   'memo_code': None,
#   'memo_code_full': None,
#   'memo_text': 'DAVID RAMADAN, STATE HOUSE 87TH VA',
#   'memoed_subtotal': False,
#   'national_committee_nonfederal_account': None,
#   'original_sub_id': None,
#   'payee_employer': None,
#   'payee_first_name': None,
#   'payee_last_name': None,
#   'payee_middle_name': None,
#   'payee_occupation': None,
#   'payee_prefix': None,
#   'payee_suffix': None,
#   'pdf_url': 'http://docquery.fec.gov/cgi-bin/fecimg/?13960611630',
#   'recipient_city': 'CHANTILLY',
#   'recipient_committee': None,
#   'recipient_committee_id': None,
#   'recipient_name': 'FRIENDS OF DAVID RAMADAN',
#   'recipient_state': 'VA',
#   'recipient_zip': '20152',
#   'ref_disp_excess_flg': None,
#   'report_type': 'YE',
#   'report_year': '2012',
#   'schedule_type': 'SB',
#   'schedule_type_full': 'ITEMIZED DISBURSEMENTS',
#   'semi_annual_bundled_refund': '0.00',
#   'spender_committee_designation': 'B',
#   'spender_committee_org_type': 'M',
#   'spender_committee_type': 'Q',
#   'sub_id': '4020520131180774315',
#   'transaction_id': '49255175',
#   'two_year_transaction_period': 2012,
#   'unused_recipient_committee_id': None},
#  {'amendment_indicator': 'A',
#   'amendment_indicator_desc': 'ADD',
#   'back_reference_schedule_id': None,
#   'back_reference_transaction_id': None,
#   'beneficiary_committee_name': None,
#   'candidate_first_name': 'RICHARD',
#   'candidate_id': None,
#   'candidate_last_name': 'ANDERSON',
#   'candidate_middle_name': None,
#   'candidate_name': 'ANDERSON, RICHARD VA DEL.',
#   'candidate_office': 'H',
#   'candidate_office_description': 'HOUSE',
#   'candidate_office_district': '51',
#   'candidate_office_state': 'VA',
#   'candidate_office_state_full': 'VIRGINIA ',
#   'candidate_prefix': 'VA DEL.',
#   'candidate_suffix': None,
#   'category_code': '011',
#   'category_code_full': 'Political Contributions',
#   'comm_dt': None,
#   'committee': {'affiliated_committee_name': 'THE NATIONAL RIFLE ASSOCIATION OF AMERICA',
#    'candidate_ids': [],
#    'city': 'FAIRFAX',
#    'committee_id': 'C00053553',
#    'committee_type': 'Q',
#    'committee_type_full': 'PAC - Qualified',
#    'cycle': 2012,
#    'cycles': [1976,
#     1978,
#     1980,
#     1982,
#     1984,
#     1986,
#     1988,
#     1990,
#     1992,
#     1994,
#     1996,
#     1998,
#     2000,
#     2002,
#     2004,
#     2006,
#     2008,
#     2010,
#     2012,
#     2014,
#     2016,
#     2018,
#     2020,
#     2022,
#     2024],
#    'cycles_has_activity': [1976,
#     1978,
#     1980,
#     1982,
#     1984,
#     1986,
#     1988,
#     1990,
#     1992,
#     1994,
#     1996,
#     1998,
#     2000,
#     2002,
#     2004,
#     2006,
#     2008,
#     2010,
#     2012,
#     2014,
#     2016,
#     2018,
#     2020,
#     2022,
#     2024],
#    'cycles_has_financial': [1976,
#     1978,
#     1980,
#     1982,
#     1984,
#     1986,
#     1988,
#     1990,
#     1992,
#     1994,
#     1996,
#     1998,
#     2000,
#     2002,
#     2004,
#     2006,
#     2008,
#     2010,
#     2012,
#     2014,
#     2016,
#     2018,
#     2020,
#     2022,
#     2024],
#    'designation': 'B',
#    'designation_full': 'Lobbyist/Registrant PAC',
#    'filing_frequency': 'M',
#    'first_f1_date': '1976-07-28',
#    'first_file_date': '1976-07-28',
#    'is_active': True,
#    'last_cycle_has_activity': 2024,
#    'last_cycle_has_financial': 2024,
#    'last_f1_date': '2023-04-20',
#    'last_file_date': '2023-07-31',
#    'name': 'NATIONAL RIFLE ASSOCIATION OF AMERICA POLITICAL VICTORY FUND',
#    'organization_type': 'M',
#    'organization_type_full': 'Membership Organization',
#    'party': 'UNK',
#    'party_full': 'UNKNOWN',
#    'state': 'VA',
#    'state_full': 'Virginia',
#    'street_1': '11250 WAPLES MILL ROAD',
#    'street_2': None,
#    'treasurer_name': 'ADKINS, MARY ROSE',
#    'zip': '22030'},
#   'committee_id': 'C00053553',
#   'conduit_committee_city': None,
#   'conduit_committee_name': None,
#   'conduit_committee_state': None,
#   'conduit_committee_street1': None,
#   'conduit_committee_street2': None,
#   'conduit_committee_zip': None,
#   'disbursement_amount': 250.0,
#   'disbursement_date': '2012-12-31',
#   'disbursement_description': 'RICHARD ANDERSON, STATE HOUSE 51ST VA',
#   'disbursement_purpose_category': 'OTHER',
#   'disbursement_type': None,
#   'disbursement_type_description': None,
#   'election_type': 'G2013',
#   'election_type_full': None,
#   'entity_type': 'COM',
#   'entity_type_desc': 'OTHER COMMITTEE',
#   'fec_election_type_desc': 'GENERAL',
#   'fec_election_year': '2013',
#   'file_number': 852382,
#   'filing_form': 'F3X',
#   'image_number': '13960611629',
#   'line_number': '29',
#   'line_number_label': 'Other Disbursements',
#   'link_id': 4013120131180363071,
#   'load_date': '2017-05-31T20:12:38.059660',
#   'memo_code': None,
#   'memo_code_full': None,
#   'memo_text': 'RICHARD ANDERSON, STATE HOUSE 51ST VA',
#   'memoed_subtotal': False,
#   'national_committee_nonfederal_account': None,
#   'original_sub_id': None,
#   'payee_employer': None,
#   'payee_first_name': None,
#   'payee_last_name': None,
#   'payee_middle_name': None,
#   'payee_occupation': None,
#   'payee_prefix': None,
#   'payee_suffix': None,
#   'pdf_url': 'http://docquery.fec.gov/cgi-bin/fecimg/?13960611629',
#   'recipient_city': 'WOODBRIDGE',
#   'recipient_committee': None,
#   'recipient_committee_id': None,
#   'recipient_name': 'FRIENDS OF RICH ANDERSON',
#   'recipient_state': 'VA',
#   'recipient_zip': '22195',
#   'ref_disp_excess_flg': None,
#   'report_type': 'YE',
#   'report_year': '2012',
#   'schedule_type': 'SB',
#   'schedule_type_full': 'ITEMIZED DISBURSEMENTS',
#   'semi_annual_bundled_refund': '0.00',
#   'spender_committee_designation': 'B',
#   'spender_committee_org_type': 'M',
#   'spender_committee_type': 'Q',
#   'sub_id': '4020520131180774314',
#   'transaction_id': '49255173',
#   'two_year_transaction_period': 2012,
#   'unused_recipient_committee_id': None},
#  {'amendment_indicator': 'A',
#   'amendment_indicator_desc': 'ADD',
#   'back_reference_schedule_id': None,
#   'back_reference_transaction_id': None,
#   'beneficiary_committee_name': None,
#   'candidate_first_name': None,
#   'candidate_id': None,
#   'candidate_last_name': None,
#   'candidate_middle_name': None,
#   'candidate_name': None,
#   'candidate_office': None,
#   'candidate_office_description': None,
#   'candidate_office_district': None,
#   'candidate_office_state': None,
#   'candidate_office_state_full': None,
#   'candidate_prefix': None,
#   'candidate_suffix': None,
#   'category_code': '011',
#   'category_code_full': 'Political Contributions',
#   'comm_dt': None,
#   'committee': {'affiliated_committee_name': 'THE NATIONAL RIFLE ASSOCIATION OF AMERICA',
#    'candidate_ids': [],
#    'city': 'FAIRFAX',
#    'committee_id': 'C00053553',
#    'committee_type': 'Q',
#    'committee_type_full': 'PAC - Qualified',
#    'cycle': 2012,
#    'cycles': [1976,
#     1978,
#     1980,
#     1982,
#     1984,
#     1986,
#     1988,
#     1990,
#     1992,
#     1994,
#     1996,
#     1998,
#     2000,
#     2002,
#     2004,
#     2006,
#     2008,
#     2010,
#     2012,
#     2014,
#     2016,
#     2018,
#     2020,
#     2022,
#     2024],
#    'cycles_has_activity': [1976,
#     1978,
#     1980,
#     1982,
#     1984,
#     1986,
#     1988,
#     1990,
#     1992,
#     1994,
#     1996,
#     1998,
#     2000,
#     2002,
#     2004,
#     2006,
#     2008,
#     2010,
#     2012,
#     2014,
#     2016,
#     2018,
#     2020,
#     2022,
#     2024],
#    'cycles_has_financial': [1976,
#     1978,
#     1980,
#     1982,
#     1984,
#     1986,
#     1988,
#     1990,
#     1992,
#     1994,
#     1996,
#     1998,
#     2000,
#     2002,
#     2004,
#     2006,
#     2008,
#     2010,
#     2012,
#     2014,
#     2016,
#     2018,
#     2020,
#     2022,
#     2024],
#    'designation': 'B',
#    'designation_full': 'Lobbyist/Registrant PAC',
#    'filing_frequency': 'M',
#    'first_f1_date': '1976-07-28',
#    'first_file_date': '1976-07-28',
#    'is_active': True,
#    'last_cycle_has_activity': 2024,
#    'last_cycle_has_financial': 2024,
#    'last_f1_date': '2023-04-20',
#    'last_file_date': '2023-07-31',
#    'name': 'NATIONAL RIFLE ASSOCIATION OF AMERICA POLITICAL VICTORY FUND',
#    'organization_type': 'M',
#    'organization_type_full': 'Membership Organization',
#    'party': 'UNK',
#    'party_full': 'UNKNOWN',
#    'state': 'VA',
#    'state_full': 'Virginia',
#    'street_1': '11250 WAPLES MILL ROAD',
#    'street_2': None,
#    'treasurer_name': 'ADKINS, MARY ROSE',
#    'zip': '22030'},
#   'committee_id': 'C00053553',
#   'conduit_committee_city': None,
#   'conduit_committee_name': None,
#   'conduit_committee_state': None,
#   'conduit_committee_street1': None,
#   'conduit_committee_street2': None,
#   'conduit_committee_zip': None,
#   'disbursement_amount': 500.0,
#   'disbursement_date': '2012-12-31',
#   'disbursement_description': None,
#   'disbursement_purpose_category': 'OTHER',
#   'disbursement_type': None,
#   'disbursement_type_description': None,
#   'election_type': None,
#   'election_type_full': None,
#   'entity_type': 'PTY',
#   'entity_type_desc': 'POLITICAL PARTY COMMITTEE',
#   'fec_election_type_desc': None,
#   'fec_election_year': None,
#   'file_number': 852382,
#   'filing_form': 'F3X',
#   'image_number': '13960611629',
#   'line_number': '29',
#   'line_number_label': 'Other Disbursements',
#   'link_id': 4013120131180363071,
#   'load_date': '2017-05-31T20:12:38.059660',
#   'memo_code': None,
#   'memo_code_full': None,
#   'memo_text': None,
#   'memoed_subtotal': False,
#   'national_committee_nonfederal_account': None,
#   'original_sub_id': None,
#   'payee_employer': None,
#   'payee_first_name': None,
#   'payee_last_name': None,
#   'payee_middle_name': None,
#   'payee_occupation': None,
#   'payee_prefix': None,
#   'payee_suffix': None,
#   'pdf_url': 'http://docquery.fec.gov/cgi-bin/fecimg/?13960611629',
#   'recipient_city': 'WILLIAMSBURG',
#   'recipient_committee': None,
#   'recipient_committee_id': None,
#   'recipient_name': 'VIRGINIA SENATE REPUBLICAN CAUCUS',
#   'recipient_state': 'VA',
#   'recipient_zip': '23187',
#   'ref_disp_excess_flg': None,
#   'report_type': 'YE',
#   'report_year': '2012',
#   'schedule_type': 'SB',
#   'schedule_type_full': 'ITEMIZED DISBURSEMENTS',
#   'semi_annual_bundled_refund': '0.00',
#   'spender_committee_designation': 'B',
#   'spender_committee_org_type': 'M',
#   'spender_committee_type': 'Q',
#   'sub_id': '4020520131180774313',
#   'transaction_id': '49255172',
#   'two_year_transaction_period': 2012,
#   'unused_recipient_committee_id': None},
#  {'amendment_indicator': 'A',
#   'amendment_indicator_desc': 'ADD',
#   'back_reference_schedule_id': None,
#   'back_reference_transaction_id': None,
#   'beneficiary_committee_name': None,
#   'candidate_first_name': None,
#   'candidate_id': None,
#   'candidate_last_name': None,
#   'candidate_middle_name': None,
#   'candidate_name': None,
#   'candidate_office': None,
#   'candidate_office_description': None,
#   'candidate_office_district': None,
#   'candidate_office_state': None,
#   'candidate_office_state_full': None,
#   'candidate_prefix': None,
#   'candidate_suffix': None,
#   'category_code': '011',
#   'category_code_full': 'Political Contributions',
#   'comm_dt': None,
#   'committee': {'affiliated_committee_name': 'THE NATIONAL RIFLE ASSOCIATION OF AMERICA',
#    'candidate_ids': [],
#    'city': 'FAIRFAX',
#    'committee_id': 'C00053553',
#    'committee_type': 'Q',
#    'committee_type_full': 'PAC - Qualified',
#    'cycle': 2012,
#    'cycles': [1976,
#     1978,
#     1980,
#     1982,
#     1984,
#     1986,
#     1988,
#     1990,
#     1992,
#     1994,
#     1996,
#     1998,
#     2000,
#     2002,
#     2004,
#     2006,
#     2008,
#     2010,
#     2012,
#     2014,
#     2016,
#     2018,
#     2020,
#     2022,
#     2024],
#    'cycles_has_activity': [1976,
#     1978,
#     1980,
#     1982,
#     1984,
#     1986,
#     1988,
#     1990,
#     1992,
#     1994,
#     1996,
#     1998,
#     2000,
#     2002,
#     2004,
#     2006,
#     2008,
#     2010,
#     2012,
#     2014,
#     2016,
#     2018,
#     2020,
#     2022,
#     2024],
#    'cycles_has_financial': [1976,
#     1978,
#     1980,
#     1982,
#     1984,
#     1986,
#     1988,
#     1990,
#     1992,
#     1994,
#     1996,
#     1998,
#     2000,
#     2002,
#     2004,
#     2006,
#     2008,
#     2010,
#     2012,
#     2014,
#     2016,
#     2018,
#     2020,
#     2022,
#     2024],
#    'designation': 'B',
#    'designation_full': 'Lobbyist/Registrant PAC',
#    'filing_frequency': 'M',
#    'first_f1_date': '1976-07-28',
#    'first_file_date': '1976-07-28',
#    'is_active': True,
#    'last_cycle_has_activity': 2024,
#    'last_cycle_has_financial': 2024,
#    'last_f1_date': '2023-04-20',
#    'last_file_date': '2023-07-31',
#    'name': 'NATIONAL RIFLE ASSOCIATION OF AMERICA POLITICAL VICTORY FUND',
#    'organization_type': 'M',
#    'organization_type_full': 'Membership Organization',
#    'party': 'UNK',
#    'party_full': 'UNKNOWN',
#    'state': 'VA',
#    'state_full': 'Virginia',
#    'street_1': '11250 WAPLES MILL ROAD',
#    'street_2': None,
#    'treasurer_name': 'ADKINS, MARY ROSE',
#    'zip': '22030'},
#   'committee_id': 'C00053553',
#   'conduit_committee_city': None,
#   'conduit_committee_name': None,
#   'conduit_committee_state': None,
#   'conduit_committee_street1': None,
#   'conduit_committee_street2': None,
#   'conduit_committee_zip': None,
#   'disbursement_amount': 500.0,
#   'disbursement_date': '2012-12-31',
#   'disbursement_description': None,
#   'disbursement_purpose_category': 'OTHER',
#   'disbursement_type': None,
#   'disbursement_type_description': None,
#   'election_type': None,
#   'election_type_full': None,
#   'entity_type': 'ORG',
#   'entity_type_desc': 'ORGANIZATION',
#   'fec_election_type_desc': None,
#   'fec_election_year': None,
#   'file_number': 852382,
#   'filing_form': 'F3X',
#   'image_number': '13960611629',
#   'line_number': '29',
#   'line_number_label': 'Other Disbursements',
#   'link_id': 4013120131180363071,
#   'load_date': '2017-05-31T20:12:38.059660',
#   'memo_code': None,
#   'memo_code_full': None,
#   'memo_text': None,
#   'memoed_subtotal': False,
#   'national_committee_nonfederal_account': None,
#   'original_sub_id': None,
#   'payee_employer': None,
# ...
#   'fec_election_type_desc': None,
#   'fec_election_year': None,
#   'file_number': 863519,
#   'filing_form': 'F3X',
#   'image_number': '13961233935',
#   'line_number': '21B',
#   'line_number_label': 'Other Federal Operating Expenditures',
#   'link_id': 4032920131185865923,
#   'load_date': '2017-05-31T20:12:38.059660',
#   'memo_code': None,
#   'memo_code_full': None,
#   'memo_text': 'CREDIT CARD FEES',
#   'memoed_subtotal': False,
#   'national_committee_nonfederal_account': None,
#   'original_sub_id': None,
#   'payee_employer': None,
#   'payee_first_name': None,
#   'payee_last_name': None,
#   'payee_middle_name': None,
#   'payee_occupation': None,
#   'payee_prefix': None,
#   'payee_suffix': None,
#   'pdf_url': 'http://docquery.fec.gov/cgi-bin/fecimg/?13961233935',
#   'recipient_city': 'SALEM',
#   'recipient_committee': None,
#   'recipient_committee_id': None,
#   'recipient_name': 'PAYMENTECH, INC.',
#   'recipient_state': 'NH',
#   'recipient_zip': '03079',
#   'ref_disp_excess_flg': None,
#   'report_type': '30G',
#   'report_year': '2012',
#   'schedule_type': 'SB',
#   'schedule_type_full': 'ITEMIZED DISBURSEMENTS',
#   'semi_annual_bundled_refund': '0.00',
#   'spender_committee_designation': 'B',
#   'spender_committee_org_type': 'M',
#   'spender_committee_type': 'Q',
#   'sub_id': '4040220131185979476',
#   'transaction_id': '48698309',
#   'two_year_transaction_period': 2012,
#   'unused_recipient_committee_id': None},
#  {'amendment_indicator': 'N',
#   'amendment_indicator_desc': 'NO CHANGE',
#   'back_reference_schedule_id': None,
#   'back_reference_transaction_id': None,
#   'beneficiary_committee_name': None,
#   'candidate_first_name': None,
#   'candidate_id': None,
#   'candidate_last_name': None,
#   'candidate_middle_name': None,
#   'candidate_name': None,
#   'candidate_office': None,
#   'candidate_office_description': None,
#   'candidate_office_district': None,
#   'candidate_office_state': None,
#   'candidate_office_state_full': None,
#   'candidate_prefix': None,
#   'candidate_suffix': None,
#   'category_code': '001',
#   'category_code_full': 'Administrative/Salary/Overhead Expenses ',
#   'comm_dt': None,
#   'committee': {'affiliated_committee_name': 'THE NATIONAL RIFLE ASSOCIATION OF AMERICA',
#    'candidate_ids': [],
#    'city': 'FAIRFAX',
#    'committee_id': 'C00053553',
#    'committee_type': 'Q',
#    'committee_type_full': 'PAC - Qualified',
#    'cycle': 2012,
#    'cycles': [1976,
#     1978,
#     1980,
#     1982,
#     1984,
#     1986,
#     1988,
#     1990,
#     1992,
#     1994,
#     1996,
#     1998,
#     2000,
#     2002,
#     2004,
#     2006,
#     2008,
#     2010,
#     2012,
#     2014,
#     2016,
#     2018,
#     2020,
#     2022,
#     2024],
#    'cycles_has_activity': [1976,
#     1978,
#     1980,
#     1982,
#     1984,
#     1986,
#     1988,
#     1990,
#     1992,
#     1994,
#     1996,
#     1998,
#     2000,
#     2002,
#     2004,
#     2006,
#     2008,
#     2010,
#     2012,
#     2014,
#     2016,
#     2018,
#     2020,
#     2022,
#     2024],
#    'cycles_has_financial': [1976,
#     1978,
#     1980,
#     1982,
#     1984,
#     1986,
#     1988,
#     1990,
#     1992,
#     1994,
#     1996,
#     1998,
#     2000,
#     2002,
#     2004,
#     2006,
#     2008,
#     2010,
#     2012,
#     2014,
#     2016,
#     2018,
#     2020,
#     2022,
#     2024],
#    'designation': 'B',
#    'designation_full': 'Lobbyist/Registrant PAC',
#    'filing_frequency': 'M',
#    'first_f1_date': '1976-07-28',
#    'first_file_date': '1976-07-28',
#    'is_active': True,
#    'last_cycle_has_activity': 2024,
#    'last_cycle_has_financial': 2024,
#    'last_f1_date': '2023-04-20',
#    'last_file_date': '2023-07-31',
#    'name': 'NATIONAL RIFLE ASSOCIATION OF AMERICA POLITICAL VICTORY FUND',
#    'organization_type': 'M',
#    'organization_type_full': 'Membership Organization',
#    'party': 'UNK',
#    'party_full': 'UNKNOWN',
#    'state': 'VA',
#    'state_full': 'Virginia',
#    'street_1': '11250 WAPLES MILL ROAD',
#    'street_2': None,
#    'treasurer_name': 'ADKINS, MARY ROSE',
#    'zip': '22030'},
#   'committee_id': 'C00053553',
#   'conduit_committee_city': None,
#   'conduit_committee_name': None,
#   'conduit_committee_state': None,
#   'conduit_committee_street1': None,
#   'conduit_committee_street2': None,
#   'conduit_committee_zip': None,
#   'disbursement_amount': 917.66,
#   'disbursement_date': '2012-10-31',
#   'disbursement_description': 'CREDIT CARD FEES',
#   'disbursement_purpose_category': 'OTHER',
#   'disbursement_type': None,
#   'disbursement_type_description': None,
#   'election_type': None,
#   'election_type_full': None,
#   'entity_type': 'ORG',
#   'entity_type_desc': 'ORGANIZATION',
#   'fec_election_type_desc': None,
#   'fec_election_year': None,
#   'file_number': 863519,
#   'filing_form': 'F3X',
#   'image_number': '13961233935',
#   'line_number': '21B',
#   'line_number_label': 'Other Federal Operating Expenditures',
#   'link_id': 4032920131185865923,
#   'load_date': '2017-05-31T20:12:38.059660',
#   'memo_code': None,
#   'memo_code_full': None,
#   'memo_text': 'CREDIT CARD FEES',
#   'memoed_subtotal': False,
#   'national_committee_nonfederal_account': None,
#   'original_sub_id': None,
#   'payee_employer': None,
#   'payee_first_name': None,
#   'payee_last_name': None,
#   'payee_middle_name': None,
#   'payee_occupation': None,
#   'payee_prefix': None,
#   'payee_suffix': None,
#   'pdf_url': 'http://docquery.fec.gov/cgi-bin/fecimg/?13961233935',
#   'recipient_city': 'PHOENIX',
#   'recipient_committee': None,
#   'recipient_committee_id': None,
#   'recipient_name': 'AMERICAN EXPRESS COMPANY',
#   'recipient_state': 'AZ',
#   'recipient_zip': '85072',
#   'ref_disp_excess_flg': None,
#   'report_type': '30G',
#   'report_year': '2012',
#   'schedule_type': 'SB',
#   'schedule_type_full': 'ITEMIZED DISBURSEMENTS',
#   'semi_annual_bundled_refund': '0.00',
#   'spender_committee_designation': 'B',
#   'spender_committee_org_type': 'M',
#   'spender_committee_type': 'Q',
#   'sub_id': '4040220131185979475',
#   'transaction_id': '48698308',
#   'two_year_transaction_period': 2012,
#   'unused_recipient_committee_id': None},
#  {'amendment_indicator': 'N',
#   'amendment_indicator_desc': 'NO CHANGE',
#   'back_reference_schedule_id': None,
#   'back_reference_transaction_id': None,
#   'beneficiary_committee_name': None,
#   'candidate_first_name': None,
#   'candidate_id': None,
#   'candidate_last_name': None,
#   'candidate_middle_name': None,
#   'candidate_name': None,
#   'candidate_office': None,
#   'candidate_office_description': None,
#   'candidate_office_district': None,
#   'candidate_office_state': None,
#   'candidate_office_state_full': None,
#   'candidate_prefix': None,
#   'candidate_suffix': None,
#   'category_code': '001',
#   'category_code_full': 'Administrative/Salary/Overhead Expenses ',
#   'comm_dt': None,
#   'committee': {'affiliated_committee_name': 'THE NATIONAL RIFLE ASSOCIATION OF AMERICA',
#    'candidate_ids': [],
#    'city': 'FAIRFAX',
#    'committee_id': 'C00053553',
#    'committee_type': 'Q',
#    'committee_type_full': 'PAC - Qualified',
#    'cycle': 2012,
#    'cycles': [1976,
#     1978,
#     1980,
#     1982,
#     1984,
#     1986,
#     1988,
#     1990,
#     1992,
#     1994,
#     1996,
#     1998,
#     2000,
#     2002,
#     2004,
#     2006,
#     2008,
#     2010,
#     2012,
#     2014,
#     2016,
#     2018,
#     2020,
#     2022,
#     2024],
#    'cycles_has_activity': [1976,
#     1978,
#     1980,
#     1982,
#     1984,
#     1986,
#     1988,
#     1990,
#     1992,
#     1994,
#     1996,
#     1998,
#     2000,
#     2002,
#     2004,
#     2006,
#     2008,
#     2010,
#     2012,
#     2014,
#     2016,
#     2018,
#     2020,
#     2022,
#     2024],
#    'cycles_has_financial': [1976,
#     1978,
#     1980,
#     1982,
#     1984,
#     1986,
#     1988,
#     1990,
#     1992,
#     1994,
#     1996,
#     1998,
#     2000,
#     2002,
#     2004,
#     2006,
#     2008,
#     2010,
#     2012,
#     2014,
#     2016,
#     2018,
#     2020,
#     2022,
#     2024],
#    'designation': 'B',
#    'designation_full': 'Lobbyist/Registrant PAC',
#    'filing_frequency': 'M',
#    'first_f1_date': '1976-07-28',
#    'first_file_date': '1976-07-28',
#    'is_active': True,
#    'last_cycle_has_activity': 2024,
#    'last_cycle_has_financial': 2024,
#    'last_f1_date': '2023-04-20',
#    'last_file_date': '2023-07-31',
#    'name': 'NATIONAL RIFLE ASSOCIATION OF AMERICA POLITICAL VICTORY FUND',
#    'organization_type': 'M',
#    'organization_type_full': 'Membership Organization',
#    'party': 'UNK',
#    'party_full': 'UNKNOWN',
#    'state': 'VA',
#    'state_full': 'Virginia',
#    'street_1': '11250 WAPLES MILL ROAD',
#    'street_2': None,
#    'treasurer_name': 'ADKINS, MARY ROSE',
#    'zip': '22030'},
#   'committee_id': 'C00053553',
#   'conduit_committee_city': None,
#   'conduit_committee_name': None,
#   'conduit_committee_state': None,
#   'conduit_committee_street1': None,
#   'conduit_committee_street2': None,
#   'conduit_committee_zip': None,
#   'disbursement_amount': 55.0,
#   'disbursement_date': '2012-10-31',
#   'disbursement_description': 'ACCOUNT ANALYSIS FEES',
#   'disbursement_purpose_category': 'OTHER',
#   'disbursement_type': None,
#   'disbursement_type_description': None,
#   'election_type': None,
#   'election_type_full': None,
#   'entity_type': 'ORG',
#   'entity_type_desc': 'ORGANIZATION',
#   'fec_election_type_desc': None,
#   'fec_election_year': None,
#   'file_number': 863519,
#   'filing_form': 'F3X',
#   'image_number': '13961233934',
#   'line_number': '21B',
#   'line_number_label': 'Other Federal Operating Expenditures',
#   'link_id': 4032920131185865923,
#   'load_date': '2017-05-31T20:12:38.059660',
#   'memo_code': None,
#   'memo_code_full': None,
#   'memo_text': 'ACCOUNT ANALYSIS FEES',
#   'memoed_subtotal': False,
#   'national_committee_nonfederal_account': None,
#   'original_sub_id': None,
#   'payee_employer': None,
#   'payee_first_name': None,
#   'payee_last_name': None,
#   'payee_middle_name': None,
#   'payee_occupation': None,
#   'payee_prefix': None,
#   'payee_suffix': None,
#   'pdf_url': 'http://docquery.fec.gov/cgi-bin/fecimg/?13961233934',
#   'recipient_city': 'MCLEAN',
#   'recipient_committee': None,
#   'recipient_committee_id': None,
#   'recipient_name': 'WELLS FARGO BANK, N.A.',
#   'recipient_state': 'VA',
#   'recipient_zip': '22101',
#   'ref_disp_excess_flg': None,
#   'report_type': '30G',
#   'report_year': '2012',
#   'schedule_type': 'SB',
#   'schedule_type_full': 'ITEMIZED DISBURSEMENTS',
#   'semi_annual_bundled_refund': '0.00',
#   'spender_committee_designation': 'B',
#   'spender_committee_org_type': 'M',
#   'spender_committee_type': 'Q',
#   'sub_id': '4040220131185979473',
#   'transaction_id': '48697760',
#   'two_year_transaction_period': 2012,
#   'unused_recipient_committee_id': None},
#  {'amendment_indicator': 'N',
#   'amendment_indicator_desc': 'NO CHANGE',
#   'back_reference_schedule_id': None,
#   'back_reference_transaction_id': None,
#   'beneficiary_committee_name': None,
#   'candidate_first_name': None,
#   'candidate_id': None,
#   'candidate_last_name': None,
#   'candidate_middle_name': None,
#   'candidate_name': None,
#   'candidate_office': None,
#   'candidate_office_description': None,
#   'candidate_office_district': None,
#   'candidate_office_state': None,
#   'candidate_office_state_full': None,
#   'candidate_prefix': None,
#   'candidate_suffix': None,
#   'category_code': '001',
#   'category_code_full': 'Administrative/Salary/Overhead Expenses ',
#   'comm_dt': None,
#   'committee': {'affiliated_committee_name': 'THE NATIONAL RIFLE ASSOCIATION OF AMERICA',
#    'candidate_ids': [],
#    'city': 'FAIRFAX',
#    'committee_id': 'C00053553',
#    'committee_type': 'Q',
#    'committee_type_full': 'PAC - Qualified',
#    'cycle': 2012,
#    'cycles': [1976,
#     1978,
#     1980,
#     1982,
#     1984,
#     1986,
#     1988,
#     1990,
#     1992,
#     1994,
#     1996,
#     1998,
#     2000,
#     2002,
#     2004,
#     2006,
#     2008,
#     2010,
#     2012,
#     2014,
#     2016,
#     2018,
#     2020,
#     2022,
#     2024],
#    'cycles_has_activity': [1976,
#     1978,
#     1980,
#     1982,
#     1984,
#     1986,
#     1988,
#     1990,
#     1992,
#     1994,
#     1996,
#     1998,
#     2000,
#     2002,
#     2004,
#     2006,
#     2008,
#     2010,
#     2012,
#     2014,
#     2016,
#     2018,
#     2020,
#     2022,
#     2024],
#    'cycles_has_financial': [1976,
#     1978,
#     1980,
#     1982,
#     1984,
#     1986,
#     1988,
#     1990,
#     1992,
#     1994,
#     1996,
#     1998,
#     2000,
#     2002,
#     2004,
#     2006,
#     2008,
#     2010,
#     2012,
#     2014,
#     2016,
#     2018,
#     2020,
#     2022,
#     2024],
#    'designation': 'B',
#    'designation_full': 'Lobbyist/Registrant PAC',
#    'filing_frequency': 'M',
#    'first_f1_date': '1976-07-28',
#    'first_file_date': '1976-07-28',
#    'is_active': True,
#    'last_cycle_has_activity': 2024,
#    'last_cycle_has_financial': 2024,
#    'last_f1_date': '2023-04-20',
#    'last_file_date': '2023-07-31',
#    'name': 'NATIONAL RIFLE ASSOCIATION OF AMERICA POLITICAL VICTORY FUND',
#    'organization_type': 'M',
#    'organization_type_full': 'Membership Organization',
#    'party': 'UNK',
#    'party_full': 'UNKNOWN',
#    'state': 'VA',
#    'state_full': 'Virginia',
#    'street_1': '11250 WAPLES MILL ROAD',
#    'street_2': None,
#    'treasurer_name': 'ADKINS, MARY ROSE',
#    'zip': '22030'},
#   'committee_id': 'C00053553',
#   'conduit_committee_city': None,
#   'conduit_committee_name': None,
#   'conduit_committee_state': None,
#   'conduit_committee_street1': None,
#   'conduit_committee_street2': None,
#   'conduit_committee_zip': None,
#   'disbursement_amount': 419.25,
#   'disbursement_date': '2012-10-31',
#   'disbursement_description': 'ACCOUNT ANALYSIS FEES',
#   'disbursement_purpose_category': 'OTHER',
#   'disbursement_type': None,
#   'disbursement_type_description': None,
#   'election_type': None,
#   'election_type_full': None,
#   'entity_type': 'ORG',
#   'entity_type_desc': 'ORGANIZATION',
#   'fec_election_type_desc': None,
#   'fec_election_year': None,
#   'file_number': 863519,
#   'filing_form': 'F3X',
#   'image_number': '13961233934',
#   'line_number': '21B',
#   'line_number_label': 'Other Federal Operating Expenditures',
#   'link_id': 4032920131185865923,
#   'load_date': '2017-05-31T20:12:38.059660',
#   'memo_code': None,
#   'memo_code_full': None,
#   'memo_text': 'ACCOUNT ANALYSIS FEES',
#   'memoed_subtotal': False,
#   'national_committee_nonfederal_account': None,
#   'original_sub_id': None,
#   'payee_employer': None,
#   'payee_first_name': None,
#   'payee_last_name': None,
#   'payee_middle_name': None,
#   'payee_occupation': None,
#   'payee_prefix': None,
#   'payee_suffix': None,
#   'pdf_url': 'http://docquery.fec.gov/cgi-bin/fecimg/?13961233934',
#   'recipient_city': 'ST. LOUIS',
#   'recipient_committee': None,
#   'recipient_committee_id': None,
#   'recipient_name': 'BANK OF AMERICA - MO',
#   'recipient_state': 'MO',
#   'recipient_zip': '63106',
#   'ref_disp_excess_flg': None,
#   'report_type': '30G',
#   'report_year': '2012',
#   'schedule_type': 'SB',
#   'schedule_type_full': 'ITEMIZED DISBURSEMENTS',
#   'semi_annual_bundled_refund': '0.00',
#   'spender_committee_designation': 'B',
#   'spender_committee_org_type': 'M',
#   'spender_committee_type': 'Q',
#   'sub_id': '4040220131185979472',
#   'transaction_id': '48697759',
#   'two_year_transaction_period': 2012,
#   'unused_recipient_committee_id': None},
#  ['api_version', 'pagination', 'results'],
#  ['api_version', 'pagination', 'results'],
#  ['api_version', 'pagination', 'results'],
#  ['api_version', 'pagination', 'results'],
#  ['api_version', 'pagination', 'results'],
#  ['api_version', 'pagination', 'results'],
#  ['api_version', 'pagination', 'results'],
#  ['api_version', 'pagination', 'results'],
#  ['api_version', 'pagination', 'results'],
#  ['api_version', 'pagination', 'results'],
#  ['api_version', 'pagination', 'results'],
#  ['api_version', 'pagination', 'results'],
#  ['api_version', 'pagination', 'results'],
#  ['api_version', 'pagination', 'results'],
#  ['api_version', 'pagination', 'results'],
#  ['api_version', 'pagination', 'results'],
#  ['api_version', 'pagination', 'results'],
#  ['api_version', 'pagination', 'results'],
#  ['api_version', 'pagination', 'results'],
#  ['api_version', 'pagination', 'results'],
#  ['api_version', 'pagination', 'results'],
#  ['api_version', 'pagination', 'results'],
#  ['api_version', 'pagination', 'results'],
#  ['api_version', 'pagination', 'results'],
#  ['api_version', 'pagination', 'results'],
#  ['api_version', 'pagination', 'results'],
#  ['api_version', 'pagination', 'results'],
#  ['api_version', 'pagination', 'results']]

# %%
del nra_list[100:]

# %%
[type(d) for d in nra_list]

# %%
# delete empty list items
nra_no_committee = [{k: v for k, v in d.items() if k != 'committee'} for d in nra_list]

# %%
nra_df = pd.DataFrame(nra_no_committee)

# %%
nra_df

# %%
nra_df.shape

# %%
nra_df.info()

# %%
#dropping null/unnecessary columns (1st round)
nra_df.drop(columns=['back_reference_schedule_id', 'back_reference_transaction_id', 'candidate_first_name', 'candidate_last_name', 'candidate_middle_name', 'candidate_suffix', 'comm_dt', 'conduit_committee_city', 'conduit_committee_name', 'conduit_committee_state', 'conduit_committee_street1', 'conduit_committee_street2', 'conduit_committee_zip', 'memo_code', 'memo_code_full', 'national_committee_nonfederal_account', 'original_sub_id', 'payee_employer', 'payee_first_name', 'payee_last_name', 'payee_middle_name', 'payee_occupation', 'payee_prefix', 'payee_suffix', 'ref_disp_excess_flg'], inplace=True)

# %%
pd.set_option('display.max_columns', None)
nra_df.head(100)

# %%
#dropping additional unnecessary columns (2nd round)
nra_df.drop(columns=['amendment_indicator_desc', 'candidate_office_state_full', 'candidate_prefix', 'category_code', 'entity_type_desc', 'fec_election_type_desc', 'fec_election_year', 'file_number', 'filing_form', 'image_number', 'line_number', 'link_id', 'load_date', 'memoed_subtotal', 'pdf_url', 'report_type', 'report_year', 'schedule_type', 'schedule_type_full', 'semi_annual_bundled_refund', 'spender_committee_designation', 'sub_id', 'two_year_transaction_period'], inplace=True)

# %%
nra_df.head(100)

# %%
#dropping additional unnecessary columns (3rd round)
nra_df.drop(columns=['candidate_office_description', 'disbursement_type', 'disbursement_type_description', 'recipient_committee', 'election_type', 'election_type_full', 'recipient_state', 'recipient_zip'], inplace=True)

# %%
nra_df.columns

# %%
#dropping additional unnecessary columns (4th round)
nra_df.drop(columns=['beneficiary_committee_name', 'candidate_office_district', 'candidate_office_state', 'line_number_label', 'memo_text', 'recipient_city'], inplace=True)

# %%
nra_df.shape

# %%
nra_df.columns

# %%
nra_df['candidate_name'].value_counts()

# %% [markdown]
# #### Schedule E - Expenditures

# %%
# loop through all candidate ids to get a master list of all expenditures made on behalf of elected congress members

def expenditures_master_pull(cand_id_list):  # add list of FEC candidate ids
    expenditures_all_pages = []
    count = 0
    
    # cycle through the first page of each rq to find the length of each expenditure list by candidate
    for ids in cand_id_list:
        expenditures_rq = rq.get(f'https://api.open.fec.gov/v1/schedules/schedule_e/by_candidate/?page=1&per_page=100&cycle=2012&election_full=true&candidate_id={ids}&sort_hide_null=false&sort_null_only=false&sort_nulls_last=false&api_key={api_key_fec}')
        pgone_rq = expenditures_rq.json()
        time.sleep(.5)
        
        # uncomment to debug 
        # print(pgone_rq.keys())   
        
        try:
            qty_pages = page_count(pgone_rq)
            count += 1

        except KeyError:
            print(f'API Request for candidate {ids} could not be found. Here\'s what was pulled:')
            print(pgone_rq)

        except JSONDecodeError:
            print(expenditures_rq.status_code)
            print(pgone_rq.keys())
            
        # with length of rq pull, loop through each page for every candidate and append to a blank list
        for i in range(1, qty_pages+1):
            all_expenditures_rq = rq.get(f'https://api.open.fec.gov/v1/schedules/schedule_e/by_candidate/?page={i}&per_page=100&cycle=2012&election_full=true&candidate_id={ids}&sort_hide_null=false&sort_null_only=false&sort_nulls_last=false&api_key={api_key_fec}')
            
            # upgraded FEC api key can pull a max of 120 calls a minute
            time.sleep(.5)
            
            try:
                all_expenditures_json = all_expenditures_rq.json()
                results = all_expenditures_json['results']
                expenditures_all_pages.append(results)

            except JSONDecodeError:
                print(all_expenditures_rq.status_code)
            
        # check status during pull
        clear_output(wait=True)
        print(f'Pulling expenditures from {ids}, on number {count} out of 433!')
        expenditures_rq.raise_for_status()
        
    
    return expenditures_all_pages

# %%
expenditures = expenditures_master_pull(candidate_ids)
# Out:
# Pulling expenditures from H0CA32101, on number 39 out of 433!
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[91], line 1
# ----> 1 expenditures = expenditures_master_pull(candidate_ids)
#
# Cell In[90], line 11, in expenditures_master_pull(cand_id_list)
#       9 expenditures_rq = rq.get(f'https://api.open.fec.gov/v1/schedules/schedule_e/by_candidate/?page=1&per_page=100&cycle=2012&election_full=true&candidate_id={ids}&sort_hide_null=false&sort_null_only=false&sort_nulls_last=false&api_key={api_key_fec}')
#      10 pgone_rq = expenditures_rq.json()
# ---> 11 time.sleep(.5)
#      13 # uncomment to debug
#      14 # print(pgone_rq.keys())
#      16 try:
#
# KeyboardInterrupt:

# %%
# #uncomment to troubleshoot errors in api requests


# problem_id = 'H4GA06087'

# problem_rq = rq.get(f'https://api.open.fec.gov/v1/schedules/schedule_e/by_candidate/?page=1&per_page=100&cycle=2012&election_full=true&candidate_id={problem_id}&sort_hide_null=false&sort_null_only=false&sort_nulls_last=false&api_key={api_key_fec}')

# print(problem_rq.status_code)
# problem_json = problem_rq.json()

# problem_json
# Out:
# 200
# {'api_version': '1.0',
#  'pagination': {'count': 1, 'page': 1, 'pages': 1, 'per_page': 100},
#  'results': [{'candidate_id': 'H4GA06087',
#    'candidate_name': 'PRICE, THOMAS EDMUNDS',
#    'committee_id': 'C00343137',
#    'committee_name': 'POLITICAL ACTION COMMITTEE OF THE AMERICAN ASSOCIATION OF ORTHOPAEDIC SURGEONS',
#    'count': 1,
#    'cycle': 2012,
#    'support_oppose_indicator': 'S',
#    'total': 20000.0}]}

# %%
# converting the list of lists of dictionaries into a dataframe 
expend_dict = pull_list_of_dicts(expenditures)
expend_df = pd.DataFrame(expend_dict)
expend_df.head(2)
# Out:
#   candidate_id         candidate_name committee_id  \
# 0    H2AL01077  BONNER, JOSIAH ROBIAS    C00502849
# 1    H0AL02087           ROBY, MARTHA    C00000935
#
#                                 committee_name  count  cycle  \
# 0      CAMPAIGN FOR PRIMARY ACCOUNTABILITY INC     13   2012
# 1  DEMOCRATIC CONGRESSIONAL CAMPAIGN COMMITTEE      3   2012
#
#   support_oppose_indicator      total
# 0                        O  123679.84
# 1                        O   11676.41

# %%
expend_df.to_csv('./datasets/expenditures.csv',sep=',',index=False)
