# %% [markdown]
# # US Representative Voting Patterns and Funding Sources

# %% [markdown]
# *Exploratory analysis of how funding influences voting habits in Congress*
#
# Part 1 of Exploratory Analysis: Pulling FEC funding data through API

# %%
import requests as rq # to pull data from FEC API
import pandas as pd # for data exploration
from keys import api_key_fec # holds secure API KEY
import sqlite3 as sq # to pull data from sqlite database
import difflib # fuzzy matching data from multiple tables

# %% [markdown]
# ***

# %% [markdown]
# ### Creating a reference table of registered committees - to use with further API requests
#
# **Conditions for filters**
# 1. Active in 2012 (election cycle)
# 2. Filing Frequency: Monthly or Quarterly Filer
# 3. Designation: All but Unauthorized
# 4. Organization Type: All
# 5. Committee_Type: All but Party, Nonqualified/Qualified/National Non-Federal Account
#
# **Steps**
# 1. Set up blank list and for loop for API pagination
# 2. Get request from API with above filters added to url
# 3. Extend all pages pulled into one list and convert to DataFrame

# %%
# example request to test result
# committees_rq = rq.get(f'https://api.open.fec.gov/v1/committees/?page=1&per_page=100&year=2012&cycle=2012&filing_frequency=M&filing_frequency=Q&designation=A&designation=J&designation=P&designation=B&designation=D&organization_type=C&organization_type=L&organization_type=M&organization_type=T&organization_type=V&organization_type=W&committee_type=C&committee_type=D&committee_type=E&committee_type=H&committee_type=I&committee_type=N&committee_type=O&committee_type=P&committee_type=Q&committee_type=S&committee_type=U&sort=name&sort_hide_null=false&sort_null_only=false&sort_nulls_last=false&api_key={api_key_fec}')

# print(committees_rq.status_code)
# committees = committees_rq.json()
# committees

# %%
# for loop to pull all ten pages of requests and combine into one DF

committees_all_pages = []
for i in range(1,11):
    committees_rq = rq.get(f'https://api.open.fec.gov/v1/committees/?page={i}&per_page=100&year=2012&cycle=2012&filing_frequency=M&filing_frequency=Q&designation=A&designation=J&designation=P&designation=B&designation=D&organization_type=C&organization_type=L&organization_type=M&organization_type=T&organization_type=V&organization_type=W&committee_type=C&committee_type=D&committee_type=E&committee_type=H&committee_type=I&committee_type=N&committee_type=O&committee_type=P&committee_type=Q&committee_type=S&committee_type=U&sort=name&sort_hide_null=false&sort_null_only=false&sort_nulls_last=false&api_key={api_key_fec}')
    
    committees = committees_rq.json()
    committees_all_pages.append(committees)

# %%
#merge all results into one DF
blank_list = []
for i in range(0,10):
    blank_list.extend(committees_all_pages[i]['results'] )

# %%
committees_df = pd.DataFrame(blank_list)

# %%
committees_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 991 entries, 0 to 990
# Data columns (total 22 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   affiliated_committee_name  976 non-null    object
#  1   candidate_ids              991 non-null    object
#  2   committee_id               991 non-null    object
#  3   committee_type             991 non-null    object
#  4   committee_type_full        991 non-null    object
#  5   cycles                     991 non-null    object
#  6   designation                991 non-null    object
#  7   designation_full           991 non-null    object
#  8   filing_frequency           991 non-null    object
#  9   first_f1_date              991 non-null    object
#  10  first_file_date            991 non-null    object
#  11  last_f1_date               991 non-null    object
#  12  last_file_date             991 non-null    object
#  13  name                       991 non-null    object
#  14  organization_type          991 non-null    object
#  15  organization_type_full     991 non-null    object
#  16  party                      105 non-null    object
#  17  party_full                 102 non-null    object
#  18  sponsor_candidate_ids      2 non-null      object
#  19  sponsor_candidate_list     991 non-null    object
#  20  state                      991 non-null    object
#  21  treasurer_name             991 non-null    object
# dtypes: object(22)
# memory usage: 170.5+ KB

# %%
committees_df.head(5)
# Out:
#   affiliated_committee_name candidate_ids committee_id committee_type  \
# 0                3M COMPANY            []    C00084475              Q
# 1       ABBOTT LABORATORIES            []    C00040279              Q
# 2                    ABBVIE            []    C00536573              Q
# 3             ABIOMED, INC.            []    C00426445              Q
# 4           ACCENTURE, INC.            []    C00300707              Q
#
#   committee_type_full                                             cycles  \
# 0     PAC - Qualified  [1978, 1980, 1982, 1984, 1986, 1988, 1990, 199...
# 1     PAC - Qualified  [1976, 1978, 1980, 1982, 1984, 1986, 1988, 199...
# 2     PAC - Qualified         [2012, 2014, 2016, 2018, 2020, 2022, 2024]
# 3     PAC - Qualified  [2006, 2008, 2010, 2012, 2014, 2016, 2018, 202...
# 4     PAC - Qualified  [1996, 1998, 2000, 2002, 2004, 2006, 2008, 201...
#
#   designation         designation_full filing_frequency first_f1_date  ...  \
# 0           B  Lobbyist/Registrant PAC                M    1978-01-10  ...
# 1           B  Lobbyist/Registrant PAC                M    1976-04-19  ...
# 2           B  Lobbyist/Registrant PAC                M    2012-11-19  ...
# 3           B  Lobbyist/Registrant PAC                Q    2006-07-17  ...
# 4           B  Lobbyist/Registrant PAC                Q    1995-01-19  ...
#
#   last_file_date                                               name  \
# 0     2023-08-14                                     3M COMPANY PAC
# 1     2023-08-18  ABBOTT LABORATORIES EMPLOYEE POLITICAL ACTION ...
# 2     2023-08-15                  ABBVIE POLITICAL ACTION COMMITTEE
# 3     2023-08-16  ABIOMED INC POLITICAL ACTION COMMITTEE (ABIOME...
# 4     2023-07-20          ACCENTURE INC. POLITICAL ACTION COMMITTEE
#
#   organization_type organization_type_full party party_full  \
# 0                 C            Corporation   PAC       None
# 1                 C            Corporation   UNK    UNKNOWN
# 2                 C            Corporation  None       None
# 3                 C            Corporation  None       None
# 4                 C            Corporation  None       None
#
#   sponsor_candidate_ids sponsor_candidate_list state         treasurer_name
# 0                  None                     []    MN       TENNESSEN, TRACY
# 1                  None                     []    IL      GUERRERO, CYNTHIA
# 2                  None                     []    IL       KOLENDA, TIMOTHY
# 3                  None                     []    MA         LIMOLI, JUSTIN
# 4                  None                     []    DC  NICHOLSON, MATTHEW R.
#
# [5 rows x 22 columns]

# %% [markdown]
# #### Committee Referential Table Clean-Up
#
# 1. Dropping unnecessary columns (blank/mostly null or not relevant to analysis)
# 2. Renaming remaining columns
# 3. Checking for any nulls, exploring basic description of data before export
# 4. Saving as csv
# 5. Create list of committee ids for funding API requests

# %%
# dropping columns: 

committees_df.drop(columns=['candidate_ids','first_f1_date','first_file_date','last_f1_date','last_file_date','sponsor_candidate_ids','sponsor_candidate_list','filing_frequency','party','party_full','committee_type','organization_type','designation','cycles','treasurer_name'],inplace=True)

# %%
committees_df.columns
# Out:
# Index(['affiliated_committee_name', 'committee_id', 'committee_type_full',
#        'designation_full', 'name', 'organization_type_full', 'state'],
#       dtype='object')

# %%
# renaming column names 
committees_df.columns = ['affiliated_committee_name', 'committee_id', 'committee_type', 'designation_type', 'name', 'organization_type', 'state']

# %%
committees_df.head(1)
# Out:
#   affiliated_committee_name committee_id   committee_type  \
# 0                3M COMPANY    C00084475  PAC - Qualified
#
#           designation_type            name organization_type state
# 0  Lobbyist/Registrant PAC  3M COMPANY PAC       Corporation    MN

# %%
committees_df.shape
# Out:
# (991, 7)

# %%
committees_df.describe(include='all')
# Out:
#        affiliated_committee_name committee_id   committee_type  \
# count                        976          991              991
# unique                       943          991                2
# top                         NONE    C00084475  PAC - Qualified
# freq                          20            1              948
#
#                designation_type            name organization_type state
# count                       991             991               991   991
# unique                        4             991                 6    45
# top     Lobbyist/Registrant PAC  3M COMPANY PAC       Corporation    DC
# freq                        986               1               577   367

# %%
committees_df.dtypes
# Out:
# affiliated_committee_name    object
# committee_id                 object
# committee_type               object
# designation_type             object
# name                         object
# organization_type            object
# state                        object
# dtype: object

# %%
committees_df.to_csv('./datasets/committees.csv',sep=',',index=False)

# %%
committee_id_list = committees_df['committee_id']
committee_id_list
# Out:
# 0      C00084475
# 1      C00040279
# 2      C00536573
# 3      C00426445
# 4      C00300707
#          ...
# 986    C00329474
# 987    C00279455
# 988    C00025536
# 989    C00399386
# 990    C00235036
# Name: committee_id, Length: 991, dtype: object

# %% [markdown]
# ***

# %% [markdown]
# ### Creating a reference table of registered candidates - to use with further API requests
#
# **Filters for Candidate Search API**
# 1. Cycle - 2012
# 2. Election Year - 2012
# 3. Office - H, S
# 4. Year - 2012
# 5. Has Raised Funds - True

# %%
# API Request

members_rq = rq.get(f'https://api.open.fec.gov/v1/candidates/search/?page=1&per_page=100&cycle=2012&election_year=2012&office=H&office=S&year=2012&has_raised_funds=true&sort=name&sort_hide_null=false&sort_null_only=false&sort_nulls_last=false&api_key={api_key_fec}')

print(members_rq.status_code)
members_json = members_rq.json()

members_json
# Out:
# 200
# {'api_version': '1.0',
#  'pagination': {'count': 2120, 'page': 1, 'pages': 22, 'per_page': 100},
#  'results': [{'active_through': 2018,
#    'candidate_id': 'S2UT00229',
#    'candidate_inactive': False,
#    'candidate_status': 'P',
#    'cycles': [2012, 2014, 2016, 2018, 2020],
#    'district': '00',
#    'district_number': 0,
#    'election_districts': ['00', '00'],
#    'election_years': [2012, 2018],
#    'federal_funds_flag': False,
#    'first_file_date': '2012-02-08',
#    'has_raised_funds': True,
#    'inactive_election_years': None,
#    'incumbent_challenge': 'O',
#    'incumbent_challenge_full': 'Open seat',
#    'last_f2_date': '2018-04-23',
#    'last_file_date': '2018-04-23',
#    'load_date': '2019-03-27T16:02:41',
#    'name': 'AALDERS, TIMOTHY NOEL',
#    'office': 'S',
#    'office_full': 'Senate',
#    'party': 'CON',
#    'party_full': 'CONSTITUTION PARTY',
#    'principal_committees': [{'affiliated_committee_name': 'NONE',
#      'candidate_ids': ['S2UT00229'],
#      'committee_id': 'C00678300',
#      'committee_type': 'S',
#      'committee_type_full': 'Senate',
#      'cycles': [2018, 2020],
#      'designation': 'P',
#      'designation_full': 'Principal campaign committee',
#      'filing_frequency': 'T',
#      'first_f1_date': '2018-05-04',
#      'first_file_date': '2018-05-04',
#      'last_f1_date': '2018-12-04',
#      'last_file_date': '2020-08-07',
#      'name': 'TIM AALDERS FOR US SENATE',
#      'organization_type': None,
#      'organization_type_full': None,
#      'party': 'CON',
#      'party_full': 'CONSTITUTION PARTY',
#      'state': 'UT',
#      'treasurer_name': 'AALDERS, TIM'},
#     {'affiliated_committee_name': None,
#      'candidate_ids': ['S2UT00229'],
#      'committee_id': 'C00512632',
#      'committee_type': 'S',
#      'committee_type_full': 'Senate',
#      'cycles': [2012, 2014, 2016],
#      'designation': 'P',
#      'designation_full': 'Principal campaign committee',
#      'filing_frequency': 'A',
#      'first_f1_date': '2012-02-08',
#      'first_file_date': '2012-02-08',
#      'last_f1_date': '2012-02-08',
#      'last_file_date': '2015-11-10',
#      'name': 'TIM AALDERS FOR SENATE',
#      'organization_type': None,
#      'organization_type_full': None,
#      'party': 'REP',
#      'party_full': 'REPUBLICAN PARTY',
#      'state': 'UT',
#      'treasurer_name': 'DWAYNE A VANCE'}],
#    'state': 'UT'},
#   {'active_through': 2012,
#    'candidate_id': 'H2CA01110',
#    'candidate_inactive': False,
#    'candidate_status': 'P',
#    'cycles': [2012, 2014, 2016],
#    'district': '01',
#    'district_number': 1,
#    'election_districts': ['01'],
#    'election_years': [2012],
#    'federal_funds_flag': False,
#    'first_file_date': '2012-02-22',
#    'has_raised_funds': True,
#    'inactive_election_years': None,
#    'incumbent_challenge': 'C',
#    'incumbent_challenge_full': 'Challenger',
#    'last_f2_date': '2012-02-22',
#    'last_file_date': '2012-02-22',
#    'load_date': '2013-04-26T09:04:30',
#    'name': 'AANESTAD, SAMUEL',
#    'office': 'H',
#    'office_full': 'House',
#    'party': 'REP',
#    'party_full': 'REPUBLICAN PARTY',
#    'principal_committees': [{'affiliated_committee_name': None,
#      'candidate_ids': ['H2CA01110'],
#      'committee_id': 'C00513580',
#      'committee_type': 'H',
#      'committee_type_full': 'House',
#      'cycles': [2012, 2014, 2016],
#      'designation': 'P',
#      'designation_full': 'Principal campaign committee',
#      'filing_frequency': 'A',
#      'first_f1_date': '2012-02-22',
#      'first_file_date': '2012-02-22',
#      'last_f1_date': '2014-07-18',
#      'last_file_date': '2015-12-16',
#      'name': 'SAM AANESTAD FOR CONGRESS COMMITTEE',
#      'organization_type': None,
#      'organization_type_full': None,
#      'party': 'REP',
#      'party_full': 'REPUBLICAN PARTY',
#      'state': 'CA',
#      'treasurer_name': 'SAM AANESTAD'}],
#    'state': 'CA'},
#   {'active_through': 2012,
#    'candidate_id': 'H2AZ02279',
#    'candidate_inactive': False,
#    'candidate_status': 'P',
#    'cycles': [2012, 2014],
#    'district': '02',
#    'district_number': 2,
#    'election_districts': ['02'],
#    'election_years': [2012],
#    'federal_funds_flag': False,
#    'first_file_date': '2012-02-15',
#    'has_raised_funds': True,
#    'inactive_election_years': None,
#    'incumbent_challenge': 'C',
#    'incumbent_challenge_full': 'Challenger',
#    'last_f2_date': '2012-02-15',
#    'last_file_date': '2012-02-15',
#    'load_date': '2013-04-26T09:04:30',
#    'name': 'ABOUD, PAULA ANN',
#    'office': 'H',
#    'office_full': 'House',
#    'party': 'DEM',
#    'party_full': 'DEMOCRATIC PARTY',
#    'principal_committees': [{'affiliated_committee_name': None,
#      'candidate_ids': ['H2AZ02279'],
#      'committee_id': 'C00514810',
#      'committee_type': 'H',
#      'committee_type_full': 'House',
#      'cycles': [2012, 2014],
#      'designation': 'P',
#      'designation_full': 'Principal campaign committee',
#      'filing_frequency': 'T',
#      'first_f1_date': '2012-03-07',
#      'first_file_date': '2012-03-07',
#      'last_f1_date': '2012-03-07',
#      'last_file_date': '2013-05-13',
#      'name': 'PAULA ABOUD FOR CONGRESS',
#      'organization_type': None,
#      'organization_type_full': None,
#      'party': 'DEM',
#      'party_full': 'DEMOCRATIC PARTY',
#      'state': 'AZ',
#      'treasurer_name': 'JEFFRY S DOBBINS'}],
#    'state': 'AZ'},
#   {'active_through': 2014,
#    'candidate_id': 'H4NY07011',
#    'candidate_inactive': False,
#    'candidate_status': 'N',
#    'cycles': [1984,
#     1986,
#     1988,
#     1990,
#     1992,
#     1994,
#     1996,
#     1998,
#     2000,
#     2002,
#     2004,
#     2006,
#     2008,
#     2010,
#     2012,
#     2014,
#     2016,
#     2018],
#    'district': '05',
#    'district_number': 5,
#    'election_districts': ['07',
#     '07',
#     '07',
#     '07',
#     '05',
#     '05',
#     '05',
#     '05',
#     '05',
#     '05',
#     '05',
#     '05',
#     '05',
#     '05',
#     '05',
#     '05'],
#    'election_years': [1984,
#     1986,
#     1988,
#     1990,
#     1992,
#     1994,
#     1996,
#     1998,
#     2000,
#     2002,
#     2004,
#     2006,
#     2008,
#     2010,
#     2012,
#     2014],
#    'federal_funds_flag': False,
#    'first_file_date': '1983-01-31',
#    'has_raised_funds': True,
#    'inactive_election_years': [2012],
#    'incumbent_challenge': 'C',
#    'incumbent_challenge_full': 'Challenger',
#    'last_f2_date': '2011-10-03',
#    'last_file_date': '2011-10-03',
#    'load_date': '2013-01-03T22:17:08',
#    'name': 'ACKERMAN, GARY L.',
#    'office': 'H',
#    'office_full': 'House',
#    'party': 'DEM',
#    'party_full': 'DEMOCRATIC PARTY',
#    'principal_committees': [{'affiliated_committee_name': 'NONE',
#      'candidate_ids': ['H4NY07011'],
#      'committee_id': 'C00165241',
#      'committee_type': 'H',
#      'committee_type_full': 'House',
#      'cycles': [1984,
#       1986,
#       1988,
#       1990,
#       1992,
#       1994,
#       1996,
#       1998,
#       2000,
#       2002,
#       2004,
#       2006,
#       2008,
#       2010,
#       2012,
#       2014,
#       2016,
#       2018],
#      'designation': 'P',
#      'designation_full': 'Principal campaign committee',
#      'filing_frequency': 'T',
#      'first_f1_date': '1983-01-31',
#      'first_file_date': '1983-01-31',
#      'last_f1_date': '2009-08-17',
#      'last_file_date': '2017-08-21',
#      'name': 'COMMITTEE TO ELECT GARY L. ACKERMAN, INC.',
#      'organization_type': None,
#      'organization_type_full': None,
#      'party': 'DEM',
#      'party_full': 'DEMOCRATIC PARTY',
#      'state': 'NY',
#      'treasurer_name': 'BARNETT, ROBERT'}],
#    'state': 'NY'},
#   {'active_through': 2012,
#    'candidate_id': 'H2CA25176',
#    'candidate_inactive': False,
#    'candidate_status': 'P',
#    'cycles': [2012, 2014, 2016],
#    'district': '25',
#    'district_number': 25,
#    'election_districts': ['25'],
#    'election_years': [2012],
#    'federal_funds_flag': False,
#    'first_file_date': '2012-03-29',
#    'has_raised_funds': True,
#    'inactive_election_years': None,
#    'incumbent_challenge': 'C',
#    'incumbent_challenge_full': 'Challenger',
#    'last_f2_date': '2012-03-29',
#    'last_file_date': '2012-03-29',
#    'load_date': '2013-04-26T09:04:30',
#    'name': 'ACOSTA, DANTE',
#    'office': 'H',
#    'office_full': 'House',
#    'party': 'REP',
#    'party_full': 'REPUBLICAN PARTY',
#    'principal_committees': [{'affiliated_committee_name': None,
#      'candidate_ids': ['H2CA25176'],
#      'committee_id': 'C00517706',
#      'committee_type': 'H',
#      'committee_type_full': 'House',
#      'cycles': [2012, 2014, 2016],
#      'designation': 'P',
#      'designation_full': 'Principal campaign committee',
#      'filing_frequency': 'A',
#      'first_f1_date': '2012-03-29',
#      'first_file_date': '2012-03-29',
#      'last_f1_date': '2012-03-29',
#      'last_file_date': '2015-02-18',
#      'name': 'DANTE ACOSTA FOR CONGRESS',
#      'organization_type': None,
#      'organization_type_full': None,
#      'party': 'REP',
#      'party_full': 'REPUBLICAN PARTY',
#      'state': 'CA',
#      'treasurer_name': 'THOMAS CHRISTENSEN'}],
#    'state': 'CA'},
#   {'active_through': 2012,
#    'candidate_id': 'H2CA08180',
#    'candidate_inactive': False,
#    'candidate_status': 'P',
#    'cycles': [2012, 2014],
#    'district': '08',
#    'district_number': 8,
#    'election_districts': ['08'],
#    'election_years': [2012],
#    'federal_funds_flag': False,
#    'first_file_date': '2012-02-22',
#    'has_raised_funds': True,
#    'inactive_election_years': None,
#    'incumbent_challenge': 'C',
#    'incumbent_challenge_full': 'Challenger',
#    'last_f2_date': '2012-02-22',
#    'last_file_date': '2012-02-22',
#    'load_date': '2014-04-01T09:54:32',
#    'name': 'ADAMS, ANTHONY T',
#    'office': 'H',
#    'office_full': 'House',
#    'party': 'NPA',
#    'party_full': 'NO PARTY AFFILIATION',
#    'principal_committees': [{'affiliated_committee_name': None,
#      'candidate_ids': ['H2CA08180'],
#      'committee_id': 'C00513416',
#      'committee_type': 'H',
#      'committee_type_full': 'House',
#      'cycles': [2012, 2014],
#      'designation': 'P',
#      'designation_full': 'Principal campaign committee',
#      'filing_frequency': 'T',
#      'first_f1_date': '2012-02-21',
#      'first_file_date': '2012-02-21',
#      'last_f1_date': '2012-03-27',
#      'last_file_date': '2013-01-10',
#      'name': 'ANTHONY ADAMS FOR CONGRESS 2012',
#      'organization_type': None,
#      'organization_type_full': None,
#      'party': 'IND',
#      'party_full': 'INDEPENDENT',
#      'state': 'CA',
#      'treasurer_name': 'LYSA RAY'}],
#    'state': 'CA'},
#   {'active_through': 2016,
#    'candidate_id': 'H6FL11175',
#    'candidate_inactive': False,
#    'candidate_status': 'N',
#    'cycles': [2006, 2008, 2010, 2012, 2014, 2016],
#    'district': '14',
#    'district_number': 14,
#    'election_districts': ['11', '11', '11', '14', '14'],
#    'election_years': [2006, 2008, 2010, 2012, 2016],
#    'federal_funds_flag': False,
#    'first_file_date': '2005-11-01',
#    'has_raised_funds': True,
#    'inactive_election_years': None,
#    'incumbent_challenge': 'C',
#    'incumbent_challenge_full': 'Challenger',
#    'last_f2_date': '2015-11-30',
#    'last_file_date': '2015-11-30',
#    'load_date': '2016-01-04T20:57:31',
#    'name': 'ADAMS, EDDIE JR',
#    'office': 'H',
#    'office_full': 'House',
#    'party': 'REP',
#    'party_full': 'REPUBLICAN PARTY',
#    'principal_committees': [{'affiliated_committee_name': None,
#      'candidate_ids': ['H6FL11175'],
#      'committee_id': 'C00592923',
#      'committee_type': 'H',
#      'committee_type_full': 'House',
#      'cycles': [2016],
#      'designation': 'P',
#      'designation_full': 'Principal campaign committee',
#      'filing_frequency': 'T',
#      'first_f1_date': '2015-11-30',
#      'first_file_date': '2015-11-30',
#      'last_f1_date': '2015-11-30',
#      'last_file_date': '2016-12-12',
#      'name': 'ADAMS FOR CONGRESS',
#      'organization_type': None,
#      'organization_type_full': None,
#      'party': 'REP',
#      'party_full': 'REPUBLICAN PARTY',
#      'state': 'FL',
#      'treasurer_name': 'ANTONIO CHASE'},
#     {'affiliated_committee_name': None,
#      'candidate_ids': ['H6FL11175'],
#      'committee_id': 'C00522797',
#      'committee_type': 'H',
#      'committee_type_full': 'House',
#      'cycles': [2012, 2014],
#      'designation': 'P',
#      'designation_full': 'Principal campaign committee',
#      'filing_frequency': 'A',
#      'first_f1_date': '2012-06-03',
#      'first_file_date': '2012-06-03',
#      'last_f1_date': '2012-06-03',
#      'last_file_date': '2013-04-08',
#      'name': 'ADAMS FOR CONGRESS',
#      'organization_type': None,
#      'organization_type_full': None,
#      'party': 'REP',
#      'party_full': 'REPUBLICAN PARTY',
#      'state': 'FL',
#      'treasurer_name': 'ELISABETH ORVOSH'},
#     {'affiliated_committee_name': 'NONE',
#      'candidate_ids': ['H6FL11175'],
#      'committee_id': 'C00467860',
#      'committee_type': 'H',
#      'committee_type_full': 'House',
#      'cycles': [2010, 2012],
#      'designation': 'A',
#      'designation_full': 'Authorized by a candidate',
#      'filing_frequency': 'T',
#      'first_f1_date': '2009-09-29',
#      'first_file_date': '2009-09-29',
#      'last_f1_date': '2010-05-25',
#      'last_file_date': '2011-05-25',
#      'name': 'ADAMS FOR CONGRESS',
#      'organization_type': None,
#      'organization_type_full': None,
#      'party': 'REP',
#      'party_full': 'REPUBLICAN PARTY',
#      'state': 'FL',
#      'treasurer_name': 'ROOKS, KAREN A'},
#     {'affiliated_committee_name': None,
#      'candidate_ids': ['H6FL11175'],
#      'committee_id': 'C00416388',
#      'committee_type': 'H',
#      'committee_type_full': 'House',
#      'cycles': [2006, 2008, 2010],
#      'designation': 'A',
#      'designation_full': 'Authorized by a candidate',
#      'filing_frequency': 'T',
#      'first_f1_date': '2005-11-01',
#      'first_file_date': '2005-11-01',
#      'last_f1_date': '2005-11-01',
#      'last_file_date': '2009-02-03',
#      'name': 'ADAMS FOR CONGRESS',
#      'organization_type': None,
#      'organization_type_full': None,
#      'party': 'REP',
#      'party_full': 'REPUBLICAN PARTY',
#      'state': 'FL',
#      'treasurer_name': 'NANCY H WATKINS'}],
#    'state': 'FL'},
#   {'active_through': 2021,
#    'candidate_id': 'H0OH15099',
#    'candidate_inactive': False,
#    'candidate_status': 'N',
#    'cycles': [2010, 2012, 2014, 2016, 2018, 2022],
#    'district': '15',
#    'district_number': 15,
#    'election_districts': ['15', '03', '03', '03', '12', '15'],
#    'election_years': [2010, 2012, 2014, 2016, 2018, 2021],
#    'federal_funds_flag': False,
#    'first_file_date': '2010-04-09',
#    'has_raised_funds': True,
#    'inactive_election_years': None,
#    'incumbent_challenge': 'O',
#    'incumbent_challenge_full': 'Open seat',
#    'last_f2_date': '2014-07-07',
#    'last_file_date': '2014-07-24',
#    'load_date': '2021-06-30T02:42:45',
#    'name': 'ADAMS, JOHN',
#    'office': 'H',
#    'office_full': 'House',
#    'party': 'REP',
#    'party_full': 'REPUBLICAN PARTY',
#    'principal_committees': [{'affiliated_committee_name': None,
#      'candidate_ids': ['H0OH15099'],
#      'committee_id': 'C00565721',
#      'committee_type': 'H',
#      'committee_type_full': 'House',
#      'cycles': [2014, 2016, 2018],
#      'designation': 'P',
#      'designation_full': 'Principal campaign committee',
#      'filing_frequency': 'A',
#      'first_f1_date': '2014-07-07',
#      'first_file_date': '2014-07-07',
#      'last_f1_date': '2014-09-08',
#      'last_file_date': '2018-08-15',
#      'name': 'JOHN ADAMS FOR CONGRESS',
#      'organization_type': None,
#      'organization_type_full': None,
#      'party': 'REP',
#      'party_full': 'REPUBLICAN PARTY',
#      'state': 'OH',
#      'treasurer_name': 'BETHANYANNE A AUSTIN'},
#     {'affiliated_committee_name': None,
#      'candidate_ids': ['H0OH15099'],
#      'committee_id': 'C00480590',
#      'committee_type': 'H',
#      'committee_type_full': 'House',
#      'cycles': [2010],
#      'designation': 'P',
#      'designation_full': 'Principal campaign committee',
#      'filing_frequency': 'T',
#      'first_f1_date': '2010-04-09',
#      'first_file_date': '2010-04-09',
#      'last_f1_date': '2010-04-09',
#      'last_file_date': '2010-06-10',
#      'name': 'JOHN ADAMS 2010 CONGRESS',
#      'organization_type': None,
#      'organization_type_full': None,
#      'party': 'REP',
#      'party_full': 'REPUBLICAN PARTY',
#      'state': 'OH',
#      'treasurer_name': 'PAUL F WARREN'}],
#    'state': 'OH'},
#   {'active_through': 2012,
#    'candidate_id': 'H2AZ06148',
#    'candidate_inactive': False,
#    'candidate_status': 'P',
#    'cycles': [2012, 2014, 2016, 2018, 2020],
#    'district': '05',
#    'district_number': 5,
#    'election_districts': ['05'],
#    'election_years': [2012],
#    'federal_funds_flag': False,
#    'first_file_date': '2011-04-29',
#    'has_raised_funds': True,
#    'inactive_election_years': None,
#    'incumbent_challenge': 'O',
#    'incumbent_challenge_full': 'Open seat',
#    'last_f2_date': '2012-02-22',
#    'last_file_date': '2012-02-22',
#    'load_date': '2013-04-26T09:04:30',
#    'name': 'ADAMS, KIRK DAVID',
#    'office': 'H',
#    'office_full': 'House',
#    'party': 'REP',
#    'party_full': 'REPUBLICAN PARTY',
#    'principal_committees': [{'affiliated_committee_name': 'NONE',
#      'candidate_ids': ['H2AZ06148'],
#      'committee_id': 'C00495986',
#      'committee_type': 'H',
#      'committee_type_full': 'House',
#      'cycles': [2012, 2014, 2016, 2018, 2020],
#      'designation': 'P',
#      'designation_full': 'Principal campaign committee',
#      'filing_frequency': 'T',
#      'first_f1_date': '2011-04-29',
#      'first_file_date': '2011-04-29',
#      'last_f1_date': '2013-05-09',
#      'last_file_date': '2019-08-29',
#      'name': 'KIRK ADAMS FOR CONGRESS',
#      'organization_type': None,
#      'organization_type_full': None,
#      'party': 'REP',
#      'party_full': 'REPUBLICAN PARTY',
#      'state': 'AZ',
#      'treasurer_name': 'SYREK, WAYNE'}],
#    'state': 'AZ'},
#   {'active_through': 2016,
#    'candidate_id': 'H0FL24049',
#    'candidate_inactive': False,
#    'candidate_status': 'P',
#    'cycles': [2010, 2012, 2014, 2016, 2018],
#    'district': '06',
#    'district_number': 6,
#    'election_districts': ['24', '07', '06'],
#    'election_years': [2010, 2012, 2016],
#    'federal_funds_flag': False,
#    'first_file_date': '2009-07-10',
#    'has_raised_funds': True,
#    'inactive_election_years': None,
#    'incumbent_challenge': 'C',
#    'incumbent_challenge_full': 'Challenger',
#    'last_f2_date': '2015-06-23',
#    'last_file_date': '2015-06-23',
#    'load_date': '2017-02-23T14:47:46',
#    'name': 'ADAMS, SANDY',
#    'office': 'H',
#    'office_full': 'House',
#    'party': 'REP',
#    'party_full': 'REPUBLICAN PARTY',
#    'principal_committees': [{'affiliated_committee_name': 'NONE',
#      'candidate_ids': ['H0FL24049'],
#      'committee_id': 'C00463877',
#      'committee_type': 'H',
#      'committee_type_full': 'House',
#      'cycles': [2010, 2012, 2014, 2016, 2018],
#      'designation': 'P',
#      'designation_full': 'Principal campaign committee',
#      'filing_frequency': 'T',
#      'first_f1_date': '2009-07-10',
#      'first_file_date': '2009-07-10',
#      'last_f1_date': '2015-06-23',
#      'last_file_date': '2018-07-08',
#      'name': 'SANDY ADAMS FOR CONGRESS',
#      'organization_type': None,
#      'organization_type_full': None,
#      'party': 'REP',
#      'party_full': 'REPUBLICAN PARTY',
#      'state': 'FL',
#      'treasurer_name': 'WATKINS, NANCY H.'}],
#    'state': 'FL'},
#   {'active_through': 2012,
#    'candidate_id': 'H2CA06275',
#    'candidate_inactive': False,
#    'candidate_status': 'P',
#    'cycles': [2012, 2014],
#    'district': '02',
#    'district_number': 2,
#    'election_districts': ['02'],
#    'election_years': [2012],
#    'federal_funds_flag': False,
#    'first_file_date': '2011-05-31',
#    'has_raised_funds': True,
#    'inactive_election_years': None,
#    'incumbent_challenge': 'O',
#    'incumbent_challenge_full': 'Open seat',
#    'last_f2_date': '2011-05-31',
#    'last_file_date': '2011-05-31',
#    'load_date': '2013-04-26T09:04:30',
#    'name': 'ADAMS, SUSAN L',
#    'office': 'H',
#    'office_full': 'House',
#    'party': 'DEM',
#    'party_full': 'DEMOCRATIC PARTY',
#    'principal_committees': [{'affiliated_committee_name': None,
#      'candidate_ids': ['H2CA06275'],
#      'committee_id': 'C00497222',
#      'committee_type': 'H',
#      'committee_type_full': 'House',
#      'cycles': [2012, 2014],
#      'designation': 'P',
#      'designation_full': 'Principal campaign committee',
#      'filing_frequency': 'T',
#      'first_f1_date': '2011-05-31',
#      'first_file_date': '2011-05-31',
#      'last_f1_date': '2011-05-31',
#      'last_file_date': '2013-05-31',
#      'name': 'SUSAN ADAMS FOR CONGRESS',
#      'organization_type': None,
#      'organization_type_full': None,
#      'party': 'DEM',
#      'party_full': 'DEMOCRATIC PARTY',
#      'state': 'CA',
#      'treasurer_name': 'TAMARA S HULL '}],
#    'state': 'CA'},
#   {'active_through': 2012,
#    'candidate_id': 'S2TX00320',
#    'candidate_inactive': False,
#    'candidate_status': 'C',
#    'cycles': [2012],
#    'district': '00',
#    'district_number': 0,
#    'election_districts': ['00'],
#    'election_years': [2012],
#    'federal_funds_flag': False,
#    'first_file_date': '2011-02-15',
#    'has_raised_funds': True,
#    'inactive_election_years': None,
#    'incumbent_challenge': 'O',
#    'incumbent_challenge_full': 'Open seat',
#    'last_f2_date': '2011-02-15',
#    'last_file_date': '2011-02-15',
#    'load_date': '2011-07-21T00:14:15',
#    'name': 'ADDISON, MARSHALL GLENN',
#    'office': 'S',
#    'office_full': 'Senate',
#    'party': 'REP',
#    'party_full': 'REPUBLICAN PARTY',
#    'principal_committees': [{'affiliated_committee_name': None,
#      'candidate_ids': ['S2TX00320'],
#      'committee_id': 'C00493346',
#      'committee_type': 'S',
#      'committee_type_full': 'Senate',
#      'cycles': [2012],
#      'designation': 'P',
#      'designation_full': 'Principal campaign committee',
#      'filing_frequency': 'T',
#      'first_f1_date': '2011-02-15',
#      'first_file_date': '2011-02-15',
#      'last_f1_date': '2011-04-05',
#      'last_file_date': '2012-08-07',
#      'name': 'GLENN ADDISON SENATE CAMPAIGN',
#      'organization_type': None,
#      'organization_type_full': None,
#      'party': 'REP',
#      'party_full': 'REPUBLICAN PARTY',
#      'state': 'TX',
#      'treasurer_name': 'JOHN LAWRENCE LYNCH'}],
#    'state': 'TX'},
#   {'active_through': 2014,
#    'candidate_id': 'H2MA05120',
#    'candidate_inactive': False,
#    'candidate_status': 'N',
#    'cycles': [2012, 2014, 2016, 2018, 2020],
#    'district': '05',
#    'district_number': 5,
#    'election_districts': ['05', '05'],
#    'election_years': [2012, 2014],
#    'federal_funds_flag': False,
#    'first_file_date': '2012-06-07',
#    'has_raised_funds': True,
#    'inactive_election_years': [2014],
#    'incumbent_challenge': 'C',
#    'incumbent_challenge_full': 'Challenger',
#    'last_f2_date': '2013-07-30',
#    'last_file_date': '2013-07-30',
#    'load_date': '2014-02-18T22:11:13',
#    'name': 'ADDIVINOLA, FRANK JOHN JR',
#    'office': 'H',
#    'office_full': 'House',
#    'party': 'REP',
#    'party_full': 'REPUBLICAN PARTY',
#    'principal_committees': [{'affiliated_committee_name': None,
#      'candidate_ids': ['H2MA05120', 'S4MA00242'],
#      'committee_id': 'C00523332',
#      'committee_type': 'S',
#      'committee_type_full': 'Senate',
#      'cycles': [2012, 2014, 2016, 2018, 2020],
#      'designation': 'P',
#      'designation_full': 'Principal campaign committee',
#      'filing_frequency': 'T',
#      'first_f1_date': '2012-06-18',
#      'first_file_date': '2012-06-18',
#      'last_f1_date': '2020-03-09',
#      'last_file_date': '2020-03-11',
#      'name': ' ADDIVINOLA COMMITTEE; THE',
#      'organization_type': None,
#      'organization_type_full': None,
#      'party': 'REP',
#      'party_full': 'REPUBLICAN PARTY',
#      'state': 'MA',
#      'treasurer_name': 'ANGELICA ADDIVINOLA'}],
#    'state': 'MA'},
#   {'active_through': 2012,
#    'candidate_id': 'H2AR03234',
#    'candidate_inactive': False,
#    'candidate_status': 'P',
#    'cycles': [2012, 2014],
#    'district': '03',
#    'district_number': 3,
#    'election_districts': ['03'],
#    'election_years': [2012],
#    'federal_funds_flag': False,
#    'first_file_date': '2011-09-14',
#    'has_raised_funds': True,
#    'inactive_election_years': None,
#    'incumbent_challenge': 'C',
#    'incumbent_challenge_full': 'Challenger',
#    'last_f2_date': '2011-09-14',
#    'last_file_date': '2011-09-14',
#    'load_date': '2013-04-26T09:04:30',
#    'name': 'ADEN, KENNETH WADE',
#    'office': 'H',
#    'office_full': 'House',
#    'party': 'DEM',
#    'party_full': 'DEMOCRATIC PARTY',
#    'principal_committees': [{'affiliated_committee_name': None,
#      'candidate_ids': ['H2AR03234'],
#      'committee_id': 'C00502138',
#      'committee_type': 'H',
#      'committee_type_full': 'House',
#      'cycles': [2012, 2014],
#      'designation': 'P',
#      'designation_full': 'Principal campaign committee',
#      'filing_frequency': 'T',
#      'first_f1_date': '2011-09-14',
#      'first_file_date': '2011-09-14',
#      'last_f1_date': '2011-09-14',
#      'last_file_date': '2013-05-11',
#      'name': 'KENNETH WADE ADEN 4 CONGRESS',
#      'organization_type': None,
#      'organization_type_full': None,
#      'party': 'DEM',
#      'party_full': 'DEMOCRATIC PARTY',
#      'state': 'AR',
#      'treasurer_name': 'RENEA DRUSILLA EUBANKS'}],
#    'state': 'AR'},
#   {'active_through': 2024,
#    'candidate_id': 'H6AL04098',
#    'candidate_inactive': False,
#    'candidate_status': 'C',
#    'cycles': [1996,
#     1998,
#     2000,
#     2002,
#     2004,
#     2006,
#     2008,
#     2010,
#     2012,
#     2014,
#     2016,
#     2018,
#     2020,
#     2022,
#     2024],
#    'district': '04',
#    'district_number': 4,
#    'election_districts': ['04',
#     '04',
#     '04',
#     '04',
#     '04',
#     '04',
#     '04',
#     '04',
#     '04',
#     '04',
#     '04',
#     '04',
#     '04',
#     '04',
#     '04'],
#    'election_years': [1996,
#     1998,
#     2000,
#     2002,
#     2004,
#     2006,
#     2008,
#     2010,
#     2012,
#     2014,
#     2016,
#     2018,
#     2020,
#     2022,
#     2024],
#    'federal_funds_flag': False,
#    'first_file_date': '1996-02-14',
#    'has_raised_funds': True,
#    'inactive_election_years': None,
#    'incumbent_challenge': 'I',
#    'incumbent_challenge_full': 'Incumbent',
#    'last_f2_date': '2022-12-01',
#    'last_file_date': '2022-12-01',
#    'load_date': '2023-08-06T21:01:25',
#    'name': 'ADERHOLT, ROBERT B. REP.',
#    'office': 'H',
#    'office_full': 'House',
#    'party': 'REP',
#    'party_full': 'REPUBLICAN PARTY',
#    'principal_committees': [{'affiliated_committee_name': 'ADERHOLT MAJORITY FUND',
#      'candidate_ids': ['H6AL04098'],
#      'committee_id': 'C00313247',
#      'committee_type': 'H',
#      'committee_type_full': 'House',
#      'cycles': [1996,
#       1998,
#       2000,
#       2002,
#       2004,
#       2006,
#       2008,
#       2010,
#       2012,
#       2014,
#       2016,
#       2018,
#       2020,
#       2022,
#       2024],
#      'designation': 'P',
#      'designation_full': 'Principal campaign committee',
#      'filing_frequency': 'Q',
#      'first_f1_date': '1996-02-14',
#      'first_file_date': '1996-02-14',
#      'last_f1_date': '2023-07-20',
#      'last_file_date': '2023-07-20',
#      'name': 'ROBERT ADERHOLT FOR CONGRESS',
#      'organization_type': None,
#      'organization_type_full': None,
#      'party': 'REP',
#      'party_full': 'REPUBLICAN PARTY',
#      'state': 'AL',
#      'treasurer_name': 'MOBLEY, JEFF MR.'}],
#    'state': 'AL'},
#   {'active_through': 2012,
#    'candidate_id': 'H2KY04139',
#    'candidate_inactive': False,
#    'candidate_status': 'C',
#    'cycles': [2012],
#    'district': '04',
#    'district_number': 4,
#    'election_districts': ['04'],
#    'election_years': [2012],
#    'federal_funds_flag': False,
#    'first_file_date': '2012-02-29',
#    'has_raised_funds': True,
#    'inactive_election_years': None,
#    'incumbent_challenge': 'O',
#    'incumbent_challenge_full': 'Open seat',
#    'last_f2_date': '2012-02-29',
#    'last_file_date': '2012-02-29',
#    'load_date': '2012-04-17T21:43:49',
#    'name': 'ADKINS, WILLIAM R. "BILL"',
#    'office': 'H',
#    'office_full': 'House',
#    'party': 'DEM',
#    'party_full': 'DEMOCRATIC PARTY',
#    'principal_committees': [{'affiliated_committee_name': None,
#      'candidate_ids': ['H2KY04139'],
#      'committee_id': 'C00514018',
#      'committee_type': 'H',
#      'committee_type_full': 'House',
#      'cycles': [2012],
#      'designation': 'P',
#      'designation_full': 'Principal campaign committee',
#      'filing_frequency': 'T',
#      'first_f1_date': '2012-02-29',
#      'first_file_date': '2012-02-29',
#      'last_f1_date': '2012-02-29',
#      'last_file_date': '2012-12-20',
#      'name': 'ADKINS FOR CONGRESSS',
#      'organization_type': None,
#      'organization_type_full': None,
#      'party': 'DEM',
#      'party_full': 'DEMOCRATIC PARTY',
#      'state': 'KY',
#      'treasurer_name': 'DARRELL LINK'}],
#    'state': 'KY'},
#   {'active_through': 2012,
#    'candidate_id': 'H2NJ03183',
#    'candidate_inactive': False,
#    'candidate_status': 'P',
#    'cycles': [2012, 2014, 2016],
#    'district': '03',
#    'district_number': 3,
#    'election_districts': ['03'],
#    'election_years': [2012],
#    'federal_funds_flag': False,
#    'first_file_date': '2012-02-13',
#    'has_raised_funds': True,
#    'inactive_election_years': None,
#    'incumbent_challenge': 'C',
#    'incumbent_challenge_full': 'Challenger',
#    'last_f2_date': '2012-02-13',
#    'last_file_date': '2012-02-13',
#    'load_date': '2013-04-26T09:04:30',
#    'name': 'ADLER, SHELLEY',
#    'office': 'H',
#    'office_full': 'House',
#    'party': 'DEM',
#    'party_full': 'DEMOCRATIC PARTY',
#    'principal_committees': [{'affiliated_committee_name': None,
#      'candidate_ids': ['H2NJ03183'],
#      'committee_id': 'C00512475',
#      'committee_type': 'H',
#      'committee_type_full': 'House',
#      'cycles': [2012, 2014, 2016],
#      'designation': 'P',
#      'designation_full': 'Principal campaign committee',
#      'filing_frequency': 'T',
#      'first_f1_date': '2012-02-13',
#      'first_file_date': '2012-02-13',
#      'last_f1_date': '2012-02-13',
#      'last_file_date': '2016-04-14',
#      'name': 'SHELLEY ADLER FOR CONGRESS',
#      'organization_type': None,
#      'organization_type_full': None,
#      'party': 'DEM',
#      'party_full': 'DEMOCRATIC PARTY',
#      'state': 'NJ',
#      'treasurer_name': 'PETER D NICHOLS'}],
#    'state': 'NJ'},
#   {'active_through': 2012,
#    'candidate_id': 'H2MD06229',
#    'candidate_inactive': False,
#    'candidate_status': 'P',
#    'cycles': [2012, 2014, 2016, 2018],
#    'district': '06',
#    'district_number': 6,
#    'election_districts': ['06'],
#    'election_years': [2012],
#    'federal_funds_flag': False,
#    'first_file_date': '2012-01-30',
#    'has_raised_funds': True,
#    'inactive_election_years': None,
#    'incumbent_challenge': 'C',
#    'incumbent_challenge_full': 'Challenger',
#    'last_f2_date': '2012-01-30',
#    'last_file_date': '2012-01-30',
#    'load_date': '2013-04-26T09:04:30',
#    'name': 'AFZALI, KATHY',
#    'office': 'H',
#    'office_full': 'House',
#    'party': 'REP',
#    'party_full': 'REPUBLICAN PARTY',
#    'principal_committees': [{'affiliated_committee_name': None,
#      'candidate_ids': ['H2MD06229'],
#      'committee_id': 'C00511360',
#      'committee_type': 'H',
#      'committee_type_full': 'House',
#      'cycles': [2012, 2014, 2016, 2018],
#      'designation': 'P',
#      'designation_full': 'Principal campaign committee',
#      'filing_frequency': 'A',
#      'first_f1_date': '2012-02-01',
#      'first_file_date': '2012-02-01',
#      'last_f1_date': '2012-02-01',
#      'last_file_date': '2017-07-26',
#      'name': 'KATHY AFZALI FOR CONGRESS',
#      'organization_type': None,
#      'organization_type_full': None,
#      'party': 'REP',
#      'party_full': 'REPUBLICAN PARTY',
#      'state': 'MD',
#      'treasurer_name': 'JOHN T CORNELIUS'}],
#    'state': 'MD'},
#   {'active_through': 2012,
#    'candidate_id': 'H2OH13199',
#    'candidate_inactive': False,
#    'candidate_status': 'P',
#    'cycles': [2012, 2014],
#    'district': '13',
#    'district_number': 13,
#    'election_districts': ['13'],
#    'election_years': [2012],
#    'federal_funds_flag': False,
#    'first_file_date': '2011-12-13',
#    'has_raised_funds': True,
#    'inactive_election_years': None,
#    'incumbent_challenge': 'C',
#    'incumbent_challenge_full': 'Challenger',
#    'last_f2_date': '2012-01-10',
#    'last_file_date': '2012-01-10',
#    'load_date': '2013-04-26T09:04:30',
#    'name': 'AGANA, MARISHA GUZMAN',
#    'office': 'H',
#    'office_full': 'House',
#    'party': 'REP',
#    'party_full': 'REPUBLICAN PARTY',
#    'principal_committees': [{'affiliated_committee_name': 'NONE',
#      'candidate_ids': ['H2OH13199'],
#      'committee_id': 'C00507491',
#      'committee_type': 'H',
#      'committee_type_full': 'House',
#      'cycles': [2012, 2014],
#      'designation': 'P',
#      'designation_full': 'Principal campaign committee',
#      'filing_frequency': 'T',
#      'first_f1_date': '2011-12-13',
#      'first_file_date': '2011-12-13',
#      'last_f1_date': '2012-07-12',
#      'last_file_date': '2014-01-02',
#      'name': 'DR MARISHA AGANA FOR CONGRESS',
#      'organization_type': None,
#      'organization_type_full': None,
#      'party': 'REP',
#      'party_full': 'REPUBLICAN PARTY',
#      'state': 'OH',
#      'treasurer_name': 'YUSKEWICH, J. MATTHEW'}],
#    'state': 'OH'},
#   {'active_through': 2012,
#    'candidate_id': 'H2IL17097',
#    'candidate_inactive': False,
#    'candidate_status': 'P',
#    'cycles': [2012, 2014, 2016],
#    'district': '17',
#    'district_number': 17,
#    'election_districts': ['17'],
#    'election_years': [2012],
#    'federal_funds_flag': False,
#    'first_file_date': '2011-08-24',
#    'has_raised_funds': True,
#    'inactive_election_years': None,
#    'incumbent_challenge': 'C',
#    'incumbent_challenge_full': 'Challenger',
#    'last_f2_date': '2011-08-24',
#    'last_file_date': '2011-08-24',
#    'load_date': '2013-04-26T09:04:30',
#    'name': 'AGUILAR, GREGORIO MIGUEL',
#    'office': 'H',
#    'office_full': 'House',
#    'party': 'DEM',
#    'party_full': 'DEMOCRATIC PARTY',
#    'principal_committees': [{'affiliated_committee_name': None,
#      'candidate_ids': ['H2IL17097'],
#      'committee_id': 'C00501809',
#      'committee_type': 'H',
#      'committee_type_full': 'House',
#      'cycles': [2012, 2014, 2016],
#      'designation': 'P',
#      'designation_full': 'Principal campaign committee',
#      'filing_frequency': 'A',
#      'first_f1_date': '2011-09-08',
#      'first_file_date': '2011-09-08',
#      'last_f1_date': '2011-11-07',
#      'last_file_date': '2015-11-12',
#      'name': 'GREG AGUILAR FOR CONGRESS',
#      'organization_type': None,
#      'organization_type_full': None,
#      'party': None,
#      'party_full': None,
#      'state': 'IL',
#      'treasurer_name': 'DAVID VYNCKE'}],
#    'state': 'IL'},
#   {'active_through': 2024,
#    'candidate_id': 'H2CA31125',
#    'candidate_inactive': False,
#    'candidate_status': 'C',
#    'cycles': [2012, 2014, 2016, 2018, 2020, 2022, 2024],
#    'district': '33',
#    'district_number': 33,
#    'election_districts': ['31', '31', '31', '31', '31', '33', '33'],
#    'election_years': [2012, 2014, 2016, 2018, 2020, 2022, 2024],
#    'federal_funds_flag': False,
#    'first_file_date': '2012-01-17',
#    'has_raised_funds': True,
#    'inactive_election_years': None,
#    'incumbent_challenge': 'I',
#    'incumbent_challenge_full': 'Incumbent',
#    'last_f2_date': '2023-01-12',
#    'last_file_date': '2023-01-12',
#    'load_date': '2023-01-31T21:14:36',
#    'name': 'AGUILAR, PETE',
#    'office': 'H',
#    'office_full': 'House',
#    'party': 'DEM',
#    'party_full': 'DEMOCRATIC PARTY',
#    'principal_committees': [{'affiliated_committee_name': 'AGUILAR LEADERSHIP FUND',
#      'candidate_ids': ['H2CA31125'],
#      'committee_id': 'C00510461',
#      'committee_type': 'H',
#      'committee_type_full': 'House',
#      'cycles': [2012, 2014, 2016, 2018, 2020, 2022, 2024],
#      'designation': 'P',
#      'designation_full': 'Principal campaign committee',
#      'filing_frequency': 'Q',
#      'first_f1_date': '2012-01-24',
#      'first_file_date': '2012-01-24',
#      'last_f1_date': '2023-07-14',
#      'last_file_date': '2023-08-14',
#      'name': 'PETE AGUILAR FOR CONGRESS',
#      'organization_type': None,
#      'organization_type_full': None,
#      'party': 'DEM',
#      'party_full': 'DEMOCRATIC PARTY',
#      'state': 'CA',
#      'treasurer_name': 'ANGERHOLZER, LINDSAY F.'}],
#    'state': 'CA'},
#   {'active_through': 2012,
#    'candidate_id': 'H2AZ03137',
#    'candidate_inactive': False,
#    'candidate_status': 'P',
#    'cycles': [2012, 2014],
#    'district': '03',
#    'district_number': 3,
#    'election_districts': ['03'],
#    'election_years': [2012],
#    'federal_funds_flag': False,
#    'first_file_date': '2012-03-15',
#    'has_raised_funds': True,
#    'inactive_election_years': None,
#    'incumbent_challenge': 'C',
#    'incumbent_challenge_full': 'Challenger',
#    'last_f2_date': '2012-03-15',
#    'last_file_date': '2012-03-15',
#    'load_date': '2013-04-26T09:04:30',
#    'name': 'AGUIRRE, AMANDA',
#    'office': 'H',
#    'office_full': 'House',
#    'party': 'DEM',
#    'party_full': 'DEMOCRATIC PARTY',
#    'principal_committees': [{'affiliated_committee_name': 'NONE',
#      'candidate_ids': ['H2AZ03137'],
#      'committee_id': 'C00515775',
#      'committee_type': 'H',
#      'committee_type_full': 'House',
#      'cycles': [2012, 2014],
#      'designation': 'P',
#      'designation_full': 'Principal campaign committee',
#      'filing_frequency': 'T',
#      'first_f1_date': '2012-03-15',
#      'first_file_date': '2012-03-15',
#      'last_f1_date': '2012-06-14',
#      'last_file_date': '2013-01-09',
#      'name': 'AMANDA AGUIRRE FOR CONGRESS D3',
#      'organization_type': None,
#      'organization_type_full': None,
#      'party': 'DEM',
#      'party_full': 'DEMOCRATIC PARTY',
#      'state': 'AZ',
#      'treasurer_name': 'MEDINA, TULY B'}],
#    'state': 'AZ'},
#   {'active_through': 2012,
#    'candidate_id': 'S8MD00088',
#    'candidate_inactive': False,
#    'candidate_status': 'P',
#    'cycles': [1988, 2012, 2014],
#    'district': '00',
#    'district_number': 0,
#    'election_districts': ['00', '00'],
#    'election_years': [1988, 2012],
#    'federal_funds_flag': False,
#    'first_file_date': '1988-05-13',
#    'has_raised_funds': True,
#    'inactive_election_years': None,
#    'incumbent_challenge': 'C',
#    'incumbent_challenge_full': 'Challenger',
#    'last_f2_date': '2012-07-09',
#    'last_file_date': '2012-07-09',
#    'load_date': '2013-04-26T09:04:30',
#    'name': 'AHMAD, IMAD ALDEAN',
#    'office': 'S',
#    'office_full': 'Senate',
#    'party': 'LIB',
#    'party_full': 'LIBERTARIAN PARTY',
#    'principal_committees': [{'affiliated_committee_name': None,
#      'candidate_ids': ['S8MD00088'],
#      'committee_id': 'C00525857',
#      'committee_type': 'S',
#      'committee_type_full': 'Senate',
#      'cycles': [2012, 2014],
#      'designation': 'P',
#      'designation_full': 'Principal campaign committee',
#      'filing_frequency': 'T',
#      'first_f1_date': '2012-07-30',
#      'first_file_date': '2012-07-30',
#      'last_f1_date': '2012-10-15',
#      'last_file_date': '2013-03-25',
#      'name': 'AHMAD FOR US SENATE',
#      'organization_type': None,
#      'organization_type_full': None,
#      'party': 'LIB',
#      'party_full': 'LIBERTARIAN PARTY',
#      'state': 'MD',
#      'treasurer_name': 'ROBERT S JOHNSTON III'},
#     {'affiliated_committee_name': None,
#      'candidate_ids': ['S8MD00088'],
#      'committee_id': 'C00227900',
#      'committee_type': 'S',
#      'committee_type_full': 'Senate',
#      'cycles': [1988],
#      'designation': 'P',
#      'designation_full': 'Principal campaign committee',
#      'filing_frequency': 'T',
#      'first_f1_date': '1988-05-10',
#      'first_file_date': '1988-05-10',
#      'last_f1_date': '1988-05-10',
#      'last_file_date': '1989-10-13',
#      'name': 'IMAD A AHMAD U S SENATE',
#      'organization_type': None,
#      'organization_type_full': None,
#      'party': None,
#      'party_full': None,
#      'state': 'MD',
#      'treasurer_name': 'ROBERT E CREAGER'}],
#    'state': 'MD'},
#   {'active_through': 2012,
#    'candidate_id': 'S0HI00084',
#    'candidate_inactive': False,
#    'candidate_status': 'P',
#    'cycles': [1990,
#     1992,
#     1994,
#     1996,
#     1998,
#     2000,
#     2002,
#     2004,
#     2006,
#     2008,
#     2010,
#     2012,
#     2014],
#    'district': '00',
#    'district_number': 0,
#    'election_districts': ['00', '00', '00', '00', '00'],
#    'election_years': [1990, 1994, 2000, 2006, 2012],
#    'federal_funds_flag': False,
#    'first_file_date': '1990-05-08',
#    'has_raised_funds': True,
#    'inactive_election_years': [2012],
#    'incumbent_challenge': 'C',
#    'incumbent_challenge_full': 'Challenger',
#    'last_f2_date': '2007-01-23',
#    'last_file_date': '2007-03-15',
#    'load_date': '2013-04-26T09:04:30',
#    'name': 'AKAKA, DANIEL KAHIKINA',
#    'office': 'S',
#    'office_full': 'Senate',
#    'party': 'DEM',
#    'party_full': 'DEMOCRATIC PARTY',
#    'principal_committees': [{'affiliated_committee_name': None,
#      'candidate_ids': ['S0HI00084'],
#      'committee_id': 'C00432880',
#      'committee_type': 'S',
#      'committee_type_full': 'Senate',
#      'cycles': [2008, 2010, 2012, 2014],
#      'designation': 'P',
#      'designation_full': 'Principal campaign committee',
#      'filing_frequency': 'T',
#      'first_f1_date': '2007-03-06',
#      'first_file_date': '2007-03-06',
#      'last_f1_date': '2007-03-06',
#      'last_file_date': '2013-05-09',
#      'name': 'AKAKA IN 2012',
#      'organization_type': None,
#      'organization_type_full': None,
#      'party': None,
#      'party_full': None,
#      'state': 'HI',
#      'treasurer_name': 'STEVEN ARASHIRO'},
#     {'affiliated_committee_name': None,
#      'candidate_ids': ['S0HI00084'],
#      'committee_id': 'C00368134',
#      'committee_type': 'S',
#      'committee_type_full': 'Senate',
#      'cycles': [2000, 2002, 2004, 2006, 2008],
#      'designation': 'A',
#      'designation_full': 'Authorized by a candidate',
#      'filing_frequency': 'T',
#      'first_f1_date': '2000-11-27',
#      'first_file_date': '2000-11-27',
#      'last_f1_date': '2006-01-25',
#      'last_file_date': '2007-07-24',
#      'name': 'AKAKA IN 2006',
#      'organization_type': None,
#      'organization_type_full': None,
#      'party': None,
#      'party_full': None,
#      'state': 'HI',
#      'treasurer_name': 'WAYNE J. YAMASAKI'},
#     {'affiliated_committee_name': None,
#      'candidate_ids': ['S0HI00084'],
#      'committee_id': 'C00301176',
#      'committee_type': 'S',
#      'committee_type_full': 'Senate',
#      'cycles': [1996, 1998, 2000, 2002],
#      'designation': 'A',
#      'designation_full': 'Authorized by a candidate',
#      'filing_frequency': 'T',
#      'first_f1_date': '1995-02-22',
#      'first_file_date': '1995-02-22',
#      'last_f1_date': '1995-02-22',
#      'last_file_date': '2001-09-14',
#      'name': 'AKAKA 2000',
#      'organization_type': None,
#      'organization_type_full': None,
#      'party': None,
#      'party_full': None,
#      'state': 'HI',
#      'treasurer_name': 'GEORGE H LUMSDEN'},
#     {'affiliated_committee_name': None,
#      'candidate_ids': ['S0HI00084'],
#      'committee_id': 'C00253435',
#      'committee_type': 'S',
#      'committee_type_full': 'Senate',
#      'cycles': [1992, 1994, 1996, 1998],
#      'designation': 'A',
#      'designation_full': 'Authorized by a candidate',
#      'filing_frequency': 'T',
#      'first_f1_date': '1991-02-14',
#      'first_file_date': '1991-02-14',
#      'last_f1_date': '1994-02-14',
#      'last_file_date': '1996-10-04',
#      'name': 'AKAKA IN 94',
#      'organization_type': None,
#      'organization_type_full': None,
#      'party': 'DEM',
#      'party_full': 'DEMOCRATIC PARTY',
#      'state': 'HI',
#      'treasurer_name': 'GEORGE H LUMSDEN'},
#     {'affiliated_committee_name': None,
#      'candidate_ids': ['H6HI02046', 'S0HI00084'],
#      'committee_id': 'C00054528',
#      'committee_type': 'S',
#      'committee_type_full': 'Senate',
#      'cycles': [1976, 1978, 1980, 1982, 1984, 1986, 1988, 1990, 1992, 1994],
#      'designation': 'A',
#      'designation_full': 'Authorized by a candidate',
#      'filing_frequency': 'T',
#      'first_f1_date': '1976-05-13',
#      'first_file_date': '1976-05-13',
#      'last_f1_date': '1991-11-04',
#      'last_file_date': '1994-11-04',
#      'name': 'DANIEL K AKAKA FOR U S SENATE',
#      'organization_type': None,
#      'organization_type_full': None,
#      'party': 'DEM',
#      'party_full': 'DEMOCRATIC PARTY',
#      'state': 'HI',
#      'treasurer_name': 'GEORGE H LUMSDEN'}],
#    'state': 'HI'},
#   {'active_through': 2012,
#    'candidate_id': 'H2CA02134',
#    'candidate_inactive': False,
#    'candidate_status': 'C',
#    'cycles': [2012],
#    'district': '02',
#    'district_number': 2,
#    'election_districts': ['02'],
#    'election_years': [2012],
#    'federal_funds_flag': False,
#    'first_file_date': '2011-10-11',
#    'has_raised_funds': True,
#    'inactive_election_years': None,
#    'incumbent_challenge': 'O',
#    'incumbent_challenge_full': 'Open seat',
#    'last_f2_date': '2011-10-11',
#    'last_file_date': '2011-10-11',
#    'load_date': '2012-02-07T21:37:26',
#    'name': 'AKHLAGHI, BANAFSHEH',
#    'office': 'H',
#    'office_full': 'House',
#    'party': 'DEM',
#    'party_full': 'DEMOCRATIC PARTY',
#    'principal_committees': [{'affiliated_committee_name': None,
#      'candidate_ids': ['H2CA02134'],
#      'committee_id': 'C00503490',
#      'committee_type': 'H',
#      'committee_type_full': 'House',
#      'cycles': [2012],
#      'designation': 'P',
#      'designation_full': 'Principal campaign committee',
#      'filing_frequency': 'T',
#      'first_f1_date': '2011-10-11',
#      'first_file_date': '2011-10-11',
#      'last_f1_date': '2011-10-11',
#      'last_file_date': '2012-04-18',
#      'name': 'BANAFSHEH AKHLAGHI FOR CONGRESS',
#      'organization_type': None,
#      'organization_type_full': None,
#      'party': 'DEM',
#      'party_full': 'DEMOCRATIC PARTY',
#      'state': 'CA',
#      'treasurer_name': 'A B CHRISTENSEN'}],
#    'state': 'CA'},
#   {'active_through': 2012,
#    'candidate_id': 'H0MO02148',
#    'candidate_inactive': False,
#    'candidate_status': 'P',
#    'cycles': [2000, 2002, 2004, 2006, 2008, 2010, 2012, 2014, 2016],
#    'district': '02',
#    'district_number': 2,
#    'election_districts': ['02', '02', '02', '02', '02', '02', '02'],
#    'election_years': [2000, 2002, 2004, 2006, 2008, 2010, 2012],
#    'federal_funds_flag': False,
#    'first_file_date': '1999-03-05',
#    'has_raised_funds': True,
#    'inactive_election_years': [2012],
#    'incumbent_challenge': 'C',
#    'incumbent_challenge_full': 'Challenger',
#    'last_f2_date': '2008-12-14',
#    'last_file_date': '2011-04-13',
#    'load_date': '2013-04-26T09:04:30',
#    'name': 'AKIN, W TODD',
#    'office': 'H',
#    'office_full': 'House',
#    'party': 'REP',
#    'party_full': 'REPUBLICAN PARTY',
#    'principal_committees': [{'affiliated_committee_name': None,
#      'candidate_ids': ['H0MO02148', 'S2MO00429'],
#      'committee_id': 'C00343475',
#      'committee_type': 'S',
#      'committee_type_full': 'Senate',
#      'cycles': [2000, 2002, 2004, 2006, 2008, 2010, 2012, 2014, 2016],
#      'designation': 'P',
#      'designation_full': 'Principal campaign committee',
#      'filing_frequency': 'T',
#      'first_f1_date': '1999-03-05',
#      'first_file_date': '1999-03-05',
#      'last_f1_date': '2014-06-04',
#      'last_file_date': '2015-05-28',
#      'name': 'TODD AKIN FOR SENATE',
#      'organization_type': None,
#      'organization_type_full': None,
#      'party': 'REP',
#      'party_full': 'REPUBLICAN PARTY',
#      'state': 'MO',
#      'treasurer_name': 'W. TODD AKIN'}],
#    'state': 'MO'},
#   {'active_through': 2018,
#    'candidate_id': 'S2MO00429',
#    'candidate_inactive': False,
#    'candidate_status': 'C',
#    'cycles': [2012, 2014, 2016, 2018],
#    'district': '00',
#    'district_number': 0,
#    'election_districts': ['00', '00'],
#    'election_years': [2012, 2018],
#    'federal_funds_flag': False,
#    'first_file_date': '2011-05-18',
#    'has_raised_funds': True,
#    'inactive_election_years': None,
#    'incumbent_challenge': 'C',
#    'incumbent_challenge_full': 'Challenger',
#    'last_f2_date': '2012-11-14',
#    'last_file_date': '2012-11-14',
#    'load_date': '2018-02-17T09:16:20',
#    'name': 'AKIN, W TODD',
#    'office': 'S',
#    'office_full': 'Senate',
#    'party': 'REP',
#    'party_full': 'REPUBLICAN PARTY',
#    'principal_committees': [{'affiliated_committee_name': None,
#      'candidate_ids': ['H0MO02148', 'S2MO00429'],
#      'committee_id': 'C00343475',
#      'committee_type': 'S',
#      'committee_type_full': 'Senate',
#      'cycles': [2000, 2002, 2004, 2006, 2008, 2010, 2012, 2014, 2016],
#      'designation': 'P',
#      'designation_full': 'Principal campaign committee',
#      'filing_frequency': 'T',
#      'first_f1_date': '1999-03-05',
# ...
#     2016,
#     2018,
#     2020,
#     2022,
#     2024],
#    'district': '02',
#    'district_number': 2,
#    'election_districts': ['02', '02', '02', '02', '02', '02', '02', '02'],
#    'election_years': [1998, 2000, 2002, 2004, 2006, 2008, 2010, 2012],
#    'federal_funds_flag': False,
#    'first_file_date': '1997-05-12',
#    'has_raised_funds': True,
#    'inactive_election_years': [2012],
#    'incumbent_challenge': 'C',
#    'incumbent_challenge_full': 'Challenger',
#    'last_f2_date': '2011-03-02',
#    'last_file_date': '2011-03-02',
#    'load_date': '2013-04-26T09:04:30',
#    'name': 'BALDWIN, TAMMY',
#    'office': 'H',
#    'office_full': 'House',
#    'party': 'DEM',
#    'party_full': 'DEMOCRATIC PARTY',
#    'principal_committees': [{'affiliated_committee_name': "PEOPLE'S VOICE PAC",
#      'candidate_ids': ['H8WI00018', 'S2WI00219'],
#      'committee_id': 'C00326801',
#      'committee_type': 'S',
#      'committee_type_full': 'Senate',
#      'cycles': [1998,
#       2000,
#       2002,
#       2004,
#       2006,
#       2008,
#       2010,
#       2012,
#       2014,
#       2016,
#       2018,
#       2020,
#       2022,
#       2024],
#      'designation': 'P',
#      'designation_full': 'Principal campaign committee',
#      'filing_frequency': 'Q',
#      'first_f1_date': '1997-03-28',
#      'first_file_date': '1997-03-28',
#      'last_f1_date': '2023-07-15',
#      'last_file_date': '2023-08-23',
#      'name': 'TAMMY BALDWIN FOR SENATE',
#      'organization_type': None,
#      'organization_type_full': None,
#      'party': 'DEM',
#      'party_full': 'DEMOCRATIC PARTY',
#      'state': 'WI',
#      'treasurer_name': 'NEWBY, DAVID'}],
#    'state': 'WI'},
#   {'active_through': 2024,
#    'candidate_id': 'S2WI00219',
#    'candidate_inactive': False,
#    'candidate_status': 'C',
#    'cycles': [2012, 2014, 2016, 2018, 2020, 2022, 2024],
#    'district': '00',
#    'district_number': 0,
#    'election_districts': ['00', '00', '00'],
#    'election_years': [2012, 2018, 2024],
#    'federal_funds_flag': False,
#    'first_file_date': '2011-09-02',
#    'has_raised_funds': True,
#    'inactive_election_years': None,
#    'incumbent_challenge': 'I',
#    'incumbent_challenge_full': 'Incumbent',
#    'last_f2_date': '2019-04-12',
#    'last_file_date': '2022-11-15',
#    'load_date': '2023-01-11T22:30:34',
#    'name': 'BALDWIN, TAMMY',
#    'office': 'S',
#    'office_full': 'Senate',
#    'party': 'DEM',
#    'party_full': 'DEMOCRATIC PARTY',
#    'principal_committees': [{'affiliated_committee_name': "PEOPLE'S VOICE PAC",
#      'candidate_ids': ['H8WI00018', 'S2WI00219'],
#      'committee_id': 'C00326801',
#      'committee_type': 'S',
#      'committee_type_full': 'Senate',
#      'cycles': [1998,
#       2000,
#       2002,
#       2004,
#       2006,
#       2008,
#       2010,
#       2012,
#       2014,
#       2016,
#       2018,
#       2020,
#       2022,
#       2024],
#      'designation': 'P',
#      'designation_full': 'Principal campaign committee',
#      'filing_frequency': 'Q',
#      'first_f1_date': '1997-03-28',
#      'first_file_date': '1997-03-28',
#      'last_f1_date': '2023-07-15',
#      'last_file_date': '2023-08-23',
#      'name': 'TAMMY BALDWIN FOR SENATE',
#      'organization_type': None,
#      'organization_type_full': None,
#      'party': 'DEM',
#      'party_full': 'DEMOCRATIC PARTY',
#      'state': 'WI',
#      'treasurer_name': 'NEWBY, DAVID'}],
#    'state': 'WI'},
#   {'active_through': 2012,
#    'candidate_id': 'H2TX27257',
#    'candidate_inactive': False,
#    'candidate_status': 'P',
#    'cycles': [2012, 2014],
#    'district': '27',
#    'district_number': 27,
#    'election_districts': ['27'],
#    'election_years': [2012],
#    'federal_funds_flag': False,
#    'first_file_date': '2012-06-08',
#    'has_raised_funds': True,
#    'inactive_election_years': None,
#    'incumbent_challenge': 'C',
#    'incumbent_challenge_full': 'Challenger',
#    'last_f2_date': '2012-06-08',
#    'last_file_date': '2012-06-08',
#    'load_date': '2013-04-26T09:04:30',
#    'name': 'BALDWIN, WILLAIM BRET',
#    'office': 'H',
#    'office_full': 'House',
#    'party': 'IND',
#    'party_full': 'INDEPENDENT',
#    'principal_committees': [{'affiliated_committee_name': None,
#      'candidate_ids': ['H2TX27257'],
#      'committee_id': 'C00522912',
#      'committee_type': 'H',
#      'committee_type_full': 'House',
#      'cycles': [2012, 2014],
#      'designation': 'P',
#      'designation_full': 'Principal campaign committee',
#      'filing_frequency': 'T',
#      'first_f1_date': '2012-06-08',
#      'first_file_date': '2012-06-08',
#      'last_f1_date': '2012-10-12',
#      'last_file_date': '2013-07-19',
#      'name': 'COMMITTEE TO ELECT BRET BALDWIN',
#      'organization_type': None,
#      'organization_type_full': None,
#      'party': 'IND',
#      'party_full': 'INDEPENDENT',
#      'state': 'TX',
#      'treasurer_name': 'KAY CHAPMAN'}],
#    'state': 'TX'},
#   {'active_through': 2012,
#    'candidate_id': 'H2CO07139',
#    'candidate_inactive': False,
#    'candidate_status': 'C',
#    'cycles': [2012],
#    'district': '07',
#    'district_number': 7,
#    'election_districts': ['07'],
#    'election_years': [2012],
#    'federal_funds_flag': False,
#    'first_file_date': '2012-02-14',
#    'has_raised_funds': True,
#    'inactive_election_years': None,
#    'incumbent_challenge': 'C',
#    'incumbent_challenge_full': 'Challenger',
#    'last_f2_date': '2012-02-14',
#    'last_file_date': '2012-02-14',
#    'load_date': '2012-05-07T21:48:14',
#    'name': 'BALL, MATTHEW CHRISTIAN',
#    'office': 'H',
#    'office_full': 'House',
#    'party': 'REP',
#    'party_full': 'REPUBLICAN PARTY',
#    'principal_committees': [{'affiliated_committee_name': None,
#      'candidate_ids': ['H2CO07139'],
#      'committee_id': 'C00512913',
#      'committee_type': 'H',
#      'committee_type_full': 'House',
#      'cycles': [2012],
#      'designation': 'P',
#      'designation_full': 'Principal campaign committee',
#      'filing_frequency': 'T',
#      'first_f1_date': '2012-02-14',
#      'first_file_date': '2012-02-14',
#      'last_f1_date': '2012-04-16',
#      'last_file_date': '2012-07-31',
#      'name': 'MATT BALL FOR CONGRESS',
#      'organization_type': None,
#      'organization_type_full': None,
#      'party': 'REP',
#      'party_full': 'REPUBLICAN PARTY',
#      'state': 'CO',
#      'treasurer_name': 'KURT DEMARAIS'}],
#    'state': 'CO'},
#   {'active_through': 2012,
#    'candidate_id': 'H2IL03113',
#    'candidate_inactive': False,
#    'candidate_status': 'C',
#    'cycles': [2012],
#    'district': '03',
#    'district_number': 3,
#    'election_districts': ['03'],
#    'election_years': [2012],
#    'federal_funds_flag': False,
#    'first_file_date': '2011-06-13',
#    'has_raised_funds': True,
#    'inactive_election_years': None,
#    'incumbent_challenge': 'C',
#    'incumbent_challenge_full': 'Challenger',
#    'last_f2_date': '2011-06-13',
#    'last_file_date': '2011-06-13',
#    'load_date': '2012-03-21T22:00:27',
#    'name': 'BAQAI, FARAH S',
#    'office': 'H',
#    'office_full': 'House',
#    'party': 'DEM',
#    'party_full': 'DEMOCRATIC PARTY',
#    'principal_committees': [{'affiliated_committee_name': None,
#      'candidate_ids': ['H2IL03113'],
#      'committee_id': 'C00497875',
#      'committee_type': 'H',
#      'committee_type_full': 'House',
#      'cycles': [2012],
#      'designation': 'P',
#      'designation_full': 'Principal campaign committee',
#      'filing_frequency': 'T',
#      'first_f1_date': '2011-06-22',
#      'first_file_date': '2011-06-22',
#      'last_f1_date': '2011-08-23',
#      'last_file_date': '2012-08-27',
#      'name': 'FARAH FOR THE PEOPLE',
#      'organization_type': None,
#      'organization_type_full': None,
#      'party': 'DEM',
#      'party_full': 'DEMOCRATIC PARTY',
#      'state': 'IL',
#      'treasurer_name': 'DONALD R CULVERSON'}],
#    'state': 'IL'},
#   {'active_through': 2014,
#    'candidate_id': 'H2AZ08094',
#    'candidate_inactive': False,
#    'candidate_status': 'P',
#    'cycles': [2012, 2014, 2016],
#    'district': '02',
#    'district_number': 2,
#    'election_districts': ['02', '02'],
#    'election_years': [2012, 2014],
#    'federal_funds_flag': False,
#    'first_file_date': '2012-03-26',
#    'has_raised_funds': True,
#    'inactive_election_years': None,
#    'incumbent_challenge': 'C',
#    'incumbent_challenge_full': 'Challenger',
#    'last_f2_date': '2013-12-17',
#    'last_file_date': '2013-12-17',
#    'load_date': '2015-04-02T15:52:44',
#    'name': 'BARBER, RONALD',
#    'office': 'H',
#    'office_full': 'House',
#    'party': 'DEM',
#    'party_full': 'DEMOCRATIC PARTY',
#    'principal_committees': [{'affiliated_committee_name': 'BARBER-VICTORY FUND',
#      'candidate_ids': ['H2AZ08094'],
#      'committee_id': 'C00512129',
#      'committee_type': 'H',
#      'committee_type_full': 'House',
#      'cycles': [2012, 2014, 2016],
#      'designation': 'P',
#      'designation_full': 'Principal campaign committee',
#      'filing_frequency': 'T',
#      'first_f1_date': '2012-02-07',
#      'first_file_date': '2012-02-07',
#      'last_f1_date': '2013-12-17',
#      'last_file_date': '2016-07-22',
#      'name': 'RON BARBER FOR CONGRESS',
#      'organization_type': None,
#      'organization_type_full': None,
#      'party': 'DEM',
#      'party_full': 'DEMOCRATIC PARTY',
#      'state': 'AZ',
#      'treasurer_name': 'ALMQUIST, LAURA T.'}],
#    'state': 'AZ'},
#   {'active_through': 2024,
#    'candidate_id': 'H2CA00096',
#    'candidate_inactive': False,
#    'candidate_status': 'C',
#    'cycles': [2012, 2014, 2016, 2018, 2020, 2022, 2024],
#    'district': '05',
#    'district_number': 5,
#    'election_districts': ['10', '10', '10', '10', '10', '05', '05'],
#    'election_years': [2012, 2014, 2016, 2018, 2020, 2022, 2024],
#    'federal_funds_flag': False,
#    'first_file_date': '2011-04-20',
#    'has_raised_funds': True,
#    'inactive_election_years': None,
#    'incumbent_challenge': 'C',
#    'incumbent_challenge_full': 'Challenger',
#    'last_f2_date': '2022-11-09',
#    'last_file_date': '2022-11-09',
#    'load_date': '2023-04-13T21:38:20',
#    'name': 'BARKLEY, MICHAEL JAMES MR.',
#    'office': 'H',
#    'office_full': 'House',
#    'party': 'DEM',
#    'party_full': 'DEMOCRATIC PARTY',
#    'principal_committees': [{'affiliated_committee_name': None,
#      'candidate_ids': ['H2CA00096'],
#      'committee_id': 'C00495507',
#      'committee_type': 'H',
#      'committee_type_full': 'House',
#      'cycles': [2012, 2014, 2016, 2018, 2020, 2022, 2024],
#      'designation': 'P',
#      'designation_full': 'Principal campaign committee',
#      'filing_frequency': 'Q',
#      'first_f1_date': '2011-04-20',
#      'first_file_date': '2011-04-20',
#      'last_f1_date': '2011-08-23',
#      'last_file_date': '2023-07-15',
#      'name': 'MIKE BARKLEY FOR CONGRESS COMMITTEE',
#      'organization_type': None,
#      'organization_type_full': None,
#      'party': 'DEM',
#      'party_full': 'DEMOCRATIC PARTY',
#      'state': 'CA',
#      'treasurer_name': 'MICHAEL J BARKLEY'}],
#    'state': 'CA'},
#   {'active_through': 2018,
#    'candidate_id': 'H2PA11098',
#    'candidate_inactive': False,
#    'candidate_status': 'P',
#    'cycles': [2002, 2004, 2006, 2008, 2010, 2012, 2014, 2016, 2018, 2020],
#    'district': '11',
#    'district_number': 11,
#    'election_districts': ['11', '11', '11', '11', '11', '11', '11'],
#    'election_years': [2002, 2008, 2010, 2012, 2014, 2016, 2018],
#    'federal_funds_flag': False,
#    'first_file_date': '2002-03-28',
#    'has_raised_funds': True,
#    'inactive_election_years': [2018],
#    'incumbent_challenge': 'I',
#    'incumbent_challenge_full': 'Incumbent',
#    'last_f2_date': '2017-06-05',
#    'last_file_date': '2017-06-05',
#    'load_date': '2019-03-27T16:02:41',
#    'name': 'BARLETTA, LOU',
#    'office': 'H',
#    'office_full': 'House',
#    'party': 'REP',
#    'party_full': 'REPUBLICAN PARTY',
#    'principal_committees': [{'affiliated_committee_name': 'LEADERS ONLY UNITE POLITICAL ACTION COMMITTEE (AKA LOU PAC)',
#      'candidate_ids': ['H2PA11098', 'S8PA00320'],
#      'committee_id': 'C00445122',
#      'committee_type': 'N',
#      'committee_type_full': 'PAC - Nonqualified',
#      'cycles': [2008, 2010, 2012, 2014, 2016, 2018, 2020],
#      'designation': 'U',
#      'designation_full': 'Unauthorized',
#      'filing_frequency': 'T',
#      'first_f1_date': '2008-02-07',
#      'first_file_date': '2008-02-07',
#      'last_f1_date': '2019-02-27',
#      'last_file_date': '2019-03-22',
#      'name': 'YANKEE PAC',
#      'organization_type': None,
#      'organization_type_full': None,
#      'party': 'REP',
#      'party_full': 'REPUBLICAN PARTY',
#      'state': 'PA',
#      'treasurer_name': 'WATKINS, NANCY H.'},
#     {'affiliated_committee_name': 'NONE',
#      'candidate_ids': ['H2PA11098'],
#      'committee_id': 'C00376004',
#      'committee_type': 'H',
#      'committee_type_full': 'House',
#      'cycles': [2002, 2004, 2006, 2008, 2010, 2012, 2014, 2016, 2018, 2020],
#      'designation': 'A',
#      'designation_full': 'Authorized by a candidate',
#      'filing_frequency': 'T',
#      'first_f1_date': '2002-03-28',
#      'first_file_date': '2002-03-28',
#      'last_f1_date': '2013-10-28',
#      'last_file_date': '2019-02-06',
#      'name': 'LOU BARLETTA FOR CONGRESS 2002',
#      'organization_type': None,
#      'organization_type_full': None,
#      'party': 'REP',
#      'party_full': 'REPUBLICAN PARTY',
#      'state': 'PA',
#      'treasurer_name': 'WATKINS, NANCY H.'}],
#    'state': 'PA'},
#   {'active_through': 2014,
#    'candidate_id': 'H2TX13075',
#    'candidate_inactive': False,
#    'candidate_status': 'P',
#    'cycles': [2012, 2014, 2016],
#    'district': '13',
#    'district_number': 13,
#    'election_districts': ['13', '13'],
#    'election_years': [2012, 2014],
#    'federal_funds_flag': False,
#    'first_file_date': '2011-08-03',
#    'has_raised_funds': True,
#    'inactive_election_years': None,
#    'incumbent_challenge': 'C',
#    'incumbent_challenge_full': 'Challenger',
#    'last_f2_date': '2011-08-03',
#    'last_file_date': '2013-11-21',
#    'load_date': '2015-04-02T15:52:44',
#    'name': 'BARLOW, PAMELA LEE  DVM',
#    'office': 'H',
#    'office_full': 'House',
#    'party': 'REP',
#    'party_full': 'REPUBLICAN PARTY',
#    'principal_committees': [{'affiliated_committee_name': None,
#      'candidate_ids': ['H2TX13075'],
#      'committee_id': 'C00500496',
#      'committee_type': 'H',
#      'committee_type_full': 'House',
#      'cycles': [2012, 2014, 2016],
#      'designation': 'P',
#      'designation_full': 'Principal campaign committee',
#      'filing_frequency': 'A',
#      'first_f1_date': '2011-08-03',
#      'first_file_date': '2011-08-03',
#      'last_f1_date': '2013-04-08',
#      'last_file_date': '2016-11-03',
#      'name': 'DR PAM BARLOW FOR CONGRESS COMMITTEE',
#      'organization_type': None,
#      'organization_type_full': None,
#      'party': 'REP',
#      'party_full': 'REPUBLICAN PARTY',
#      'state': 'TX',
#      'treasurer_name': 'PAMELA LEE BARLOW DVM'}],
#    'state': 'TX'},
#   {'active_through': 2012,
#    'candidate_id': 'H2MN03070',
#    'candidate_inactive': False,
#    'candidate_status': 'P',
#    'cycles': [2012, 2014],
#    'district': '03',
#    'district_number': 3,
#    'election_districts': ['03'],
#    'election_years': [2012],
#    'federal_funds_flag': False,
#    'first_file_date': '2011-10-09',
#    'has_raised_funds': True,
#    'inactive_election_years': None,
#    'incumbent_challenge': 'C',
#    'incumbent_challenge_full': 'Challenger',
#    'last_f2_date': '2011-10-09',
#    'last_file_date': '2011-10-09',
#    'load_date': '2013-04-26T09:04:30',
#    'name': 'BARNES, BRIAN PATRICK',
#    'office': 'H',
#    'office_full': 'House',
#    'party': 'DFL',
#    'party_full': 'DEMOCRATIC-FARMER-LABOR',
#    'principal_committees': [{'affiliated_committee_name': 'NONE',
#      'candidate_ids': ['H2MN03070'],
#      'committee_id': 'C00504068',
#      'committee_type': 'H',
#      'committee_type_full': 'House',
#      'cycles': [2012, 2014],
#      'designation': 'P',
#      'designation_full': 'Principal campaign committee',
#      'filing_frequency': 'T',
#      'first_f1_date': '2011-10-09',
#      'first_file_date': '2011-10-09',
#      'last_f1_date': '2012-07-19',
#      'last_file_date': '2013-07-26',
#      'name': 'BARNES FOR CONGRESS',
#      'organization_type': None,
#      'organization_type_full': None,
#      'party': 'DEM',
#      'party_full': 'DEMOCRATIC PARTY',
#      'state': 'MN',
#      'treasurer_name': 'MILLER, LISA'}],
#    'state': 'MN'}]}

# %%
# for loop to pull all twenty-two pages of requests and combine into one DF

candidates_all_pages = []
for i in range(1,23):
    candidates_rq = rq.get(f'https://api.open.fec.gov/v1/candidates/search/?page={i}&per_page=100&cycle=2012&election_year=2012&office=H&office=S&year=2012&has_raised_funds=true&sort=name&sort_hide_null=false&sort_null_only=false&sort_nulls_last=false&api_key={api_key_fec}')
    
    candidates = candidates_rq.json()
    candidates_all_pages.append(candidates)

# %%
#merge all results into one DF
blank_list = []
for i in range(0,22):
    blank_list.extend(candidates_all_pages[i]['results'])

# %%
candidates_df = pd.DataFrame(blank_list)

# %%
candidates_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2120 entries, 0 to 2119
# Data columns (total 25 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   active_through            2120 non-null   int64
#  1   candidate_id              2120 non-null   object
#  2   candidate_inactive        2120 non-null   bool
#  3   candidate_status          2120 non-null   object
#  4   cycles                    2120 non-null   object
#  5   district                  2118 non-null   object
#  6   district_number           2118 non-null   float64
#  7   election_districts        2120 non-null   object
#  8   election_years            2120 non-null   object
#  9   federal_funds_flag        2120 non-null   bool
#  10  first_file_date           2105 non-null   object
#  11  has_raised_funds          2120 non-null   bool
#  12  inactive_election_years   330 non-null    object
#  13  incumbent_challenge       2111 non-null   object
#  14  incumbent_challenge_full  2111 non-null   object
#  15  last_f2_date              2098 non-null   object
#  16  last_file_date            2105 non-null   object
#  17  load_date                 2120 non-null   object
#  18  name                      2120 non-null   object
#  19  office                    2120 non-null   object
#  20  office_full               2120 non-null   object
#  21  party                     2117 non-null   object
#  22  party_full                2115 non-null   object
#  23  principal_committees      2120 non-null   object
#  24  state                     2120 non-null   object
# dtypes: bool(3), float64(1), int64(1), object(20)
# memory usage: 370.7+ KB

# %%
candidates_df.drop(columns=['active_through', 'cycles', 'candidate_inactive', 'district_number', 'election_districts', 'election_years', 'federal_funds_flag', 'first_file_date', 'inactive_election_years', 'incumbent_challenge', 'last_f2_date', 'last_file_date', 'load_date', 'party', 'office'],inplace=True)

# %%
candidates_df.shape
# Out:
# (2120, 10)

# %%
candidates_df.columns = ['candidate_id', 'status', 'district', 'has_raised_funds', 'incumbent_challenge', 'name', 'office', 'party', 'committees', 'state']

# %%
candidates_df.columns
# Out:
# Index(['candidate_id', 'status', 'district', 'has_raised_funds',
#        'incumbent_challenge', 'name', 'office', 'party', 'committees',
#        'state'],
#       dtype='object')

# %%
candidates_df.head()
# Out:
#   candidate_id status district  has_raised_funds incumbent_challenge  \
# 0    S2UT00229      P       00              True           Open seat
# 1    H2CA01110      P       01              True          Challenger
# 2    H2AZ02279      P       02              True          Challenger
# 3    H4NY07011      N       05              True          Challenger
# 4    H2CA25176      P       25              True          Challenger
#
#                     name  office               party  \
# 0  AALDERS, TIMOTHY NOEL  Senate  CONSTITUTION PARTY
# 1       AANESTAD, SAMUEL   House    REPUBLICAN PARTY
# 2       ABOUD, PAULA ANN   House    DEMOCRATIC PARTY
# 3      ACKERMAN, GARY L.   House    DEMOCRATIC PARTY
# 4          ACOSTA, DANTE   House    REPUBLICAN PARTY
#
#                                           committees state
# 0  [{'affiliated_committee_name': 'NONE', 'candid...    UT
# 1  [{'affiliated_committee_name': None, 'candidat...    CA
# 2  [{'affiliated_committee_name': None, 'candidat...    AZ
# 3  [{'affiliated_committee_name': 'NONE', 'candid...    NY
# 4  [{'affiliated_committee_name': None, 'candidat...    CA

# %%
candidates_df = candidates_df.loc[candidates_df['has_raised_funds'] == True]

# %%
candidates_df = candidates_df.apply(lambda row: row[candidates_df['party'].isin(['REPUBLICAN PARTY','DEMOCRATIC PARTY', 'INDEPENDENT'])])

# %%
candidates_df.shape
# Out:
# (1992, 10)

# %%
candidates_df.to_csv('./datasets/candidates.csv',sep=',',index=False)

# %% [markdown]
# #### Match Names from Members and Candidates
#
# 1. Link members of the 113th congress to their candidate information from the FEC
# 2. Add congress id to candidate table as a foreign key

# %%
conn = sq.connect('congress.db')
members = pd.read_sql_query("SELECT * FROM members", conn)

# %%
members.head(2)
# Out:
#      chamber  icpsr_id district state  party                             name  \
# 0  President     99911        0   USA    100                    OBAMA, Barack
# 1      House     20300        1    AL    200  BONNER, Jr., Josiah Robins (Jo)
#
#   congress_id  nominate_dim1  nominate_dim2
# 0     O000167         -0.358         -0.197
# 1     B001244          0.367          0.513

# %%
members['name'] = members['name'].str.lower()
members.head()
# Out:
#      chamber  icpsr_id district state  party                             name  \
# 0  President     99911        0   USA    100                    obama, barack
# 1      House     20300        1    AL    200  bonner, jr., josiah robins (jo)
# 2      House     20301        3    AL    200              rogers, mike dennis
# 3      House     21102        7    AL    100                    sewell, terri
# 4      House     21192        2    AL    200                     roby, martha
#
#   congress_id  nominate_dim1  nominate_dim2
# 0     O000167         -0.358         -0.197
# 1     B001244          0.367          0.513
# 2     R000575          0.363          0.455
# 3     S001185         -0.396          0.398
# 4     R000591          0.362          0.658

# %%
candidates_df.head(2)
# Out:
#   candidate_id status district  has_raised_funds incumbent_challenge  \
# 1    H2CA01110      P       01              True          Challenger
# 2    H2AZ02279      P       02              True          Challenger
#
#                name office             party  \
# 1  aanestad, samuel  House  REPUBLICAN PARTY
# 2  aboud, paula ann  House  DEMOCRATIC PARTY
#
#                                           committees state
# 1  [{'affiliated_committee_name': None, 'candidat...    CA
# 2  [{'affiliated_committee_name': None, 'candidat...    AZ

# %%
candidates_df['name'] = candidates_df['name'].str.lower()
candidates_df.head()
# Out:
#   candidate_id status district  has_raised_funds incumbent_challenge  \
# 1    H2CA01110      P       01              True          Challenger
# 2    H2AZ02279      P       02              True          Challenger
# 3    H4NY07011      N       05              True          Challenger
# 4    H2CA25176      P       25              True          Challenger
# 6    H6FL11175      N       14              True          Challenger
#
#                 name office             party  \
# 1   aanestad, samuel  House  REPUBLICAN PARTY
# 2   aboud, paula ann  House  DEMOCRATIC PARTY
# 3  ackerman, gary l.  House  DEMOCRATIC PARTY
# 4      acosta, dante  House  REPUBLICAN PARTY
# 6    adams, eddie jr  House  REPUBLICAN PARTY
#
#                                           committees state
# 1  [{'affiliated_committee_name': None, 'candidat...    CA
# 2  [{'affiliated_committee_name': None, 'candidat...    AZ
# 3  [{'affiliated_committee_name': 'NONE', 'candid...    NY
# 4  [{'affiliated_committee_name': None, 'candidat...    CA
# 6  [{'affiliated_committee_name': None, 'candidat...    FL

# %%
# creating a duplicate column of names in members table
members['name_match'] = members['name']

# %%
# convert member name in members table to the name it most closely matches in candidate_df
members['name_match'] = members['name_match'].apply(lambda x: difflib.get_close_matches(x, candidates_df['name'], n=1))

# %%
pd.set_option('display.max_rows', None)
members
# Out:
#        chamber  icpsr_id district state  party  \
# 0    President     99911        0   USA    100
# 1        House     20300        1    AL    200
# 2        House     20301        3    AL    200
# 3        House     21102        7    AL    100
# 4        House     21192        2    AL    200
# 5        House     21193        5    AL    200
# 6        House     21376        1    AL    200
# 7        House     29301        6    AL    200
# 8        House     29701        4    AL    200
# 9        House     14066        1    AK    200
# 10       House     20304        8    AZ    200
# 11       House     20305        3    AZ    100
# 12       House     20902        1    AZ    100
# 13       House     21103        4    AZ    200
# 14       House     21105        6    AZ    200
# 15       House     21199        2    AZ    100
# 16       House     21300        9    AZ    100
# 17       House     29101        7    AZ    100
# 18       House     29500        5    AZ    200
# 19       House     21106        1    AR    200
# 20       House     21107        2    AR    200
# 21       House     21108        3    AR    200
# 22       House     21301        4    AR    200
# 23       House     14256       11    CA    100
# 24       House     14280       33    CA    100
# 25       House     15448       12    CA    100
# 26       House     15621       48    CA    200
# 27       House     20103       17    CA    100
# 28       House     20104       28    CA    100
# 29       House     20107       49    CA    200
# 30       House     20108       53    CA    100
# 31       House     20307       22    CA    200
# 32       House     20310       38    CA    100
# 33       House     20501       16    CA    100
# 34       House     20538        6    CA    100
# 35       House     20539       45    CA    200
# 36       House     20702        9    CA    100
# 37       House     20703       23    CA    200
# 38       House     20762       14    CA    100
# 39       House     20903        4    CA    200
# 40       House     20955       27    CA    100
# 41       House     20958        3    CA    100
# 42       House     20963       50    CA    200
# 43       House     21109       10    CA    200
# 44       House     21110       37    CA    100
# 45       House     21195       44    CA    100
# 46       House     21302        1    CA    200
# 47       House     21303        2    CA    100
# 48       House     21304        7    CA    100
# 49       House     21305        8    CA    200
# 50       House     21306       15    CA    100
# 51       House     21307       21    CA    200
# 52       House     21308       26    CA    100
# 53       House     21309       29    CA    100
# 54       House     21310       35    CA    100
# 55       House     21311       36    CA    100
# 56       House     21312       41    CA    100
# 57       House     21313       47    CA    100
# 58       House     21314       51    CA    100
# 59       House     21315       52    CA    100
# 60       House     29106       43    CA    100
# 61       House     29312       18    CA    100
# 62       House     29313       20    CA    100
# 63       House     29315       25    CA    200
# 64       House     29316       34    CA    100
# 65       House     29317       40    CA    100
# 66       House     29321       39    CA    200
# 67       House     29323       42    CA    200
# 68       House     29504       19    CA    100
# 69       House     29707       30    CA    100
# 70       House     29709       46    CA    100
# 71       House     29774       24    CA    100
# 72       House     29778       13    CA    100
# 73       House     29901        5    CA    100
# 74       House     29903       32    CA    100
# 75       House     29905       31    CA    200
# 76       House     20704        5    CO    200
# 77       House     20705        7    CO    100
# 78       House     20904        2    CO    100
# 79       House     20906        6    CO    200
# 80       House     21111        3    CO    200
# 81       House     21112        4    CO    200
# 82       House     29710        1    CO    100
# 83       House     20706        2    CT    100
# 84       House     20907        4    CT    100
# 85       House     21316        5    CT    100
# 86       House     29109        3    CT    100
# 87       House     29908        1    CT    100
# 88       House     21113        1    DE    100
# 89       House     13047       13    FL    200
# 90       House     15634       27    FL    200
# 91       House     20110        1    FL    200
# 92       House     20111        4    FL    200
# 93       House     20316       25    FL    200
# 94       House     20504       23    FL    100
# 95       House     20708       14    FL    100
# 96       House     20709       16    FL    200
# 97       House     20758       12    FL    200
# 98       House     20908        9    FL    100
# 99       House     20909        8    FL    200
# 100      House     20910       17    FL    200
# 101      House     20959       21    FL    100
# 102      House     21114        2    FL    200
# 103      House     21115       11    FL    200
# 104      House     21116       10    FL    200
# 105      House     21117       15    FL    200
# 106      House     21118       24    FL    100
# 107      House     21317        3    FL    200
# 108      House     21318        6    FL    200
# 109      House     21319       18    FL    100
# 110      House     21320       19    FL    200
# 111      House     21321       22    FL    100
# 112      House     21322       26    FL    100
# 113      House     21377       19    FL    200
# 114      House     21401       13    FL    200
# 115      House     29328        5    FL    100
# 116      House     29331        7    FL    200
# 117      House     29337       20    FL    100
# 118      House     15431        5    GA    100
# 119      House     20319       11    GA    200
# 120      House     20321       13    GA    100
# 121      House     20505        6    GA    200
# 122      House     20506        3    GA    200
# 123      House     20507       12    GA    100
# 124      House     20712        4    GA    100
# 125      House     20753       10    GA    200
# 126      House     20962       14    GA    200
# 127      House     21122        7    GA    200
# 128      House     21123        8    GA    200
# 129      House     21323        9    GA    200
# 130      House     29338        1    GA    200
# 131      House     29339        2    GA    100
# 132      House     21124        1    HI    100
# 133      House     21324        2    HI    100
# 134      House     21125        1    ID    200
# 135      House     29910        2    ID    200
# 136      House     20508        3    IL    100
# 137      House     20715        6    IL    200
# 138      House     20749       11    IL    100
# 139      House     20914       18    IL    200
# 140      House     20954        5    IL    100
# 141      House     21128       16    IL    200
# 142      House     21129       14    IL    200
# 143      House     21325        8    IL    100
# 144      House     21326       10    IL    100
# 145      House     21327       12    IL    100
# 146      House     21328       13    IL    200
# 147      House     21329       17    IL    100
# 148      House     21371        2    IL    100
# 149      House     29346        1    IL    100
# 150      House     29348        4    IL    100
# 151      House     29717        7    IL    100
# 152      House     29718       15    IL    200
# 153      House     29911        9    IL    100
# 154      House     15124        1    IN    100
# 155      House     20757        7    IN    100
# 156      House     21100        3    IN    200
# 157      House     21131        4    IN    200
# 158      House     21132        8    IN    200
# 159      House     21133        9    IN    200
# 160      House     21330        2    IN    200
# 161      House     21331        5    IN    200
# 162      House     21332        6    IN    200
# 163      House     20325        4    IA    200
# 164      House     20719        1    IA    100
# 165      House     20720        2    IA    100
# 166      House     29522        3    IA    200
# 167      House     20915        2    KS    200
# 168      House     21134        1    KS    200
# 169      House     21135        3    KS    200
# 170      House     21136        4    KS    200
# 171      House     14854        5    KY    200
# 172      House     20723        3    KY    100
# 173      House     20916        2    KY    200
# 174      House     21333        6    KY    200
# 175      House     29525        1    KY    200
# 176      House     31102        4    KY    200
# 177      House     20514        3    LA    200
# 178      House     20759        1    LA    200
# 179      House     20918        4    LA    200
# 180      House     20919        6    LA    200
# 181      House     21137        2    LA    100
# 182      House     21374        5    LA    200
# 183      House     90327        5    LA    200
# 184      House     20328        2    ME    100
# 185      House     20920        1    ME    100
# 186      House     14873        5    MD    100
# 187      House     20329        2    MD    100
# 188      House     20330        8    MD    100
# 189      House     20724        3    MD    100
# 190      House     20763        4    MD    100
# 191      House     21139        1    MD    200
# 192      House     21334        6    MD    100
# 193      House     29587        7    MD    100
# 194      House     14435        5    MA    100
# 195      House     15616        1    MA    100
# 196      House     20119        8    MA    100
# 197      House     20754        3    MA    100
# 198      House     21140        9    MA    100
# 199      House     21335        4    MA    100
# 200      House     21375        5    MA    100
# 201      House     29729        2    MA    100
# 202      House     29730        6    MA    100
# 203      House     29919        7    MA    100
# 204      House      2605       12    MI    100
# 205      House     10713       13    MI    100
# 206      House     15033        9    MI    100
# 207      House     15446        6    MI    200
# 208      House     20120        8    MI    200
# 209      House     20331       10    MI    200
# 210      House     20725        7    MI    200
# 211      House     20923       14    MI    100
# 212      House     21141        1    MI    200
# 213      House     21142        2    MI    200
# 214      House     21143        3    MI    200
# 215      House     21336       11    MI    200
# 216      House     21372        5    MI    100
# 217      House     29124        4    MI    200
# 218      House     14263        8    MN    100
# 219      House     20122        4    MN    100
# 220      House     20333        2    MN    200
# 221      House     20726        1    MN    100
# 222      House     20727        5    MN    100
# 223      House     20728        6    MN    200
# 224      House     20924        3    MN    200
# 225      House     29127        7    MN    100
# 226      House     20925        3    MS    200
# 227      House     21147        1    MS    200
# 228      House     21148        4    MS    200
# 229      House     29368        2    MS    100
# 230      House     20124        6    MO    200
# 231      House     20147        1    MO    100
# 232      House     20517        5    MO    100
# 233      House     20926        3    MO    200
# 234      House     21149        4    MO    200
# 235      House     21150        7    MO    200
# 236      House     21337        2    MO    200
# 237      House     21373        8    MO    200
# 238      House     29736        8    MO    200
# 239      House     21338        1    MT    200
# 240      House     20518        1    NE    200
# 241      House     20729        3    NE    200
# 242      House     29921        2    NE    200
# 243      House     20927        1    NV    100
# 244      House     21151        3    NV    200
# 245      House     21196        2    NV    200
# 246      House     21339        4    NV    100
# 247      House     20731        1    NH    100
# 248      House     21340        2    NH    100
# 249      House     14863        4    NJ    200
# 250      House     15454        6    NJ    100
# 251      House     20336        5    NJ    200
# 252      House     20542        8    NJ    100
# 253      House     20929        7    NJ    200
# 254      House     21153        3    NJ    200
# 255      House     21536        1    NJ    100
# 256      House     29132        1    NJ    100
# 257      House     29539        2    NJ    200
# 258      House     29541       11    NJ    200
# 259      House     29741        9    NJ    100
# 260      House     29923       12    NJ    100
# 261      House     31103       10    NJ    100
# 262      House     20337        2    NM    200
# 263      House     20932        3    NM    100
# 264      House     21341        1    NM    100
# 265      House     13035       13    NY    100
# 266      House     15444       25    NY    100
# 267      House     15603       16    NY    100
# 268      House     15612       17    NY    100
# 269      House     20129        3    NY    100
# 270      House     20338        1    NY    100
# 271      House     20519       26    NY    100
# 272      House     20733        9    NY    100
# 273      House     20934       20    NY    100
# 274      House     20935       24    NY    100
# 275      House     20957       21    NY    100
# 276      House     21101       23    NY    200
# 277      House     21154       11    NY    200
# 278      House     21156       19    NY    200
# 279      House     21157       22    NY    200
# 280      House     21342        6    NY    100
# 281      House     21343        8    NY    100
# 282      House     21344       18    NY    100
# 283      House     21345       27    NY    200
# 284      House     29134       15    NY    100
# 285      House     29375        2    NY    200
# 286      House     29377       10    NY    100
# 287      House     29378        7    NY    100
# 288      House     29379       12    NY    100
# 289      House     29744        4    NY    100
# 290      House     29776        5    NY    100
# 291      House     29925       14    NY    100
# 292      House     15092        6    NC    200
# 293      House     15438        4    NC    100
# 294      House     20340        1    NC    100
# 295      House     20521        5    NC    200
# 296      House     20522       10    NC    200
# 297      House     21159        2    NC    200
# 298      House     21346        8    NC    200
# 299      House     21347        9    NC    200
# 300      House     21348       11    NC    200
# 301      House     21349       13    NC    200
# 302      House     21545       12    NC    100
# 303      House     29383       12    NC    100
# 304      House     29546        3    NC    200
# 305      House     29746        7    NC    100
# 306      House     21350        1    ND    200
# 307      House     15029        9    OH    100
# 308      House     20130       12    OH    200
# 309      House     20342       10    OH    200
# 310      House     20343       13    OH    100
# 311      House     20738        4    OH    200
# 312      House     20755        5    OH    200
# 313      House     20941       11    OH    100
# 314      House     21162        6    OH    200
# 315      House     21163       15    OH    200
# 316      House     21164       16    OH    200
# 317      House     21165        7    OH    200
# 318      House     21351        2    OH    200
# 319      House     21352        3    OH    100
# 320      House     21353       14    OH    200
# 321      House     29137        8    OH    200
# 322      House     29550        1    OH    200
# 323      House     20344        4    OK    200
# 324      House     21166        5    OK    200
# 325      House     21354        1    OK    200
# 326      House     21355        2    OK    200
# 327      House     29393        3    OK    200
# 328      House     15410        4    OR    100
# 329      House     20944        5    OR    100
# 330      House     21198        1    OR    100
# 331      House     29588        3    OR    100
# 332      House     29932        2    OR    200
# 333      House     20134        9    PA    200
# 334      House     20345        6    PA    200
# 335      House     20346       18    PA    200
# 336      House     20524        8    PA    200
# 337      House     20525       13    PA    100
# 338      House     20526       15    PA    200
# 339      House     20946        5    PA    200
# 340      House     21167        3    PA    200
# 341      House     21168        7    PA    200
# 342      House     21170       10    PA    200
# 343      House     21171       11    PA    200
# 344      House     21356        4    PA    200
# 345      House     21357       12    PA    200
# 346      House     21358       17    PA    100
# 347      House     29559        2    PA    100
# 348      House     29561       14    PA    100
# 349      House     29752       16    PA    200
# 350      House     29777        1    PA    100
# 351      House     20136        2    RI    100
# 352      House     21172        1    RI    100
# 353      House     20138        2    SC    200
# 354      House     21174        3    SC    200
# 355      House     21175        4    SC    200
# 356      House     21176        5    SC    200
# 357      House     21359        7    SC    200
# 358      House     29565        1    SC    200
# 359      House     39301        6    SC    100
# 360      House     21177        1    SD    200
# 361      House     15019        5    TN    100
# 362      House     15455        2    TN    200
# 363      House     20351        7    TN    200
# 364      House     20748        9    TN    100
# 365      House     20947        1    TN    200
# 366      House     21178        3    TN    200
# 367      House     21179        4    TN    200
# 368      House     21180        6    TN    200
# 369      House     21181        8    TN    200
# 370      House     15085        6    TX    200
# 371      House     15445       21    TX    200
# 372      House     20139        7    TX    200
# 373      House     20352        5    TX    200
# 374      House     20353       19    TX    200
# 375      House     20355       26    TX    200
# 376      House     20356       31    TX    200
# 377      House     20527        1    TX    200
# 378      House     20528        2    TX    200
# 379      House     20529        9    TX    100
# 380      House     20530       10    TX    200
# 381      House     20531       11    TX    200
# 382      House     20532       24    TX    200
# 383      House     20533       28    TX    100
# 384      House     20948       22    TX    200
# 385      House     21182       17    TX    200
# 386      House     21184       27    TX    200
# 387      House     21360       14    TX    200
# 388      House     21361       16    TX    100
# 389      House     21362       20    TX    100
# 390      House     21363       23    TX    100
# 391      House     21364       25    TX    200
# 392      House     21365       33    TX    100
# 393      House     21366       34    TX    100
# 394      House     29143        3    TX    200
# 395      House     29570       36    TX    200
# 396      House     29571       35    TX    100
# 397      House     29572       13    TX    200
# 398      House     29573       18    TX    100
# 399      House     29759       32    TX    200
# 400      House     29760        8    TX    200
# 401      House     29762       12    TX    200
# 402      House     29763       15    TX    100
# 403      House     39304       29    TX    100
# 404      House     39305       30    TX    100
# 405      House     94828        4    TX    200
# 406      House     20140        4    UT    100
# 407      House     20357        1    UT    200
# 408      House     20949        3    UT    200
# 409      House     21367        2    UT    200
# 410      House     20750        1    VT    100
# 411      House     14869       10    VA    200
# 412      House     20143        4    VA    200
# 413      House     20144        7    VA    200
# 414      House     20756        1    VA    200
# 415      House     20952       11    VA    100
# 416      House     21185        2    VA    200
# 417      House     21186        5    VA    200
# 418      House     21191        9    VA    200
# 419      House     21553        7    VA    200
# 420      House     29149        8    VA    100
# 421      House     39307        3    VA    100
# 422      House     39308        6    VA    200
# 423      House     15613        7    WA    100
# 424      House     20145        2    WA    100
# 425      House     20535        5    WA    200
# 426      House     20536        8    WA    200
# 427      House     21187        3    WA    200
# 428      House     21368        6    WA    100
# 429      House     21369       10    WA    100
# 430      House     29580        4    WA    200
# 431      House     29768        9    WA    100
# 432      House     31101        1    WA    100
# 433      House     14448        3    WV    100
# 434      House     20146        2    WV    200
# 435      House     21188        1    WV    200
# 436      House     14657        5    WI    200
# 437      House     14675        6    WI    200
# 438      House     20537        4    WI    100
# 439      House     21189        7    WI    200
# 440      House     21190        8    WI    200
# 441      House     21370        2    WI    100
# 442      House     29769        3    WI    100
# 443      House     29939        1    WI    200
# 444      House     20953        1    WY    200
# 445     Senate     49700        0    AL    200
# 446     Senate     94659        0    AL    200
# 447     Senate     40300        0    AK    200
# 448     Senate     40900        0    AK    100
# 449     Senate     15039        0    AZ    200
# 450     Senate     20100        0    AZ    200
# 451     Senate     20101        0    AR    200
# 452     Senate     40301        0    AR    100
# 453     Senate     15011        0    CA    100
# 454     Senate     49300        0    CA    100
# 455     Senate     29906        0    CO    100
# 456     Senate     40910        0    CO    100
# 457     Senate     20707        0    CT    100
# 458     Senate     41101        0    CT    100
# 459     Senate     15015        0    DE    100
# 460     Senate     40916        0    DE    100
# 461     Senate     14651        0    FL    100
# 462     Senate     41102        0    FL    200
# 463     Senate     29512        0    GA    200
# 464     Senate     29909        0    GA    200
# 465     Senate     20713        0    HI    100
# 466     Senate     41112        0    HI    100
# 467     Senate     29345        0    ID    200
# 468     Senate     40902        0    ID    200
# 469     Senate     15021        0    IL    100
# 470     Senate     20115        0    IL    200
# 471     Senate     14806        0    IN    200
# 472     Senate     20717        0    IN    100
# 473     Senate     14226        0    IA    200
# 474     Senate     14230        0    IA    100
# 475     Senate     14852        0    KS    200
# 476     Senate     29722        0    KS    200
# 477     Senate     14921        0    KY    200
# 478     Senate     41104        0    KY    200
# 479     Senate     29918        0    LA    200
# 480     Senate     49702        0    LA    100
# 481     Senate     41300        0    ME    328
# 482     Senate     49703        0    ME    200
# 483     Senate     14440        0    MD    100
# 484     Senate     15408        0    MD    100
# 485     Senate     14435        0    MA    100
# 486     Senate     14920        0    MA    100
# 487     Senate     41301        0    MA    100
# 488     Senate     41306        0    MA    100
# 489     Senate     14709        0    MI    100
# 490     Senate     29732        0    MI    100
# 491     Senate     40700        0    MN    100
# 492     Senate     40904        0    MN    100
# 493     Senate     14009        0    MS    200
# 494     Senate     29534        0    MS    200
# 495     Senate     29735        0    MO    200
# 496     Senate     40701        0    MO    100
# 497     Senate     14203        0    MT    100
# 498     Senate     40702        0    MT    100
# 499     Senate     41309        0    MT    100
# 500     Senate     40905        0    NE    200
# 501     Senate     41302        0    NE    200
# 502     Senate     15054        0    NV    100
# 503     Senate     20730        0    NV    200
# 504     Senate     40906        0    NH    100
# 505     Senate     41106        0    NH    200
# 506     Senate     14914        0    NJ    100
# 507     Senate     29373        0    NJ    100
# 508     Senate     41307        0    NJ    200
# 509     Senate     41308        0    NJ    100
# 510     Senate     20930        0    NM    100
# 511     Senate     29924        0    NM    100
# 512     Senate     14858        0    NY    100
# 513     Senate     20735        0    NY    100
# 514     Senate     29548        0    NC    200
# 515     Senate     40907        0    NC    100
# 516     Senate     41107        0    ND    200
# 517     Senate     41303        0    ND    100
# 518     Senate     29386        0    OH    200
# 519     Senate     29389        0    OH    100
# 520     Senate     15424        0    OK    200
# 521     Senate     29555        0    OK    200
# 522     Senate     14871        0    OR    100
# 523     Senate     40908        0    OR    100
# 524     Senate     29935        0    PA    200
# 525     Senate     40703        0    PA    100
# 526     Senate     29142        0    RI    100
# 527     Senate     40704        0    RI    100
# 528     Senate     21173        0    SC    200
# 529     Senate     29566        0    SC    200
# 530     Senate     15425        0    SD    100
# 531     Senate     29754        0    SD    200
# 532     Senate     40304        0    TN    200
# 533     Senate     40705        0    TN    200
# 534     Senate     40305        0    TX    200
# 535     Senate     41304        0    TX    200
# 536     Senate     14503        0    UT    200
# 537     Senate     41110        0    UT    200
# 538     Senate     14307        0    VT    100
# 539     Senate     29147        0    VT    328
# 540     Senate     40909        0    VA    100
# 541     Senate     41305        0    VA    100
# 542     Senate     39310        0    WA    100
# 543     Senate     49308        0    WA    100
# 544     Senate     14922        0    WV    100
# 545     Senate     40915        0    WV    100
# 546     Senate     29940        0    WI    100
# 547     Senate     41111        0    WI    200
# 548     Senate     40707        0    WY    200
# 549     Senate     49706        0    WY    200
#
#                                            name congress_id  nominate_dim1  \
# 0                                 obama, barack     O000167         -0.358
# 1               bonner, jr., josiah robins (jo)     B001244          0.367
# 2                           rogers, mike dennis     R000575          0.363
# 3                                 sewell, terri     S001185         -0.396
# 4                                  roby, martha     R000591          0.362
# 5                                    brooks, mo     B001274          0.652
# 6                                byrne, bradley     B001289          0.610
# 7                       bachus, spencer t., iii     B000013          0.387
# 8                              aderholt, robert     A000055          0.386
# 9                           young, donald edwin     Y000033          0.283
# 10                                franks, trent     F000448          0.749
# 11                            grijalva, raúl m.     G000551         -0.598
# 12                             kirkpatrick, ann     K000368         -0.169
# 13                                  gosar, paul     G000565          0.699
# 14                            schweikert, david     S001183          0.571
# 15                                  barber, ron     B001279         -0.123
# 16                              sinema, kyrsten     S001191         -0.105
# 17                                   pastor, ed     P000099         -0.421
# 18                        salmon, matthew james     S000018          0.673
# 19                               crawford, rick     C001087          0.445
# 20                                 griffin, tim     G000567          0.410
# 21                                womack, steve     W000809          0.352
# 22                                  cotton, tom     C001095          0.599
# 23                               miller, george     M000725         -0.552
# 24                         waxman, henry arnold     W000215         -0.473
# 25                                pelosi, nancy     P000197         -0.490
# 26                            rohrabacher, dana     R000409          0.626
# 27                                  honda, mike     H001034         -0.529
# 28                                 schiff, adam     S001150         -0.350
# 29                                issa, darrell     I000056          0.490
# 30                              davis, susan a.     D000598         -0.343
# 31                                 nunes, devin     N000181          0.450
# 32                            sánchez, linda t.     S001156         -0.508
# 33                                   costa, jim     C001059         -0.195
# 34                                matsui, doris     M001163         -0.435
# 35               campbell, john (of california)     C001064          0.748
# 36                              mcnerney, jerry     M001166         -0.263
# 37                              mccarthy, kevin     M001165          0.456
# 38   speier, karen lorraine jacqueline (jackie)     S001175         -0.381
# 39                              mcclintock, tom     M001177          0.687
# 40                                    chu, judy     C001080         -0.488
# 41                              garamendi, john     G000559         -0.309
# 42                         hunter, duncan duane     H001048          0.539
# 43                                 denham, jeff     D000612          0.306
# 44                                  bass, karen     B001270         -0.584
# 45                                 hahn, janice     H001063         -0.390
# 46                                lamalfa, doug     L000578          0.534
# 47                               huffman, jared     H001068         -0.430
# 48                                    bera, ami     B001287         -0.238
# 49                                   cook, paul     C001094          0.372
# 50                               swalwell, eric     S001193         -0.362
# 51                            valadao, david g.     V000129          0.267
# 52                              brownley, julia     B001285         -0.291
# 53                               cárdenas, tony     C001097         -0.390
# 54                       negrete mcleod, gloria     N000187         -0.437
# 55                                   ruiz, raul     R000599         -0.249
# 56                                 takano, mark     T000472         -0.464
# 57                              lowenthal, alan     L000579         -0.449
# 58                                 vargas, juan     V000130         -0.403
# 59                                peters, scott     P000608         -0.186
# 60                               waters, maxine     W000187         -0.656
# 61                          eshoo, anna georges     E000215         -0.380
# 62                                    farr, sam     F000030         -0.455
# 63                     mckeon, howard p. (buck)     M000508          0.396
# 64                              becerra, xavier     B000287         -0.512
# 65                       roybal-allard, lucille     R000486         -0.469
# 66                        royce, edward randall     R000487          0.657
# 67                                 calvert, ken     C000059          0.349
# 68                                 lofgren, zoe     L000397         -0.400
# 69                                sherman, brad     S000344         -0.344
# 70                             sanchez, loretta     S000030         -0.367
# 71                                  capps, lois     C001036         -0.389
# 72                                 lee, barbara     L000551         -0.677
# 73                            thompson, michael     T000460         -0.393
# 74                     napolitano, grace flores     N000179         -0.448
# 75                              miller, gary g.     M001139          0.478
# 76                                lamborn, doug     L000564          0.666
# 77                               perlmutter, ed     P000593         -0.282
# 78                                 polis, jared     P000598         -0.278
# 79                                coffman, mike     C001077          0.492
# 80                                tipton, scott     T000470          0.451
# 81                                gardner, cory     G000562          0.444
# 82                               degette, diana     D000197         -0.431
# 83                                courtney, joe     C001069         -0.342
# 84                              himes, james a.     H001047         -0.239
# 85                              esty, elizabeth     E000293         -0.315
# 86                             delauro, rosa l.     D000216         -0.414
# 87                              larson, john b.     L000557         -0.396
# 88                         carney, john c., jr.     C001083         -0.256
# 89                young, charles william (bill)     Y000031          0.325
# 90                         ros-lehtinen, ileana     R000435          0.244
# 91                  miller, jefferson b. (jeff)     M001144          0.633
# 92                              crenshaw, ander     C001045          0.333
# 93                           diaz-balart, mario     D000600          0.286
# 94                    wasserman schultz, debbie     W000797         -0.418
# 95                                castor, kathy     C001066         -0.438
# 96                          buchanan, vernon g.     B001260          0.362
# 97                               bilirakis, gus     B001257          0.410
# 98                                grayson, alan     G000556         -0.363
# 99                                  posey, bill     P000599          0.527
# 100                           rooney, thomas j.     R000583          0.458
# 101                   deutch, theodore e. (ted)     D000610         -0.401
# 102                          southerland, steve     S001186          0.560
# 103                             nugent, richard     N000185          0.483
# 104                          webster, daniel a.     W000806          0.527
# 105                                ross, dennis     R000593          0.531
# 106                           wilson, frederica     W000808         -0.480
# 107                                   yoho, ted     Y000065          0.704
# 108                               desantis, ron     D000621          0.663
# 109                             murphy, patrick     M001191         -0.186
# 110                                 radel, trey     R000596          0.702
# 111                               frankel, lois     F000462         -0.402
# 112                                 garcia, joe     G000573         -0.204
# 113                               clawson, curt     C001102          0.626
# 114                             jolly, david w.     J000296          0.230
# 115                              brown, corrine     B000911         -0.429
# 116                               mica, john l.     M000689          0.453
# 117                       hastings, alcee lamar     H000324         -0.564
# 118                              lewis, john r.     L000287         -0.589
# 119                               gingrey, phil     G000550          0.561
# 120                                scott, david     S001157         -0.304
# 121                                  price, tom     P000591          0.644
# 122                       westmoreland, lynn a.     W000796          0.672
# 123                                barrow, john     B001252         -0.119
# 124                               johnson, hank     J000288         -0.470
# 125                         broun, paul c., jr.     B001262          0.913
# 126                                 graves, tom     G000560          0.716
# 127                                woodall, rob     W000810          0.593
# 128                               scott, austin     S001189          0.558
# 129                               collins, doug     C001093          0.610
# 130                              kingston, jack     K000220          0.540
# 131                  bishop, sanford dixon, jr.     B000490         -0.284
# 132                           hanabusa, colleen     H001050         -0.370
# 133                              gabbard, tulsi     G000571         -0.274
# 134                           labrador, raúl r.     L000573          0.735
# 135                         simpson, michael k.     S001148          0.301
# 136                            lipinski, daniel     L000563         -0.227
# 137                               roskam, peter     R000580          0.429
# 138                                foster, bill     F000454         -0.232
# 139                               schock, aaron     S001179          0.311
# 140                               quigley, mike     Q000023         -0.323
# 141                             kinzinger, adam     K000378          0.234
# 142                             hultgren, randy     H001059          0.490
# 143                            duckworth, tammy     D000622         -0.336
# 144                             schneider, brad     S001190         -0.185
# 145                                enyart, bill     E000292         -0.251
# 146                               davis, rodney     D000619          0.279
# 147                               bustos, cheri     B001286         -0.239
# 148                             kelly, robin l.     K000385         -0.465
# 149                              rush, bobby l.     R000515         -0.479
# 150                          gutiérrez, luis v.     G000535         -0.487
# 151                             davis, danny k.     D000096         -0.486
# 152                            shimkus, john m.     S000364          0.375
# 153                       schakowsky, janice d.     S001145         -0.603
# 154                            visclosky, peter     V000108         -0.402
# 155                               carson, andré     C001072         -0.428
# 156                            stutzman, marlin     S001188          0.742
# 157                                rokita, todd     R000592          0.602
# 158                              bucshon, larry     B001275          0.408
# 159                                 young, todd     Y000064          0.449
# 160                            walorski, jackie     W000813          0.436
# 161                               brooks, susan     B001284          0.352
# 162                                messer, luke     M001189          0.563
# 163                                 king, steve     K000362          0.613
# 164                               braley, bruce     B001259         -0.310
# 165                              loebsack, dave     L000565         -0.276
# 166                              latham, thomas     L000111          0.302
# 167                               jenkins, lynn     J000290          0.523
# 168                              huelskamp, tim     H001057          0.744
# 169                                yoder, kevin     Y000063          0.558
# 170                                pompeo, mike     P000602          0.660
# 171                 rogers, harold dallas (hal)     R000395          0.339
# 172                               yarmuth, john     Y000062         -0.378
# 173                              guthrie, brett     G000558          0.418
# 174                  barr, garland h. (andy) iv     B001282          0.476
# 175                whitfield, wayne edward (ed)     W000413          0.303
# 176                              massie, thomas     M001184          0.678
# 177                        boustany, charles w.     B001255          0.392
# 178                              scalise, steve     S001176          0.555
# 179                               fleming, john     F000456          0.590
# 180                               cassidy, bill     C001075          0.469
# 181                            richmond, cedric     R000588         -0.486
# 182                        mcallister, vance m.     M001192          0.393
# 183                           alexander, rodney     A000361          0.331
# 184                         michaud, michael h.     M001149         -0.283
# 185                            pingree, chellie     P000597         -0.420
# 186                       hoyer, steny hamilton     H000874         -0.381
# 187                ruppersberger, c. a. (dutch)     R000576         -0.296
# 188                     van hollen, christopher     V000128         -0.392
# 189                              sarbanes, john     S001168         -0.467
# 190                           edwards, donna f.     E000290         -0.562
# 191                                harris, andy     H001052          0.673
# 192                               delaney, john     D000620         -0.276
# 193                     cummings, elijah eugene     C000984         -0.438
# 194                         markey, edward john     M000133         -0.514
# 195                        neal, richard edmund     N000015         -0.417
# 196                           lynch, stephen f.     L000562         -0.349
# 197                   tsongas, nicola s. (niki)     T000465         -0.396
# 198                         keating, william r.     K000375         -0.332
# 199                      kennedy, joseph p. iii     K000379         -0.421
# 200                         clark, katherine m.     C001101         -0.482
# 201                          mcgovern, james p.     M000312         -0.538
# 202                            tierney, john f.     T000266         -0.488
# 203                    capuano, michael everett     C001037         -0.580
# 204                    dingell, john david, jr.     D000355         -0.448
# 205                          conyers, john, jr.     C000714         -0.658
# 206                        levin, sander martin     L000263         -0.379
# 207                    upton, frederick stephen     U000031          0.320
# 208                                rogers, mike     R000572          0.400
# 209                          miller, candice s.     M001150          0.343
# 210                                walberg, tim     W000798          0.508
# 211                             peters, gary c.     P000595         -0.246
# 212                               benishek, dan     B001271          0.491
# 213                              huizenga, bill     H001058          0.550
# 214                               amash, justin     A000367          0.654
# 215                           bentivolio, kerry     B001280          0.723
# 216                                 kildee, dan     K000380         -0.374
# 217                             camp, david lee     C000071          0.385
# 218                      nolan, richard michael     N000127         -0.372
# 219                             mccollum, betty     M001143         -0.417
# 220                                 kline, john     K000363          0.490
# 221                                   walz, tim     W000799         -0.275
# 222                              ellison, keith     E000288         -0.537
# 223                           bachmann, michele     B001256          0.584
# 224                               paulsen, erik     P000594          0.402
# 225                      peterson, collin clark     P000258         -0.148
# 226                               harper, gregg     H001045          0.384
# 227                              nunnelee, alan     N000186          0.488
# 228                             palazzo, steven     P000601          0.535
# 229                            thompson, bennie     T000193         -0.517
# 230                              graves, samuel     G000546          0.438
# 231                     clay, william lacy, jr.     C001049         -0.481
# 232                        cleaver, emanuel, ii     C001061         -0.453
# 233                         luetkemeyer, blaine     L000569          0.444
# 234                             hartzler, vicky     H001053          0.478
# 235                                 long, billy     L000576          0.544
# 236                                 wagner, ann     W000812          0.416
# 237                                smith, jason     S001195          0.581
# 238                             emerson, jo ann     E000172          0.269
# 239                               daines, steve     D000618          0.585
# 240                           fortenberry, jeff     F000449          0.304
# 241                               smith, adrian     S001172          0.515
# 242                          terry, lee raymond     T000459          0.426
# 243                         titus, alice (dina)     T000468         -0.301
# 244                                   heck, joe     H001055          0.324
# 245                             amodei, mark e.     A000369          0.384
# 246                            horsford, steven     H001066         -0.347
# 247                          shea-porter, carol     S001170         -0.315
# 248                          kuster, ann mclane     K000382         -0.260
# 249                    smith, christopher henry     S000522          0.173
# 250                         pallone, frank, jr.     P000034         -0.405
# 251                              garrett, scott     G000548          0.688
# 252                                sires, albio     S001165         -0.404
# 253                              lance, leonard     L000567          0.329
# 254                                 runyan, jon     R000594          0.222
# 255                            norcross, donald     N000188         -0.422
# 256                      andrews, robert ernest     A000210         -0.297
# 257                          lobiondo, frank a.     L000554          0.211
# 258                    frelinghuysen, rodney p.     F000372          0.292
# 259                   pascrell, william j., jr.     P000096         -0.368
# 260                                  holt, rush     H001032         -0.463
# ...
# 275          0.409                     [owens, william]
# 276          0.120                     [reed, thomas w]
# 277          0.136                     [grimm, michael]
# 278         -0.455              [gibson, christopher p]
# 279         -0.145                  [hanna, richard l.]
# 280         -0.222                        [meng, grace]
# 281         -0.088                   [jeffries, hakeem]
# 282          0.114              [maloney, sean patrick]
# 283          0.236             [collins, christopher c]
# 284         -0.377                   [serrano, jose e.]
# 285         -0.030                         [king, pete]
# 286         -0.496                 [nadler, jerrold l.]
# 287         -0.345                [velazquez, nydia m.]
# 288         -0.285                [maloney, carolyn b.]
# 289         -0.040                  [mccarthy, carolyn]
# 290         -0.071                  [meeks, gregory w.]
# 291         -0.070                    [crowley, joseph]
# 292         -0.081                 [coble, john howard]
# 293         -0.030                       [price, david]
# 294          0.184        [butterfield, george kenneth]
# 295          0.164                 [foxx, virginia ann]
# 296          0.128           [mchenry, patrick timothy]
# 297          0.338             [ellmers, renee jacisin]
# 298          0.163             [hudson, richard l. jr.]
# 299          0.333                    [mittman, robert]
# 300         -0.201                    [meadows, mark r]
# 301          0.165              [holding, george e mr.]
# 302          0.021                     [adams, susan l]
# 303         -0.155                     [watt, melvin l]
# 304         -0.362                    [jones, walter b]
# 305          0.560                [mcintyre, mike rep.]
# 306          0.392                  [cramer, kevin mr.]
# 307          0.115            [kaptur, marcy hon. m.c.]
# 308         -0.026                 [tiberi, patrick j.]
# 309          0.222             [turner, michael r rep.]
# 310          0.208                      [ryan, timothy]
# 311         -0.200                          [horn, jim]
# 312          0.282               [latta, robert edward]
# 313          0.140                   [fudge, marcia l.]
# 314          0.273                      [johnson, bill]
# 315          0.269                 [stivers, steve mr.]
# 316          0.143                  [renacci, james b.]
# 317          0.284                      [gibbs, robert]
# 318          0.255                 [wenstrup, brad dr.]
# 319          0.040                      [beatty, joyce]
# 320          0.275                    [joyce, david p.]
# 321          0.040                   [boehner, john a.]
# 322         -0.137                      [chabot, steve]
# 323          0.377                          [cole, tom]
# 324          0.172           [lankford, james paul mr.]
# 325         -0.157                         [berns, jim]
# 326          0.246              [mullin, markwayne mr.]
# 327          0.419                    [lucas, frank d.]
# 328         -0.002                   [defazio, peter a]
# 329          0.054                     [schrader, kurt]
# 330         -0.413              [bonamici, suzanne ms.]
# 331         -0.647                   [blumenauer, earl]
# 332         -0.011                       [anders, greg]
# 333          0.323          [foster, g. william (bill)]
# 334         -0.107                       [gerlach, jim]
# 335          0.198                    [murphy, timothy]
# 336         -0.186            [fitzpatrick, michael g.]
# 337         -0.008               [schwartz, allyson y.]
# 338         -0.085               [dent, charles wieder]
# 339          0.384                [thompson, glenn mr.]
# 340          0.400                        [kelly, kurt]
# 341          0.076              [meehan, patrick l. mr]
# 342          0.477             [marino, thomas anthony]
# 343          0.393                      [barletta, lou]
# 344         -0.451                       [perry, scott]
# 345          0.044                 [rothfus, keith mr.]
# 346         -0.015             [cartwright, matthew a.]
# 347         -0.054                  [fattah, chaka mr.]
# 348          0.099                     [doyle, michael]
# 349          0.012                   [pitts, joseph r.]
# 350          0.225                    [brady, robert a]
# 351          0.114        [langevin, james r honorable]
# 352         -0.262                   [cicilline, david]
# 353          0.151                                   []
# 354         -0.097                       [denham, jeff]
# 355         -0.002                        [gowdy, trey]
# 356         -0.592                      [quigley, mike]
# 357         -0.217                          [rice, tom]
# 358         -0.728                       [wyland, mark]
# 359          0.250                  [clyburn, james e.]
# 360          0.326                  [noem, kristi lynn]
# 361         -0.033                      [cooper, james]
# 362         -0.476            [duncan, john j rep. jr.]
# 363          0.147             [blackburn, marsha mrs.]
# 364         -0.340                     [lynch, stephen]
# 365          0.024             [roe, david phillip dr.]
# 366          0.277             [fleischmann, charles j]
# 367         -0.059             [desjarlais, scott hon.]
# 368          0.219                [black, diane l mrs.]
# 369          0.181                 [fincher, steve mr.]
# 370          0.047                  [barton, joe linus]
# 371          0.061                       [smith, lamar]
# 372          0.366                    [culberson, john]
# 373          0.040               [hensarling, jeb hon.]
# 374          0.322        [neugebauer, randy honorable]
# 375         -0.206            [burgess, michael c. dr.]
# 376          0.563                [carter, john r rep.]
# 377         -0.406                     [gohmert, louis]
# 378         -0.029                           [poe, ted]
# 379          0.291                            [lee, al]
# 380          0.125                    [mccaul, michael]
# 381          0.367                     [scala, michael]
# 382          0.154              [marchant, kenny e mr.]
# 383          0.623                  [cuellar, henry r.]
# 384          0.308                    [olson, peter g.]
# 385          0.293                       [flores, bill]
# 386          0.016         [farenthold, randolph blake]
# 387          0.025                       [weber, randy]
# 388         -0.331              [o'rourke, robert beto]
# 389         -0.050                    [castro, joaquin]
# 390          0.378                      [gallego, pete]
# 391          0.120                    [williams, roger]
# 392          0.336               [veasey, marc allison]
# 393          0.407                      [vela, filemon]
# 394          0.277                   [johnson, sam mr.]
# 395         -0.438                    [stockman, steve]
# 396         -0.316                     [doggett, lloyd]
# 397          0.313                    [thornberry, mac]
# 398          0.125                     [jackson, duane]
# 399          0.136                     [sessions, pete]
# 400          0.239                       [brady, kevin]
# 401          0.234                       [granger, kay]
# 402          0.235                 [hinojosa, ruben e.]
# 403          0.453           [green, raymond e. 'gene']
# 404          0.198             [johnson, eddie bernice]
# 405          0.308                  [hall, ralph moody]
# 406          0.546              [matheson, james david]
# 407          0.105                     [bishop, robert]
# 408         -0.278                    [chaffetz, jason]
# 409          0.167                     [stewart, chris]
# 410         -0.362                       [welch, peter]
# 411         -0.213                     [wolf, frank r.]
# 412          0.218                   [forbes, j. randy]
# 413          0.191                       [cantor, eric]
# 414          0.014             [wittman, robert j. mr.]
# 415         -0.032            [connolly, gerald edward]
# 416         -0.084           [rigell, edward scott mr.]
# 417          0.000                       [hurt, robert]
# 418         -0.392                 [griffith, h morgan]
# 419         -0.325                      [rosa, david a]
# 420         -0.203                [moran, james p. jr.]
# 421          0.014                    [scott, robert c]
# 422         -0.002               [goodlatte, robert w.]
# 423         -0.197                   [mcdermott, james]
# 424          0.180               [snuffer, richard ray]
# 425          0.141            [mcmorris rodgers, cathy]
# 426         -0.146                     [reichert, dave]
# 427         -0.129             [herrera beutler, jaime]
# 428         -0.015                      [kilmer, derek]
# 429         -0.128                       [heck, dennis]
# 430          0.411                  [eustis, richard a]
# 431         -0.165                     [smith, d. adam]
# 432         -0.200                   [delbene, suzan k]
# 433          0.450                 [rahall, nick j. ii]
# 434          0.129          [capito, shelley moore ms.]
# 435          0.178             [mckinley, david b. mr.]
# 436         -0.579        [sensenbrenner, f. james jr.]
# 437         -0.367                      [petri, thomas]
# 438         -0.251                      [moore, gwen s]
# 439         -0.109                        [duffy, sean]
# 440         -0.333               [ribble, reid j. rep.]
# 441         -0.552                        [pocan, mark]
# 442         -0.080                       [richard, ron]
# 443         -0.250                      [ryan, paul d.]
# 444         -0.340              [lummis, cynthia marie]
# 445          0.130                                   []
# 446          0.570                  [tisei, richard r.]
# 447         -0.306                     [borowsky, lisa]
# 448          0.150                     [baechler, mary]
# 449         -0.626                   [manchin, joe iii]
# 450         -0.518                        [flake, jeff]
# 451          0.334                      [hartman, john]
# 452          0.463                        [pocan, mark]
# 453         -0.423                       [lee, barbara]
# 454         -0.184                  [feinstein, dianne]
# 455          0.049                        [donka, mark]
# 456         -0.169            [bennett, michael s mike]
# 457         -0.202              [murphy, christopher s]
# 458         -0.166                  [nugent, richard b]
# 459         -0.226                  [carper, thomas r.]
# 460         -0.212             [collins, christopher c]
# 461          0.337          [foster, g. william (bill)]
# 462         -0.165                        [critz, mark]
# 463          0.205              [chambless, dallas ray]
# 464         -0.011                   [atkinson, john m]
# 465         -0.085                   [hirono, mazie k.]
# 466         -0.105                                   []
# 467          0.283                 [capuano, michael e]
# 468          0.395                       [reese, james]
# 469         -0.303             [shurin, michael joseph]
# 470         -0.647           [koskiniemi, mark stephen]
# 471         -0.227                   [roberts, daniel ]
# 472          0.435                 [donnelly, joseph s]
# 473         -0.045             [bradley, charles wayne]
# 474         -0.546             [marino, thomas anthony]
# 475         -0.090                [roberts, jason eric]
# 476          0.217                    [tetalman, jerry]
# 477          0.014                                   []
# 478         -0.454                    [paul, ronald e.]
# 479          0.323                      [rivera, david]
# 480          0.444                   [landrieu, gary c]
# 481         -0.209                 [king, angus s. jr.]
# 482         -0.531               [cissna, sharon marie]
# 483         -0.128                 [carlson, barbara j]
# 484         -0.228                 [cardin, benjamin l]
# 485         -0.462                [markey, edward john]
# 486         -0.382                   [kerrey, j robert]
# 487         -0.335                  [warren, elizabeth]
# 488          0.348                    [tong, william m]
# 489         -0.116                    [lukens, charles]
# 490         -0.016                   [stabenow, debbie]
# 491         -0.363                                   []
# 492         -0.169                   [frankel, lois j.]
# 493          0.051                 [long, william todd]
# 494          0.350                 [wicker, roger sen.]
# 495          0.180                       [blum, rodney]
# 496          0.023                  [mccaskill, claire]
# 497          0.017                                   []
# 498          0.164                     [tester, r. jon]
# 499          0.462                         [walsh, joe]
# 500          0.293                       [boland, mike]
# 501          0.306                  [fischer, debra s.]
# 502          0.258                      [pierce, harry]
# 503         -0.459                       [heller, dean]
# 504         -0.135                       [hahn, janice]
# 505         -0.612                      [yoder, shelli]
# 506         -0.579             [antenori, frank ronald]
# 507         -0.123                   [menendez, robert]
# 508          0.384                                   []
# 509         -0.271                [oxner, mark anthony]
# 510         -0.026                   [heinrich, martin]
# 511          0.161                [wamp, thomas weston]
# 512         -0.417         [summers, charles edward jr]
# 513         -0.418                [gillibrand, kirsten]
# 514         -0.070                    [muri, richard w]
# 515          0.281                       [granger, kay]
# 516          0.438                    [macgovern, john]
# 517          0.399                    [heitkamp, heidi]
# 518         -0.208                 [marx, robert (bob)]
# 519         -0.105                     [brown, sherrod]
# 520          0.045                    [windle, james t]
# 521          0.055               [potter, thomas allen]
# 522         -0.479                    [young, donald e]
# 523         -0.735                        [flake, jeff]
# 524         -0.378                  [murphy, patrick e]
# 525          0.168               [casey, robert p. jr.]
# 526         -0.174            [lugar, john r jr (jack)]
# 527         -0.086                [whitehouse, sheldon]
# 528         -0.008                     [scott, timothy]
# 529         -0.267                [grantham, travis w.]
# 530          0.143                 [johnson, timothy v]
# 531          0.212                      [house, john m]
# 532         -0.176        [alexander, matthew clifford]
# 533         -0.344                 [marx, robert (bob)]
# 534         -0.079                       [carney, john]
# 535         -0.195           [cruz, rafael edward  ted]
# 536         -0.004                     [hatch, orrin g]
# 537         -0.454                        [pence, mike]
# 538         -0.121                   [flynn, patrick j]
# 539         -0.398                   [sanders, bernard]
# 540         -0.051                       [wyland, mark]
# 541         -0.062             [kaine, timothy michael]
# 542         -0.411                    [cantwell, maria]
# 543         -0.305                  [murray, j patrick]
# 544          0.177                                   []
# 545          0.406                   [manchin, joe iii]
# 546         -0.135                     [baldwin, tammy]
# 547         -0.146                      [johnson, bill]
# 548          0.224                   [barrasso, john a]
# 549          0.199                   [cino, michael j.]

# %%
members.dtypes
# Out:
# chamber           object
# icpsr_id           int64
# district          object
# state             object
# party              int64
# name              object
# congress_id       object
# nominate_dim1    float64
# nominate_dim2    float64
# name_match        object
# dtype: object

# %%
# members_fec = candidates_df.merge(members, left_on)

# %% [markdown]
# ### Set up API Funding Request Template
#
# **Conditions for Schedule A Filters**
# 1. Contributor Type - Committee
# 2. Two Year Transaction Period - 2012 (end of election cycle)
# 3. Recipient Committee Type - House, Senate
#
# **Conditions for Schedule B Filters**
# 1. Spender Committee Designation - all but unauthorized
# 2. Spender Committee Org Type - all
# 3. Spender Committee_Type - all but Party, nonqualified/qualified/national
# 4. Two Year Transaction Period - 2012 (end of election cycle)

# %% [markdown]
# #### Schedule A - Candidate Receipts

# %%
# testing schedule A pull request for member of the house --> John Boehner : H0OH08029 and contributions from the NRA

# Pulling first page to get disbursement date and index for pagination while loop

boehner_rq = rq.get(f'https://api.open.fec.gov/v1/schedules/schedule_a/?committee_id=C00237198&contributor_id=C00053553&contributor_type=committee&two_year_transaction_period=2012&recipient_committee_type=H&recipient_committee_type=S&per_page=100&sort=-contribution_receipt_date&sort_hide_null=false&sort_null_only=false&api_key={api_key_fec}')

print(boehner_rq.status_code)
boehner_json = boehner_rq.json()

boehner_page_test = boehner_json['pagination']
boehner_index_test = boehner_page_test['last_indexes']
boehner_index_test

# %%
boehner_json

# %%
boehner_list = boehner_json['results']
boehner_list

# %%
# create while loop for pagination capture

# variables set by first page request, count set to track number of pages requested
last_contribution_receipt_date = '2012-09-21'
last_index = '4102220121167751830'
count = 1

while True:
    try:
        # api request that inserts api key variable, as well as the last index and disbursement date from the first page request
        boehner_rq_loop = rq.get(f'https://api.open.fec.gov/v1/schedules/schedule_a/?contributor_id=C00053553&contributor_type=committee&two_year_transaction_period=2012&recipient_committee_type=H&recipient_committee_type=S&per_page=100&sort=-contribution_receipt_date&sort_hide_null=false&sort_null_only=false&api_key={api_key_fec}&last_disbursement_date={last_contribution_receipt_date}')

        # check status during while loop
        print(f'Requesting page {count}')
        boehner_rq_loop.raise_for_status()

        # convert request into json file
        boehner_json_loop = boehner_rq_loop.json()

        # move through json to pull new last index and disbursement dates
        boehner_page_loop = boehner_json_loop['pagination']
        boehner_index_loop = boehner_page_loop['last_indexes']
        boehner_index = boehner_index_loop['last_index']
        boehner_contribution_date = boehner_index_loop['last_contribution_receipt_date']
       
        # convert loop into a list and append to boehner_list
        boehner_list_loop = list(boehner_json_loop)
        boehner_list.append(boehner_list_loop)
        
        # add to counter
        count += 1
        
    except TypeError:
        print('No more valid pages to loop through')
        break

# %% [markdown]
# #### Schedule B - Committee Fund Designation

# %%
# testing schedule b pull request for one committee id --> NRA : C00053553

nra_rq = rq.get(f'https://api.open.fec.gov/v1/schedules/schedule_b/?committee_id=C00053553&spender_committee_designation=A&spender_committee_designation=J&spender_committee_designation=P&spender_committee_designation=B&spender_committee_designation=D&spender_committee_org_type=C&spender_committee_org_type=L&spender_committee_org_type=M&spender_committee_org_type=T&spender_committee_org_type=V&spender_committee_org_type=W&spender_committee_type=C&spender_committee_type=D&spender_committee_type=E&spender_committee_type=H&spender_committee_type=I&spender_committee_type=N&spender_committee_type=O&spender_committee_type=P&spender_committee_type=Q&spender_committee_type=S&spender_committee_type=U&spender_committee_type=V&spender_committee_type=W&two_year_transaction_period=2012&per_page=100&sort=-disbursement_date&sort_hide_null=false&sort_null_only=false&api_key={api_key_fec}')

print(nra_rq.status_code)
nra_json = nra_rq.json()

# %%
nra_page_test = nra_json['pagination']
nra_index_test = nra_page_test['last_indexes']
nra_index_test['last_index']
nra_index_test['last_disbursement_date']

# %%
nra_list = nra_json['results']
nra_list

# %%
# create while loop for pagination capture

# variables set by first page request, count set to track number of pages requested
last_disbursement_date = '2012-10-31'
last_index = '4040220131185979472'
count = 1

while True:
    try:
        # api request that inserts api key variable, as well as the last index and disbursement date from the first page request
        nra_rq_loop = rq.get(f'https://api.open.fec.gov/v1/schedules/schedule_b/?committee_id=C00053553&spender_committee_designation=A&spender_committee_designation=J&spender_committee_designation=P&spender_committee_designation=B&spender_committee_designation=D&spender_committee_org_type=C&spender_committee_org_type=L&spender_committee_org_type=M&spender_committee_org_type=T&spender_committee_org_type=V&spender_committee_org_type=W&spender_committee_type=C&spender_committee_type=D&spender_committee_type=E&spender_committee_type=H&spender_committee_type=I&spender_committee_type=N&spender_committee_type=O&spender_committee_type=P&spender_committee_type=Q&spender_committee_type=S&spender_committee_type=U&spender_committee_type=V&spender_committee_type=W&two_year_transaction_period=2012&per_page=100&sort=-disbursement_date&sort_hide_null=false&sort_null_only=false&api_key={api_key_fec}&last_index={last_index}&last_disbursement_date={last_disbursement_date}')

        # check status during while loop
        print(f'Requesting page {count}')
        nra_rq_loop.raise_for_status()

        # convert request into json file
        nra_json_loop = nra_rq_loop.json()

        # move through json to pull new last index and disbursement dates
        nra_page_loop = nra_json_loop['pagination']
        nra_index_loop = nra_page_loop['last_indexes']
        last_index = nra_index_loop['last_index']
        last_disbursement_date = nra_index_loop['last_disbursement_date']
       
        # convert loop into a list and append to nra_list
        nra_list_loop = list(nra_json_loop)
        nra_list.append(nra_list_loop)
        
        # add to counter
        count += 1
        
    except TypeError:
        print('No more valid pages to loop through')
        break

# %%
nra_list

# %%
del nra_list[100:]

# %%
[type(d) for d in nra_list]

# %%
# delete empty list items
nra_no_committee = [{k: v for k, v in d.items() if k != 'committee'} for d in nra_list]

# %%
nra_df = pd.DataFrame(nra_no_committee)

# %%
nra_df

# %%
nra_df.info()

# %%
nra_df['candidate_name'].value_counts()
